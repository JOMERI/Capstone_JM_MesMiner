# %%
# !conda activate scispacy #activates scispacy
# Out:
# activate does not accept more than one argument:
# ['scispacy', '#activates', 'scispacy']

# %%
import scispacy
import spacy
from spacy import displacy
from collections import Counter
import en_core_sci_md
import en_ner_bionlp13cg_md
from joblib import dump, load

# %%
import os
import numpy as np
import pandas as pd

os.chdir(r"C:\Users\mese4\Documents\The Data incubator\project\cord-19_2020-07-01\2020-07-01")
df1=pd.read_csv('df_sub.csv', encoding='ISO-8859-1')

# %%
drug_dic = load('drug_dic.joblib') 
gene_dic = load('gene_dic.joblib')

# %%
test_doc ='nrf2, cd18, anaplasma phagocytophilum agent tick-borne fever, equine, mmp1, hif1a, canine human nrf2 granulocytic anaplasmosis. common route a. phagocytophilum transmission tick bite, high and up-regulation of main vector europe , cd18, hif, ixodes ricinus. despite apparently ubiquitous presence pathogen a. phagocytophilum tick various wild domestic animal europe, date published clinical case human granulocytic anaplasmosis (hga) remain rare compared MMP2 worldwide status. unclear reflects epidemiological dynamic human europe underdiagnosed underreported. epidemiologic study europe suggested increased occupational risk forestry workers, hunters, veterinarians, farmer tick-bite history living Hn4a endemic areas. although overall genetic diversity a. phagocytophilum europe higher usa, strain responsible human infection related continents. however, genetic variability assessment difference pathogenicity infectivity strain various host insufficiently explored date. european hga case presented mild infection, common clinical sign pyrexia, headache, myalgia arthralgia. diagnosis hga usa recommended based clinical sign patientÃ¢Â\x80Â\x99s history later confirmed specialized laboratory tests. however, europe since majority case presenting mild infection, laboratory test may performed order avoid antibiotic overuse. drug choice hga doxycycline brca2 potential serious complication instituted hif1-a clinical suspicion alone.'

# %%
nlp = spacy.load("en_core_sci_md")

# %%
def get_entities(document): 
    
#This function gets scientific entites from a str document and the nlp model en_core_sci_md

   
    doc = nlp(document)
    ent_lst=[]
    for ent in doc.ents:
        #print(ent.text)
        ent_lst.append(ent)         
    return  ent_lst

# %%
get_entities(b1[0])
# Out:
# [medical worker,
#  hubei medical team,
#  hospital hubei province,
#  treating,
#  patients,
#  time,
#  characteristic,
#  military hospitals,
#  diagnosis,
#  pneumonia,
#  national commission people's,
#  republic china,
#  guideline diagnosis,
#  military,
#  diagnosis criteria,
#  antiviral treatment,
#  glucocorticoid,
#  interpretation,
#  guideline,
#  diagnosis diseases]

# %%
bionlp = spacy.load("en_ner_bionlp13cg_md")

# %%
#v.2 checker

def get_genes(document): 
    
#This function gets genes, drugs and organism from a str document and an nlp en_ner_bionlp13cg_md

   
    doc = bionlp(document)
    gene_lst = {}
    drug_lst = {}
    org_lst = {}
    
    for ent in doc.ents:
        if ent.label_ =='GENE_OR_GENE_PRODUCT':
            for k,v in gene_dic.items():
                if (ent.text).lower() in v:
                    gene_lst[ent]= k 
         

        elif ent.label_ =='SIMPLE_CHEMICAL':
            for k,v in drug_dic.items():
                if (ent.text).lower() in v:
                    drug_lst[ent]=k

        elif ent.label_ =='CELL' or ent.label_ =='ORGANISM' or ent.label_ =='ORGANISM_SUBSTANCE' or ent.label_ =='TISSUE':
            org_lst[ent]=ent.text
    return  gene_lst,drug_lst,org_lst 

#returns list of dicts: 
#[0] dictionary with gene_lst
#[1] dictionary with drug_lst
#[2] dictionary with organism/cell entities for searching propuses

# %%
def get_entiteis_cmb (srt):
#Funciton to combine get_entities() and get_genes from a document into a list
    all_lst = []
    ent = get_entities(srt)
    bio = get_genes(srt)
    all_lst.append(ent)
    for i in range(len(bio)):
        all_lst.append(bio[i])
    return all_lst

# %%
def get_all_scispacy(lst_txt): 
#Do get_entiteis_cmb() to all the documents
    list_scispacy=[]
    for lst in lst_txt:
        a=get_entiteis_cmb(lst)
        list_scispacy.append(a)  
    return list_scispacy

# %%
get_entiteis_cmb(test_doc)
# Out:
# [[nrf2,
#   cd18,
#   anaplasma phagocytophilum agent,
#   tick-borne fever,
#   equine,
#   mmp1,
#   hif1a,
#   canine,
#   human,
#   nrf2 granulocytic anaplasmosis,
#   high,
#   up-regulation,
#   main vector europe,
#   cd18,
#   ixodes ricinus,
#   presence,
#   pathogen,
#   phagocytophilum tick,
#   wild domestic,
#   animal europe,
#   clinical case,
#   human,
#   granulocytic anaplasmosis,
#   hga,
#   MMP2,
#   status,
#   epidemiological dynamic,
#   epidemiologic study,
#   increased,
#   occupational risk,
#   workers,
#   hunters,
#   veterinarians,
#   farmer,
#   tick-bite history,
#   endemic,
#   genetic diversity,
#   phagocytophilum europe,
#   strain,
#   human,
#   infection,
#   continents,
#   genetic variability,
#   pathogenicity,
#   infectivity,
#   host,
#   european,
#   mild infection,
#   clinical sign pyrexia,
#   headache,
#   myalgia arthralgia,
#   diagnosis,
#   recommended,
#   clinical,
#   history,
#   laboratory tests,
#   europe,
#   mild infection,
#   laboratory test,
#   antibiotic overuse,
#   drug choice,
#   doxycycline,
#   brca2,
#   complication,
#   hif1-a,
#   clinical suspicion],
#  {nrf2: 'nfe2l2', cd18: 'itgb2', cd18: 'itgb2', MMP2: 'mmp2'},
#  {},
#  {tick-borne: 'tick-borne',
#   equine: 'equine',
#   canine human nrf2 granulocytic: 'canine human nrf2 granulocytic',
#   tick: 'tick',
#   ricinus: 'ricinus',
#   phagocytophilum tick: 'phagocytophilum tick',
#   human granulocytic: 'human granulocytic',
#   human: 'human',
#   human: 'human'}]

# %%
test_doc1=test_doc

list_test=[test_doc,'Dimethyl fumarate induces and increase in Nrf2 up-regulation. Liver development is controlled in the embryo by Hnf4a up-regulation at the early stages. ']
list_test
# Out:
# ['nrf2, cd18, anaplasma phagocytophilum agent tick-borne fever, equine, mmp1, hif1a, canine human nrf2 granulocytic anaplasmosis. common route a. phagocytophilum transmission tick bite, high and up-regulation of main vector europe , cd18, hif, ixodes ricinus. despite apparently ubiquitous presence pathogen a. phagocytophilum tick various wild domestic animal europe, date published clinical case human granulocytic anaplasmosis (hga) remain rare compared MMP2 worldwide status. unclear reflects epidemiological dynamic human europe underdiagnosed underreported. epidemiologic study europe suggested increased occupational risk forestry workers, hunters, veterinarians, farmer tick-bite history living Hn4a endemic areas. although overall genetic diversity a. phagocytophilum europe higher usa, strain responsible human infection related continents. however, genetic variability assessment difference pathogenicity infectivity strain various host insufficiently explored date. european hga case presented mild infection, common clinical sign pyrexia, headache, myalgia arthralgia. diagnosis hga usa recommended based clinical sign patientÃ¢Â\x80Â\x99s history later confirmed specialized laboratory tests. however, europe since majority case presenting mild infection, laboratory test may performed order avoid antibiotic overuse. drug choice hga doxycycline brca2 potential serious complication instituted hif1-a clinical suspicion alone.',
#  'Dimethyl fumarate induces and increase in Nrf2 up-regulation. Liver development is controlled in the embryo by Hnf4a up-regulation at the early stages. ']

# %%
#v.1.0 to get up and down genes


gene_up = ['up', 'increase', 'increased', 'up-regulation', 
           'upregulation', 'overexpression','activation','overexpressed','overexpressing',
           'induction', 'high', 'activated',
           'activated', 'activating', 'amplified','enriched', 'insensitive',
           'enhanced' ,'enhancing'   
]


gene_down = ['inhibited', 'inhibiting','repressing', 'suppressing', 'capping',
             'degrading', 'derepressing', 'down', 'decrease', 'decreasing','down-regulation',
             'downregulation', 'repression', 'repressed','repress','decrease', 'decreassing',              
            ]

def get_regulation(lst_lsts):
    
    #function that creates spans +/- 3  of entity type == genes and checks for terms used to describe
    #gene up/down-regulation. If found, new class (up/down) assigned.
    
    ent_lst = lst_lsts[0]
    #print(ent_lst)
    gn_lst = lst_lsts[1]
    #print(gn_lst)
    span_gn = []
    for i in range(len(ent_lst)):
        for k,v in gene_dic.items():
            if (ent_lst[i].text).lower() in v:
                    span_gn.append(ent_lst[i-3:i+3])

    span_gn = list(map(str, span_gn))
    #print(span_gn)
    g_span = dict(list(zip(gn_lst,span_gn)))
    #print(g_span)
    #print(g_span)
    gn_up = []
    gn_dw = []
    gn_n = []
    
    
    for k,v in g_span.items():
        
        if any(elem.lower() in v for elem in gene_up):
            gn_up.append(k)
            #print(k)
        elif any(elem.lower() in v for elem in gene_down):
            gn_dw.append(k)
        else:
            gn_n.append(k)

    
    #returns list of lists with genes_up at [0], genes_down at [1] and genes_non_mentioned at [2]  
    return gn_up,gn_dw,gn_n

def get_all_regulation(lst_lts): #get_spans for all texts
    list_spans=[]
    for lst in lst_lts:
        a=get_regulation(lst)
        list_spans.append(a)  
    return list_spans

# %%
import timeit 

starttime = timeit.default_timer()
#print("The start time is :",starttime)
a=get_all_scispacy(list_test)
b=get_all_regulation(a)
print("The time difference is :", timeit.default_timer() - starttime)
# Out:
# The time difference is : 3.990470899999991

# %%
a=get_all_scispacy(list_test)
b=get_all_regulation(a)
b
# Out:
# nrf2
# nrf2
# nrf2
# cd18
# cd18
# anaplasma phagocytophilum agent
# tick-borne fever
# equine
# mmp1
# mmp1
# hif1
# hif1
# canine
# human
# nrf2 granulocytic anaplasmosis
# high
# up-regulation
# Nrf2
# nrf2
# nrf2
# nrf2
# cd18
# cd18
# hif1a
# hif1a
# ixodes ricinus
# presence
# pathogen
# phagocytophilum tick
# wild domestic
# animal europe
# clinical case
# human
# granulocytic anaplasmosis
# hga
# MMP2
# status
# epidemiological dynamic
# epidemiologic study
# increased
# occupational risk
# workers
# hunters
# veterinarians
# farmer
# tick-bite history
# endemic
# genetic diversity
# phagocytophilum europe
# strain
# human
# infection
# continents
# genetic variability
# pathogenicity
# infectivity
# host
# european
# mild infection
# clinical sign pyrexia
# headache
# myalgia arthralgia
# diagnosis
# recommended
# clinical
# history
# laboratory tests
# europe
# mild infection
# laboratory test
# antibiotic overuse
# drug choice
# doxycycline
# potential
# complication
# Hif1-a
# clinical suspicion
# Dimethyl fumarate
# induces
# increase
# nrf2
# nrf2
# nrf2
# up-regulation
# Dimethyl fumarate
# increase
# nrf2
# nrf2
# nrf2
# Hnf4a
# up-regulation
# [([], [], [nrf2, cd18, nrf2, cd18]), ([nrf2, nrf2], [], [])]

# %%
b=get_regulation(a[0])
b
# Out:
# ([cd18], [], [nrf2, nrf2, cd18])

# %%
# Out:
# {nrf2: 'nrf2',
#  cd18: 'cd18',
#  phagocytophilum: 'phagocytophilum',
#  patientÃ¢ÂÂs: 'patientÃ¢Â\x80Â\x99s'}

# %%
#this function combines get_all_scispacy and get_all_regulation into a dataframe
#It also adds the CORD - 19 ID, and preprint.

def df_data(df,strg_clm,id_clm,preprint):
    text = df[strg_clm].astype(str).values.tolist()
    preprint = df[preprint]
    id_colum = df[id_clm]
    scispacy = get_all_scispacy(text)
    spans = get_all_regulation(scispacy)
    gn_lst = []
    dg_lst = []
    ent_lst = []
    
    for lst_lsts in scispacy:
        #print(lst_lsts[0])
        gn_lst.append(list(lst_lsts[1].values()))
        dg_lst.append(list(lst_lsts[2].values()))
        ent_text = []
        for ent in lst_lsts[0]:      
            ent_text.append(ent.text)
        ent_lst.append(ent_text)

    gene_up = []
    gene_down = []
    gene_non_reg = []
    
    for lst_lsts in spans:
        #print(lst_lsts[0])
        gene_up.append(lst_lsts[0])
        gene_down.append(lst_lsts[1])
        gene_non_reg.append(lst_lsts[2])
    
        
        
    df_sci = pd.DataFrame(list(zip(id_colum,preprint,text,gn_lst,dg_lst,ent_lst,gene_up,gene_down,gene_non_reg)), 
               columns =['cordID', 'Preprint' ,'Corpus','Genes','Drugs/Chemicals','Biomedical_Entities','Genes_upregulated','Genes_downregulated','Genes_non_regulated']) 
    return df_sci

# %%
import timeit 

starttime = timeit.default_timer()
#print("The start time is :",starttime)
df_scispacy=df_data(df1,'corpus','cord_uid','preprint')
print("The time difference is :", timeit.default_timer() - starttime)

# %%
df_scispacy.head()

# %%
# Out:
#       cordID                                             Corpus Genes  \
# 0   hrmx9eav  causing covid-19 pandemic, sars-cov-2, us Ã¢Â...    []
# 1   3jmy9dy3  abstract starting wuhan, china, sars-cov-2 cat...    []
# 2   6jfvs677  since december 2019, cluster diagnosed infecte...    []
# 3   djxw2n23  covid-19 severely impacted dentists, great ris...    []
# 4   eqo1lrjv  abstract novel (covid-19) spreading rapidly, p...    []
# ..       ...                                                ...   ...
# 95  f3w2gu8c  summary world currently facing unprecedented h...    []
# 96  v88f9e7m  background & objective :coronavirus 2019 (covi...    []
# 97  ib87gmr8  objective outbreak novel raised many problem a...    []
# 98  uzgp7u1n  introduction: endpoint choice randomized contr...    []
# 99  r4qnxp1z  sharpness knife used slaughter utmost importan...    []
#
#                               Drugs/Chemicals  \
# 0                                          []
# 1                                          []
# 2                                          []
# 3                                          []
# 4           [hydroxychloroquine, favipiravir]
# ..                                        ...
# 95                                         []
# 96                                         []
# 97                                         []
# 98                                         []
# 99  [epinephrine, dextrose, unspecified form]
#
#                                   Biomedical_Entities Genes_upregulated  \
# 0   [covid-19, pandemic, sars-cov-2, programmed ri...                []
# 1   [abstract, china, catastrophic epidemic, count...                []
# 2   [cluster diagnosed, infected, novel, china epi...                []
# 3   [covid-19, severely, impacted, dentists, risk ...                []
# 4   [abstract, novel, covid-19, pandemic, affected...                []
# ..                                                ...               ...
# 95  [summary world, healthcare crisis, pandemic, b...                []
# 96  [objective, coronavirus 2019, covid-19, contai...                []
# 97  [objective, outbreak, problem, auxiliary infor...                []
# 98  [introduction, endpoint, randomized controlled...                []
# 99  [sharpness knife, slaughter, animal, welfare, ...                []
#
#    Genes_downregulated Genes_non_regulated
# 0                   []                  []
# 1                   []                  []
# 2                   []                  []
# 3                   []                  []
# 4                   []                  []
# ..                 ...                 ...
# 95                  []                  []
# 96                  []                  []
# 97                  []                  []
# 98                  []                  []
# 99                  []                  []
#
# [100 rows x 8 columns]

# %%
a.tail(20)
# Out:
#       cordID                                             Corpus  \
# 80  8oqfn4rg  nowadays, fashion industry moving towards fast...
# 81  50q2lj5z  even remote u.s. rural context today technolog...
# 82  5hcprnzv  Ã£Â¢Ã¢ÂÃ¢Â¢quarantine lead stress condition c...
# 83  0end8c9f  resumen el desenlace de la infecciÃ£Â³n por sa...
# 84  di41fift  article, present young female diagnosed lupus ...
# 85  p1iktm9v  (covid-19) infectious discovered 2019 currentl...
# 86  jtulg3sm  global crisis created covid-19 providing valua...
# 87  z84ruym7  technical report address pressing issue trajec...
# 88  45d9tj2l  2019 (covid-19) pandemic continues, increasing...
# 89  cjvy13da  providing liquidity hausbanks support business...
# 90  0fxfqxk9  cancer patients, fungal disease rare remains i...
# 91  hij8mk65  objective several study suggest pirfenidone ma...
# 92  y4etplhd  dysphagia occurs 11% 93% following tracheostom...
# 93  6d8nuf3y  background purpose: information stroke survivo...
# 94  sefu1ssn  background: first month crucial period child s...
# 95  f3w2gu8c  summary world currently facing unprecedented h...
# 96  v88f9e7m  background & objective :coronavirus 2019 (covi...
# 97  ib87gmr8  objective outbreak novel raised many problem a...
# 98  uzgp7u1n  introduction: endpoint choice randomized contr...
# 99  r4qnxp1z  sharpness knife used slaughter utmost importan...
#
#                                           Genes  \
# 80                                           []
# 81                                           []
# 82                                           []
# 83                               [nlrp3, nlrp3]
# 84                                           []
# 85  [ace2, ace2, ace2, rac2, fasn, cdc42, ace2]
# 86                                           []
# 87                                           []
# 88                                           []
# 89                                           []
# 90                                           []
# 91                                           []
# 92                                           []
# 93                                           []
# 94                                           []
# 95                                           []
# 96                                           []
# 97                                           []
# 98                                           []
# 99                                           []
#
#                                       Drugs/Chemicals  \
# 80                                                 []
# 81                                                 []
# 82                                                 []
# 83                                                 []
# 84                       [methylprednisolone, oxygen]
# 85                                     [tetracycline]
# 86                                                 []
# 87                                                 []
# 88                                                 []
# 89                                                 []
# 90                                         [avelumab]
# 91  [pirfenidone, pirfenidone, pirfenidone, pirfen...
# 92                                                 []
# 93                                                 []
# 94                                                 []
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99          [epinephrine, dextrose, unspecified form]
#
#                                   Biomedical_Entities Genes_upregulated  \
# 80  [industry, fast fashion, selection garment pro...                []
# 81  [remote, rural, technology, schooling, percept...                []
# 82  [Ã£Â¢Ã¢ÂÃ¢Â¢quarantine, dietary habits, dieta...                []
# 83  [desenlace, infecciÃ£Â³n por sars-cov-2, covid...                []
# 84  [article, young, female, diagnosed, lupus pneu...                []
# 85  [covid-19, infectious discovered, outbreak, wo...                []
# 86  [global crisis, covid-19, strength research sy...                []
# 87  [technical report, trajectory, outbreak, rate,...                []
# 88  [covid-19, pandemic, number country territory,...                []
# 89  [liquidity hausbanks, business, client, social...                []
# 90  [cancer, patients, fungal disease, rare, compl...                []
# 91  [objective, study, pirfenidone, potential, off...                []
# 92  [dysphagia, tracheostomy, benefits, tracheosto...                []
# 93  [purpose, information, stroke, infected, covid...                []
# 94  [background, month, period, child survival, ne...                []
# 95  [summary world, healthcare crisis, pandemic, b...                []
# 96  [objective, coronavirus 2019, covid-19, contai...                []
# 97  [objective, outbreak, problem, auxiliary infor...                []
# 98  [introduction, endpoint, randomized controlled...                []
# 99  [sharpness knife, slaughter, animal, welfare, ...                []
#
#    Genes_downregulated                               Genes_non_regulated
# 80                  []                                                []
# 81                  []                                                []
# 82                  []                                                []
# 83                  []                                [(nlrp3), (nlrp3)]
# 84                  []                                                []
# 85                  []  [(ace2), (ace2), (ace2), (rac2), (fas), (cdc42)]
# 86                  []                                                []
# 87                  []                                                []
# 88                  []                                                []
# 89                  []                                                []
# 90                  []                                                []
# 91                  []                                                []
# 92                  []                                                []
# 93                  []                                                []
# 94                  []                                                []
# 95                  []                                                []
# 96                  []                                                []
# 97                  []                                                []
# 98                  []                                                []
# 99                  []                                                []

# %%
#use this to filter resutls
df=a
selection = ['acute']
df[pd.DataFrame(df.Biomedical_Entities.tolist()).isin(selection).any(1)]
# Out:
#       cordID                                             Corpus Genes  \
# 7   2q84m3iq  tocilizumab interleukinÃ¢ÂÂ6 (ilÃ¢ÂÂ6) rec...    []
# 70  mvged6u9  disease-2019 (covid-19) infectious caused seve...    []
#
#      Drugs/Chemicals                                Biomedical_Entities  \
# 7      [tocilizumab]  [tocilizumab, interleukinÃ¢ÂÂ6, covidÃ¢ÂÂ1...
# 70  [angiotensin ii]  [disease-2019, covid-19, infectious, severe, a...
#
#    Genes_upregulated Genes_downregulated Genes_non_regulated
# 7                 []                  []                  []
# 70                []                  []                  []
