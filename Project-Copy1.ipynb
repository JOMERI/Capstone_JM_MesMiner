# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from matplotlib.dates import (YEARLY, DateFormatter,
                              rrulewrapper, RRuleLocator, drange)
import datetime
import seaborn as sns
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer#nltk.download('wordnet') 


os.chdir(r"C:\Users\mese4\Documents\The Data incubator\project\cord-19_2020-07-01\2020-07-01")
df=pd.read_csv('metadata.csv', encoding='ISO-8859-1')
# Out:
# C:\Users\mese4\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5,6,13,14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Get drug names database

df_drugs=pd.read_csv(r"C:\Users\mese4\Documents\The Data incubator\project\Drugmap\drugbank vocabulary.csv", encoding='ISO-8859-1')
df_drugs.head()

df_drugs
# Out:
#       DrugBank ID     Accession Numbers                   Common_name  \
# 0         DB00001  BIOD00024 | BTD00024                     Lepirudin
# 1         DB00002  BIOD00071 | BTD00071                     Cetuximab
# 2         DB00003  BIOD00001 | BTD00001                  Dornase alfa
# 3         DB00004  BIOD00084 | BTD00084           Denileukin diftitox
# 4         DB00005  BIOD00052 | BTD00052                    Etanercept
# ...           ...                   ...                           ...
# 13575     DB15689                   NaN              Azoximer bromide
# 13576     DB15690                   NaN          Fluoroestradiol F-18
# 13577     DB15691                   NaN     Anti-SARS-CoV-2 REGN-COV2
# 13578     DB15692                   NaN  COVID-19 convalescent plasma
# 13579     DB15693                   NaN                      INO-4800
#
#                CAS        UNII  \
# 0      138068-37-8  Y43GF64R34
# 1      205923-56-4  PQX0D8J21J
# 2      143831-71-4  953A26OA1Y
# 3      173146-27-5  25E79B5CTM
# 4      185243-69-0  OP401G7OJC
# ...            ...         ...
# 13575  892497-01-7  90G53638ZD
# 13576   94153-53-4  T32277KB09
# 13577          NaN         NaN
# 13578          NaN  YM6LN8TU2V
# 13579          NaN         NaN
#
#                                                 Synonyms  \
# 0              Hirudin variant-1 | Lepirudin recombinant
# 1                   Cetuximab | CÃ©tuximab | Cetuximabum
# 2      Deoxyribonuclease (human clone 18-1 protein mo...
# 3      Denileukin | Interleukin-2/diptheria toxin fus...
# 4      Etanercept | etanercept-szzs | etanercept-ykro...
# ...                                                  ...
# 13575  Poly((1-(carboxymethyl)piperazin-1-ium-1,4-diy...
# 13576  (18F)FES | 16-alpha-(18-Fluoro)-17betaestradio...
# 13577            REGN10933+REGN10987 combination therapy
# 13578                     Convalescent plasma (COVID-19)
# 13579                   INO-4800 DNA Coronavirus Vaccine
#
#                 Standard InChI Key
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 13575                          NaN
# 13576  KDLLNMRYZGUVMA-ZYMZXAKXSA-N
# 13577                          NaN
# 13578                          NaN
# 13579                          NaN
#
# [13580 rows x 7 columns]

# %%
alias=df_drugs['Synonyms']

alias=alias['Synonyms']

alias=alias.tolist()


def aliases_lst(df_alias_lst):
    
    alias_lst=[]
    for x in alias:
        gn=x.split('|')
        alias_lst.append(gn)
    
    flat_list = []
    for sublist in alias_lst:
        for item in sublist:
            item=item.lower()
            flat_list.append(item)
    return flat_list

lst_alias_drugs=aliases_lst(alias) 

symbol=df_drugs['Common name']
symbol=symbol.tolist()
drug_check=symbol+lst_alias_drugs
drug_check
drug_check_lower=aliases_lst(drug_check)
drug_check_lower
# Out:
# ['hirudin variant-1 ',
#  ' lepirudin recombinant',
#  'cetuximab ',
#  ' cã©tuximab ',
#  ' cetuximabum',
#  'deoxyribonuclease (human clone 18-1 protein moiety) ',
#  ' dornasa alfa ',
#  ' dornase alfa, recombinant ',
#  ' dornase alpha ',
#  ' recombinant deoxyribonuclease (dnase)',
#  'denileukin ',
#  ' interleukin-2/diptheria toxin fusion protein',
#  'etanercept ',
#  ' etanercept-szzs ',
#  ' etanercept-ykro ',
#  ' recombinant human tnf ',
#  ' rhu tnfr:fc ',
#  ' rhu-tnfr:fc ',
#  ' tnfr-immunoadhesin',
#  'bivalirudin ',
#  ' bivalirudina ',
#  ' bivalirudinum',
#  'leuprorelin ',
#  ' leuprorelina ',
#  ' leuproreline ',
#  ' leuprorelinum',
#  'peg-ifn alfa-2a ',
#  ' peg-interferon alfa-2a ',
#  ' peginterferon alfa-2a ',
#  ' pegylated interfeaon alfa-2a ',
#  ' pegylated interferon alfa-2a ',
#  ' pegylated interferon alpha-2a ',
#  ' pegylated-interferon alfa 2a',
#  'alteplasa ',
#  ' alteplase (genetical recombination) ',
#  ' alteplase, recombinant ',
#  ' alteplase,recombinant ',
#  ' plasminogen activator (human tissue-type protein moiety) ',
#  ' rt-pa ',
#  ' t-pa ',
#  ' t-plasminogen activator ',
#  ' tissue plasminogen activator ',
#  ' tissue plasminogen activator alteplase ',
#  ' tissue plasminogen activator, recombinant ',
#  ' tpa',
#  'interferon alpha-n1 (ins)',
#  'darbepoetin ',
#  ' darbepoetin alfa,recombinant ',
#  ' darbepoetina alfa',
#  'kinase (enzyme-activating), uro-urokinase ',
#  ' tcuk ',
#  ' tissue culture urokinase ',
#  ' two-chain urokinase ',
#  ' urochinasi ',
#  ' urokinase ',
#  ' urokinasum ',
#  ' uroquinasa',
#  'goserelin ',
#  ' goserelina',
#  'human t-pa (residues 1-3 and 176-527) ',
#  ' reteplasa ',
#  ' reteplase, recombinant ',
#  ' reteplase,recombinant',
#  'e.p.o. ',
#  ' epoetin alfa ',
#  ' epoetin alfa rdna ',
#  ' epoetin alfa-epbx ',
#  ' epoetin alfa, recombinant ',
#  ' epoetin beta ',
#  ' epoetin beta rdna ',
#  ' epoetin epsilon ',
#  ' epoetin gamma ',
#  ' epoetin gamma rdna ',
#  ' epoetin kappa ',
#  ' epoetin omega ',
#  ' epoetin theta ',
#  ' epoetin zeta ',
#  ' epoetina alfa ',
#  ' epoetina beta ',
#  ' epoetina dseta ',
#  ' epoetina zeta ',
#  ' epoã©tine zãªta ',
#  ' epoetinum zeta ',
#  ' erythropoiesis stimulating factor ',
#  ' erythropoietin (human, recombinant) ',
#  ' erythropoietin (recombinant human) ',
#  ' esf ',
#  ' sh-polypeptide-72',
#  'calcitonin (salmon synthetic) ',
#  ' calcitonin salmon ',
#  ' calcitonin salmon recombinant ',
#  ' calcitonin-salmon ',
#  ' calcitonin, salmon ',
#  ' calcitonina salmã³n sintã©tica ',
#  ' recombinant salmon calcitonin ',
#  ' salmon calcitonin',
#  'granulocyte colony-stimulating factor pegfilgrastim ',
#  ' peg-filgrastim ',
#  ' pegfilgrastim-apgf ',
#  ' pegfilgrastim-bmez ',
#  ' pegfilgrastim-cbqv ',
#  ' pegfilgrastim-jmdb',
#  'recombinant human granulocyte-macrophage colony stimulating factor ',
#  ' rgm-csf ',
#  ' rhu gm-csf ',
#  ' sargramostim',
#  'asparaginase ',
#  ' asparaginase (e. coli) ',
#  ' colaspase ',
#  ' escherichia coli l-asparaginase ',
#  ' l-asparaginase ',
#  ' l-asparagine amidohydrolase',
#  'recombinant human thyroid stimulating hormone ',
#  ' recombinant thyrotropin alfa ',
#  ' rhtsh ',
#  ' rtsh ',
#  ' thyrotropin alpha',
#  'antihemophilic factor (recombinant) ',
#  ' antihemophilic factor recombinant ',
#  ' antihemophilic factor, human recombinant ',
#  ' antihemophilic factor, recombinant ',
#  ' factor viii (rdna) ',
#  ' factor viii (recombinant) ',
#  ' factor viii recombin ',
#  ' factor viii, recombinant ',
#  ' human factor viii (recombinant) ',
#  ' human factor viii recombinant ',
#  ' octocog alfa ',
#  ' rahf ',
#  ' recombinant antihemophilic factor viii',
#  'anakinra ',
#  ' il-1ra ',
#  ' interleukin-1 receptor antagonist anakinra',
#  'bacillus brevis gramicidin d ',
#  ' gramicidin ',
#  ' gramicidin a ',
#  ' gramicidin b ',
#  ' gramicidin c ',
#  ' gramicidina ',
#  ' gramicidine',
#  'human igg ',
#  ' human immunoglobulin g ',
#  ' human normal immunoglobulin ',
#  ' immune globulin (human) ',
#  ' immune globulin human ',
#  ' immunoglobulin (human) ',
#  ' immunoglobulin g (human) ',
#  ' immunoglobulin g, human ',
#  ' ivig',
#  'anisoylated plasminogen streptokinase activator complex ',
#  ' apsac',
#  'high molecular weight insulin human ',
#  ' human insulin ',
#  ' human insulin (rdna) ',
#  ' insulin (human) ',
#  ' insulin human ',
#  ' insulin human [rdna origin] ',
#  ' insulin human regular ',
#  ' insulin human regular (rdna) ',
#  ' insulin human, rdna origin ',
#  ' insulin recombinant human ',
#  ' insulin recombinant purified human ',
#  ' insulin regular ',
#  ' insulin, human ',
#  ' insulina regular ',
#  ' regular insulin, human',
#  'tenecteplasa ',
#  ' tnk-tpa',
#  'human menopausal gonadotrophin ',
#  ' menotrophin ',
#  ' menotropin ',
#  ' menotropina ',
#  ' menotropins (fsh;lh)',
#  'ifn-gamma 1b ',
#  ' ifn-gamma-1b ',
#  ' interferon gamma 1-b ',
#  ' interferon gamma-1b ',
#  ' interferon gamma-1b, recombinant ',
#  ' interferon gamma-2a',
#  'interferon alfa-2a ',
#  ' interferon alfa-2a (recombinant) ',
#  ' interferon alfa-2a, recombinant ',
#  ' interferon alfa-2a,recombinant ',
#  ' interferon alpha-2a ',
#  ' interferon-alfa-2a ',
#  ' recombinant human interferon alfa-2a ',
#  ' recombinant human interferon-alfa-2a ',
#  ' rifn-alpha-2a ',
#  ' sh-polypeptide-46',
#  '1-(3-mercaptopropionic acid)-8-d-arginine-vasopressin ',
#  ' 1-deamino-8-d-arginine vasopressin ',
#  ' 1-desamino-8-d-arginine vasopressin ',
#  ' ddavp ',
#  ' desmopresina ',
#  ' desmopressin ',
#  ' desmopressine ',
#  ' desmopressinum',
#  'coagulation factor viia ',
#  ' coagulation factor viia (recombinant) ',
#  ' coagulation factor viia (recombinant)-jncw ',
#  ' eptacog alfa ',
#  ' eptacog alfa (activated) ',
#  ' rfviia',
#  'il-11 ',
#  ' interleukin 11 ',
#  ' interleukin-11 ',
#  ' oprelvekin ',
#  ' recombinant interleukin-11',
#  '24-163 fibroblast growth factor 7 (human) ',
#  ' palifermina',
#  'glucagon ',
#  ' glucagon (recombinant dna origin) ',
#  ' glucagon recombinant ',
#  ' glucagon, human ',
#  ' glucagon, porcine ',
#  ' glucagone ',
#  ' glucagonum',
#  '125-l-serine-2-133-interleukin 2 (human reduced) ',
#  ' aldesleukina ',
#  ' interleukin-2 aldesleukin ',
#  ' interleukin-2(2-133),125-ser ',
#  ' recombinant interleukin-2 human',
#  'botulin b ',
#  ' botulinum b toxin ',
#  ' botulinum neurotoxin type b precursor ',
#  ' btx-b ',
#  ' rimabotulinumtoxinb ',
#  ' toxina botulã\xadnica b',
#  'lutropin alfa ',
#  ' lutropin alpha ',
#  ' lutropina alfa',
#  'lipoprotein ospa antigen recombinant ',
#  ' lipoprotein outer surface a borrelia burgdorferi antigen ',
#  ' ospa lipoprotein',
#  'insulin lispro (genetical recombination) ',
#  ' insulin lispro (rdna origin) ',
#  ' insulin lispro protamine ',
#  ' insulin lispro protamine recombinant ',
#  ' insulin lispro recombinant ',
#  ' insulin lispro-aabc ',
#  ' insulin,lispro,human/rdna ',
#  ' insulin,lispro,protamine/rdna ',
#  ' insulina lispro',
#  'insulin glargine ',
#  ' insulin glargine (rdna origin) ',
#  ' insulin glargine recombinant ',
#  ' insulina glargina',
#  'clostridium histolyticum enzymes ',
#  ' collagenase ',
#  ' collagenase clostridium histolyticum',
#  'rasburicasa ',
#  ' rasburicase ',
#  ' urate oxidase',
#  'cetrorelix ',
#  ' cetrorelixum',
#  'adalimumab (genetical recombination) ',
#  ' adalimumab-adaz ',
#  ' adalimumab-adbm ',
#  ' adalimumab-afzb ',
#  ' adalimumab-atto ',
#  ' adalimumab-bwwd',
#  'growth hormone ',
#  ' growth hormone (human) ',
#  ' hgh ',
#  ' human growth hormone ',
#  ' recombinant human growth hormone ',
#  ' rhgh ',
#  ' somatotropin (human) ',
#  ' somatotropin human ',
#  ' somatotropin human growth hormone ',
#  ' somatropin ',
#  ' somatropin (rdna origin) ',
#  ' somatropin (recombinant dna origin) ',
#  ' somatropin [rdna origin] ',
#  ' somatropin recombinant ',
#  ' somatropin(recombinant dna origin) ',
#  ' somatropina',
#  'imiglucerasa',
#  'abciximab ',
#  ' abciximab (genetical recombination) ',
#  ' c7e3',
#  'activated protein c ',
#  ' blood coagulation factor xiv (human) ',
#  ' drotrecogin alfa (activated) ',
#  ' drotrecogin alfa (activated), lyophilized ',
#  ' drotrecogin alfa activated ',
#  ' drotrecogin alfa, activated ',
#  ' drotrecogin-alfa ',
#  ' recombinant human activated protein c (rh-apc)',
#  'indium (111in) satumomab pendetide ',
#  ' indium in 111 satumomab pendetide ',
#  ' indium-111 satumomab pendetide',
#  'alfa 1-proteinase inhibitor (human) ',
#  ' alfa-1-antitripsina ',
#  ' alfa1 antitrypsin ',
#  ' alpha 1-antitrypsin ',
#  ' alpha 1-proteinase inhibitor ',
#  ' alpha 1-proteinase inhibitor (human) ',
#  ' alpha 1-proteinase inhibitor, human ',
#  ' alpha-1 protease inhibitor ',
#  ' alpha-1 proteinase inhibitor (human) ',
#  ' alpha-1-antiproteinase ',
#  ' alpha-1-antitrypsin ',
#  ' alpha-1-proteinase inhibitor (human) ',
#  ' alpha-1-proteinase inhibitor human ',
#  ' alpha-1-proteinase inhibitor, human ',
#  ' alpha-1-proteinase inhibitor,human ',
#  ' alpha1-proteinase inhibitor ',
#  ' alpha1-proteinase inhibitor (human) ',
#  ' alpha1-proteinase inhibitor human ',
#  ' api',
#  'peg-asparaginase ',
#  ' peg/l-asparaginase ',
#  ' pegaspargasa',
#  'interferon beta 1-a ',
#  ' interferon beta 1a ',
#  ' interferon beta-1a (recombinant human) ',
#  ' interferon beta-1a,recombinant ',
#  ' interferon-beta-1a',
#  '(monomethoxypolyethylene glycol succinimidyl) 11-17-adenosine deaminase ',
#  ' peg-adenosine deaminase ',
#  ' pegada ',
#  ' pegademase ',
#  ' pegademase bovine',
#  'albumin (human) ',
#  ' albumin human ',
#  ' albumin, blood ',
#  ' albumin, human ',
#  ' albumin, human-kjda ',
#  ' human albumin ',
#  ' human serum albumin ',
#  ' serum albumin',
#  'eptifibatida ',
#  ' eptifibatide ',
#  ' integrelin ',
#  ' intrifiban',
#  'infliximab (genetical recombination) ',
#  ' infliximab-abda ',
#  ' infliximab-axxq ',
#  ' infliximab-dyyb ',
#  ' infliximab-qbtx',
#  'folitropina alfa ',
#  ' folitropina beta ',
#  ' folitropina delta ',
#  ' follicle stimulating hormone ',
#  ' follitrophin alfa ',
#  ' follitrophin alpha ',
#  ' follitrophin beta ',
#  ' follitropin alfa ',
#  ' follitropin alfa/beta ',
#  ' follitropin alpha ',
#  ' follitropin beta ',
#  ' follitropin delta ',
#  ' follitropin gamma ',
#  ' follotropin recombinant ',
#  ' fsh ',
#  ' fsh alpha ',
#  ' fsh-a ',
#  ' fsh-b ',
#  ' fsh-beta ',
#  ' recombinant human follicle stimulating hormone beta ',
#  ' recombinant human follicle-stimulating hormone (r-hfsh) ',
#  ' rfsh-alpha',
#  'vasopressin, unspecified ',
#  ' vasopressina',
#  'interferon beta 1b (recombinant) ',
#  ' interferon beta-1b,recombinant ',
#  ' interferon-beta-1b ',
#  ' recombinant interferon beta-1b',
#  'ifn alfacon-1 ',
#  ' ifn-con1 ',
#  ' interferon alfacon-1',
#  'hyaluronidase (glycoprotein, sheep testis isoenzyme) ',
#  ' hyaluronidase (ovine) ',
#  ' hyaluronidase (sheep testis isoenzyme) ',
#  ' hyaluronidase, ovine ',
#  ' ovine hyaluronidase',
#  'insulin (pork) ',
#  ' insulin porcine ',
#  ' insulin purified porcine ',
#  ' insulin purified pork ',
#  ' insulin, porcine ',
#  ' insulin, regular, pork ',
#  ' porcine insulin',
#  'rhumab her2 ',
#  ' trastuzumab-anns ',
#  ' trastuzumab-dkst ',
#  ' trastuzumab-dttb ',
#  ' trastuzumab-pkrb ',
#  ' trastuzumab-qyyp',
#  'rituximab-abbs ',
#  ' rituximab-pvvr',
#  'basiliximab',
#  'anti-cd3 ',
#  ' muromonab-cd3',
#  'digitalis antitoxin ',
#  ' digoxin immune fab, ovine ',
#  ' digoxin-specific antibody fragments ',
#  ' ovine digoxin immune fab',
#  'ibritumomab ',
#  ' mab murine (igg1) anti p19437 (cd20_mouse)',
#  'daptomicina ',
#  ' daptomycin ',
#  ' daptomycine ',
#  ' daptomycinum',
#  'abobotulinumtoxina ',
#  ' botulinum a neurotoxin ',
#  ' botulinum toxin a ',
#  ' botulinum toxin type a ',
#  ' btx-a ',
#  ' evabotulinumtoxina ',
#  ' incobotulinumtoxina ',
#  ' onabotulinumtoxina ',
#  ' prabotulinumtoxin a ',
#  ' toxina botulã\xadnica a ',
#  ' toxine botulinique a',
#  'pancrealipase ',
#  ' pancreatic extract pancrelipase ',
#  ' pancreatic protease ',
#  ' pancreatin ',
#  ' pancreatinum ',
#  ' pancrelipase (amylase;lipase;protease)',
#  'estreptoquinasa ',
#  ' streptochinasi ',
#  ' streptococcal fibrinolysin ',
#  ' streptokinase ',
#  ' streptokinasum',
#  '(111in)-capromab pendetide ',
#  ' indium (111in) capromab pendetide ',
#  ' indium 111 capromab pendetide ',
#  ' indium in 111 capromab pendetide',
#  'alpha-l-idosiduronase ',
#  ' human recombinant alpha-l-iduronidase ',
#  ' laronidasa ',
#  ' laronidase ',
#  ' laronidase (genetical recombination)',
#  'ciclosporin ',
#  ' ciclosporina ',
#  ' ciclosporine ',
#  ' ciclosporinum ',
#  ' csa ',
#  ' cya ',
#  ' cyclosporin ',
#  ' cyclosporin a ',
#  ' cyclosporine',
#  '2-(l-phenylalanine)-8-l-lysinevasopressin ',
#  ' felipresina ',
#  ' felypressin ',
#  ' felypressine ',
#  ' felypressinum ',
#  ' plv-2',
#  'follitropin human ',
#  ' urofollitrophin',
#  'anti-cd11a ',
#  ' anticd11 alpha ',
#  ' efalizumab',
#  'choriogonadotropin alpha ',
#  ' chorionic gonadotropin (recombinant)',
#  'anti-human thymocyte immunoglobulin, rabbit ',
#  ' anti-t-lymphocyte immune globulin, rabbit ',
#  ' anti-thymocyte globulin (rabbit) ',
#  ' anti-thymocyte globulin rabbit ',
#  ' antithymocyte immunoglobulin ',
#  ' lapine t-lymphocyte immune globulin ',
#  ' rabbit anti-human thymocyte globulin ',
#  ' rabbit anti-human thymocyte globulin (ratg) ',
#  ' rabbit anti-human thymocyte immunoglobulin ',
#  ' rabbit anti-thymocyte immunoglobulin ',
#  ' rabbit antithymocyte globulin ',
#  ' rabbit atg ',
#  ' ratg ',
#  ' thymoglobulin ',
#  ' thymoglobuline',
#  'filgrastim-aafi ',
#  ' filgrastim-sndz ',
#  ' g-csf  ',
#  ' granulocyte colony stimulating factor  ',
#  ' tbo-filgrastim',
#  'coagulation factor ix (recombinant) ',
#  ' coagulation factor ix recombinant human ',
#  ' factor ix (recombinant) ',
#  ' nonacog alfa ',
#  ' nonacog gamma ',
#  ' recombinant factor ix',
#  'becaplermin ',
#  ' pdgf-2 ',
#  ' pdgf-bb ',
#  ' pdgfb ',
#  ' platelet-derived growth factor bb, recombinant ',
#  ' platelet-derived growth factor beta polypeptide ',
#  ' recombinant platelet-derived growth factor bb ',
#  ' rhpdgf-bb ',
#  ' rpdgf-bb ',
#  ' sh-polypeptide-59',
#  'agalsidasa alfa ',
#  ' agalsidasa beta ',
#  ' agalsidase alfa ',
#  ' alpha-galactosidase a',
#  'octreotida ',
#  ' octreotide ',
#  ' octreotidum ',
#  ' octrotide',
#  'interferon alfa-2b ',
#  ' interferon alfa-2b, recombinant ',
#  ' interferon alpha-2b ',
#  ' interferon î±-2b ',
#  ' intron (interferon î±2b) ',
#  ' intron a ',
#  ' intron a (interferon î±2b) ',
#  ' r-inf-alpha ',
#  ' rifn-alpha-2b',
#  'abarelix',
#  'oxitocina ',
#  ' oxytocin',
#  'anti-alpha4 integrin ',
#  ' anti-vla4',
#  'enfuvirtida',
#  'palivizumab',
#  'dacliximab ',
#  ' daclizumab beta',
#  'anti-vegf humanized monoclonal antibody ',
#  ' anti-vegf monoclonal antibody ',
#  ' bevacizumab ',
#  ' bevacizumab-awwb ',
#  ' rhumab-vegf',
#  'arcitumomab technetium-99m ',
#  ' technetium (99mtc) arcitumomab ',
#  ' technetium tc 99m arcitumomab ',
#  ' technetium-99m arcitumomab',
#  '3-hydroxy-2-methyl-5-((phosphonooxy)methyl)-4-pyridinecarboxaldehyde ',
#  ' 3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde 5-phosphate ',
#  ' codecarboxylase ',
#  ' plp ',
#  ' pyridoxal 5-monophosphoric acid ester ',
#  ' pyridoxal 5-phosphate ',
#  " pyridoxal 5'-phosphate ",
#  ' pyridoxal p ',
#  ' pyridoxal phosphate anhydrous ',
#  ' pyridoxal-5p ',
#  ' pyridoxal-p',
#  'cianocobalamina ',
#  ' cyanocob(iii)alamin ',
#  ' cyanocobalamin ',
#  ' cyanocobalamine ',
#  ' cyanocobalaminum ',
#  ' vitamin b12 ',
#  ' vitamin b12 complex ',
#  ' vitamin b12 nos',
#  '5,6,7,8-tetrahydrofolate ',
#  ' 5,6,7,8-tetrahydrofolic acid ',
#  ' tetrahydrofolate',
#  '(s)-4-(2-amino-2-carboxyethyl)imidazole ',
#  ' (s)-a-amino-1h-imidazole-4-propanoic acid ',
#  ' (s)-alpha-amino-1h-imidazole-4-propanoic acid ',
#  ' (s)-alpha-amino-1h-imidazole-4-propionic acid ',
#  ' (s)-î±-amino-1h-imidazole-4-propanoic acid ',
#  ' his ',
#  ' histidina ',
#  ' histidine ',
#  ' l-(â\x88\x92)-histidine ',
#  ' l-histidin ',
#  ' l-histidine',
#  'ademetionine ',
#  ' adomet ',
#  ' l-s-adenosylmethionine ',
#  ' s-adenosylmethionine ',
#  ' sam ',
#  ' sam-e ',
#  ' same',
#  '2-ketopropionic acid ',
#  ' 2-oxopropanoic acid ',
#  ' 2-oxopropansã¤ure ',
#  ' 2-oxopropionsã¤ure ',
#  ' a-ketopropionic acid ',
#  ' acetylformic acid ',
#  ' acide pyruvique ',
#  ' alpha-ketopropionic acid ',
#  ' brenztraubensã¤ure ',
#  ' bts ',
#  ' pyroracemic acid ',
#  ' î±-ketopropionic acid ',
#  ' î±-oxopropionsã¤ure',
#  '(s)-2-amino-3-phenylpropionic acid ',
#  ' (s)-alpha-amino-beta-phenylpropionic acid ',
#  ' 3-phenyl-l-alanine ',
#  ' beta-phenyl-l-alanine ',
#  ' f ',
#  ' fenilalanina ',
#  ' l-phenylalanine ',
#  ' phe ',
#  ' phenylalanine ',
#  ' phenylalaninum ',
#  ' î²-phenyl-l-alanine',
#  '(+)-cis-hexahydro-2-oxo-1h-thieno[3,4]imidazole-4-valeric acid ',
#  ' (3as,4s,6ar)-hexahydro-2-oxo-1h-thieno[3,4-d]imidazole-4-valeric acid ',
#  ' 5-(2-oxohexahydro-1h-thieno[3,4-d]imidazol-4-yl)pentanoic acid ',
#  ' biotin ',
#  ' biotina ',
#  ' biotine ',
#  ' biotinum ',
#  ' cis-(+)-tetrahydro-2-oxothieno[3,4]imidazoline-4-valeric acid ',
#  ' cis-hexahydro-2-oxo-1h-thieno(3,4)imidazole-4-valeric acid ',
#  ' cis-tetrahydro-2-oxothieno(3,4-d)imidazoline-4-valeric acid ',
#  ' coenzyme r ',
#  ' d-(+)-biotin ',
#  ' d-biotin ',
#  ' vitamin b7 ',
#  ' vitamin h',
#  'bilineurine ',
#  ' choline ion ',
#  ' n-trimethylethanolamine ',
#  ' n,n,n-trimethylethanol-ammonium ',
#  ' trimethylethanolamine ',
#  ' vitamin j',
#  '(s)-2,6-diaminohexanoic acid ',
#  ' (s)-lysine ',
#  ' (s)-î±,îµ-diaminocaproic acid ',
#  ' 6-ammonio-l-norleucine ',
#  ' l-2,6-diaminocaproic acid ',
#  ' l-lys ',
#  ' l-lysin ',
#  ' lys ',
#  ' lysina ',
#  ' lysine ',
#  ' lysine acid ',
#  ' lysinum',
#  '(2s)-2-amino-5-(carbamimidamido)pentanoic acid ',
#  ' (2s)-2-amino-5-guanidinopentanoic acid ',
#  ' (s)-2-amino-5-guanidinopentanoic acid ',
#  ' (s)-2-amino-5-guanidinovaleric acid ',
#  ' arg ',
#  ' arginina ',
#  ' arginine ',
#  ' l-(+)-arginine ',
#  ' l-arg ',
#  ' l-arginin ',
#  ' l-arginine ',
#  ' r',
#  'acide ascorbique ',
#  ' ã¡cido ascã³rbico ',
#  ' acidum ascorbicum ',
#  ' acidum ascorbinicum ',
#  ' ascorbate ',
#  ' ascorbic acid ',
#  ' ascorbinsã¤ure ',
#  ' l-(+)-ascorbic acid ',
#  ' l-ascorbate ',
#  ' l-ascorbic acid ',
#  ' vitamin c ',
#  ' vitamina c',
#  '4,9-diaza-1,12-dodecanediamine ',
#  ' 4,9-diazadodecane-1,12-diamine ',
#  ' musculamine ',
#  " n,n'-bis(3-aminopropyl)-1,4-butanediamine ",
#  ' spermina ',
#  ' spermine',
#  '(s)-2-aminobutanedioic acid ',
#  ' (s)-2-aminosuccinic acid ',
#  ' 2-aminosuccinic acid ',
#  ' ã¡cido aspã¡rtico ',
#  ' acidum asparticum ',
#  ' asp ',
#  ' aspartic acid ',
#  ' d ',
#  ' l-asp ',
#  ' l-asparaginsã¤ure ',
#  ' l-aspartate ',
#  ' l-aspartic acid',
#  '(s)-2,5-diaminopentanoate ',
#  ' (s)-2,5-diaminopentanoic acid ',
#  ' (s)-2,5-diaminovaleric acid ',
#  ' (s)-ornithine ',
#  ' (s)-î±,î´-diaminovaleric acid ',
#  ' l-ornithine ',
#  ' levo-ornithine ',
#  ' ornithine ',
#  ' ornithinum ',
#  ' ornitina',
#  '(2s)-2-amino-4-carbamoylbutanoic acid ',
#  ' (2s)-2,5-diamino-5-oxopentanoic acid ',
#  ' (s)-2,5-diamino-5-oxopentanoic acid ',
#  ' glutamic acid 5-amide ',
#  ' glutamic acid amide ',
#  ' glutamina ',
#  ' glutamine ',
#  ' l-(+)-glutamine ',
#  ' l-2-aminoglutaramic acid ',
#  ' l-glutamic acid î³-amide ',
#  ' l-glutamin ',
#  ' l-glutaminsã¤ure-5-amid ',
#  ' levoglutamide ',
#  ' q',
#  "5'-adenosine monophosphate ",
#  " 5'-adenylic acid ",
#  " 5'-amp ",
#  " 5'-o-phosphonoadenosine ",
#  " adenosine 5'-(dihydrogen phosphate) ",
#  " adenosine 5'-monophosphate ",
#  " adenosine 5'-phosphate ",
#  ' adenosine monophosphate ',
#  ' adenosine phosphate ',
#  " adenosine-5'-monophosphate ",
#  " adenosine-5'-monophosphoric acid ",
#  " adenosine-5'p ",
#  ' adenosini phosphas ',
#  ' adenylate ',
#  ' adenylic acid ',
#  " ado5'p ",
#  ' amp ',
#  ' fosfato de adenosina ',
#  ' pado ',
#  " phosphate d'adã©nosine",
#  '(9,12,15)-linolenic acid ',
#  ' (9z,12z,15z)-octadecatrienoic acid ',
#  ' (z,z,z)-9,12,15-octadecatrienoic acid ',
#  ' 9-cis,12-cis,15-cis-octadecatrienoic acid ',
#  ' 9,12,15-octadecatrienoic acid ',
#  ' ala ',
#  ' all-cis-9,12,15-octadecatrienoic acid ',
#  ' alpha-linolenic acid ',
#  ' cis-delta(9,12,15)-octadecatrienoic acid ',
#  ' cis,cis,cis-9,12,15-octadecatrienoic acid ',
#  ' linolenic acid ',
#  ' î±-linolenic acid',
#  '(s)-2-amino-3-hydroxypropanoic acid ',
#  ' (s)-serine ',
#  ' alpha-amino-beta-hydroxypropionic acid ',
#  ' beta-hydroxyalanine ',
#  ' l-serine ',
#  ' ser ',
#  ' serina ',
#  ' serine ',
#  ' serinum',
#  '(2s)-2-amino-4-(methylsulfanyl)butanoic acid ',
#  ' (s)-2-amino-4-(methylthio)butanoic acid ',
#  ' (s)-2-amino-4-(methylthio)butyric acid ',
#  ' (s)-methionine ',
#  ' l-(â\x88\x92)-methionine ',
#  ' l-a-amino-g-methylthiobutyric acid ',
#  ' l-methionin ',
#  ' l-methionine ',
#  ' l-î±-amino-î³-methylmercaptobutyric acid ',
#  ' m ',
#  ' met ',
#  ' methionine',
#  '(â\x88\x92)-î±-amino-p-hydroxyhydrocinnamic acid ',
#  ' (2s)-2-amino-3-(4-hydroxyphenyl)propanoic acid ',
#  ' (s)-(-)-tyrosine ',
#  ' (s)-2-amino-3-(p-hydroxyphenyl)propionic acid ',
#  ' (s)-3-(p-hydroxyphenyl)alanine ',
#  ' (s)-alpha-amino-4-hydroxybenzenepropanoic acid ',
#  ' (s)-tyrosine ',
#  ' (s)-î±-amino-4-hydroxybenzenepropanoic acid ',
#  ' 4-hydroxy-l-phenylalanine ',
#  ' l-tyrosin ',
#  ' l-tyrosine ',
#  ' tirosina ',
#  ' tyr ',
#  ' tyrosine ',
#  ' tyrosinum ',
#  ' y',
#  '(1s,3r,5z,7e)-9,10-secocholesta-5,7,10-triene-1,3,25-triol ',
#  ' (1î±,3î²,5z,7e)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol ',
#  ' (5z,7e)-(1s,3r)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol ',
#  ' 1-alpha-25-dihydroxyvitamin d3 ',
#  ' 1,25-dhcc ',
#  ' 1,25-dihydroxycholecalciferol ',
#  ' 1î±,25-dihydroxycholecalciferol ',
#  ' 1î±,25-dihydroxyvitamin d3 ',
#  ' 1î±,25(oh)2d3 ',
#  ' calcitriol ',
#  ' calcitriolum',
#  'xanthophyll ',
#  ' xantofyl',
#  "(r,r)-3,3'-dithiobis(2-aminopropanoic acid) ",
#  ' cistina ',
#  ' l-alpha-diamino-beta-dithiolactic acid ',
#  ' l-cystine ',
#  ' l-dicysteine ',
#  " î²,î²'-dithiodialanine",
#  '1,2-ethanedicarboxylic acid ',
#  ' acide butanedioã¯que ',
#  ' acide succinique ',
#  ' acidum succinicum ',
#  ' amber acid ',
#  ' asuccin ',
#  ' bernsteinsã¤ure ',
#  ' butandisã¤ure ',
#  ' butanedioic acid ',
#  ' butanedionic acid ',
#  ' dihydrofumaric acid ',
#  ' ethylenesuccinic acid ',
#  ' spirit of amber ',
#  ' succinic acid',
#  '1-deoxy-1-(7,8-dimethyl-2,4-dioxo-3,4-dihydrobenzo[g]pteridin-10(2h)-yl)pentitol ',
#  ' 6,7-dimethyl-9-d-ribitylisoalloxazine ',
#  ' 7,8-dimethyl-10-(d-ribo-2,3,4,5-tetrahydroxypentyl)isoalloxazine ',
#  ' 7,8-dimethyl-10-ribitylisoalloxazine ',
#  ' lactoflavin ',
#  ' lactoflavine ',
#  ' riboflavin ',
#  ' riboflavina ',
#  ' riboflavine ',
#  ' riboflavinum ',
#  ' vitamin b2 ',
#  ' vitamin bi ',
#  ' vitamin g',
#  '2-acetamido-2-deoxy-d-glucose ',
#  ' aldehydo-n-acetyl-d-glucosamine ',
#  ' d-glcnac ',
#  ' n-acetyl-d-glucosamine ',
#  ' n-acetylchitosamine',
#  '(2s)-2-aminopentanedioic acid ',
#  ' (s)-2-aminopentanedioic acid ',
#  ' (s)-glutamic acid ',
#  ' ã¡cido glutã¡mico ',
#  ' glu ',
#  ' glutamic acid ',
#  ' l-glutamate ',
#  ' l-glutamic acid ',
#  ' l-glutaminic acid',
#  '5-l-glutamyl-l-cysteinylglycine ',
#  ' gamma-l-glutamyl-l-cysteinyl-glycine ',
#  ' glutathione ',
#  ' glutathione-sh ',
#  ' gsh ',
#  ' n-(n-gamma-l-glutamyl-l-cysteinyl)glycine ',
#  ' reduced glutathione',
#  'phosphatidyl-l-serine ',
#  ' phosphatidylserine ',
#  ' ps ',
#  ' ptd-l-ser',
#  'aminoacetic acid ',
#  ' aminoessigsã¤ure ',
#  ' aminoethanoic acid ',
#  ' glicina ',
#  ' gly ',
#  ' glycin ',
#  ' glycine ',
#  ' glycocoll ',
#  ' glykokoll ',
#  ' glyzin ',
#  ' leimzucker',
#  '(3s,5z,7e)-9,10-secocholesta-5,7,10-triene-3,25-diol ',
#  ' (3î²,5z,7e)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol ',
#  ' (5z,7e)-(3s)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol ',
#  ' 25-hydroxycholecalciferol ',
#  ' 25-hydroxyvitamin d3 ',
#  ' calcidiol ',
#  ' calcifã©diol ',
#  ' calcifediol ',
#  ' calcifediol anhydrous ',
#  ' calcifediolum',
#  '2-methyl-3-hydroxy-4-formyl-5-hydroxymethylpyridine ',
#  ' 3-hydroxy-5-(hydroxymethyl)-2-methyl-4-pyridinecarboxaldehyde ',
#  ' 3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde ',
#  ' 3-hydroxy-5-(hydroxymethyl)-2-methylpyridine-4-carboxaldehyde ',
#  ' piridoxal ',
#  ' pyridoxaldehyde',
#  '((amino(imino)methyl)(methyl)amino)acetic acid ',
#  ' (alpha-methylguanido)acetic acid ',
#  ' (n-methylcarbamimidamido)acetic acid ',
#  ' (î±-methylguanido)acetic acid ',
#  ' alpha-methylguanidino acetic acid ',
#  ' creatin ',
#  ' creatine ',
#  ' kreatin ',
#  ' methylglycocyamine ',
#  ' n-(aminoiminomethyl)-n-methylglycine ',
#  ' n-amidinosarcosine ',
#  ' n-carbamimidoyl-n-methylglycine ',
#  ' n-methyl-n-guanylglycine',
#  '(2s)-2-amino-4-methylpentanoic acid ',
#  ' (2s)-alpha-2-amino-4-methylvaleric acid ',
#  ' (2s)-alpha-leucine ',
#  ' (s)-(+)-leucine ',
#  ' (s)-leucine ',
#  ' 2-amino-4-methylvaleric acid ',
#  ' l ',
#  ' l-leucin ',
#  ' l-leucine ',
#  ' l-leuzin ',
#  ' leu ',
#  ' leucine',
#  '(2s)-2-amino-3-(1h-indol-3-yl)propanoic acid ',
#  ' (s)-alpha-amino-beta-(3-indolyl)-propionic acid ',
#  ' (s)-tryptophan ',
#  ' (s)-î±-amino-1h-indole-3-propanoic acid ',
#  ' l-(-)-tryptophan ',
#  ' l-(â\x88\x92)-tryptophan ',
#  ' l-tryptophan ',
#  ' l-î²-3-indolylalanine ',
#  ' triptofano ',
#  ' trp ',
#  ' tryptophan ',
#  ' tryptophane ',
#  ' tryptophanum ',
#  ' w',
#  '(2r)-2-amino-3-mercaptopropanoic acid ',
#  ' (2r)-2-amino-3-sulfanylpropanoic acid ',
#  ' (r)-2-amino-3-mercaptopropanoic acid ',
#  ' cisteina ',
#  ' cisteinum ',
#  ' cys ',
#  ' cysteine ',
#  ' cysteinum ',
#  ' free cysteine ',
#  ' l-2-amino-3-mercaptopropionic acid ',
#  ' l-cys ',
#  ' l-cystein ',
#  ' l-zystein',
#  'aneurin ',
#  ' antiberiberi factor ',
#  ' thiamin ',
#  ' thiamine ',
#  ' thiamine(1+) ',
#  ' thiamine(1+) ion ',
#  ' thiaminium ',
#  ' thiaminum ',
#  ' tiamina ',
#  ' vitamin b1',
#  '(3î²,5z,7e,22e)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol ',
#  ' (5z,7e,22e)-(3s)-9,10-seco-5,7,10(19),22-ergostatetraen-3-ol ',
#  ' (5z,7e,22e)-(3s)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol ',
#  ' activated ergosterol ',
#  ' ercalciol ',
#  ' ergocalcifã©rol ',
#  ' ergocalciferol ',
#  ' ergocalciferolum ',
#  ' oleovitamin d2 ',
#  ' viosterol ',
#  ' vitamin d2 ',
#  ' vitamina d2',
#  '(8z,11z,14z)-icosatrienoic acid ',
#  ' (z,z,z)-8,11,14-eicosatrienoic acid ',
#  ' (z,z,z)-8,11,14-icosatrienoate ',
#  ' (z,z,z)-8,11,14-icosatrienoic acid ',
#  ' 20:3, n-6,9,12 all-cis ',
#  ' 8,11,14-eicosatrienoic acid ',
#  ' 8c,11c,14c-eicosatrienoic acid ',
#  ' 8c,11c,14c-eicosatriensã¤ure ',
#  ' all-cis-8,11,14-eicosatrienoic acid ',
#  ' all-cis-8,11,14-icosatrienoic acid ',
#  ' all-cis-eicosa-8,11,14-trienoic acid ',
#  ' all-cis-eicosa-8,11,14-triensã¤ure ',
#  ' all-cis-icosa-8,11,14-trienoic acid ',
#  ' c20:3, n-6,9,12 all-cis ',
#  ' cis,cis,cis-8,11,14-eicosatrienoic acid ',
#  ' dgla ',
#  ' dihomo-î³-linolenic acid ',
#  ' eicosa-8z,11z,14z-trienoic acid ',
#  ' gamma-homolinolenic acid ',
#  ' homo-gamma-linolenic acid ',
#  ' homo-gamma-linolensã¤ure ',
#  ' homo-î³-linolensã¤ure',
#  '(s)-2-amino-5-ureidopentanoic acid ',
#  ' 2-amino-5-ureidovaleric acid ',
#  ' alpha-amino-delta-ureidovaleric acid ',
#  ' cit ',
#  ' citrulina ',
#  ' citrulline ',
#  ' delta-ureidonorvaline ',
#  ' l-2-amino-5-ureidovaleric acid ',
#  ' l-citrulline ',
#  ' n(5)-(aminocarbonyl)-l-ornithine ',
#  ' n(delta)-carbamylornithine ',
#  ' n5-(aminocarbonyl)ornithine ',
#  ' n5-carbamoyl-l-ornithine ',
#  ' n5-carbamoylornithine ',
#  ' î±-amino-î´-ureidovaleric acid ',
#  ' î´-ureidonorvaline',
#  '(2s,3r)-(-)-threonine ',
#  ' (2s)-threonine ',
#  ' 2-amino-3-hydroxybutyric acid ',
#  ' l-(-)-threonine ',
#  ' l-2-amino-3-hydroxybutyric acid ',
#  ' l-alpha-amino-beta-hydroxybutyric acid ',
#  ' l-threonin ',
#  ' l-threonine ',
#  ' l-î±-amino-î²-hydroxybutyric acid ',
#  ' thr ',
#  ' threonine ',
#  ' threoninum ',
#  ' treonina',
#  '1,4-dihydronicotinamide adenine dinucleotide ',
#  ' dpnh ',
#  ' nad reduced form ',
#  ' nicotinamide adenine dinucleotide (reduced) ',
#  ' nicotinamide-adenine dinucleotide, reduced ',
#  ' reduced nicotinamide adenine diphosphate ',
#  ' reduced nicotinamide-adenine dinucleotide',
#  'acide folique ',
#  ' ã¡cido fã³lico ',
#  ' acidum folicum ',
#  ' folacin ',
#  ' folate ',
#  ' folic acid ',
#  ' folsã¤ure ',
#  ' n-[(4-{[(2-amino-4-oxo-1,4-dihydropteridin-6-yl)methyl]amino}phenyl)carbonyl]-l-glutamic acid ',
#  ' n-pteroyl-l-glutamic acid ',
#  ...]

# %%
#pd.Series(df_drugs.Synonyms,index=df_drugs.Common_name).to_dict()

synonyms = []
drug_names = df_drugs['Common_name'].tolist()

for row in df_drugs['Synonyms']:
    row=str(row)
    words = row.split(' | ')
    synonyms.append(words)

#print(synonyms)
for x, y in zip(synonyms, drug_names):
    x.append(y)
drug_lists= list(zip(drug_names, synonyms))
drug_dic = dict(drug_lists)

drug_dic

keys = [key for key, value in drug_dic.items() if 'Cetuximab' in value]
keys
# Out:
# ['Cetuximab']

# %%
drug_dic = {k:[elem for elem in v if elem != 'nan' ] for k,v in drug_dic.items()}
drug_dic
# Out:
# {'Lepirudin': ['Hirudin variant-1', 'Lepirudin recombinant', 'Lepirudin'],
#  'Cetuximab': ['Cetuximab', 'CÃ©tuximab', 'Cetuximabum', 'Cetuximab'],
#  'Dornase alfa': ['Deoxyribonuclease (human clone 18-1 protein moiety)',
#   'Dornasa alfa',
#   'Dornase alfa, recombinant',
#   'Dornase alpha',
#   'Recombinant deoxyribonuclease (DNAse)',
#   'Dornase alfa'],
#  'Denileukin diftitox': ['Denileukin',
#   'Interleukin-2/diptheria toxin fusion protein',
#   'Denileukin diftitox'],
#  'Etanercept': ['Etanercept',
#   'etanercept-szzs',
#   'etanercept-ykro',
#   'Recombinant human TNF',
#   'rhu TNFR:Fc',
#   'rhu-TNFR:Fc',
#   'TNFR-Immunoadhesin',
#   'Etanercept'],
#  'Bivalirudin': ['Bivalirudin',
#   'Bivalirudina',
#   'Bivalirudinum',
#   'Bivalirudin'],
#  'Leuprolide': ['Leuprorelin',
#   'Leuprorelina',
#   'Leuproreline',
#   'Leuprorelinum',
#   'Leuprolide'],
#  'Peginterferon alfa-2a': ['PEG-IFN alfa-2A',
#   'PEG-Interferon alfa-2A',
#   'Peginterferon alfa-2a',
#   'Pegylated Interfeaon alfa-2A',
#   'Pegylated interferon alfa-2a',
#   'Pegylated interferon alpha-2a',
#   'Pegylated-interferon alfa 2a',
#   'Peginterferon alfa-2a'],
#  'Alteplase': ['Alteplasa',
#   'Alteplase (genetical recombination)',
#   'Alteplase, recombinant',
#   'Alteplase,recombinant',
#   'Plasminogen activator (human tissue-type protein moiety)',
#   'rt-PA',
#   't-PA',
#   't-plasminogen activator',
#   'Tissue plasminogen activator',
#   'Tissue plasminogen activator alteplase',
#   'Tissue plasminogen activator, recombinant',
#   'tPA',
#   'Alteplase'],
#  'Sermorelin': ['Sermorelin'],
#  'Interferon alfa-n1': ['Interferon alpha-n1 (INS)', 'Interferon alfa-n1'],
#  'Darbepoetin alfa': ['Darbepoetin',
#   'Darbepoetin alfa,recombinant',
#   'Darbepoetina alfa',
#   'Darbepoetin alfa'],
#  'Urokinase': ['Kinase (enzyme-activating), uro-urokinase',
#   'TCUK',
#   'Tissue culture urokinase',
#   'Two-chain urokinase',
#   'Urochinasi',
#   'Urokinase',
#   'Urokinasum',
#   'Uroquinasa',
#   'Urokinase'],
#  'Goserelin': ['Goserelin', 'Goserelina', 'Goserelin'],
#  'Reteplase': ['Human t-PA (residues 1-3 and 176-527)',
#   'Reteplasa',
#   'Reteplase, recombinant',
#   'Reteplase,recombinant',
#   'Reteplase'],
#  'Erythropoietin': ['E.P.O.',
#   'Epoetin alfa',
#   'Epoetin alfa rDNA',
#   'Epoetin alfa-epbx',
#   'Epoetin alfa, recombinant',
#   'Epoetin beta',
#   'Epoetin beta rDNA',
#   'Epoetin epsilon',
#   'Epoetin gamma',
#   'Epoetin gamma rDNA',
#   'Epoetin kappa',
#   'Epoetin omega',
#   'Epoetin theta',
#   'Epoetin zeta',
#   'Epoetina alfa',
#   'Epoetina beta',
#   'Epoetina dseta',
#   'Epoetina zeta',
#   'EpoÃ©tine zÃªta',
#   'Epoetinum zeta',
#   'Erythropoiesis stimulating factor',
#   'Erythropoietin (human, recombinant)',
#   'Erythropoietin (recombinant human)',
#   'ESF',
#   'SH-polypeptide-72',
#   'Erythropoietin'],
#  'Salmon calcitonin': ['Calcitonin (Salmon Synthetic)',
#   'Calcitonin salmon',
#   'Calcitonin salmon recombinant',
#   'Calcitonin-salmon',
#   'Calcitonin, salmon',
#   'Calcitonina salmÃ³n sintÃ©tica',
#   'Recombinant salmon calcitonin',
#   'Salmon calcitonin',
#   'Salmon calcitonin'],
#  'Interferon alfa-n3': ['Interferon alfa-n3'],
#  'Pegfilgrastim': ['Granulocyte colony-stimulating factor pegfilgrastim',
#   'peg-filgrastim',
#   'pegfilgrastim-apgf',
#   'pegfilgrastim-bmez',
#   'pegfilgrastim-cbqv',
#   'pegfilgrastim-jmdb',
#   'Pegfilgrastim'],
#  'Sargramostim': ['Recombinant human granulocyte-macrophage colony stimulating factor',
#   'rGM-CSF',
#   'rHu GM-CSF',
#   'Sargramostim',
#   'Sargramostim'],
#  'Peginterferon alfa-2b': ['Peginterferon alfa-2b'],
#  'Asparaginase Escherichia coli': ['Asparaginase',
#   'Asparaginase (E. coli)',
#   'Colaspase',
#   'Escherichia coli L-asparaginase',
#   'L-asparaginase',
#   'L-asparagine amidohydrolase',
#   'Asparaginase Escherichia coli'],
#  'Thyrotropin alfa': ['Recombinant Human Thyroid Stimulating Hormone',
#   'Recombinant thyrotropin alfa',
#   'rhTSH',
#   'rTSH',
#   'Thyrotropin alpha',
#   'Thyrotropin alfa'],
#  'Antihemophilic factor, human recombinant': ['Antihemophilic factor (recombinant)',
#   'Antihemophilic factor recombinant',
#   'Antihemophilic factor, human recombinant',
#   'Antihemophilic factor, recombinant',
#   'Factor VIII (rDNA)',
#   'Factor VIII (Recombinant)',
#   'Factor VIII recombin',
#   'Factor VIII, recombinant',
#   'Human Factor VIII (Recombinant)',
#   'Human factor VIII recombinant',
#   'Octocog alfa',
#   'rAHF',
#   'Recombinant antihemophilic factor VIII',
#   'Antihemophilic factor, human recombinant'],
#  'Anakinra': ['Anakinra',
#   'IL-1RA',
#   'Interleukin-1 receptor antagonist anakinra',
#   'Anakinra'],
#  'Gramicidin D': ['Bacillus brevis gramicidin D',
#   'Gramicidin',
#   'Gramicidin A',
#   'Gramicidin B',
#   'Gramicidin C',
#   'Gramicidina',
#   'Gramicidine',
#   'Gramicidin D'],
#  'Human immunoglobulin G': ['Human IGG',
#   'Human immunoglobulin G',
#   'Human normal immunoglobulin',
#   'Immune globulin (human)',
#   'Immune globulin human',
#   'Immunoglobulin (human)',
#   'Immunoglobulin G (human)',
#   'Immunoglobulin G, human',
#   'IVIg',
#   'Human immunoglobulin G'],
#  'Anistreplase': ['Anisoylated plasminogen streptokinase activator complex',
#   'APSAC',
#   'Anistreplase'],
#  'Insulin human': ['High molecular weight insulin human',
#   'Human insulin',
#   'human insulin (rDNA)',
#   'Insulin (human)',
#   'Insulin human',
#   'Insulin human [rDNA origin]',
#   'Insulin Human Regular',
#   'Insulin human regular (rDNA)',
#   'Insulin human, rDNA origin',
#   'Insulin recombinant human',
#   'Insulin recombinant purified human',
#   'Insulin regular',
#   'Insulin, human',
#   'Insulina regular',
#   'Regular Insulin, human',
#   'Insulin human'],
#  'Tenecteplase': ['Tenecteplasa', 'TNK-tPA', 'Tenecteplase'],
#  'Menotropins': ['Human menopausal gonadotrophin',
#   'Menotrophin',
#   'Menotropin',
#   'Menotropina',
#   'Menotropins (FSH;LH)',
#   'Menotropins'],
#  'Interferon gamma-1b': ['IFN-gamma 1b',
#   'IFN-gamma-1b',
#   'Interferon gamma 1-b',
#   'Interferon gamma-1b',
#   'Interferon gamma-1b, recombinant',
#   'Interferon gamma-2a',
#   'Interferon gamma-1b'],
#  'Interferon alfa-2a, Recombinant': ['Interferon alfa-2a',
#   'Interferon alfa-2a (recombinant)',
#   'Interferon alfa-2a, recombinant',
#   'Interferon alfa-2a,recombinant',
#   'Interferon alpha-2a',
#   'Interferon-alfa-2a',
#   'Recombinant human interferon alfa-2a',
#   'Recombinant human interferon-alfa-2a',
#   'rIFN-alpha-2a',
#   'SH-polypeptide-46',
#   'Interferon alfa-2a, Recombinant'],
#  'Desmopressin': ['1-(3-mercaptopropionic acid)-8-D-arginine-vasopressin',
#   '1-deamino-8-D-arginine vasopressin',
#   '1-desamino-8-D-arginine vasopressin',
#   'dDAVP',
#   'Desmopresina',
#   'Desmopressin',
#   'Desmopressine',
#   'Desmopressinum',
#   'Desmopressin'],
#  'Coagulation factor VIIa Recombinant Human': ['Coagulation factor VIIa',
#   'Coagulation factor VIIa (recombinant)',
#   'Coagulation factor VIIa (recombinant)-jncw',
#   'Eptacog alfa',
#   'Eptacog alfa (activated)',
#   'rFVIIa',
#   'Coagulation factor VIIa Recombinant Human'],
#  'Oprelvekin': ['IL-11',
#   'Interleukin 11',
#   'Interleukin-11',
#   'Oprelvekin',
#   'Recombinant interleukin-11',
#   'Oprelvekin'],
#  'Palifermin': ['24-163 fibroblast growth factor 7 (human)',
#   'Palifermina',
#   'Palifermin'],
#  'Glucagon': ['Glucagon',
#   'Glucagon (recombinant dna origin)',
#   'Glucagon recombinant',
#   'Glucagon, human',
#   'Glucagon, porcine',
#   'Glucagone',
#   'Glucagonum',
#   'Glucagon'],
#  'Aldesleukin': ['125-L-serine-2-133-interleukin 2 (human reduced)',
#   'Aldesleukina',
#   'Interleukin-2 aldesleukin',
#   'Interleukin-2(2-133),125-ser',
#   'Recombinant interleukin-2 human',
#   'Aldesleukin'],
#  'Botulinum Toxin Type B': ['Botulin B',
#   'Botulinum B toxin',
#   'Botulinum neurotoxin type B precursor',
#   'BTX-B',
#   'RimabotulinumtoxinB',
#   'Toxina botulÃ\xadnica B',
#   'Botulinum Toxin Type B'],
#  'Omalizumab': ['Omalizumab'],
#  'Lutropin alfa': ['Lutropin alfa',
#   'Lutropin alpha',
#   'Lutropina alfa',
#   'Lutropin alfa'],
#  'Lyme disease vaccine (recombinant OspA)': ['Lipoprotein OspA antigen recombinant',
#   'Lipoprotein outer surface a borrelia burgdorferi antigen',
#   'OspA lipoprotein',
#   'Lyme disease vaccine (recombinant OspA)'],
#  'Insulin lispro': ['Insulin lispro (genetical recombination)',
#   'Insulin lispro (rDNA origin)',
#   'Insulin lispro protamine',
#   'Insulin lispro protamine recombinant',
#   'Insulin lispro recombinant',
#   'insulin lispro-aabc',
#   'Insulin,lispro,human/rDNA',
#   'Insulin,lispro,protamine/rDNA',
#   'Insulina lispro',
#   'Insulin lispro'],
#  'Insulin glargine': ['Insulin glargine',
#   'Insulin Glargine (rDNA origin)',
#   'Insulin glargine recombinant',
#   'Insulina glargina',
#   'Insulin glargine'],
#  'Collagenase clostridium histolyticum': ['Clostridium histolyticum enzymes',
#   'Collagenase',
#   'Collagenase clostridium histolyticum',
#   'Collagenase clostridium histolyticum'],
#  'Rasburicase': ['Rasburicasa', 'Rasburicase', 'Urate oxidase', 'Rasburicase'],
#  'Cetrorelix': ['Cetrorelix', 'Cetrorelixum', 'Cetrorelix'],
#  'Adalimumab': ['Adalimumab (genetical recombination)',
#   'adalimumab-adaz',
#   'adalimumab-adbm',
#   'adalimumab-afzb',
#   'adalimumab-atto',
#   'adalimumab-bwwd',
#   'Adalimumab'],
#  'Somatotropin': ['Growth hormone',
#   'Growth hormone (human)',
#   'hGH',
#   'Human growth hormone',
#   'Recombinant human growth hormone',
#   'rhGH',
#   'Somatotropin (human)',
#   'Somatotropin human',
#   'Somatotropin human growth hormone',
#   'Somatropin',
#   'Somatropin (rDNA origin)',
#   'Somatropin (recombinant DNA origin)',
#   'Somatropin [rDNA origin]',
#   'Somatropin recombinant',
#   'Somatropin(recombinant DNA origin)',
#   'Somatropina',
#   'Somatotropin'],
#  'Imiglucerase': ['Imiglucerasa', 'Imiglucerase'],
#  'Abciximab': ['Abciximab',
#   'Abciximab (genetical recombination)',
#   'c7E3',
#   'Abciximab'],
#  'Drotrecogin alfa': ['Activated protein C',
#   'Blood coagulation factor XIV (human)',
#   'Drotrecogin alfa (activated)',
#   'Drotrecogin alfa (activated), lyophilized',
#   'Drotrecogin alfa activated',
#   'Drotrecogin alfa, activated',
#   'Drotrecogin-alfa',
#   'Recombinant human activated protein C (rH-APC)',
#   'Drotrecogin alfa'],
#  'Gemtuzumab ozogamicin': ['Gemtuzumab ozogamicin'],
#  'Indium In-111 satumomab pendetide': ['Indium (111In) satumomab pendetide',
#   'Indium In 111 satumomab pendetide',
#   'Indium-111 satumomab pendetide',
#   'Indium In-111 satumomab pendetide'],
#  'Alpha-1-proteinase inhibitor': ['Alfa 1-proteinase inhibitor (human)',
#   'Alfa-1-antitripsina',
#   'Alfa1 antitrypsin',
#   'Alpha 1-antitrypsin',
#   'Alpha 1-Proteinase Inhibitor',
#   'Alpha 1-proteinase inhibitor (human)',
#   'Alpha 1-proteinase inhibitor, human',
#   'Alpha-1 protease inhibitor',
#   'Alpha-1 proteinase inhibitor (human)',
#   'Alpha-1-antiproteinase',
#   'Alpha-1-antitrypsin',
#   'Alpha-1-proteinase Inhibitor (human)',
#   'Alpha-1-proteinase inhibitor human',
#   'Alpha-1-proteinase Inhibitor, Human',
#   'Alpha-1-proteinase inhibitor,human',
#   'Alpha1-proteinase Inhibitor',
#   'Alpha1-proteinase inhibitor (human)',
#   'alpha1-proteinase inhibitor human',
#   'API',
#   'Alpha-1-proteinase inhibitor'],
#  'Pegaspargase': ['Peg-asparaginase',
#   'Peg/L-asparaginase',
#   'Pegaspargasa',
#   'Pegaspargase'],
#  'Interferon beta-1a': ['Interferon beta 1-a',
#   'Interferon beta 1a',
#   'Interferon beta-1a (recombinant human)',
#   'Interferon beta-1a,recombinant',
#   'Interferon-beta-1a',
#   'Interferon beta-1a'],
#  'Pegademase': ['(monomethoxypolyethylene glycol succinimidyl) 11-17-adenosine deaminase',
#   'PEG-adenosine deaminase',
#   'pegADA',
#   'Pegademase',
#   'Pegademase bovine',
#   'Pegademase'],
#  'Albumin human': ['Albumin (human)',
#   'Albumin human',
#   'Albumin, blood',
#   'Albumin, human',
#   'Albumin, human-kjda',
#   'Human albumin',
#   'Human serum albumin',
#   'Serum albumin',
#   'Albumin human'],
#  'Eptifibatide': ['Eptifibatida',
#   'Eptifibatide',
#   'Integrelin',
#   'Intrifiban',
#   'Eptifibatide'],
#  'Infliximab': ['Infliximab (genetical recombination)',
#   'Infliximab-abda',
#   'Infliximab-axxq',
#   'Infliximab-dyyb',
#   'Infliximab-qbtx',
#   'Infliximab'],
#  'Follitropin': ['Folitropina alfa',
#   'Folitropina beta',
#   'Folitropina delta',
#   'Follicle stimulating hormone',
#   'Follitrophin alfa',
#   'Follitrophin alpha',
#   'Follitrophin beta',
#   'Follitropin alfa',
#   'Follitropin alfa/beta',
#   'Follitropin alpha',
#   'Follitropin beta',
#   'Follitropin delta',
#   'Follitropin gamma',
#   'Follotropin recombinant',
#   'FSH',
#   'FSH alpha',
#   'FSH-a',
#   'FSH-b',
#   'FSH-beta',
#   'Recombinant human follicle stimulating hormone beta',
#   'Recombinant human follicle-stimulating hormone (r-HFSH)',
#   'rFSH-alpha',
#   'Follitropin'],
#  'Vasopressin': ['Vasopressin, unspecified', 'Vasopressina', 'Vasopressin'],
#  'Interferon beta-1b': ['Interferon beta 1b (recombinant)',
#   'Interferon beta-1b,recombinant',
#   'Interferon-beta-1b',
#   'Recombinant interferon beta-1b',
#   'Interferon beta-1b'],
#  'Interferon alfacon-1': ['IFN Alfacon-1',
#   'IFN-Con1',
#   'Interferon alfacon-1',
#   'Interferon alfacon-1'],
#  'Hyaluronidase (ovine)': ['Hyaluronidase (glycoprotein, sheep testis isoenzyme)',
#   'Hyaluronidase (ovine)',
#   'Hyaluronidase (sheep testis isoenzyme)',
#   'Hyaluronidase, ovine',
#   'Ovine hyaluronidase',
#   'Hyaluronidase (ovine)'],
#  'Insulin pork': ['Insulin (pork)',
#   'Insulin porcine',
#   'Insulin purified porcine',
#   'Insulin purified pork',
#   'Insulin, porcine',
#   'Insulin, regular, pork',
#   'Porcine insulin',
#   'Insulin pork'],
#  'Trastuzumab': ['RHUMAB HER2',
#   'trastuzumab-anns',
#   'trastuzumab-dkst',
#   'trastuzumab-dttb',
#   'trastuzumab-pkrb',
#   'trastuzumab-qyyp',
#   'Trastuzumab'],
#  'Rituximab': ['rituximab-abbs', 'rituximab-pvvr', 'Rituximab'],
#  'Basiliximab': ['Basiliximab', 'Basiliximab'],
#  'Muromonab': ['Anti-CD3', 'Muromonab-CD3', 'Muromonab'],
#  'Digoxin Immune Fab (Ovine)': ['Digitalis antitoxin',
#   'Digoxin Immune Fab, Ovine',
#   'Digoxin-specific Antibody Fragments',
#   'Ovine digoxin immune fab',
#   'Digoxin Immune Fab (Ovine)'],
#  'Ibritumomab tiuxetan': ['Ibritumomab',
#   'mAb Murine (IGG1) Anti P19437 (CD20_MOUSE)',
#   'Ibritumomab tiuxetan'],
#  'Daptomycin': ['Daptomicina',
#   'Daptomycin',
#   'Daptomycine',
#   'Daptomycinum',
#   'Daptomycin'],
#  'Tositumomab': ['Tositumomab'],
#  'Pegvisomant': ['Pegvisomant'],
#  'Botulinum toxin type A': ['AbobotulinumtoxinA',
#   'Botulinum A neurotoxin',
#   'Botulinum toxin A',
#   'Botulinum toxin type A',
#   'BTX-A',
#   'Evabotulinumtoxina',
#   'IncobotulinumtoxinA',
#   'OnabotulinumtoxinA',
#   'Prabotulinumtoxin A',
#   'Toxina botulÃ\xadnica A',
#   'Toxine botulinique A',
#   'Botulinum toxin type A'],
#  'Pancrelipase': ['Pancrealipase',
#   'Pancreatic extract pancrelipase',
#   'Pancreatic protease',
#   'Pancreatin',
#   'Pancreatinum',
#   'Pancrelipase (amylase;lipase;protease)',
#   'Pancrelipase'],
#  'Streptokinase': ['Estreptoquinasa',
#   'Streptochinasi',
#   'Streptococcal fibrinolysin',
#   'Streptokinase',
#   'Streptokinasum',
#   'Streptokinase'],
#  'Alemtuzumab': ['Alemtuzumab'],
#  'Alglucerase': ['Alglucerase'],
#  'Capromab pendetide': ['(111In)-Capromab pendetide',
#   'Indium (111In) capromab pendetide',
#   'Indium 111 Capromab Pendetide',
#   'Indium In 111 capromab pendetide',
#   'Capromab pendetide'],
#  'Laronidase': ['alpha-L-Idosiduronase',
#   'Human Recombinant alpha-L-iduronidase',
#   'Laronidasa',
#   'Laronidase',
#   'Laronidase (genetical recombination)',
#   'Laronidase'],
#  'Cyclosporine': ['Ciclosporin',
#   'Ciclosporina',
#   'Ciclosporine',
#   'Ciclosporinum',
#   'CsA',
#   'CyA',
#   'Cyclosporin',
#   'Cyclosporin A',
#   'Cyclosporine',
#   'Cyclosporine'],
#  'Alefacept': ['Alefacept'],
#  'Felypressin': ['2-(L-phenylalanine)-8-L-lysinevasopressin',
#   'Felipresina',
#   'Felypressin',
#   'Felypressine',
#   'Felypressinum',
#   'PLV-2',
#   'Felypressin'],
#  'Urofollitropin': ['Follitropin human', 'Urofollitrophin', 'Urofollitropin'],
#  'Efalizumab': ['anti-CD11a', 'antiCD11 alpha', 'Efalizumab', 'Efalizumab'],
#  'Choriogonadotropin alfa': ['Choriogonadotropin alpha',
#   'Chorionic gonadotropin (recombinant)',
#   'Choriogonadotropin alfa'],
#  'Antithymocyte immunoglobulin (rabbit)': ['Anti-human thymocyte immunoglobulin, rabbit',
#   'Anti-T-lymphocyte immune globulin, rabbit',
#   'Anti-thymocyte globulin (rabbit)',
#   'Anti-thymocyte globulin rabbit',
#   'Antithymocyte immunoglobulin',
#   'Lapine T-lymphocyte immune globulin',
#   'Rabbit anti-human thymocyte globulin',
#   'Rabbit anti-human thymocyte globulin (rATG)',
#   'Rabbit anti-human thymocyte immunoglobulin',
#   'Rabbit anti-thymocyte immunoglobulin',
#   'Rabbit antithymocyte globulin',
#   'Rabbit ATG',
#   'rATG',
#   'Thymoglobulin',
#   'Thymoglobuline',
#   'Antithymocyte immunoglobulin (rabbit)'],
#  'Filgrastim': ['Filgrastim-aafi',
#   'Filgrastim-sndz',
#   'G-CSF ',
#   'Granulocyte Colony Stimulating Factor ',
#   'Tbo-filgrastim',
#   'Filgrastim'],
#  'Coagulation Factor IX (Recombinant)': ['Coagulation factor IX (recombinant)',
#   'Coagulation factor IX recombinant human',
#   'Factor IX (Recombinant)',
#   'nonacog alfa',
#   'nonacog gamma',
#   'Recombinant factor IX',
#   'Coagulation Factor IX (Recombinant)'],
#  'Becaplermin': ['Becaplermin',
#   'PDGF-2',
#   'PDGF-BB',
#   'PDGFB',
#   'Platelet-derived growth factor BB, recombinant',
#   'Platelet-derived growth factor beta polypeptide',
#   'Recombinant platelet-derived growth factor BB',
#   'rhPDGF-BB',
#   'rPDGF-BB',
#   'SH-POLYPEPTIDE-59',
#   'Becaplermin'],
#  'Agalsidase beta': ['Agalsidasa alfa',
#   'Agalsidasa beta',
#   'Agalsidase alfa',
#   'Alpha-galactosidase A',
#   'Agalsidase beta'],
#  'Octreotide': ['Octreotida',
#   'Octreotide',
#   'Octreotidum',
#   'Octrotide',
#   'Octreotide'],
#  'Interferon alfa-2b': ['Interferon alfa-2b',
#   'Interferon alfa-2b, recombinant',
#   'Interferon alpha-2B',
#   'Interferon Î±-2b',
#   'Intron (Interferon Î±2b)',
#   'Intron A',
#   'Intron A (Interferon Î±2b)',
#   'r-INF-alpha',
#   'rIFN-alpha-2b',
#   'Interferon alfa-2b'],
#  'Abarelix': ['Abarelix', 'Abarelix'],
#  'Oxytocin': ['Oxitocina', 'Oxytocin', 'Oxytocin'],
#  'Natalizumab': ['Anti-alpha4 integrin', 'Anti-VLA4', 'Natalizumab'],
#  'Enfuvirtide': ['Enfuvirtida', 'Enfuvirtide'],
#  'Palivizumab': ['Palivizumab', 'Palivizumab'],
#  'Daclizumab': ['Dacliximab', 'Daclizumab beta', 'Daclizumab'],
#  'Bevacizumab': ['Anti-VEGF Humanized Monoclonal Antibody',
#   'Anti-VEGF monoclonal antibody',
#   'Bevacizumab',
#   'bevacizumab-awwb',
#   'rhuMAb-VEGF',
#   'Bevacizumab'],
#  'Technetium Tc-99m arcitumomab': ['Arcitumomab technetium-99m',
#   'Technetium (99mTc) arcitumomab',
#   'Technetium Tc 99m arcitumomab',
#   'Technetium-99m arcitumomab',
#   'Technetium Tc-99m arcitumomab'],
#  'Pyridoxal phosphate': ['3-hydroxy-2-methyl-5-((phosphonooxy)methyl)-4-pyridinecarboxaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde 5-phosphate',
#   'Codecarboxylase',
#   'PLP',
#   'Pyridoxal 5-monophosphoric acid ester',
#   'Pyridoxal 5-phosphate',
#   "Pyridoxal 5'-phosphate",
#   'Pyridoxal P',
#   'Pyridoxal phosphate anhydrous',
#   'Pyridoxal-5P',
#   'Pyridoxal-P',
#   'Pyridoxal phosphate'],
#  'Cyanocobalamin': ['Cianocobalamina',
#   'Cyanocob(III)alamin',
#   'Cyanocobalamin',
#   'Cyanocobalamine',
#   'Cyanocobalaminum',
#   'Vitamin B12',
#   'Vitamin B12 complex',
#   'Vitamin B12 NOS',
#   'Cyanocobalamin'],
#  'Tetrahydrofolic acid': ['5,6,7,8-tetrahydrofolate',
#   '5,6,7,8-tetrahydrofolic acid',
#   'Tetrahydrofolate',
#   'Tetrahydrofolic acid'],
#  'Histidine': ['(S)-4-(2-Amino-2-carboxyethyl)imidazole',
#   '(S)-a-Amino-1H-imidazole-4-propanoic acid',
#   '(S)-alpha-amino-1H-Imidazole-4-propanoic acid',
#   '(S)-alpha-Amino-1H-imidazole-4-propionic acid',
#   '(S)-Î±-amino-1H-Imidazole-4-propanoic acid',
#   'HIS',
#   'Histidina',
#   'Histidine',
#   'L-(â\x88\x92)-histidine',
#   'L-Histidin',
#   'L-Histidine',
#   'Histidine'],
#  'Ademetionine': ['Ademetionine',
#   'AdoMet',
#   'L-S-Adenosylmethionine',
#   'S-Adenosylmethionine',
#   'SAM',
#   'SAM-e',
#   'SAMe',
#   'Ademetionine'],
#  'Pyruvic acid': ['2-ketopropionic acid',
#   '2-oxopropanoic acid',
#   '2-OxopropansÃ¤ure',
#   '2-OxopropionsÃ¤ure',
#   'a-Ketopropionic acid',
#   'Acetylformic acid',
#   'acide pyruvique',
#   'alpha-ketopropionic acid',
#   'BrenztraubensÃ¤ure',
#   'BTS',
#   'Pyroracemic acid',
#   'Î±-ketopropionic acid',
#   'Î±-OxopropionsÃ¤ure',
#   'Pyruvic acid'],
#  'Phenylalanine': ['(S)-2-Amino-3-phenylpropionic acid',
#   '(S)-alpha-Amino-beta-phenylpropionic acid',
#   '3-phenyl-L-alanine',
#   'beta-Phenyl-L-alanine',
#   'F',
#   'Fenilalanina',
#   'L-Phenylalanine',
#   'Phe',
#   'Phenylalanine',
#   'Phenylalaninum',
#   'Î²-phenyl-L-alanine',
#   'Phenylalanine'],
#  'Biotin': ['(+)-cis-Hexahydro-2-oxo-1H-thieno[3,4]imidazole-4-valeric acid',
#   '(3aS,4S,6aR)-Hexahydro-2-oxo-1H-thieno[3,4-d]imidazole-4-valeric acid',
#   '5-(2-oxohexahydro-1H-thieno[3,4-d]imidazol-4-yl)pentanoic acid',
#   'Biotin',
#   'Biotina',
#   'Biotine',
#   'Biotinum',
#   'cis-(+)-Tetrahydro-2-oxothieno[3,4]imidazoline-4-valeric acid',
#   'cis-Hexahydro-2-oxo-1H-thieno(3,4)imidazole-4-valeric acid',
#   'cis-Tetrahydro-2-oxothieno(3,4-d)imidazoline-4-valeric acid',
#   'Coenzyme R',
#   'D-(+)-biotin',
#   'D-Biotin',
#   'Vitamin B7',
#   'Vitamin H',
#   'Biotin'],
#  'Choline': ['Bilineurine',
#   'Choline ion',
#   'N-trimethylethanolamine',
#   'N,N,N-trimethylethanol-ammonium',
#   'trimethylethanolamine',
#   'Vitamin J',
#   'Choline'],
#  'L-Lysine': ['(S)-2,6-diaminohexanoic acid',
#   '(S)-lysine',
#   '(S)-Î±,Îµ-diaminocaproic acid',
#   '6-ammonio-L-norleucine',
#   'L-2,6-Diaminocaproic acid',
#   'L-lys',
#   'L-Lysin',
#   'LYS',
#   'Lysina',
#   'Lysine',
#   'Lysine acid',
#   'Lysinum',
#   'L-Lysine'],
#  'Arginine': ['(2S)-2-amino-5-(carbamimidamido)pentanoic acid',
#   '(2S)-2-amino-5-guanidinopentanoic acid',
#   '(S)-2-amino-5-guanidinopentanoic acid',
#   '(S)-2-Amino-5-guanidinovaleric acid',
#   'Arg',
#   'Arginina',
#   'Arginine',
#   'L-(+)-Arginine',
#   'L-Arg',
#   'L-Arginin',
#   'L-arginine',
#   'R',
#   'Arginine'],
#  'Ascorbic acid': ['acide ascorbique',
#   'Ã¡cido ascÃ³rbico',
#   'Acidum ascorbicum',
#   'acidum ascorbinicum',
#   'Ascorbate',
#   'Ascorbic acid',
#   'AscorbinsÃ¤ure',
#   'L-(+)-ascorbic acid',
#   'L-Ascorbate',
#   'L-Ascorbic Acid',
#   'Vitamin C',
#   'Vitamina C',
#   'Ascorbic acid'],
#  'Spermine': ['4,9-diaza-1,12-dodecanediamine',
#   '4,9-diazadodecane-1,12-diamine',
#   'Musculamine',
#   "N,N'-Bis(3-aminopropyl)-1,4-butanediamine",
#   'Spermina',
#   'Spermine',
#   'Spermine'],
#  'Aspartic acid': ['(S)-2-aminobutanedioic acid',
#   '(S)-2-aminosuccinic acid',
#   '2-Aminosuccinic acid',
#   'Ã¡cido aspÃ¡rtico',
#   'Acidum asparticum',
#   'Asp',
#   'Aspartic acid',
#   'D',
#   'L-Asp',
#   'L-AsparaginsÃ¤ure',
#   'L-Aspartate',
#   'L-Aspartic acid',
#   'Aspartic acid'],
#  'Ornithine': ['(S)-2,5-Diaminopentanoate',
#   '(S)-2,5-Diaminopentanoic acid',
#   '(S)-2,5-diaminovaleric acid',
#   '(S)-ornithine',
#   '(S)-Î±,Î´-diaminovaleric acid',
#   'L-Ornithine',
#   'levo-ornithine',
#   'Ornithine',
#   'Ornithinum',
#   'Ornitina',
#   'Ornithine'],
#  'L-Glutamine': ['(2S)-2-amino-4-carbamoylbutanoic acid',
#   '(2S)-2,5-diamino-5-oxopentanoic acid',
#   '(S)-2,5-diamino-5-oxopentanoic acid',
#   'Glutamic acid 5-amide',
#   'Glutamic acid amide',
#   'Glutamina',
#   'Glutamine',
#   'L-(+)-glutamine',
#   'L-2-aminoglutaramic acid',
#   'L-glutamic acid Î³-amide',
#   'L-Glutamin',
#   'L-GlutaminsÃ¤ure-5-amid',
#   'Levoglutamide',
#   'Q',
#   'L-Glutamine'],
#  'Adenosine phosphate': ["5'-Adenosine monophosphate",
#   "5'-Adenylic acid",
#   "5'-AMP",
#   "5'-O-Phosphonoadenosine",
#   "Adenosine 5'-(dihydrogen phosphate)",
#   "Adenosine 5'-monophosphate",
#   "Adenosine 5'-phosphate",
#   'Adenosine monophosphate',
#   'Adenosine phosphate',
#   "Adenosine-5'-Monophosphate",
#   "Adenosine-5'-monophosphoric acid",
#   "Adenosine-5'P",
#   'Adenosini phosphas',
#   'Adenylate',
#   'Adenylic acid',
#   "Ado5'P",
#   'AMP',
#   'Fosfato de adenosina',
#   'PAdo',
#   "Phosphate d'adÃ©nosine",
#   'Adenosine phosphate'],
#  'alpha-Linolenic acid': ['(9,12,15)-linolenic acid',
#   '(9Z,12Z,15Z)-Octadecatrienoic acid',
#   '(Z,Z,Z)-9,12,15-octadecatrienoic acid',
#   '9-cis,12-cis,15-cis-octadecatrienoic acid',
#   '9,12,15-Octadecatrienoic acid',
#   'ALA',
#   'all-cis-9,12,15-Octadecatrienoic acid',
#   'alpha-Linolenic acid',
#   'cis-delta(9,12,15)-Octadecatrienoic acid',
#   'cis,cis,cis-9,12,15-Octadecatrienoic acid',
#   'Linolenic acid',
#   'Î±-linolenic acid',
#   'alpha-Linolenic acid'],
#  'Serine': ['(S)-2-Amino-3-hydroxypropanoic acid',
#   '(S)-Serine',
#   'alpha-Amino-beta-hydroxypropionic acid',
#   'beta-Hydroxyalanine',
#   'L-Serine',
#   'Ser',
#   'Serina',
#   'Serine',
#   'Serinum',
#   'Serine'],
#  'Methionine': ['(2S)-2-amino-4-(methylsulfanyl)butanoic acid',
#   '(S)-2-amino-4-(methylthio)butanoic acid',
#   '(S)-2-amino-4-(methylthio)butyric acid',
#   '(S)-methionine',
#   'L-(â\x88\x92)-methionine',
#   'L-a-Amino-g-methylthiobutyric acid',
#   'L-Methionin',
#   'L-Methionine',
#   'L-Î±-amino-Î³-methylmercaptobutyric acid',
#   'M',
#   'Met',
#   'Methionine',
#   'Methionine'],
#  'Tyrosine': ['(â\x88\x92)-Î±-amino-p-hydroxyhydrocinnamic acid',
#   '(2S)-2-amino-3-(4-hydroxyphenyl)propanoic acid',
#   '(S)-(-)-Tyrosine',
#   '(S)-2-Amino-3-(p-hydroxyphenyl)propionic acid',
#   '(S)-3-(p-Hydroxyphenyl)alanine',
#   '(S)-alpha-amino-4-Hydroxybenzenepropanoic acid',
#   '(S)-Tyrosine',
#   '(S)-Î±-amino-4-hydroxybenzenepropanoic acid',
#   '4-hydroxy-L-phenylalanine',
#   'L-Tyrosin',
#   'L-tyrosine',
#   'Tirosina',
#   'Tyr',
#   'Tyrosine',
#   'Tyrosinum',
#   'Y',
#   'Tyrosine'],
#  'Calcitriol': ['(1S,3R,5Z,7E)-9,10-secocholesta-5,7,10-triene-1,3,25-triol',
#   '(1Î±,3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol',
#   '(5Z,7E)-(1S,3R)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol',
#   '1-alpha-25-Dihydroxyvitamin D3',
#   '1,25-DHCC',
#   '1,25-dihydroxycholecalciferol',
#   '1Î±,25-dihydroxycholecalciferol',
#   '1Î±,25-dihydroxyvitamin D3',
#   '1Î±,25(OH)2D3',
#   'Calcitriol',
#   'Calcitriolum',
#   'Calcitriol'],
#  'Lutein': ['Xanthophyll', 'Xantofyl', 'Lutein'],
#  'Cystine': ["(R,R)-3,3'-dithiobis(2-aminopropanoic acid)",
#   'Cistina',
#   'L-alpha-Diamino-beta-dithiolactic acid',
#   'L-Cystine',
#   'L-Dicysteine',
#   "Î²,Î²'-dithiodialanine",
#   'Cystine'],
#  'Succinic acid': ['1,2-ethanedicarboxylic acid',
#   'Acide butanedioÃ¯que',
#   'Acide succinique',
#   'Acidum succinicum',
#   'Amber acid',
#   'Asuccin',
#   'BernsteinsÃ¤ure',
#   'ButandisÃ¤ure',
#   'Butanedioic acid',
#   'Butanedionic acid',
#   'Dihydrofumaric acid',
#   'Ethylenesuccinic acid',
#   'Spirit of amber',
#   'Succinic acid',
#   'Succinic acid'],
#  'Riboflavin': ['1-Deoxy-1-(7,8-dimethyl-2,4-dioxo-3,4-dihydrobenzo[g]pteridin-10(2H)-yl)pentitol',
#   '6,7-Dimethyl-9-D-ribitylisoalloxazine',
#   '7,8-Dimethyl-10-(D-ribo-2,3,4,5-tetrahydroxypentyl)isoalloxazine',
#   '7,8-Dimethyl-10-ribitylisoalloxazine',
#   'Lactoflavin',
#   'Lactoflavine',
#   'Riboflavin',
#   'Riboflavina',
#   'Riboflavine',
#   'Riboflavinum',
#   'Vitamin B2',
#   'Vitamin Bi',
#   'Vitamin G',
#   'Riboflavin'],
#  'N-Acetylglucosamine': ['2-Acetamido-2-deoxy-D-glucose',
#   'aldehydo-N-acetyl-D-glucosamine',
#   'D-GlcNAc',
#   'N-Acetyl-D-glucosamine',
#   'N-Acetylchitosamine',
#   'N-Acetylglucosamine'],
#  'Glutamic acid': ['(2S)-2-Aminopentanedioic acid',
#   '(S)-2-Aminopentanedioic acid',
#   '(S)-Glutamic acid',
#   'Ã¡cido glutÃ¡mico',
#   'Glu',
#   'Glutamic acid',
#   'L-Glutamate',
#   'L-Glutamic acid',
#   'L-Glutaminic acid',
#   'Glutamic acid'],
#  'Glutathione': ['5-L-Glutamyl-L-cysteinylglycine',
#   'gamma-L-Glutamyl-L-cysteinyl-glycine',
#   'Glutathione',
#   'Glutathione-SH',
#   'GSH',
#   'N-(N-gamma-L-Glutamyl-L-cysteinyl)glycine',
#   'Reduced glutathione',
#   'Glutathione'],
#  'Phosphatidyl serine': ['Phosphatidyl-L-serine',
#   'Phosphatidylserine',
#   'PS',
#   'Ptd-L-Ser',
#   'Phosphatidyl serine'],
#  'Glycine': ['Aminoacetic acid',
#   'AminoessigsÃ¤ure',
#   'Aminoethanoic acid',
#   'Glicina',
#   'Gly',
#   'Glycin',
#   'Glycine',
#   'Glycocoll',
#   'Glykokoll',
#   'Glyzin',
#   'Leimzucker',
#   'Glycine'],
#  'Calcifediol': ['(3S,5Z,7E)-9,10-secocholesta-5,7,10-triene-3,25-diol',
#   '(3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol',
#   '(5Z,7E)-(3S)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol',
#   '25-hydroxycholecalciferol',
#   '25-Hydroxyvitamin D3',
#   'Calcidiol',
#   'CalcifÃ©diol',
#   'Calcifediol',
#   'Calcifediol anhydrous',
#   'Calcifediolum',
#   'Calcifediol'],
#  'Pyridoxal': ['2-methyl-3-hydroxy-4-formyl-5-hydroxymethylpyridine',
#   '3-hydroxy-5-(hydroxymethyl)-2-methyl-4-pyridinecarboxaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylpyridine-4-carboxaldehyde',
#   'Piridoxal',
#   'Pyridoxaldehyde',
#   'Pyridoxal'],
#  'Creatine': ['((amino(Imino)methyl)(methyl)amino)acetic acid',
#   '(alpha-Methylguanido)acetic acid',
#   '(N-methylcarbamimidamido)acetic acid',
#   '(Î±-methylguanido)acetic acid',
#   'alpha-Methylguanidino acetic acid',
#   'Creatin',
#   'Creatine',
#   'Kreatin',
#   'Methylglycocyamine',
#   'N-(aminoiminomethyl)-N-methylglycine',
#   'N-amidinosarcosine',
#   'N-carbamimidoyl-N-methylglycine',
#   'N-methyl-N-guanylglycine',
#   'Creatine'],
#  'Leucine': ['(2S)-2-Amino-4-methylpentanoic acid',
#   '(2S)-alpha-2-Amino-4-methylvaleric acid',
#   '(2S)-alpha-Leucine',
#   '(S)-(+)-Leucine',
#   '(S)-Leucine',
#   '2-Amino-4-methylvaleric acid',
#   'L',
#   'L-Leucin',
#   'L-Leucine',
#   'L-Leuzin',
#   'Leu',
#   'Leucine',
#   'Leucine'],
#  'Tryptophan': ['(2S)-2-amino-3-(1H-indol-3-yl)propanoic acid',
#   '(S)-alpha-Amino-beta-(3-indolyl)-propionic acid',
#   '(S)-Tryptophan',
#   '(S)-Î±-amino-1H-indole-3-propanoic acid',
#   'L-(-)-Tryptophan',
#   'L-(â\x88\x92)-tryptophan',
#   'L-Tryptophan',
#   'L-Î²-3-indolylalanine',
#   'Triptofano',
#   'Trp',
#   'Tryptophan',
#   'Tryptophane',
#   'Tryptophanum',
#   'W',
#   'Tryptophan'],
#  'Cysteine': ['(2R)-2-amino-3-mercaptopropanoic acid',
#   '(2R)-2-amino-3-sulfanylpropanoic acid',
#   '(R)-2-Amino-3-mercaptopropanoic acid',
#   'Cisteina',
#   'Cisteinum',
#   'Cys',
#   'Cysteine',
#   'Cysteinum',
#   'Free Cysteine',
#   'L-2-Amino-3-mercaptopropionic acid',
#   'L-Cys',
#   'L-Cystein',
#   'L-Zystein',
#   'Cysteine'],
#  'Thiamine': ['Aneurin',
#   'Antiberiberi factor',
#   'Thiamin',
#   'Thiamine',
#   'thiamine(1+)',
#   'thiamine(1+) ion',
#   'thiaminium',
#   'Thiaminum',
#   'Tiamina',
#   'Vitamin B1',
#   'Thiamine'],
#  'Ergocalciferol': ['(3Î²,5Z,7E,22E)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol',
#   '(5Z,7E,22E)-(3S)-9,10-seco-5,7,10(19),22-ergostatetraen-3-ol',
#   '(5Z,7E,22E)-(3S)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol',
#   'Activated ergosterol',
#   'Ercalciol',
#   'ErgocalcifÃ©rol',
#   'Ergocalciferol',
#   'Ergocalciferolum',
#   'Oleovitamin D2',
#   'Viosterol',
#   'Vitamin D2',
#   'Vitamina D2',
#   'Ergocalciferol'],
#  'Dihomo-gamma-linolenic acid': ['(8Z,11Z,14Z)-Icosatrienoic acid',
#   '(Z,Z,Z)-8,11,14-Eicosatrienoic acid',
#   '(Z,Z,Z)-8,11,14-Icosatrienoate',
#   '(Z,Z,Z)-8,11,14-Icosatrienoic acid',
#   '20:3, n-6,9,12 all-cis',
#   '8,11,14-Eicosatrienoic Acid',
#   '8c,11c,14c-eicosatrienoic acid',
#   '8c,11c,14c-EicosatriensÃ¤ure',
#   'all-cis-8,11,14-eicosatrienoic acid',
#   'all-cis-8,11,14-icosatrienoic acid',
#   'all-cis-eicosa-8,11,14-trienoic acid',
#   'all-cis-Eicosa-8,11,14-triensÃ¤ure',
#   'all-cis-icosa-8,11,14-trienoic acid',
#   'C20:3, n-6,9,12 all-cis',
#   'cis,cis,cis-8,11,14-eicosatrienoic acid',
#   'DGLA',
#   'dihomo-Î³-linolenic acid',
#   'eicosa-8Z,11Z,14Z-trienoic acid',
#   'gamma-Homolinolenic acid',
#   'Homo-gamma-linolenic acid',
#   'Homo-gamma-linolensÃ¤ure',
#   'Homo-Î³-linolensÃ¤ure',
#   'Dihomo-gamma-linolenic acid'],
#  'Citrulline': ['(S)-2-Amino-5-ureidopentanoic acid',
#   '2-Amino-5-ureidovaleric acid',
#   'alpha-amino-delta-Ureidovaleric acid',
#   'Cit',
#   'Citrulina',
#   'Citrulline',
#   'delta-Ureidonorvaline',
#   'L-2-Amino-5-ureidovaleric acid',
#   'L-Citrulline',
#   'N(5)-(Aminocarbonyl)-L-ornithine',
#   'N(delta)-Carbamylornithine',
#   'N5-(Aminocarbonyl)ornithine',
#   'N5-Carbamoyl-L-ornithine',
#   'N5-carbamoylornithine',
#   'Î±-amino-Î´-ureidovaleric acid',
#   'Î´-ureidonorvaline',
#   'Citrulline'],
#  'Threonine': ['(2S,3R)-(-)-Threonine',
#   '(2S)-threonine',
#   '2-Amino-3-hydroxybutyric acid',
#   'L-(-)-Threonine',
#   'L-2-Amino-3-hydroxybutyric acid',
#   'L-alpha-amino-beta-hydroxybutyric acid',
#   'L-Threonin',
#   'L-Threonine',
#   'L-Î±-amino-Î²-hydroxybutyric acid',
#   'Thr',
#   'Threonine',
#   'Threoninum',
#   'Treonina',
#   'Threonine'],
#  'NADH': ['1,4-dihydronicotinamide adenine dinucleotide',
#   'DPNH',
#   'NAD reduced form',
#   'Nicotinamide adenine dinucleotide (reduced)',
#   'Nicotinamide-adenine dinucleotide, reduced',
#   'Reduced nicotinamide adenine diphosphate',
#   'Reduced nicotinamide-adenine dinucleotide',
#   'NADH'],
#  'Folic acid': ['Acide folique',
#   'Ã¡cido fÃ³lico',
#   'Acidum folicum',
#   'Folacin',
#   'Folate',
#   'Folic acid',
#   'FolsÃ¤ure',
#   'N-[(4-{[(2-amino-4-oxo-1,4-dihydropteridin-6-yl)methyl]amino}phenyl)carbonyl]-L-glutamic acid',
#   'N-pteroyl-L-glutamic acid',
#   'PGA',
#   'PteGlu',
#   'Pteroyl-L-glutamate',
#   'Pteroyl-L-glutamic acid',
#   'Pteroyl-L-monoglutamic acid',
#   'Pteroylglutamic acid',
#   'Vitamin B9',
#   'Vitamin Bc',
#   'Vitamin M',
#   'Folic acid'],
#  'Icosapent': ['(5Z,8Z,11Z,14Z,17Z)-5,8,11,14,17-eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoate',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Icosapentaenoic acid',
#   '(all-Z)-5,8,11,14,17-eicosapentaenoic acid',
#   '5,8,11,14,17-eicosapentaenoic acid',
#   '5,8,11,14,17-Icosapentaenoic acid',
#   'all-cis-5,8,11,14,17-eicosapentaenoic acid',
#   'all-cis-5,8,11,14,17-icosapentaenoic acid',
#   'all-cis-icosa-5,8,11,14,17-pentaenoic acid',
#   'cis-5,8,11,14,17-eicosapentaenoic acid',
#   'cis-5,8,11,14,17-EPA',
#   'cis-delta(5,8,11,14,17)-Eicosapentaenoic acid',
#   'Eicosapentaenoic acid',
#   'EPA',
#   'Icosapent',
#   'Icosapentaenoic acid',
#   'Icosapento',
#   'Icosapentum',
#   'Timnodonic acid',
#   'Icosapent'],
#  'Alanine': ['(2S)-2-aminopropanoic acid',
#   '(S)-2-aminopropanoic acid',
#   '(S)-alanine',
#   'Alanina',
#   'Alanine',
#   'Alaninum',
#   'L-2-Aminopropionic acid',
#   'L-Alanin',
#   'L-alanine',
#   'L-alpha-Alanine',
#   'L-Î±-alanine',
#   'Alanine'],
#  'Valine': ['(2S)-2-Amino-3-methylbutanoic acid',
#   '(S)-Valine',
#   '2-Amino-3-methylbutyric acid',
#   'L-(+)-alpha-Aminoisovaleric acid',
#   'L-alpha-Amino-beta-methylbutyric acid',
#   'L-valin',
#   'L-valine',
#   'Val',
#   'Valine',
#   'Valine'],
#  'Vitamin A': ['(2E,4E,6E,8E)-3,7-dimethyl-9-(2,6,6-trimethylcyclohex-1-en-1-yl)nona-2,4,6,8-tetraen-1-ol',
#   'all-trans-retinol',
#   'all-trans-retinyl alcohol',
#   'all-trans-vitamin A alcohol',
#   'Retinol',
#   'Retinolum',
#   'Vitamin A1',
#   'Vitamin A'],
#  'Vitamin E': ['(+)-Î±-tocopherol',
#   "(2R,4'R,8'R)-Î±-tocopherol",
#   '(2R)-2,5,7,8-TETRAMETHYL-2-[(4R,8R)-4,8,12-TRIMETHYLTRIDECYL]CHROMAN-6-OL',
#   '(R,R,R)-Î±-tocopherol',
#   '5,7,8-trimethyltocol',
#   'alpha-tocopherol',
#   'd-Î±-tocopherol',
#   'Vitamin E'],
#  'Pyridoxine': ['2-methyl-3-hydroxy-4,5-dihydroxymethylpyridine',
#   '3-hydroxy-4,5-bis(hydroxymethyl)-2-methylpyridine',
#   '3-hydroxy-4,5-dimethylol-Î±-picoline',
#   '5-hydroxy-6-methyl-3,4-pyridinedimethanol',
#   'Piridoxina',
#   'Pyridoxine',
#   'Pyridoxinum',
#   'Pyridoxol',
#   'Vitamin B6',
#   'Pyridoxine'],
#  'Lipoic acid': ['(+)-alpha-Lipoic acid',
#   '(R)-(+)-Lipoate',
#   '(R)-(+)-lipoic acid',
#   '(R)-1,2-Dithiolane-3-pentanoic acid',
#   '(R)-1,2-dithiolane-3-valeric acid',
#   '(R)-6,8-thioctic acid',
#   '(R)-lipoic acid',
#   'Alpha lipoic acid',
#   'alpha-Lipoic acid',
#   'alpha-LiponsÃ¤ure',
#   'D-thioctic acid',
#   'Lipoic acid',
#   'R-(+)-thioctic acid',
#   'R-alpha-lipoic acid',
#   'Thioctic acid',
#   'Thioctic acid D-form',
#   'Î±-lipoic acid',
#   'Lipoic acid'],
#  'Isoleucine': ['(2S,3S)-2-Amino-3-methylpentanoic acid',
#   '2-Amino-3-methylvaleric acid',
#   'alpha-amino-beta-methylvaleric acid',
#   'Ile',
#   'Isoleucina',
#   'Isoleucine',
#   'Isoleucinum',
#   'L-Isoleucine',
#   'Î±-amino-Î²-methylvaleric acid',
#   'Isoleucine'],
#  'Aspartame': ['1-Methyl N-L-alpha-aspartyl-L-phenylalanate',
#   '1-methyl N-L-Î±-aspartyl-L-phenylalanate',
#   '3-Amino-N-(alpha-carboxyphenethyl)succinamic acid N-methyl ester',
#   '3-Amino-N-(alpha-methoxycarbonylphenethyl) succinamic acid',
#   '3-Amino-N-(Î±-carboxyphenethyl)succinamic acid N-methyl ester',
#   '3-Amino-N-(Î±-methoxycarbonylphenethyl) succinamic acid',
#   'Asp-phe-ome',
#   'Aspartam',
#   'Aspartame',
#   'Aspartamo',
#   'Aspartamum',
#   'Aspartylphenylalanine methyl ester',
#   'L-Aspartyl-L-phenylalanine methyl ester',
#   'Aspartame'],
#  'Cholecalciferol': ['(+)-vitamin D3',
#   '(3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-trien-3-ol',
#   '(5Z,7E)-(3S)-9,10-secocholesta-5,7,10(19)-trien-3-ol',
#   'Activated 7-dehydrocholesterol',
#   'Calciol',
#   'CC',
#   'Cholecalciferol',
#   'Cholecalciferolum',
#   'Colecalciferol',
#   'Colecalciferolum',
#   'Oleovitamin D3',
#   'Vitamin D-3',
#   'Vitamin D3',
#   'Cholecalciferol'],
#  'Menadione': ['2-Methyl-1,4-Naphthalenedione',
#   '2-Methyl-1,4-naphthochinon',
#   '2-Methyl-1,4-naphthoquinone',
#   'Vitamin K 3',
#   'Vitamin K3',
#   'Menadione'],
#  'ATP': ["Adenosine 5'-triphosphate",
#   'Adenosine triphosphate',
#   "Adenosine-5'-triphosphate",
#   'ATP',
#   'ATP'],
#  'Proline': ['(-)-2-Pyrrolidinecarboxylic acid',
#   '(â\x88\x92)-(S)-proline',
#   '(â\x88\x92)-2-pyrrolidinecarboxylic acid',
#   '(â\x88\x92)-proline',
#   '(2S)-pyrrolidine-2-carboxylic acid',
#   '(S)-2-Carboxypyrrolidine',
#   '(S)-2-Pyrrolidinecarboxylic acid',
#   '(S)-pyrrolidine-2-carboxylic acid',
#   '2-Pyrrolidinecarboxylic acid',
#   'L-(â\x88\x92)-proline',
#   'L-alpha-pyrrolidinecarboxylic acid',
#   'L-Prolin',
#   'L-Proline',
#   'L-pyrrolidine-2-carboxylic acid',
#   'L-Î±-pyrrolidinecarboxylic acid',
#   'P',
#   'Prolina',
#   'Proline',
#   'Prolinum',
#   'Proline'],
#  'Adenine': ['6-Aminopurine', 'Adenin', 'Vitamin B4', 'Adenine'],
#  'Asparagine': ['(2S)-2-amino-3-carbamoylpropanoic acid',
#   '(2S)-2,4-diamino-4-oxobutanoic acid',
#   '(S)-2-amino-3-carbamoylpropanoic acid',
#   '(S)-Asparagine',
#   '2-Aminosuccinamic acid',
#   'alpha-aminosuccinamic acid',
#   'Asn',
#   'Asparagine',
#   'Aspartamic acid',
#   'L-2-aminosuccinamic acid',
#   'L-Asparagine',
#   'L-aspartic acid beta-amide',
#   'L-aspartic acid Î²-amide',
#   'Î±-aminosuccinamic acid',
#   'Asparagine'],
#  'Pravastatin': ['(+)-(3R,5R)-3,5-dihydroxy-7-[(1S,2S,6S,8S,8aR)-6-hydroxy-2-methyl-8-{[(S)-2-methylbutyryl]oxy}-1,2,6,7,8,8a-hexahydro-1-naphthyl]heptanoic acid',
#   'Pravastatin',
#   'Pravastatin acid',
#   'Pravastatina',
#   'Pravastatine',
#   'Pravastatinum',
#   'Pravastatin'],
#  'Fluvoxamine': ['Fluvoxamina', 'Fluvoxamine', 'Fluvoxaminum', 'Fluvoxamine'],
#  'Valsartan': ["(S)-N-Valeryl-N-{[2'-(1H-tetrazol-5-yl)biphenyl-4-yl]-methyl}-valine",
#   'N-(P-(O-1H-Tetrazol-5-ylphenyl)benzyl)-N-valeryl-L-valine',
#   "N-pentanoyl-N-{[2'-(1H-tetrazol-5-yl)biphenyl-4-yl]methyl}-L-valine",
#   'Valsartan',
#   'Valsartan'],
#  'Ramipril': ['(2S-(1(R*(R*)),2alpha,3abeta,6abeta))-1-(2-((1-(Ethoxycarbonyl)-3-phenylpropyl)amino)-1-oxopropyl)octahydrocyclopenta(b)pyrrole-2-carboxylic acid',
#   'Ramipril',
#   'Ramiprilum',
#   'Ramipril'],
#  'Masoprocol': ['erythro-nordihydroguaiaretic acid',
#   'masoprocol',
#   'Masoprocolum',
#   'meso-1,4-bis(3,4-dihydroxyphenyl)-2,3-dimethylbutane',
#   'meso-2,3-bis(3,4-dihydroxyphenylmethyl)butane',
#   'meso-4-[4-(3,4-dihydroxyphenyl)-2,3-dimethylbutyl]benzene-1,2-diol',
#   "meso-4,4'-(2,3-dimethyl-1,4-butanediyl)bis(pyrocatechol)",
#   "meso-4,4'-(2,3-dimethyltetramethylene)dipyrocatechol",
#   'meso-NDGA',
#   'meso-nordihydroguaiaretic acid',
#   'meso-Î²,Î³-dimethyl-Î±,Î´-bis(3,4-dihydroxyphenyl)butan',
#   'Nordihydroguaiaretic acid',
#   'Masoprocol'],
#  'Flunisolide': ['Flunisolida',
#   'Flunisolide',
#   'Flunisolide anhydrous',
#   'Flunisolidum',
#   'Flunisolide'],
#  'Baclofen': ['(+-)-Baclofen',
#   '4-Amino-3-(4-chlorophenyl)butyric acid',
#   'Baclofen',
#   'BaclofÃ¨ne',
#   'Baclofeno',
#   'Baclofenum',
#   'beta-(4-Chlorophenyl)gaba',
#   'beta-(Aminomethyl)-4-chlorobenzenepropanoic acid',
#   'beta-(Aminomethyl)-p-chlorohydrocinnamic acid',
#   'beta-(p-Chlorophenyl)-gamma-aminobutyric acid',
#   'DL-4-Amino-3-p-chlorophenylbutanoic acid',
#   'DL-Baclofen',
#   'gamma-Amino-beta-(p-chlorophenyl)butyric acid',
#   'Baclofen'],
#  'Amphetamine': ['(+-)-alpha-Methylphenylethylamine',
#   '1-phenyl-2-aminopropane',
#   'alpha-Methylbenzeneethaneamine',
#   'Amfetamina',
#   'Amfetamine',
#   'Amfetaminum',
#   'Amphetamine',
#   'beta-Aminopropylbenzene',
#   'beta-Phenylisopropylamin',
#   'Desoxynorephedrine',
#   'rac-(2R)-1-phenylpropan-2-amine',
#   'rac-amphetamine',
#   'Î±-methylbenzeneethaneamine',
#   'Î±-methylphenethylamine',
#   'Î²-aminopropylbenzene',
#   'Î²-phenylisopropylamine',
#   'Amphetamine'],
#  'Pentagastrin': ['Pentagastrin', 'Pentagastrin'],
#  'Nicotine': ['(â\x88\x92)-nicotine',
#   '(S)-(â\x88\x92)-nicotine',
#   '(S)-3-(1-methylpyrrolidin-2-yl)pyridine',
#   '(S)-3-(N-methylpyrrolidin-2-yl)pyridine',
#   '(S)-Nicotine',
#   '3-(2-(N-methylpyrrolidinyl))pyridine',
#   '3-(N-methylpyrollidino)pyridine',
#   'L(â\x88\x92)-nicotine',
#   'Nicotina',
#   'Nicotine betadex',
#   'Nicotine polacrilex',
#   'Nikotin',
#   'Nikotyna',
#   'Nicotine'],
#  'Cevimeline': ['2-Methyspiro(1,3-oxathiolane-5,3)quinuclidine',
#   'Cevimelina',
#   'CÃ©vimÃ¨line',
#   'Cevimeline',
#   'Cevimelinum',
#   'Cevimeline'],
#  'Lorazepam': ['Loracepam',
#   'Lorazepam',
#   'o-Chlorooxazepam',
#   'o-Chloroxazepam',
#   'Lorazepam'],
#  'Esmolol': ['(Â±)-esmolol',
#   '(Â±)-methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate',
#   '3-[4-(2-Hydroxy-3-isopropylamino-propoxy)-phenyl]-propionic acid methyl ester',
#   'Esmolol',
#   'Methyl 4-(2-hydroxy-3-((1-methylethyl)amino)propoxy)benzenepropanoate',
#   'methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate',
#   'Esmolol'],
#  'Bortezomib': ['[(1R)-3-methyl-1-({(2S)-3-phenyl-2-[(pyrazin-2-ylcarbonyl)amino]propanoyl}amino)butyl]boronic acid',
#   'Bortezomib',
#   'N-[(1R)-1-(DIHYDROXYBORYL)-3-methylbutyl]-N-(pyrazin-2-ylcarbonyl)-L-phenylalaninamide',
#   'Bortezomib'],
#  'Ethchlorvynol': ['1-chloro-3-ethyl-1-penten-4-yn-3-ol',
#   '1-Chloro-3-ethyl-pent-1-en-4-yn-3-ol',
#   '3-(beta-chlorovinyl)-1-pentyn-3-ol',
#   '3-(Î²-chlorovinyl)-1-pentyn-3-ol',
#   'etclorvinol',
#   'Ethchlorvynol',
#   'ethyl Î²-chlorovinyl ethynyl carbinol',
#   'Î²-chlorovinyl ethyl ethynyl carbinol',
#   'Ethchlorvynol'],
#  'Carbidopa': ['(-)-L-alpha-Hydrazino-3,4-dihydroxy-alpha-methylhydrocinnamic acid monohydrate',
#   '(S)-(â\x88\x92)-carbidopa',
#   '(S)-carbidopa',
#   '(Î±S)-Î±-hydrazino-3,4-dihydroxy-Î±-methylbenzenepropanoic acid',
#   'Carbidopa',
#   'Carbidopa (anhydrous)',
#   'Carbidopa anhydrous',
#   'Carbidopum',
#   'L-3-(3,4-dihydroxyphenyl)-2-methyl-2-hydrazinopropionic acid',
#   'L-Î±-methyldopahydrazine',
#   'Carbidopa'],
#  'Phentermine': ['alpha,alpha-Dimethylphenethylamine',
#   'Fentermina',
#   'Phentermine',
#   'Phentermine resin',
#   'Phenterminum',
#   'Phentermine'],
#  'Indecainide': ['Indecainida', 'Indecainide', 'Indecainidum', 'Indecainide'],
#  'Tramadol': ['Tramadol', 'Tramadolum', 'Tramadol'],
#  'Vidarabine': ['9-beta-D-arabinofuranosyl-9H-purin-6-amine',
#   '9-beta-D-arabinofuranosyl-adenine',
#   '9-beta-D-Arabinofuranosyladenine',
#   '9-Î²-D-arabinofuranosyl-9H-purin-6-amine',
#   '9-Î²-D-arabinofuranosyladenine',
#   'Spongoadenosine',
#   'Vidarabine',
#   'Vidarabinum',
#   'Vidarabine'],
#  'Betaxolol': ['1-(4-(2-(cyclopropylmethoxy)ethyl)phenoxy)-3-((1-methylethyl)amino)-2-propanol',
#   '1-(isopropylamino)-3-[p-(cyclopropylmethoxyethyl)phenoxy]-2-propanol',
#   'Betaxolol',
#   'BÃ©taxolol',
#   'Betaxololum',
#   'Betaxolol'],
#  'Fluconazole': ['Diflucan',
#   'Difluconazole',
#   'Fluconazol',
#   'Fluconazole',
#   'Fluconazolum',
#   'Triflucan',
#   'Fluconazole'],
#  'Troglitazone': ['Troglitazona', 'Troglitazone', 'Troglitazone'],
#  'Oseltamivir': ['(â\x88\x92)-oseltamivir',
#   '1-Cyclohexene-1-carboxylic acid, 4-(acetylamino)-5-amino-3-(1-ethylpropoxy)-, ethyl ester, (3R-(3alpha,4beta,5alpha))-',
#   'Ethyl (3R,4R,5S)-4-acetamido-5-amino-3-(1-ethylpropoxy)-1-cyclohexene-1-carboxylate',
#   'Oseltamivir',
#   'OsÃ©ltamivir',
#   'Oseltamivirum',
#   'Oseltamivir'],
#  'Erythromycin': ["3''-O-demethylerythromycin",
#   'Abomacetin',
#   'Eritromicina',
#   'Erythromycin',
#   'Erythromycin A',
#   'Erythromycin C',
#   'Ã©rythromycine',
#   'Erythromycinum',
#   'Erythromycin'],
#  'Hydroxocobalamin': ['Hydroxocobalamin',
#   'Hydroxocobalamin anhydrous',
#   'Hydroxocobalamine',
#   'Hydroxocobalaminum anhydrous',
#   'Hydroxycobalamin',
#   'OH-Cbl',
#   'Vitamin B-12b',
#   'Hydroxocobalamin'],
#  'Caffeine': ['1-methyltheobromine',
#   '1,3,7-trimethyl-2,6-dioxopurine',
#   '1,3,7-trimethylpurine-2,6-dione',
#   '1,3,7-trimethylxanthine',
#   '3,7-Dihydro-1,3,7-trimethyl-1H-purin-2,6-dion',
#   '7-methyltheophylline',
#   'Anhydrous caffeine',
#   'CafeÃ\xadna',
#   'CafÃ©ine',
#   'Caffeinum',
#   'Coffein',
#   'Coffeinum',
#   'Guaranine',
#   'Koffein',
#   'MateÃ\xadna',
#   'Methyltheobromine',
#   'TeÃ\xadna',
#   'Thein',
#   'Theine',
#   'Caffeine'],
#  'Succinylcholine': ["2,2'-[(1,4-dioxobutane-1,4-diyl)bis(oxy)]bis(N,N,N-trimethylethanaminium)",
#   'Dicholine succinate',
#   'Succinocholine',
#   'Succinoylcholine',
#   'Succinylbischoline',
#   'Succinyldicholine',
#   'Suxamethonium',
#   'Succinylcholine'],
#  'Sildenafil': ['1-((3-(4,7-Dihydro-1-methyl-7-oxo-3-propyl-1H-pyrazolo(4,3-d)pyrimidin-5-yl)-4-ethoxyphenyl)sulfonyl)-4-methylpiperazine',
#   'Sildenafil',
#   'Sildenafilo',
#   'Sildenafil'],
#  'Dofetilide': ['beta-((p-Methanesulfonamidophenethyl)methylamino)methanesulfono-p-phenetidide',
#   'Dofetilida',
#   'Dofetilide',
#   'Dofetilidum',
#   'Dofetilide'],
#  'Pyrimethamine': ['2,4-Diamino-5-(4-chlorophenyl)-6-ethylpyrimidine',
#   '2,4-Diamino-5-(P-chlorophenyl)-6-ethylpyrimidine',
#   '2,4-Diamino-5-chlorophenyl-6-ethylpyrimidine',
#   '5-(4-Chlorophenyl)-6-ethyl-2,4-diaminopyrimidine',
#   '5-(4-Chlorophenyl)-6-ethyl-2,4-pyrimidinediamine',
#   "5-(4'-Chlorophenyl)-2,4-diamino-6-ethylpyrimidine",
#   'CD',
#   'Chloridine',
#   'Chloridyn',
#   'Diaminopyritamin',
#   'Ethylpyrimidine',
#   'Pirimetamina',
#   'Primethamine',
#   'Pyrimethamine',
#   'PyrimÃ©thamine',
#   'Pyrimethaminum',
#   'Pyrimethamine'],
#  'Reserpine': ['(â\x88\x92)-reserpine',
#   '(3beta,16beta,17alpha,18beta,20alpha)-11,17-Dimethoxy-18-[(3,4,5-trimethoxybenzoyl)oxy]yohimban-16-carboxylic acid methyl ester',
#   '3,4,5-trimethoxybenzoyl methyl reserpate',
#   'Reserpin',
#   'Reserpine',
#   'Reserpine'],
#  'Azithromycin': ['Azithromycin',
#   'Azithromycine',
#   'Azithromycinum',
#   'Azitromicina',
#   'Azithromycin'],
#  'Ticlopidine': ['Ticlopidina', 'Ticlopidine', 'Ticlopidinum', 'Ticlopidine'],
#  'Trospium': ['Trospium'],
#  'Adapalene': ['6-(3-(1-Adamantyl)-4-methoxyphenyl)-2-naphthoic acid',
#   'Adapalene',
#   'AdapalÃ¨ne',
#   'Adapaleno',
#   'Adapalenum',
#   'Adapalene'],
#  'Midodrine': ['(Â±)-2-amino-N-(Î²-hydroxy-2,5-dimethoxyphenethyl)acetamide',
#   "1-(2',5'-Dimethoxyphenyl)-2-glycinamidoethanol",
#   '2-Amino-N-(2,5-dimethoxy-beta-hydroxyphenethyl)acetamide',
#   'DL-N1-(beta-Hydroxy-2,5-dimethoxyphenethyl)glycinamid',
#   'Midodrin',
#   'Midodrina',
#   'Midodrine',
#   'Midodrinum',
#   'Midodrine'],
#  'Remikiren': ['Remikiren', 'Remikiren'],
#  'Pantoprazole': ['Pantoprazol',
#   'Pantoprazole',
#   'Pantoprazolum',
#   'Pantoprazole'],
#  'Torasemide': ['1-Isopropyl-3-((4-m-toluidino-3-pyridyl)sulfonyl)urea',
#   'N-(((1-Methylethyl)amino)carbonyl)-4-((3-methylphenyl)amino)-3-pyridinesulfonamide',
#   'Torasemida',
#   'Torasemide',
#   'TorasÃ©mide',
#   'Torasemidum',
#   'Torsemide',
#   'Torasemide'],
#  'Citalopram': ['Citalopram', 'Citalopramum', 'Nitalapram ', 'Citalopram'],
#  'Eletriptan': ['Eletriptan',
#   'Ã©lÃ©triptan',
#   'EletriptÃ¡n',
#   'Eletriptanum',
#   'Eletriptan'],
#  'Bethanidine': ['Betanidina',
#   'Betanidine',
#   'BÃ©tanidine',
#   'Betanidinum',
#   'Bethanidine',
#   "N,N'-dimethyl-N''-(phenylmethyl)-guanidine",
#   'Bethanidine'],
#  'Moxifloxacin': ['1-Cyclopropyl-6-fluoro-1,4-dihydro-8-methoxy-7-((4as,7as)-octahydro-6H-pyrrolo(3,4-b)pyridin-6-yl)-4-oxo-3-quinolinecarboxylic acid',
#   'Moxifloxacin',
#   'Moxifloxacino',
#   'Moxifloxacin'],
#  'Oxyphenonium': ['Oxyphenonium cation', 'Oxyphenonium ion', 'Oxyphenonium'],
#  'Nelfinavir': ['Nelfinavir', 'Nelfinavir'],
#  'Isoetharine': ['Isoetarina', 'Isoetarinum', 'Isoetharine', 'Isoetharine'],
#  'Glimepiride': ['Glimepirida',
#   'Glimepiride',
#   'GlimÃ©piride',
#   'Glimepiridum',
#   'Glimepiride'],
#  'Diflorasone': ['(6Î±,11Î²,16Î²)-6,9-difluoro-11,17,21-trihydroxy-16-methylpregna-1,4-diene-3,20-dione',
#   'Diflorasona',
#   'Diflorasone',
#   'Diflorasonum',
#   'Diflorasone'],
#  'Indinavir': ['(1(1S,2R),5(S))-2,3,5-Trideoxy-N-(2,3-dihydro-2-hydroxy-1H-inden-1-yl)-5-(2-(((1,1-dimethylethyl)amino)carbonyl)-4-(3-pyridinylmethyl)-1-piperazinyl)-2-(phenylmethyl)-D-erythro-pentonamide',
#   'Indinavir',
#   'Indinavir anhydrous',
#   'Indinavir'],
#  'Gadodiamide': ['Gadodiamida',
#   'Gadodiamide',
#   'Gadodiamide anhydrous',
#   'Gadodiamide'],
#  'Guanadrel': ['Guanadrel', 'Guanadrelum', 'Guanadrel'],
# ...
#   'Hidrocodona',
#   'Hydrocodon',
#   'Hydrocodone',
#   'Hydrocodonum',
#   'Hydrocone',
#   'Hydroconum',
#   'Idrocodone',
#   'Hydrocodone'],
#  'Norgestimate': ['(+)-13-Ethyl-17-hydroxy-18,19-dinor-17Î±-pregn-4-en-20-yn-3-one oxime acetate (ester)',
#   '(17Î±)-17-(Acetyloxy)-13-ethyl-18,19-dinorpregn-4-en-20-yn-3-one 3-oxime',
#   'd-13Î²-Ethyl-17Î±-ethynyl-17Î²-acetoxygon-4-en-3-one oxime',
#   'Dexnorgestrel Acetime',
#   'Norgestimate',
#   'Norgestimato',
#   'Norgestimatum',
#   'Norgestimate'],
#  'Carboplatin': ['Carboplatin',
#   'Carboplatine',
#   'Carboplatino',
#   'CBDCA',
#   'cis-(1,1-cyclobutanedicarboxylato)diammineplatinum(II)',
#   'cis-diammine(1,1-cyclobutanedicarboxylato)platinum',
#   'cis-diammine(1,1-cyclobutanedicarboxylato)platinum(II)',
#   'Carboplatin'],
#  'Methylprednisolone': ['(6Î±,11Î²)-11,17,21-trihydroxy-6-methylpregna-1,4-diene-3,20-dione',
#   '1-dehydro-6Î±-methylhydrocortisone',
#   '6Î±-methyl-11Î²,17Î±,21-triol-1,4-pregnadiene-3,20-dione',
#   'delta(1)-6alpha-Methylhydrocortisone',
#   'Methylprednisolon',
#   'Methylprednisolone',
#   'Methylprednisolonum',
#   'Metilprednisolona',
#   'Methylprednisolone'],
#  'Pindolol': ['1-(1H-indol-4-yloxy)-3-(isopropylamino)propan-2-ol',
#   '1-(1H-indol-4-yloxy)-3-(propan-2-ylamino)-propan-2-ol',
#   '1-(1H-indol-4-yloxy)-3-[(1-methylethyl)amino]propan-2-ol',
#   '4-(2-hydroxy-3-isopropylaminopropoxy)-indole',
#   'Pindolol',
#   'Pindololum',
#   'Pindolol'],
#  'Mepivacaine': ["(+-)-1-Methyl-2',6'-pipecoloxylidide",
#   "1-methyl-2',6'-pipecoloxylidide",
#   'DL-Mepivacaine',
#   'Mepivacaina',
#   'Mepivacaine',
#   'Mepivacainum',
#   'N-(2,6-Dimethylphenyl)-1-methyl-2-piperidinecarboxamide',
#   'N-(2,6-Dimethylphenyl)-1-methylpiperidine-2-carboxamide',
#   'Mepivacaine'],
#  'Zaleplon': ["3'-(3-Cyanopyrazolo(1,5-a)pyrimidin-7-yl)-N-ethylacetanilide",
#   'Zaleplon',
#   'Zaleplon'],
#  'Bromfenac': ['[2-Amino-3-(4-bromo-benzoyl)-phenyl]-acetic acid',
#   '2-amino-3-(4-bromobenzoyl)benzeneacetic acid',
#   'Bromfenac',
#   'Bromfenaco',
#   'Bromfenacum',
#   'Bromfenac'],
#  'Apraclonidine': ['4-Aminoclonidine',
#   'Apraclonidina',
#   'Apraclonidine',
#   'Apraclonidinum',
#   'Apraclonidine'],
#  'Ethiodized oil': ['Ethiodized oil'],
#  'Telmisartan': ["4'-((1,4'-dimethyl-2'-propyl(2,6'-bi-1H-benzimidazol)-1'-yl)methyl)-(1,1'-biphenyl)-2-carboxylic acid",
#   "4'-((4-methyl-6-(1-methyl-2-benzimidazolyl)-2-propyl-1-benzimidazolyl)methyl)-2-biphenylcarboxylic acid",
#   "4'-[(1,4'-dimethyl-2'propyl[2,6'-bi-1H-benzimidazol]-1'-yl)methyl]-[1,1'-biphenyl]-2-carboxylic acid",
#   "4'-[(1,7'-dimethyl-2'-propyl-1H,3'H-2,5'-bibenzimidazol-3'-yl)methyl]biphenyl-2-carboxylic acid",
#   'Telmisartan',
#   'Telmisartan'],
#  'Desloratadine': ['8-Chloro-11-piperidin-4-ylidene-6,11-dihydro-5H-benzo[5,6]cyclohepta[1,2-b]pyridine',
#   '8-chloro-6,11-dihydro-11-(4-piperidinylidene)-5H-benzo(5,6)cyclohepta(1,2-b)pyridine',
#   'Descarboethoxyloratadine',
#   'Desloratadina',
#   'Desloratadine',
#   'Desloratadine'],
#  'Methyldopa': ['(S)-(-)-alpha-Methyldopa',
#   '3-Hydroxy-alpha-methyl-L-tyrosine',
#   'Alpha medopa',
#   'alpha-Methyl dopa',
#   'alpha-methyl-L-dopa',
#   'Alphamethyldopa',
#   'AMD',
#   'Anhydrous methyldopa',
#   'L-alpha-Methyldopa',
#   'L-Methyl Dopa',
#   'Methyl dopa',
#   'Methyldopa',
#   'Methyldopa anhydrous',
#   'metildopa',
#   'Î±-Methyl dopa',
#   'Î±-methyl-L-dopa',
#   'Methyldopa'],
#  'Alosetron': ['2,3,4,5-Tetrahydro-5-methyl-2-((5-methyl-1H-imidazol-4-yl)methyl)-1H-pyrido(4,3-b)indol-1-one',
#   'Alosetron',
#   'Alosetron'],
#  'Dactinomycin': ["2-amino-N,N'-bis(hexadecahydro-2,5,9-trimethyl-6,13-bis(1-methylethyl)-1,4,7,11,14-pentaoxo-1H-pyrrolo(2,1-i)(1,4,7,10,13)oxatetra-azacyclohexadecin-10-yl)-4,6-dimethyl-3-oxo-3H-phenoxazine-1,9-dicarboxamide",
#   'ActD',
#   'Actinomycin C1',
#   'Actinomycin D',
#   'Actinomycin IV',
#   'Dactinomicina',
#   'Dactinomycin',
#   'Dactinomycine',
#   'Dactinomycinum',
#   'Meractinomycin',
#   'Dactinomycin'],
#  'Selenium Sulfide': ['Selenii disulfidum',
#   'Selenium disulfide',
#   'Selenium disulphide',
#   'Selenium sulfide, micronized',
#   'Selenium sulphide',
#   'Selenium sulphide, micronized',
#   'Selenium(IV) disulfide',
#   'Selenium(IV) disulphide',
#   'Selenium(IV) sulfide',
#   'Selenium(IV) sulphide',
#   'Selenium Sulfide'],
#  'Azelastine': ['4-(p-Chlorobenzyl)-2-(hexahydro-1-methyl-1H-azepin-4-yl)-1-(2H)-phthalazinone',
#   'Azelastina',
#   'Azelastine',
#   'AzÃ©lastine',
#   'Azelastinum',
#   'Azelastine'],
#  'Ezetimibe': ['Ezetimiba',
#   'Ã©zÃ©timibe',
#   'Ezetimibe',
#   'Ezetimibum',
#   'Ezetimibe'],
#  'Edetic acid': ['(ethylenedinitrilo)tetraacetic acid, ion(4â\x88\x92)',
#   '{[-(bis-carboxymethyl-amino)-ethyl]-carboxymethyl-amino}-acetic acid',
#   "2,2',2'',2'''-(ethane-1,2-diyldinitrilo)tetraacetate",
#   'Acide edetique',
#   'Acide ethylenediaminetetracetique',
#   'Acido edetico',
#   'Acidum edeticum',
#   'Edetic acid',
#   'EDTA',
#   'EDTA, ion(4-)',
#   'Ethylenediaminetetraacetate',
#   'Ethylenediaminetetraacetic acid',
#   "N,N'-1,2-Ethane diylbis-(N-(carboxymethyl)glycine)",
#   'Edetic acid'],
#  'Dipyridamole': ['Dipiridamol',
#   'Dipyridamine',
#   'Dipyridamole',
#   'Dipyridamolum',
#   'Dipyudamine',
#   'Dypyridamol',
#   'Dipyridamole'],
#  'Telithromycin': ['Telithromycin', 'telitromicina', 'Telithromycin'],
#  'Ethinylestradiol': ['17-ethinyl-3,17-estradiol',
#   '17-ethinyl-3,17-oestradiol',
#   '17-ethinylestradiol',
#   '17alpha-Ethinyl estradiol',
#   '17Î±-ethynylestradiol',
#   'Ethinyl estradiol',
#   'Ethinylestradiol',
#   'Ethinylestradiolum',
#   'Ethinyloestradiol',
#   'Ethynyl estradiol',
#   'Etinilestradiol',
#   'Ethinylestradiol'],
#  'Lomefloxacin': ['(Â±)-1-ethyl-6,8-difluoro-1,4-dihydro-7-(3-methyl-1-piperazinyl)-4-oxo-3-quinolinecarboxylic acid',
#   '1,4-Dihydro-6,8-difluoro-1-ethyl-7-(3-methyl-1-piperazinyl)-4-oxo-3-quinolinecarboxylic acid',
#   'LFLX',
#   'Lomefloxacin',
#   'Lomefloxacine',
#   'Lomefloxacino',
#   'Lomefloxacinum',
#   'Lomefloxacin'],
#  'Cyclopentolate': ['(Â±)-cyclopentolate',
#   '1-hydroxy-Î±-phenylcyclopentaneacetic acid 2-(dimethylamino)ethyl ester',
#   '2-(dimethylamino)ethyl 1-hydroxy-Î±-phenylcyclopentaneacetate',
#   '2-(dimethylamino)ethyl 2-(1-hydroxycyclopentyl)-2-phenylacetate',
#   '2-phenyl-2-(1-hydroxycyclopentyl)ethanoic acid Î²-(dimethylamino)ethyl ester',
#   'Ciclopentolato',
#   'Cyclopentolate',
#   'Cyclopentolatum',
#   'Î±-(1-hydroxycyclopentyl)benzeneacetic acid 2-(dimethylamino)ethyl ester',
#   'Î²-(dimethylamino)ethyl (1-hydroxycyclopentyl)phenylacetate',
#   'Î²-dimethylaminoethyl (1-hydroxycyclopentyl)phenylacetate',
#   'Cyclopentolate'],
#  'Ramelteon': ['Ramelteon', 'Ramelteon'],
#  'Physostigmine': ['Eserine', 'Physostigmine', 'Physostol', 'Physostigmine'],
#  'Isotretinoin': ['(7E,9E,11E,13Z)-retinoic acid',
#   '13-cis-retinoic acid',
#   '13-cis-Vitamin A acid',
#   '13-RA',
#   'cis-RA',
#   'Isotretinoin',
#   'IsotretinoÃ\xadna',
#   'IsotrÃ©tinoine',
#   'Isotretinoino',
#   'Isotretinoinum',
#   'Neovitamin A acid',
#   'Isotretinoin'],
#  'Formoterol': ["2'-hydroxy-5'-(1-hydroxy-2-((p-methoxy-Î±-methylphenethyl)amino)ethyl)formanilide",
#   "2'-hydroxy-5'-{1-hydroxy-2-[(p-methoxy-Î±-methylphenethyl)amino]ethyl}formanilide",
#   'Formoterol',
#   'Formoterolum',
#   'N-[2-hydroxy-5-(1-hydroxy-2-{[2-(4-methoxyphenyl)-1-methylethyl]amino}ethyl)phenyl]formamide',
#   'Formoterol'],
#  'Nandrolone phenpropionate': ['19NTPP',
#   'Nadrolone phenylpropionate',
#   'Nandrolon phenylpropionate',
#   'Nandrolone phenylpionate',
#   'Nandrolone phenylpropionate',
#   'Norandrolone phenyl propionate',
#   'Norandrostenolone phenylpropionate',
#   'Nortestosterone phenylpropionate',
#   'NPP',
#   'NTPP',
#   'Nandrolone phenpropionate'],
#  'Dimenhydrinate': ['(O-benzhydryl(dimethylamino)ethanol) 8-chlorotheophyllinate',
#   '8-chloro-1,3-dimethyl-3,7-dihydro-1H-purine-2,6-dione - 2-(diphenylmethoxy)-N,N-dimethylethanamine (1:1)',
#   'Benzhydryl-Î²-dimethylaminoethylether 8-chlorotheophylline',
#   'Dimenhidrinato',
#   'Dimenhydrinate',
#   'Dimenhydrinatum',
#   'diphenhydramine 8-chlorotheophyllinate',
#   'diphenhydramine 8-chlorotheophylline',
#   'Diphenhydramine theoclate',
#   'N,N-dimethyl-2-diphenylmethoxyethylamine 8-chlorotheophyllinate',
#   'O-benzhydryldimethylaminoethanol 8-chlorotheophyllinate',
#   'Î²-dimethylaminoethyl benzhydryl ether 1,3-dimethyl-8-chloroxanthine',
#   'Dimenhydrinate'],
#  'Glycopyrronium': ['Glicopirronio',
#   'Glycopyrrolate cation',
#   'Glycopyrrolate ion',
#   'Glycopyrronium',
#   'Glycopyrronium cation',
#   'Glycopyrronium ion',
#   'Glycopyrronium'],
#  'Cytarabine': ['1-beta-D-Arabinofuranosylcytosine',
#   '4-Amino-1-beta-D-arabinofuranosyl-2(1H)-pyrimidinone',
#   'Citarabina',
#   'Cytarabine',
#   'Cytarabinum',
#   'Cytosine arabinoside',
#   'Cytosine-1-beta-D-arabinofuranoside',
#   'cytosine-Î²-D-arabinofuranoside',
#   'Cytarabine'],
#  'Dopamine': ['2-(3,4-dihydroxyphenyl)ethylamine',
#   '3-Hydroxytyramine',
#   '3,4-Dihydroxyphenethylamine',
#   '4-(2-aminoethyl)-1,2-benzenediol',
#   '4-(2-Aminoethyl)benzene-1,2-diol',
#   '4-(2-aminoethyl)catechol',
#   '4-(2-aminoethyl)pyrocatechol',
#   'Dopamina',
#   'Dopamine',
#   'Dopaminum',
#   'Oxytyramine',
#   'Dopamine'],
#  'Rivastigmine': ['(S)-3-(1-(Dimethylamino)ethyl)phenyl ethylmethylcarbamate',
#   'm-((S)-1-(Dimethylamino)ethyl)phenyl ethylmethylcarbamate',
#   'Rivastigmina',
#   'Rivastigmine',
#   'Rivastigmine'],
#  'Exemestane': ['6-methyleneandrosta-1,4-diene-3,17-dione',
#   'Exemestane',
#   'Exemestano',
#   'Exemestanum',
#   'Exemestane'],
#  'Oxaprozin': ['Oxaprozin',
#   'Oxaprozina',
#   'Oxaprozine',
#   'Oxaprozinum',
#   'Oxaprozin'],
#  'Methyl aminolevulinate': ['5-aminolevulinic acid methyl ester',
#   'Aminolevulinato de metilo',
#   'Aminolevulinic acid methyl ester',
#   'methyl 5-aminolevulinate',
#   'Methyl aminolevulinate',
#   'Methyl delta-aminolevulinate',
#   'methyl Î´-aminolevulinate',
#   'Methyl aminolevulinate'],
#  'Azathioprine': ['6-((1-Methyl-4-nitro-1H-imidazol-5-yl)thio)-1H-purine',
#   "6-(1'-Methyl-4'-nitro-5'-imidazolyl)-mercaptopurine",
#   'Azamun',
#   'Azathioprine',
#   'Azathioprinum',
#   'Azatioprina',
#   'Azathioprine'],
#  'Neomycin': ['Fradiomycin',
#   'Kaomycine',
#   'Neomicina',
#   'Neomycin',
#   'Vonamycin',
#   'Neomycin'],
#  'Auranofin': ['(1-Thio-beta-D-glucopyranosato)(triethylphosphine)gold 2,3,4,6-tetraacetate',
#   '2,3,4,6-Tetra-O-acetyl-1-thio-beta-D-glucopyranosato-S (triethylphosphine)gold',
#   'Auranofin',
#   'Auranofina',
#   'Auranofine',
#   'Auranofinum',
#   'Triethylphosphine gold',
#   'Auranofin'],
#  'Gabapentin': ['1-(Aminomethyl)cyclohexaneacetic acid',
#   'Gabapentin',
#   'Gabapentina',
#   'Gabapentine',
#   'Gabapentino',
#   'Gabapentinum',
#   'Gabapentin'],
#  'Doxorubicin': ['(1S,3S)-3-glycoloyl-3,5,12-trihydroxy-10-methoxy-6,11-dioxo-1,2,3,4,6,11-hexahydrotetracen-1-yl 3-amino-2,3,6-trideoxy-Î±-L-lyxo-hexopyranoside',
#   '(8S-cis)-10-((3-amino-2,3,6-trideoxy-Î±-L-lyxo-hexopyranosyl)oxy)-7,8,9,10-tetrahydro-6,8,11-trihydroxy-8-(hydroxyacetyl)-1-methoxy-5,12-naphthacenedione',
#   '14-hydroxydaunomycin',
#   '14-hydroxydaunorubicine',
#   'Doxorubicin',
#   'Doxorubicina',
#   'Doxorubicine',
#   'Doxorubicinum',
#   'Hydroxydaunorubicin',
#   'Doxorubicin'],
#  'Frovatriptan': ['Frovatriptan', 'Frovatriptan'],
#  'Hydrochlorothiazide': ['HCTZ',
#   'Hidroclorotiazida',
#   'Hydrochlorothiazide',
#   'Hydrochlorothiazidum',
#   'Hydrochlorothiazide'],
#  'Cyclacillin': ['(1-aminocyclohexyl)penicillin',
#   '(2S,5R,6R)-6-{[(1-aminocyclohexyl)carbonyl]amino}-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylic acid',
#   '6-(1-aminocyclohexanecarboxamido)penicillanic acid',
#   '6-(1-aminocyclohexylcarboxamido)penicillanic acid',
#   'Ciclacilina',
#   'Ciclacillin',
#   'Ciclacilline',
#   'Ciclacillinum',
#   'Cyclacillin',
#   'Cyclacillin'],
#  'Salbutamol': ['Albuterol', 'Salbutamol', 'Salbutamolum', 'Salbutamol'],
#  'Levobupivacaine': ['(-)-bupivacaine',
#   "(S)-1-butyl-2',6'-pipecoloxylidide",
#   '(S)-bupivacaine',
#   "L-(-)-1-Butyl-2',6'-pipecoloxylidide",
#   'L-(â\x88\x92)-bupivacaine',
#   'LevobupivacaÃ\xadna',
#   'Levobupivacaine',
#   'Levobupivacaine'],
#  'Cromoglicic acid': ['5-[3-(2-carboxy-4-oxo-4H-5-chromenyloxy)-2-hydroxypropoxy]-4-oxo-4H-2-chromenecarboxylic acid',
#   'Acide Cromoglicique',
#   'Acido Cromoglicico',
#   'Acidum Cromoglicicum',
#   'Cromoglicate',
#   'Cromoglicic acid',
#   'Cromoglycate',
#   'Cromoglycic acid',
#   'Cromolyn',
#   'Cromoglicic acid'],
#  'Ganciclovir': ['2-(6-Amino-purin-9-ylmethoxy)-propane-1,3-diol',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-1H-purin-6(9H)-one',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-3H-purin-6(9H)-one',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-9H-purin-6-ol',
#   '2-Amino-9-(2-hydroxy-1-hydroxymethyl-ethoxymethyl)-1,9-dihydro-purin-6-one',
#   '2-amino-9-(2-hydroxy-1-hydroxymethylethoxymethyl)-6,9-dihydro-1H-6-purinone',
#   '9-((2-Hydroxy-1-(hydroxymethyl)ethoxy)methyl)guanine',
#   '9-[(1,3-dihydroxy-2-propoxy)methyl]guanine',
#   'GA2',
#   'Ganciclovir',
#   'Ganciclovirum',
#   'Gancyclovir',
#   'Ganciclovir'],
#  'Hydroxyurea': ['Carbamohydroxamic acid',
#   'Carbamohydroximic acid',
#   'Carbamoyl oxime',
#   'Carbamyl hydroxamate',
#   'Hidroxicarbamida',
#   'Hydrea',
#   'Hydroxycarbamid',
#   'Hydroxycarbamide',
#   'Hydroxycarbamidum',
#   'Hydroxyharnstoff',
#   'Hydroxyurea',
#   'N-Carbamoylhydroxylamine',
#   'N-Hydroxyurea',
#   'Oxyurea',
#   'Hydroxyurea'],
#  'Letrozole': ['Letrozol', 'Letrozole', 'Letrozole'],
#  'Tioconazole': ['Tioconazol', 'Tioconazole', 'Tioconazolum', 'Tioconazole'],
#  'Busulfan': ['1,4-Bis(methanesulfonoxy)butane',
#   '1,4-Butanediol dimethanesulfonate',
#   '1,4-Dimesyloxybutane',
#   '1,4-Dimethanesulfonoxybutane',
#   'Busulfan',
#   'Busulfano',
#   'Busulfanum',
#   'Busulphan',
#   'Tetramethylene bis(methanesulfonate)',
#   'Busulfan'],
#  'Ketoprofen': ['2-(3-Benzoylphenyl)propionic acid',
#   '3-Benzoyl-alpha-methylbenzeneacetic acid',
#   '3-Benzoyl-Î±-methylbenzeneacetic acid',
#   '3-Benzoylhydratropic acid',
#   'Ketoprofen',
#   'Ketoprofeno',
#   "L'acide (benzoyl-3-phenyl)-2-propionique",
#   'm-Benzoylhydratropic acid',
#   'Ketoprofen'],
#  'Edrophonium': ['(3-hydroxyphenyl)dimethylethylammonium',
#   '3-hydroxy-N,N-dimethyl-N-ethylanilinium',
#   'Edrophonium cation',
#   'Edrophonium ion',
#   'Ethyl-(3-hydroxy-phenyl)-dimethyl-ammonium',
#   'N-ethyl-3-hydroxy-N,N-dimethylanilinium',
#   'N-ethyl-3-hydroxy-N,N-dimethylbenzenaminium',
#   'Edrophonium'],
#  'Metyrapone': ['Metirapona',
#   'MÃ©tyrapone',
#   'Metyrapone',
#   'Metyraponum',
#   'Metyrapone'],
#  'Cinacalcet': ['(R)-Î±-methyl-N-[3-[3-(trifluoromethyl)phenyl]propyl]-1-naphthalenemethane amine',
#   'Cinacalcet',
#   'CNC',
#   'N-((1R)-1-(Naphthalen-1-yl)ethyl)-3-(3-(trifluoromethyl)phenyl)propan-1-amine',
#   'Cinacalcet'],
#  'Clobetasol propionate': ['21-chloro-9-fluoro-11Î²,17-dihydroxy-16Î²-methylpregna-1,4-diene-3,20-dione 17-propionate',
#   'clobetasol 17-propanoate',
#   'clobetasol 17-propionate',
#   'Clobetasol propionate',
#   'Clobetasol propionate E',
#   'Clobetasol propionate'],
#  'Balsalazide': ['(E)-5-((4-(((2-carboxyethyl)amino)carbonyl)phenyl)azo)-2-hydroxybenzoic acid',
#   '(E)-5-({p-[(2-carboxyethyl)carbamoyl]phenyl}azo)-2-salicylic acid',
#   '3-(2-{4-[(2-carboxyethyl)carbamoyl]phenyl}hydrazinylidene)-6-oxocyclohexa-1,4-diene-1-carboxylic acid',
#   '5-[4-(2-carboxy-ethylcarbamoyl)-phenylazo]-2-hydroxy-benzoic acid',
#   'Balsalazida',
#   'Balsalazide',
#   'Balsalazidum',
#   'Balsalazide'],
#  'Sulfamethoxazole': ['3-(p-Aminophenylsulfonamido)-5-methylisoxazole',
#   '3-Sulfanilamido-5-methylisoxazole',
#   '4-Amino-N-(5-methyl-3-isoxazolyl)benzenesulfonamide',
#   'SMX',
#   'Sulfamethoxazole',
#   'Sulfametoxazol',
#   'Sulphamethoxazole',
#   'Sulfamethoxazole'],
#  'Glyburide': ['1-((p-(2-(5-chloro-o-anisamido)ethyl)phenyl)sulfonyl)-3-cyclohexylurea',
#   '1-(p-(2-(5-chloro-2-methoxybenzamido)ethyl)benzenesulfonyl)-3-cyclohexylurea',
#   '5-chloro-N-(2-(4-((((cyclohexylamino)carbonyl)amino)sulfonyl)phenyl)ethyl)-2-methoxybenzamide',
#   'Glibenclamida',
#   'Glibenclamide',
#   'Glibenclamidum',
#   'Glyburide',
#   'Glyburide'],
#  'Minocycline': ['(4S,4aS,5aR,12aS)-4,7-bis(dimethylamino)-3,10,12,12a-tetrahydroxy-1,11-dioxo-1,4,4a,5,5a,6,11,12a-octahydrotetracene-2-carboxamide',
#   '7-Dimethylamino-6-demethyl-6-deoxytetracycline',
#   'Minociclina',
#   'Minociclinum',
#   'Minocyclin',
#   'Minocycline',
#   'Minocyclinum',
#   'Minomycin',
#   'Minocycline'],
#  ...}

# %%
from joblib import dump, load

dump(drug_dic, 'drug_dic.joblib') 
drug_dic = load('drug_dic.joblib')

# %%
# Out:
# {'Lepirudin': ['Hirudin variant-1', 'Lepirudin recombinant', 'Lepirudin'],
#  'Cetuximab': ['Cetuximab', 'CÃ©tuximab', 'Cetuximabum', 'Cetuximab'],
#  'Dornase alfa': ['Deoxyribonuclease (human clone 18-1 protein moiety)',
#   'Dornasa alfa',
#   'Dornase alfa, recombinant',
#   'Dornase alpha',
#   'Recombinant deoxyribonuclease (DNAse)',
#   'Dornase alfa'],
#  'Denileukin diftitox': ['Denileukin',
#   'Interleukin-2/diptheria toxin fusion protein',
#   'Denileukin diftitox'],
#  'Etanercept': ['Etanercept',
#   'etanercept-szzs',
#   'etanercept-ykro',
#   'Recombinant human TNF',
#   'rhu TNFR:Fc',
#   'rhu-TNFR:Fc',
#   'TNFR-Immunoadhesin',
#   'Etanercept'],
#  'Bivalirudin': ['Bivalirudin',
#   'Bivalirudina',
#   'Bivalirudinum',
#   'Bivalirudin'],
#  'Leuprolide': ['Leuprorelin',
#   'Leuprorelina',
#   'Leuproreline',
#   'Leuprorelinum',
#   'Leuprolide'],
#  'Peginterferon alfa-2a': ['PEG-IFN alfa-2A',
#   'PEG-Interferon alfa-2A',
#   'Peginterferon alfa-2a',
#   'Pegylated Interfeaon alfa-2A',
#   'Pegylated interferon alfa-2a',
#   'Pegylated interferon alpha-2a',
#   'Pegylated-interferon alfa 2a',
#   'Peginterferon alfa-2a'],
#  'Alteplase': ['Alteplasa',
#   'Alteplase (genetical recombination)',
#   'Alteplase, recombinant',
#   'Alteplase,recombinant',
#   'Plasminogen activator (human tissue-type protein moiety)',
#   'rt-PA',
#   't-PA',
#   't-plasminogen activator',
#   'Tissue plasminogen activator',
#   'Tissue plasminogen activator alteplase',
#   'Tissue plasminogen activator, recombinant',
#   'tPA',
#   'Alteplase'],
#  'Sermorelin': ['Sermorelin'],
#  'Interferon alfa-n1': ['Interferon alpha-n1 (INS)', 'Interferon alfa-n1'],
#  'Darbepoetin alfa': ['Darbepoetin',
#   'Darbepoetin alfa,recombinant',
#   'Darbepoetina alfa',
#   'Darbepoetin alfa'],
#  'Urokinase': ['Kinase (enzyme-activating), uro-urokinase',
#   'TCUK',
#   'Tissue culture urokinase',
#   'Two-chain urokinase',
#   'Urochinasi',
#   'Urokinase',
#   'Urokinasum',
#   'Uroquinasa',
#   'Urokinase'],
#  'Goserelin': ['Goserelin', 'Goserelina', 'Goserelin'],
#  'Reteplase': ['Human t-PA (residues 1-3 and 176-527)',
#   'Reteplasa',
#   'Reteplase, recombinant',
#   'Reteplase,recombinant',
#   'Reteplase'],
#  'Erythropoietin': ['E.P.O.',
#   'Epoetin alfa',
#   'Epoetin alfa rDNA',
#   'Epoetin alfa-epbx',
#   'Epoetin alfa, recombinant',
#   'Epoetin beta',
#   'Epoetin beta rDNA',
#   'Epoetin epsilon',
#   'Epoetin gamma',
#   'Epoetin gamma rDNA',
#   'Epoetin kappa',
#   'Epoetin omega',
#   'Epoetin theta',
#   'Epoetin zeta',
#   'Epoetina alfa',
#   'Epoetina beta',
#   'Epoetina dseta',
#   'Epoetina zeta',
#   'EpoÃ©tine zÃªta',
#   'Epoetinum zeta',
#   'Erythropoiesis stimulating factor',
#   'Erythropoietin (human, recombinant)',
#   'Erythropoietin (recombinant human)',
#   'ESF',
#   'SH-polypeptide-72',
#   'Erythropoietin'],
#  'Salmon calcitonin': ['Calcitonin (Salmon Synthetic)',
#   'Calcitonin salmon',
#   'Calcitonin salmon recombinant',
#   'Calcitonin-salmon',
#   'Calcitonin, salmon',
#   'Calcitonina salmÃ³n sintÃ©tica',
#   'Recombinant salmon calcitonin',
#   'Salmon calcitonin',
#   'Salmon calcitonin'],
#  'Interferon alfa-n3': ['Interferon alfa-n3'],
#  'Pegfilgrastim': ['Granulocyte colony-stimulating factor pegfilgrastim',
#   'peg-filgrastim',
#   'pegfilgrastim-apgf',
#   'pegfilgrastim-bmez',
#   'pegfilgrastim-cbqv',
#   'pegfilgrastim-jmdb',
#   'Pegfilgrastim'],
#  'Sargramostim': ['Recombinant human granulocyte-macrophage colony stimulating factor',
#   'rGM-CSF',
#   'rHu GM-CSF',
#   'Sargramostim',
#   'Sargramostim'],
#  'Peginterferon alfa-2b': ['Peginterferon alfa-2b'],
#  'Asparaginase Escherichia coli': ['Asparaginase',
#   'Asparaginase (E. coli)',
#   'Colaspase',
#   'Escherichia coli L-asparaginase',
#   'L-asparaginase',
#   'L-asparagine amidohydrolase',
#   'Asparaginase Escherichia coli'],
#  'Thyrotropin alfa': ['Recombinant Human Thyroid Stimulating Hormone',
#   'Recombinant thyrotropin alfa',
#   'rhTSH',
#   'rTSH',
#   'Thyrotropin alpha',
#   'Thyrotropin alfa'],
#  'Antihemophilic factor, human recombinant': ['Antihemophilic factor (recombinant)',
#   'Antihemophilic factor recombinant',
#   'Antihemophilic factor, human recombinant',
#   'Antihemophilic factor, recombinant',
#   'Factor VIII (rDNA)',
#   'Factor VIII (Recombinant)',
#   'Factor VIII recombin',
#   'Factor VIII, recombinant',
#   'Human Factor VIII (Recombinant)',
#   'Human factor VIII recombinant',
#   'Octocog alfa',
#   'rAHF',
#   'Recombinant antihemophilic factor VIII',
#   'Antihemophilic factor, human recombinant'],
#  'Anakinra': ['Anakinra',
#   'IL-1RA',
#   'Interleukin-1 receptor antagonist anakinra',
#   'Anakinra'],
#  'Gramicidin D': ['Bacillus brevis gramicidin D',
#   'Gramicidin',
#   'Gramicidin A',
#   'Gramicidin B',
#   'Gramicidin C',
#   'Gramicidina',
#   'Gramicidine',
#   'Gramicidin D'],
#  'Human immunoglobulin G': ['Human IGG',
#   'Human immunoglobulin G',
#   'Human normal immunoglobulin',
#   'Immune globulin (human)',
#   'Immune globulin human',
#   'Immunoglobulin (human)',
#   'Immunoglobulin G (human)',
#   'Immunoglobulin G, human',
#   'IVIg',
#   'Human immunoglobulin G'],
#  'Anistreplase': ['Anisoylated plasminogen streptokinase activator complex',
#   'APSAC',
#   'Anistreplase'],
#  'Insulin human': ['High molecular weight insulin human',
#   'Human insulin',
#   'human insulin (rDNA)',
#   'Insulin (human)',
#   'Insulin human',
#   'Insulin human [rDNA origin]',
#   'Insulin Human Regular',
#   'Insulin human regular (rDNA)',
#   'Insulin human, rDNA origin',
#   'Insulin recombinant human',
#   'Insulin recombinant purified human',
#   'Insulin regular',
#   'Insulin, human',
#   'Insulina regular',
#   'Regular Insulin, human',
#   'Insulin human'],
#  'Tenecteplase': ['Tenecteplasa', 'TNK-tPA', 'Tenecteplase'],
#  'Menotropins': ['Human menopausal gonadotrophin',
#   'Menotrophin',
#   'Menotropin',
#   'Menotropina',
#   'Menotropins (FSH;LH)',
#   'Menotropins'],
#  'Interferon gamma-1b': ['IFN-gamma 1b',
#   'IFN-gamma-1b',
#   'Interferon gamma 1-b',
#   'Interferon gamma-1b',
#   'Interferon gamma-1b, recombinant',
#   'Interferon gamma-2a',
#   'Interferon gamma-1b'],
#  'Interferon alfa-2a, Recombinant': ['Interferon alfa-2a',
#   'Interferon alfa-2a (recombinant)',
#   'Interferon alfa-2a, recombinant',
#   'Interferon alfa-2a,recombinant',
#   'Interferon alpha-2a',
#   'Interferon-alfa-2a',
#   'Recombinant human interferon alfa-2a',
#   'Recombinant human interferon-alfa-2a',
#   'rIFN-alpha-2a',
#   'SH-polypeptide-46',
#   'Interferon alfa-2a, Recombinant'],
#  'Desmopressin': ['1-(3-mercaptopropionic acid)-8-D-arginine-vasopressin',
#   '1-deamino-8-D-arginine vasopressin',
#   '1-desamino-8-D-arginine vasopressin',
#   'dDAVP',
#   'Desmopresina',
#   'Desmopressin',
#   'Desmopressine',
#   'Desmopressinum',
#   'Desmopressin'],
#  'Coagulation factor VIIa Recombinant Human': ['Coagulation factor VIIa',
#   'Coagulation factor VIIa (recombinant)',
#   'Coagulation factor VIIa (recombinant)-jncw',
#   'Eptacog alfa',
#   'Eptacog alfa (activated)',
#   'rFVIIa',
#   'Coagulation factor VIIa Recombinant Human'],
#  'Oprelvekin': ['IL-11',
#   'Interleukin 11',
#   'Interleukin-11',
#   'Oprelvekin',
#   'Recombinant interleukin-11',
#   'Oprelvekin'],
#  'Palifermin': ['24-163 fibroblast growth factor 7 (human)',
#   'Palifermina',
#   'Palifermin'],
#  'Glucagon': ['Glucagon',
#   'Glucagon (recombinant dna origin)',
#   'Glucagon recombinant',
#   'Glucagon, human',
#   'Glucagon, porcine',
#   'Glucagone',
#   'Glucagonum',
#   'Glucagon'],
#  'Aldesleukin': ['125-L-serine-2-133-interleukin 2 (human reduced)',
#   'Aldesleukina',
#   'Interleukin-2 aldesleukin',
#   'Interleukin-2(2-133),125-ser',
#   'Recombinant interleukin-2 human',
#   'Aldesleukin'],
#  'Botulinum Toxin Type B': ['Botulin B',
#   'Botulinum B toxin',
#   'Botulinum neurotoxin type B precursor',
#   'BTX-B',
#   'RimabotulinumtoxinB',
#   'Toxina botulÃ\xadnica B',
#   'Botulinum Toxin Type B'],
#  'Omalizumab': ['Omalizumab'],
#  'Lutropin alfa': ['Lutropin alfa',
#   'Lutropin alpha',
#   'Lutropina alfa',
#   'Lutropin alfa'],
#  'Lyme disease vaccine (recombinant OspA)': ['Lipoprotein OspA antigen recombinant',
#   'Lipoprotein outer surface a borrelia burgdorferi antigen',
#   'OspA lipoprotein',
#   'Lyme disease vaccine (recombinant OspA)'],
#  'Insulin lispro': ['Insulin lispro (genetical recombination)',
#   'Insulin lispro (rDNA origin)',
#   'Insulin lispro protamine',
#   'Insulin lispro protamine recombinant',
#   'Insulin lispro recombinant',
#   'insulin lispro-aabc',
#   'Insulin,lispro,human/rDNA',
#   'Insulin,lispro,protamine/rDNA',
#   'Insulina lispro',
#   'Insulin lispro'],
#  'Insulin glargine': ['Insulin glargine',
#   'Insulin Glargine (rDNA origin)',
#   'Insulin glargine recombinant',
#   'Insulina glargina',
#   'Insulin glargine'],
#  'Collagenase clostridium histolyticum': ['Clostridium histolyticum enzymes',
#   'Collagenase',
#   'Collagenase clostridium histolyticum',
#   'Collagenase clostridium histolyticum'],
#  'Rasburicase': ['Rasburicasa', 'Rasburicase', 'Urate oxidase', 'Rasburicase'],
#  'Cetrorelix': ['Cetrorelix', 'Cetrorelixum', 'Cetrorelix'],
#  'Adalimumab': ['Adalimumab (genetical recombination)',
#   'adalimumab-adaz',
#   'adalimumab-adbm',
#   'adalimumab-afzb',
#   'adalimumab-atto',
#   'adalimumab-bwwd',
#   'Adalimumab'],
#  'Somatotropin': ['Growth hormone',
#   'Growth hormone (human)',
#   'hGH',
#   'Human growth hormone',
#   'Recombinant human growth hormone',
#   'rhGH',
#   'Somatotropin (human)',
#   'Somatotropin human',
#   'Somatotropin human growth hormone',
#   'Somatropin',
#   'Somatropin (rDNA origin)',
#   'Somatropin (recombinant DNA origin)',
#   'Somatropin [rDNA origin]',
#   'Somatropin recombinant',
#   'Somatropin(recombinant DNA origin)',
#   'Somatropina',
#   'Somatotropin'],
#  'Imiglucerase': ['Imiglucerasa', 'Imiglucerase'],
#  'Abciximab': ['Abciximab',
#   'Abciximab (genetical recombination)',
#   'c7E3',
#   'Abciximab'],
#  'Drotrecogin alfa': ['Activated protein C',
#   'Blood coagulation factor XIV (human)',
#   'Drotrecogin alfa (activated)',
#   'Drotrecogin alfa (activated), lyophilized',
#   'Drotrecogin alfa activated',
#   'Drotrecogin alfa, activated',
#   'Drotrecogin-alfa',
#   'Recombinant human activated protein C (rH-APC)',
#   'Drotrecogin alfa'],
#  'Gemtuzumab ozogamicin': ['Gemtuzumab ozogamicin'],
#  'Indium In-111 satumomab pendetide': ['Indium (111In) satumomab pendetide',
#   'Indium In 111 satumomab pendetide',
#   'Indium-111 satumomab pendetide',
#   'Indium In-111 satumomab pendetide'],
#  'Alpha-1-proteinase inhibitor': ['Alfa 1-proteinase inhibitor (human)',
#   'Alfa-1-antitripsina',
#   'Alfa1 antitrypsin',
#   'Alpha 1-antitrypsin',
#   'Alpha 1-Proteinase Inhibitor',
#   'Alpha 1-proteinase inhibitor (human)',
#   'Alpha 1-proteinase inhibitor, human',
#   'Alpha-1 protease inhibitor',
#   'Alpha-1 proteinase inhibitor (human)',
#   'Alpha-1-antiproteinase',
#   'Alpha-1-antitrypsin',
#   'Alpha-1-proteinase Inhibitor (human)',
#   'Alpha-1-proteinase inhibitor human',
#   'Alpha-1-proteinase Inhibitor, Human',
#   'Alpha-1-proteinase inhibitor,human',
#   'Alpha1-proteinase Inhibitor',
#   'Alpha1-proteinase inhibitor (human)',
#   'alpha1-proteinase inhibitor human',
#   'API',
#   'Alpha-1-proteinase inhibitor'],
#  'Pegaspargase': ['Peg-asparaginase',
#   'Peg/L-asparaginase',
#   'Pegaspargasa',
#   'Pegaspargase'],
#  'Interferon beta-1a': ['Interferon beta 1-a',
#   'Interferon beta 1a',
#   'Interferon beta-1a (recombinant human)',
#   'Interferon beta-1a,recombinant',
#   'Interferon-beta-1a',
#   'Interferon beta-1a'],
#  'Pegademase': ['(monomethoxypolyethylene glycol succinimidyl) 11-17-adenosine deaminase',
#   'PEG-adenosine deaminase',
#   'pegADA',
#   'Pegademase',
#   'Pegademase bovine',
#   'Pegademase'],
#  'Albumin human': ['Albumin (human)',
#   'Albumin human',
#   'Albumin, blood',
#   'Albumin, human',
#   'Albumin, human-kjda',
#   'Human albumin',
#   'Human serum albumin',
#   'Serum albumin',
#   'Albumin human'],
#  'Eptifibatide': ['Eptifibatida',
#   'Eptifibatide',
#   'Integrelin',
#   'Intrifiban',
#   'Eptifibatide'],
#  'Infliximab': ['Infliximab (genetical recombination)',
#   'Infliximab-abda',
#   'Infliximab-axxq',
#   'Infliximab-dyyb',
#   'Infliximab-qbtx',
#   'Infliximab'],
#  'Follitropin': ['Folitropina alfa',
#   'Folitropina beta',
#   'Folitropina delta',
#   'Follicle stimulating hormone',
#   'Follitrophin alfa',
#   'Follitrophin alpha',
#   'Follitrophin beta',
#   'Follitropin alfa',
#   'Follitropin alfa/beta',
#   'Follitropin alpha',
#   'Follitropin beta',
#   'Follitropin delta',
#   'Follitropin gamma',
#   'Follotropin recombinant',
#   'FSH',
#   'FSH alpha',
#   'FSH-a',
#   'FSH-b',
#   'FSH-beta',
#   'Recombinant human follicle stimulating hormone beta',
#   'Recombinant human follicle-stimulating hormone (r-HFSH)',
#   'rFSH-alpha',
#   'Follitropin'],
#  'Vasopressin': ['Vasopressin, unspecified', 'Vasopressina', 'Vasopressin'],
#  'Interferon beta-1b': ['Interferon beta 1b (recombinant)',
#   'Interferon beta-1b,recombinant',
#   'Interferon-beta-1b',
#   'Recombinant interferon beta-1b',
#   'Interferon beta-1b'],
#  'Interferon alfacon-1': ['IFN Alfacon-1',
#   'IFN-Con1',
#   'Interferon alfacon-1',
#   'Interferon alfacon-1'],
#  'Hyaluronidase (ovine)': ['Hyaluronidase (glycoprotein, sheep testis isoenzyme)',
#   'Hyaluronidase (ovine)',
#   'Hyaluronidase (sheep testis isoenzyme)',
#   'Hyaluronidase, ovine',
#   'Ovine hyaluronidase',
#   'Hyaluronidase (ovine)'],
#  'Insulin pork': ['Insulin (pork)',
#   'Insulin porcine',
#   'Insulin purified porcine',
#   'Insulin purified pork',
#   'Insulin, porcine',
#   'Insulin, regular, pork',
#   'Porcine insulin',
#   'Insulin pork'],
#  'Trastuzumab': ['RHUMAB HER2',
#   'trastuzumab-anns',
#   'trastuzumab-dkst',
#   'trastuzumab-dttb',
#   'trastuzumab-pkrb',
#   'trastuzumab-qyyp',
#   'Trastuzumab'],
#  'Rituximab': ['rituximab-abbs', 'rituximab-pvvr', 'Rituximab'],
#  'Basiliximab': ['Basiliximab', 'Basiliximab'],
#  'Muromonab': ['Anti-CD3', 'Muromonab-CD3', 'Muromonab'],
#  'Digoxin Immune Fab (Ovine)': ['Digitalis antitoxin',
#   'Digoxin Immune Fab, Ovine',
#   'Digoxin-specific Antibody Fragments',
#   'Ovine digoxin immune fab',
#   'Digoxin Immune Fab (Ovine)'],
#  'Ibritumomab tiuxetan': ['Ibritumomab',
#   'mAb Murine (IGG1) Anti P19437 (CD20_MOUSE)',
#   'Ibritumomab tiuxetan'],
#  'Daptomycin': ['Daptomicina',
#   'Daptomycin',
#   'Daptomycine',
#   'Daptomycinum',
#   'Daptomycin'],
#  'Tositumomab': ['Tositumomab'],
#  'Pegvisomant': ['Pegvisomant'],
#  'Botulinum toxin type A': ['AbobotulinumtoxinA',
#   'Botulinum A neurotoxin',
#   'Botulinum toxin A',
#   'Botulinum toxin type A',
#   'BTX-A',
#   'Evabotulinumtoxina',
#   'IncobotulinumtoxinA',
#   'OnabotulinumtoxinA',
#   'Prabotulinumtoxin A',
#   'Toxina botulÃ\xadnica A',
#   'Toxine botulinique A',
#   'Botulinum toxin type A'],
#  'Pancrelipase': ['Pancrealipase',
#   'Pancreatic extract pancrelipase',
#   'Pancreatic protease',
#   'Pancreatin',
#   'Pancreatinum',
#   'Pancrelipase (amylase;lipase;protease)',
#   'Pancrelipase'],
#  'Streptokinase': ['Estreptoquinasa',
#   'Streptochinasi',
#   'Streptococcal fibrinolysin',
#   'Streptokinase',
#   'Streptokinasum',
#   'Streptokinase'],
#  'Alemtuzumab': ['Alemtuzumab'],
#  'Alglucerase': ['Alglucerase'],
#  'Capromab pendetide': ['(111In)-Capromab pendetide',
#   'Indium (111In) capromab pendetide',
#   'Indium 111 Capromab Pendetide',
#   'Indium In 111 capromab pendetide',
#   'Capromab pendetide'],
#  'Laronidase': ['alpha-L-Idosiduronase',
#   'Human Recombinant alpha-L-iduronidase',
#   'Laronidasa',
#   'Laronidase',
#   'Laronidase (genetical recombination)',
#   'Laronidase'],
#  'Cyclosporine': ['Ciclosporin',
#   'Ciclosporina',
#   'Ciclosporine',
#   'Ciclosporinum',
#   'CsA',
#   'CyA',
#   'Cyclosporin',
#   'Cyclosporin A',
#   'Cyclosporine',
#   'Cyclosporine'],
#  'Alefacept': ['Alefacept'],
#  'Felypressin': ['2-(L-phenylalanine)-8-L-lysinevasopressin',
#   'Felipresina',
#   'Felypressin',
#   'Felypressine',
#   'Felypressinum',
#   'PLV-2',
#   'Felypressin'],
#  'Urofollitropin': ['Follitropin human', 'Urofollitrophin', 'Urofollitropin'],
#  'Efalizumab': ['anti-CD11a', 'antiCD11 alpha', 'Efalizumab', 'Efalizumab'],
#  'Choriogonadotropin alfa': ['Choriogonadotropin alpha',
#   'Chorionic gonadotropin (recombinant)',
#   'Choriogonadotropin alfa'],
#  'Antithymocyte immunoglobulin (rabbit)': ['Anti-human thymocyte immunoglobulin, rabbit',
#   'Anti-T-lymphocyte immune globulin, rabbit',
#   'Anti-thymocyte globulin (rabbit)',
#   'Anti-thymocyte globulin rabbit',
#   'Antithymocyte immunoglobulin',
#   'Lapine T-lymphocyte immune globulin',
#   'Rabbit anti-human thymocyte globulin',
#   'Rabbit anti-human thymocyte globulin (rATG)',
#   'Rabbit anti-human thymocyte immunoglobulin',
#   'Rabbit anti-thymocyte immunoglobulin',
#   'Rabbit antithymocyte globulin',
#   'Rabbit ATG',
#   'rATG',
#   'Thymoglobulin',
#   'Thymoglobuline',
#   'Antithymocyte immunoglobulin (rabbit)'],
#  'Filgrastim': ['Filgrastim-aafi',
#   'Filgrastim-sndz',
#   'G-CSF ',
#   'Granulocyte Colony Stimulating Factor ',
#   'Tbo-filgrastim',
#   'Filgrastim'],
#  'Coagulation Factor IX (Recombinant)': ['Coagulation factor IX (recombinant)',
#   'Coagulation factor IX recombinant human',
#   'Factor IX (Recombinant)',
#   'nonacog alfa',
#   'nonacog gamma',
#   'Recombinant factor IX',
#   'Coagulation Factor IX (Recombinant)'],
#  'Becaplermin': ['Becaplermin',
#   'PDGF-2',
#   'PDGF-BB',
#   'PDGFB',
#   'Platelet-derived growth factor BB, recombinant',
#   'Platelet-derived growth factor beta polypeptide',
#   'Recombinant platelet-derived growth factor BB',
#   'rhPDGF-BB',
#   'rPDGF-BB',
#   'SH-POLYPEPTIDE-59',
#   'Becaplermin'],
#  'Agalsidase beta': ['Agalsidasa alfa',
#   'Agalsidasa beta',
#   'Agalsidase alfa',
#   'Alpha-galactosidase A',
#   'Agalsidase beta'],
#  'Octreotide': ['Octreotida',
#   'Octreotide',
#   'Octreotidum',
#   'Octrotide',
#   'Octreotide'],
#  'Interferon alfa-2b': ['Interferon alfa-2b',
#   'Interferon alfa-2b, recombinant',
#   'Interferon alpha-2B',
#   'Interferon Î±-2b',
#   'Intron (Interferon Î±2b)',
#   'Intron A',
#   'Intron A (Interferon Î±2b)',
#   'r-INF-alpha',
#   'rIFN-alpha-2b',
#   'Interferon alfa-2b'],
#  'Abarelix': ['Abarelix', 'Abarelix'],
#  'Oxytocin': ['Oxitocina', 'Oxytocin', 'Oxytocin'],
#  'Natalizumab': ['Anti-alpha4 integrin', 'Anti-VLA4', 'Natalizumab'],
#  'Enfuvirtide': ['Enfuvirtida', 'Enfuvirtide'],
#  'Palivizumab': ['Palivizumab', 'Palivizumab'],
#  'Daclizumab': ['Dacliximab', 'Daclizumab beta', 'Daclizumab'],
#  'Bevacizumab': ['Anti-VEGF Humanized Monoclonal Antibody',
#   'Anti-VEGF monoclonal antibody',
#   'Bevacizumab',
#   'bevacizumab-awwb',
#   'rhuMAb-VEGF',
#   'Bevacizumab'],
#  'Technetium Tc-99m arcitumomab': ['Arcitumomab technetium-99m',
#   'Technetium (99mTc) arcitumomab',
#   'Technetium Tc 99m arcitumomab',
#   'Technetium-99m arcitumomab',
#   'Technetium Tc-99m arcitumomab'],
#  'Pyridoxal phosphate': ['3-hydroxy-2-methyl-5-((phosphonooxy)methyl)-4-pyridinecarboxaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde 5-phosphate',
#   'Codecarboxylase',
#   'PLP',
#   'Pyridoxal 5-monophosphoric acid ester',
#   'Pyridoxal 5-phosphate',
#   "Pyridoxal 5'-phosphate",
#   'Pyridoxal P',
#   'Pyridoxal phosphate anhydrous',
#   'Pyridoxal-5P',
#   'Pyridoxal-P',
#   'Pyridoxal phosphate'],
#  'Cyanocobalamin': ['Cianocobalamina',
#   'Cyanocob(III)alamin',
#   'Cyanocobalamin',
#   'Cyanocobalamine',
#   'Cyanocobalaminum',
#   'Vitamin B12',
#   'Vitamin B12 complex',
#   'Vitamin B12 NOS',
#   'Cyanocobalamin'],
#  'Tetrahydrofolic acid': ['5,6,7,8-tetrahydrofolate',
#   '5,6,7,8-tetrahydrofolic acid',
#   'Tetrahydrofolate',
#   'Tetrahydrofolic acid'],
#  'Histidine': ['(S)-4-(2-Amino-2-carboxyethyl)imidazole',
#   '(S)-a-Amino-1H-imidazole-4-propanoic acid',
#   '(S)-alpha-amino-1H-Imidazole-4-propanoic acid',
#   '(S)-alpha-Amino-1H-imidazole-4-propionic acid',
#   '(S)-Î±-amino-1H-Imidazole-4-propanoic acid',
#   'HIS',
#   'Histidina',
#   'Histidine',
#   'L-(â\x88\x92)-histidine',
#   'L-Histidin',
#   'L-Histidine',
#   'Histidine'],
#  'Ademetionine': ['Ademetionine',
#   'AdoMet',
#   'L-S-Adenosylmethionine',
#   'S-Adenosylmethionine',
#   'SAM',
#   'SAM-e',
#   'SAMe',
#   'Ademetionine'],
#  'Pyruvic acid': ['2-ketopropionic acid',
#   '2-oxopropanoic acid',
#   '2-OxopropansÃ¤ure',
#   '2-OxopropionsÃ¤ure',
#   'a-Ketopropionic acid',
#   'Acetylformic acid',
#   'acide pyruvique',
#   'alpha-ketopropionic acid',
#   'BrenztraubensÃ¤ure',
#   'BTS',
#   'Pyroracemic acid',
#   'Î±-ketopropionic acid',
#   'Î±-OxopropionsÃ¤ure',
#   'Pyruvic acid'],
#  'Phenylalanine': ['(S)-2-Amino-3-phenylpropionic acid',
#   '(S)-alpha-Amino-beta-phenylpropionic acid',
#   '3-phenyl-L-alanine',
#   'beta-Phenyl-L-alanine',
#   'F',
#   'Fenilalanina',
#   'L-Phenylalanine',
#   'Phe',
#   'Phenylalanine',
#   'Phenylalaninum',
#   'Î²-phenyl-L-alanine',
#   'Phenylalanine'],
#  'Biotin': ['(+)-cis-Hexahydro-2-oxo-1H-thieno[3,4]imidazole-4-valeric acid',
#   '(3aS,4S,6aR)-Hexahydro-2-oxo-1H-thieno[3,4-d]imidazole-4-valeric acid',
#   '5-(2-oxohexahydro-1H-thieno[3,4-d]imidazol-4-yl)pentanoic acid',
#   'Biotin',
#   'Biotina',
#   'Biotine',
#   'Biotinum',
#   'cis-(+)-Tetrahydro-2-oxothieno[3,4]imidazoline-4-valeric acid',
#   'cis-Hexahydro-2-oxo-1H-thieno(3,4)imidazole-4-valeric acid',
#   'cis-Tetrahydro-2-oxothieno(3,4-d)imidazoline-4-valeric acid',
#   'Coenzyme R',
#   'D-(+)-biotin',
#   'D-Biotin',
#   'Vitamin B7',
#   'Vitamin H',
#   'Biotin'],
#  'Choline': ['Bilineurine',
#   'Choline ion',
#   'N-trimethylethanolamine',
#   'N,N,N-trimethylethanol-ammonium',
#   'trimethylethanolamine',
#   'Vitamin J',
#   'Choline'],
#  'L-Lysine': ['(S)-2,6-diaminohexanoic acid',
#   '(S)-lysine',
#   '(S)-Î±,Îµ-diaminocaproic acid',
#   '6-ammonio-L-norleucine',
#   'L-2,6-Diaminocaproic acid',
#   'L-lys',
#   'L-Lysin',
#   'LYS',
#   'Lysina',
#   'Lysine',
#   'Lysine acid',
#   'Lysinum',
#   'L-Lysine'],
#  'Arginine': ['(2S)-2-amino-5-(carbamimidamido)pentanoic acid',
#   '(2S)-2-amino-5-guanidinopentanoic acid',
#   '(S)-2-amino-5-guanidinopentanoic acid',
#   '(S)-2-Amino-5-guanidinovaleric acid',
#   'Arg',
#   'Arginina',
#   'Arginine',
#   'L-(+)-Arginine',
#   'L-Arg',
#   'L-Arginin',
#   'L-arginine',
#   'R',
#   'Arginine'],
#  'Ascorbic acid': ['acide ascorbique',
#   'Ã¡cido ascÃ³rbico',
#   'Acidum ascorbicum',
#   'acidum ascorbinicum',
#   'Ascorbate',
#   'Ascorbic acid',
#   'AscorbinsÃ¤ure',
#   'L-(+)-ascorbic acid',
#   'L-Ascorbate',
#   'L-Ascorbic Acid',
#   'Vitamin C',
#   'Vitamina C',
#   'Ascorbic acid'],
#  'Spermine': ['4,9-diaza-1,12-dodecanediamine',
#   '4,9-diazadodecane-1,12-diamine',
#   'Musculamine',
#   "N,N'-Bis(3-aminopropyl)-1,4-butanediamine",
#   'Spermina',
#   'Spermine',
#   'Spermine'],
#  'Aspartic acid': ['(S)-2-aminobutanedioic acid',
#   '(S)-2-aminosuccinic acid',
#   '2-Aminosuccinic acid',
#   'Ã¡cido aspÃ¡rtico',
#   'Acidum asparticum',
#   'Asp',
#   'Aspartic acid',
#   'D',
#   'L-Asp',
#   'L-AsparaginsÃ¤ure',
#   'L-Aspartate',
#   'L-Aspartic acid',
#   'Aspartic acid'],
#  'Ornithine': ['(S)-2,5-Diaminopentanoate',
#   '(S)-2,5-Diaminopentanoic acid',
#   '(S)-2,5-diaminovaleric acid',
#   '(S)-ornithine',
#   '(S)-Î±,Î´-diaminovaleric acid',
#   'L-Ornithine',
#   'levo-ornithine',
#   'Ornithine',
#   'Ornithinum',
#   'Ornitina',
#   'Ornithine'],
#  'L-Glutamine': ['(2S)-2-amino-4-carbamoylbutanoic acid',
#   '(2S)-2,5-diamino-5-oxopentanoic acid',
#   '(S)-2,5-diamino-5-oxopentanoic acid',
#   'Glutamic acid 5-amide',
#   'Glutamic acid amide',
#   'Glutamina',
#   'Glutamine',
#   'L-(+)-glutamine',
#   'L-2-aminoglutaramic acid',
#   'L-glutamic acid Î³-amide',
#   'L-Glutamin',
#   'L-GlutaminsÃ¤ure-5-amid',
#   'Levoglutamide',
#   'Q',
#   'L-Glutamine'],
#  'Adenosine phosphate': ["5'-Adenosine monophosphate",
#   "5'-Adenylic acid",
#   "5'-AMP",
#   "5'-O-Phosphonoadenosine",
#   "Adenosine 5'-(dihydrogen phosphate)",
#   "Adenosine 5'-monophosphate",
#   "Adenosine 5'-phosphate",
#   'Adenosine monophosphate',
#   'Adenosine phosphate',
#   "Adenosine-5'-Monophosphate",
#   "Adenosine-5'-monophosphoric acid",
#   "Adenosine-5'P",
#   'Adenosini phosphas',
#   'Adenylate',
#   'Adenylic acid',
#   "Ado5'P",
#   'AMP',
#   'Fosfato de adenosina',
#   'PAdo',
#   "Phosphate d'adÃ©nosine",
#   'Adenosine phosphate'],
#  'alpha-Linolenic acid': ['(9,12,15)-linolenic acid',
#   '(9Z,12Z,15Z)-Octadecatrienoic acid',
#   '(Z,Z,Z)-9,12,15-octadecatrienoic acid',
#   '9-cis,12-cis,15-cis-octadecatrienoic acid',
#   '9,12,15-Octadecatrienoic acid',
#   'ALA',
#   'all-cis-9,12,15-Octadecatrienoic acid',
#   'alpha-Linolenic acid',
#   'cis-delta(9,12,15)-Octadecatrienoic acid',
#   'cis,cis,cis-9,12,15-Octadecatrienoic acid',
#   'Linolenic acid',
#   'Î±-linolenic acid',
#   'alpha-Linolenic acid'],
#  'Serine': ['(S)-2-Amino-3-hydroxypropanoic acid',
#   '(S)-Serine',
#   'alpha-Amino-beta-hydroxypropionic acid',
#   'beta-Hydroxyalanine',
#   'L-Serine',
#   'Ser',
#   'Serina',
#   'Serine',
#   'Serinum',
#   'Serine'],
#  'Methionine': ['(2S)-2-amino-4-(methylsulfanyl)butanoic acid',
#   '(S)-2-amino-4-(methylthio)butanoic acid',
#   '(S)-2-amino-4-(methylthio)butyric acid',
#   '(S)-methionine',
#   'L-(â\x88\x92)-methionine',
#   'L-a-Amino-g-methylthiobutyric acid',
#   'L-Methionin',
#   'L-Methionine',
#   'L-Î±-amino-Î³-methylmercaptobutyric acid',
#   'M',
#   'Met',
#   'Methionine',
#   'Methionine'],
#  'Tyrosine': ['(â\x88\x92)-Î±-amino-p-hydroxyhydrocinnamic acid',
#   '(2S)-2-amino-3-(4-hydroxyphenyl)propanoic acid',
#   '(S)-(-)-Tyrosine',
#   '(S)-2-Amino-3-(p-hydroxyphenyl)propionic acid',
#   '(S)-3-(p-Hydroxyphenyl)alanine',
#   '(S)-alpha-amino-4-Hydroxybenzenepropanoic acid',
#   '(S)-Tyrosine',
#   '(S)-Î±-amino-4-hydroxybenzenepropanoic acid',
#   '4-hydroxy-L-phenylalanine',
#   'L-Tyrosin',
#   'L-tyrosine',
#   'Tirosina',
#   'Tyr',
#   'Tyrosine',
#   'Tyrosinum',
#   'Y',
#   'Tyrosine'],
#  'Calcitriol': ['(1S,3R,5Z,7E)-9,10-secocholesta-5,7,10-triene-1,3,25-triol',
#   '(1Î±,3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol',
#   '(5Z,7E)-(1S,3R)-9,10-secocholesta-5,7,10(19)-triene-1,3,25-triol',
#   '1-alpha-25-Dihydroxyvitamin D3',
#   '1,25-DHCC',
#   '1,25-dihydroxycholecalciferol',
#   '1Î±,25-dihydroxycholecalciferol',
#   '1Î±,25-dihydroxyvitamin D3',
#   '1Î±,25(OH)2D3',
#   'Calcitriol',
#   'Calcitriolum',
#   'Calcitriol'],
#  'Lutein': ['Xanthophyll', 'Xantofyl', 'Lutein'],
#  'Cystine': ["(R,R)-3,3'-dithiobis(2-aminopropanoic acid)",
#   'Cistina',
#   'L-alpha-Diamino-beta-dithiolactic acid',
#   'L-Cystine',
#   'L-Dicysteine',
#   "Î²,Î²'-dithiodialanine",
#   'Cystine'],
#  'Succinic acid': ['1,2-ethanedicarboxylic acid',
#   'Acide butanedioÃ¯que',
#   'Acide succinique',
#   'Acidum succinicum',
#   'Amber acid',
#   'Asuccin',
#   'BernsteinsÃ¤ure',
#   'ButandisÃ¤ure',
#   'Butanedioic acid',
#   'Butanedionic acid',
#   'Dihydrofumaric acid',
#   'Ethylenesuccinic acid',
#   'Spirit of amber',
#   'Succinic acid',
#   'Succinic acid'],
#  'Riboflavin': ['1-Deoxy-1-(7,8-dimethyl-2,4-dioxo-3,4-dihydrobenzo[g]pteridin-10(2H)-yl)pentitol',
#   '6,7-Dimethyl-9-D-ribitylisoalloxazine',
#   '7,8-Dimethyl-10-(D-ribo-2,3,4,5-tetrahydroxypentyl)isoalloxazine',
#   '7,8-Dimethyl-10-ribitylisoalloxazine',
#   'Lactoflavin',
#   'Lactoflavine',
#   'Riboflavin',
#   'Riboflavina',
#   'Riboflavine',
#   'Riboflavinum',
#   'Vitamin B2',
#   'Vitamin Bi',
#   'Vitamin G',
#   'Riboflavin'],
#  'N-Acetylglucosamine': ['2-Acetamido-2-deoxy-D-glucose',
#   'aldehydo-N-acetyl-D-glucosamine',
#   'D-GlcNAc',
#   'N-Acetyl-D-glucosamine',
#   'N-Acetylchitosamine',
#   'N-Acetylglucosamine'],
#  'Glutamic acid': ['(2S)-2-Aminopentanedioic acid',
#   '(S)-2-Aminopentanedioic acid',
#   '(S)-Glutamic acid',
#   'Ã¡cido glutÃ¡mico',
#   'Glu',
#   'Glutamic acid',
#   'L-Glutamate',
#   'L-Glutamic acid',
#   'L-Glutaminic acid',
#   'Glutamic acid'],
#  'Glutathione': ['5-L-Glutamyl-L-cysteinylglycine',
#   'gamma-L-Glutamyl-L-cysteinyl-glycine',
#   'Glutathione',
#   'Glutathione-SH',
#   'GSH',
#   'N-(N-gamma-L-Glutamyl-L-cysteinyl)glycine',
#   'Reduced glutathione',
#   'Glutathione'],
#  'Phosphatidyl serine': ['Phosphatidyl-L-serine',
#   'Phosphatidylserine',
#   'PS',
#   'Ptd-L-Ser',
#   'Phosphatidyl serine'],
#  'Glycine': ['Aminoacetic acid',
#   'AminoessigsÃ¤ure',
#   'Aminoethanoic acid',
#   'Glicina',
#   'Gly',
#   'Glycin',
#   'Glycine',
#   'Glycocoll',
#   'Glykokoll',
#   'Glyzin',
#   'Leimzucker',
#   'Glycine'],
#  'Calcifediol': ['(3S,5Z,7E)-9,10-secocholesta-5,7,10-triene-3,25-diol',
#   '(3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol',
#   '(5Z,7E)-(3S)-9,10-secocholesta-5,7,10(19)-triene-3,25-diol',
#   '25-hydroxycholecalciferol',
#   '25-Hydroxyvitamin D3',
#   'Calcidiol',
#   'CalcifÃ©diol',
#   'Calcifediol',
#   'Calcifediol anhydrous',
#   'Calcifediolum',
#   'Calcifediol'],
#  'Pyridoxal': ['2-methyl-3-hydroxy-4-formyl-5-hydroxymethylpyridine',
#   '3-hydroxy-5-(hydroxymethyl)-2-methyl-4-pyridinecarboxaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylisonicotinaldehyde',
#   '3-hydroxy-5-(hydroxymethyl)-2-methylpyridine-4-carboxaldehyde',
#   'Piridoxal',
#   'Pyridoxaldehyde',
#   'Pyridoxal'],
#  'Creatine': ['((amino(Imino)methyl)(methyl)amino)acetic acid',
#   '(alpha-Methylguanido)acetic acid',
#   '(N-methylcarbamimidamido)acetic acid',
#   '(Î±-methylguanido)acetic acid',
#   'alpha-Methylguanidino acetic acid',
#   'Creatin',
#   'Creatine',
#   'Kreatin',
#   'Methylglycocyamine',
#   'N-(aminoiminomethyl)-N-methylglycine',
#   'N-amidinosarcosine',
#   'N-carbamimidoyl-N-methylglycine',
#   'N-methyl-N-guanylglycine',
#   'Creatine'],
#  'Leucine': ['(2S)-2-Amino-4-methylpentanoic acid',
#   '(2S)-alpha-2-Amino-4-methylvaleric acid',
#   '(2S)-alpha-Leucine',
#   '(S)-(+)-Leucine',
#   '(S)-Leucine',
#   '2-Amino-4-methylvaleric acid',
#   'L',
#   'L-Leucin',
#   'L-Leucine',
#   'L-Leuzin',
#   'Leu',
#   'Leucine',
#   'Leucine'],
#  'Tryptophan': ['(2S)-2-amino-3-(1H-indol-3-yl)propanoic acid',
#   '(S)-alpha-Amino-beta-(3-indolyl)-propionic acid',
#   '(S)-Tryptophan',
#   '(S)-Î±-amino-1H-indole-3-propanoic acid',
#   'L-(-)-Tryptophan',
#   'L-(â\x88\x92)-tryptophan',
#   'L-Tryptophan',
#   'L-Î²-3-indolylalanine',
#   'Triptofano',
#   'Trp',
#   'Tryptophan',
#   'Tryptophane',
#   'Tryptophanum',
#   'W',
#   'Tryptophan'],
#  'Cysteine': ['(2R)-2-amino-3-mercaptopropanoic acid',
#   '(2R)-2-amino-3-sulfanylpropanoic acid',
#   '(R)-2-Amino-3-mercaptopropanoic acid',
#   'Cisteina',
#   'Cisteinum',
#   'Cys',
#   'Cysteine',
#   'Cysteinum',
#   'Free Cysteine',
#   'L-2-Amino-3-mercaptopropionic acid',
#   'L-Cys',
#   'L-Cystein',
#   'L-Zystein',
#   'Cysteine'],
#  'Thiamine': ['Aneurin',
#   'Antiberiberi factor',
#   'Thiamin',
#   'Thiamine',
#   'thiamine(1+)',
#   'thiamine(1+) ion',
#   'thiaminium',
#   'Thiaminum',
#   'Tiamina',
#   'Vitamin B1',
#   'Thiamine'],
#  'Ergocalciferol': ['(3Î²,5Z,7E,22E)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol',
#   '(5Z,7E,22E)-(3S)-9,10-seco-5,7,10(19),22-ergostatetraen-3-ol',
#   '(5Z,7E,22E)-(3S)-9,10-secoergosta-5,7,10(19),22-tetraen-3-ol',
#   'Activated ergosterol',
#   'Ercalciol',
#   'ErgocalcifÃ©rol',
#   'Ergocalciferol',
#   'Ergocalciferolum',
#   'Oleovitamin D2',
#   'Viosterol',
#   'Vitamin D2',
#   'Vitamina D2',
#   'Ergocalciferol'],
#  'Dihomo-gamma-linolenic acid': ['(8Z,11Z,14Z)-Icosatrienoic acid',
#   '(Z,Z,Z)-8,11,14-Eicosatrienoic acid',
#   '(Z,Z,Z)-8,11,14-Icosatrienoate',
#   '(Z,Z,Z)-8,11,14-Icosatrienoic acid',
#   '20:3, n-6,9,12 all-cis',
#   '8,11,14-Eicosatrienoic Acid',
#   '8c,11c,14c-eicosatrienoic acid',
#   '8c,11c,14c-EicosatriensÃ¤ure',
#   'all-cis-8,11,14-eicosatrienoic acid',
#   'all-cis-8,11,14-icosatrienoic acid',
#   'all-cis-eicosa-8,11,14-trienoic acid',
#   'all-cis-Eicosa-8,11,14-triensÃ¤ure',
#   'all-cis-icosa-8,11,14-trienoic acid',
#   'C20:3, n-6,9,12 all-cis',
#   'cis,cis,cis-8,11,14-eicosatrienoic acid',
#   'DGLA',
#   'dihomo-Î³-linolenic acid',
#   'eicosa-8Z,11Z,14Z-trienoic acid',
#   'gamma-Homolinolenic acid',
#   'Homo-gamma-linolenic acid',
#   'Homo-gamma-linolensÃ¤ure',
#   'Homo-Î³-linolensÃ¤ure',
#   'Dihomo-gamma-linolenic acid'],
#  'Citrulline': ['(S)-2-Amino-5-ureidopentanoic acid',
#   '2-Amino-5-ureidovaleric acid',
#   'alpha-amino-delta-Ureidovaleric acid',
#   'Cit',
#   'Citrulina',
#   'Citrulline',
#   'delta-Ureidonorvaline',
#   'L-2-Amino-5-ureidovaleric acid',
#   'L-Citrulline',
#   'N(5)-(Aminocarbonyl)-L-ornithine',
#   'N(delta)-Carbamylornithine',
#   'N5-(Aminocarbonyl)ornithine',
#   'N5-Carbamoyl-L-ornithine',
#   'N5-carbamoylornithine',
#   'Î±-amino-Î´-ureidovaleric acid',
#   'Î´-ureidonorvaline',
#   'Citrulline'],
#  'Threonine': ['(2S,3R)-(-)-Threonine',
#   '(2S)-threonine',
#   '2-Amino-3-hydroxybutyric acid',
#   'L-(-)-Threonine',
#   'L-2-Amino-3-hydroxybutyric acid',
#   'L-alpha-amino-beta-hydroxybutyric acid',
#   'L-Threonin',
#   'L-Threonine',
#   'L-Î±-amino-Î²-hydroxybutyric acid',
#   'Thr',
#   'Threonine',
#   'Threoninum',
#   'Treonina',
#   'Threonine'],
#  'NADH': ['1,4-dihydronicotinamide adenine dinucleotide',
#   'DPNH',
#   'NAD reduced form',
#   'Nicotinamide adenine dinucleotide (reduced)',
#   'Nicotinamide-adenine dinucleotide, reduced',
#   'Reduced nicotinamide adenine diphosphate',
#   'Reduced nicotinamide-adenine dinucleotide',
#   'NADH'],
#  'Folic acid': ['Acide folique',
#   'Ã¡cido fÃ³lico',
#   'Acidum folicum',
#   'Folacin',
#   'Folate',
#   'Folic acid',
#   'FolsÃ¤ure',
#   'N-[(4-{[(2-amino-4-oxo-1,4-dihydropteridin-6-yl)methyl]amino}phenyl)carbonyl]-L-glutamic acid',
#   'N-pteroyl-L-glutamic acid',
#   'PGA',
#   'PteGlu',
#   'Pteroyl-L-glutamate',
#   'Pteroyl-L-glutamic acid',
#   'Pteroyl-L-monoglutamic acid',
#   'Pteroylglutamic acid',
#   'Vitamin B9',
#   'Vitamin Bc',
#   'Vitamin M',
#   'Folic acid'],
#  'Icosapent': ['(5Z,8Z,11Z,14Z,17Z)-5,8,11,14,17-eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoate',
#   '(5Z,8Z,11Z,14Z,17Z)-Eicosapentaenoic acid',
#   '(5Z,8Z,11Z,14Z,17Z)-Icosapentaenoic acid',
#   '(all-Z)-5,8,11,14,17-eicosapentaenoic acid',
#   '5,8,11,14,17-eicosapentaenoic acid',
#   '5,8,11,14,17-Icosapentaenoic acid',
#   'all-cis-5,8,11,14,17-eicosapentaenoic acid',
#   'all-cis-5,8,11,14,17-icosapentaenoic acid',
#   'all-cis-icosa-5,8,11,14,17-pentaenoic acid',
#   'cis-5,8,11,14,17-eicosapentaenoic acid',
#   'cis-5,8,11,14,17-EPA',
#   'cis-delta(5,8,11,14,17)-Eicosapentaenoic acid',
#   'Eicosapentaenoic acid',
#   'EPA',
#   'Icosapent',
#   'Icosapentaenoic acid',
#   'Icosapento',
#   'Icosapentum',
#   'Timnodonic acid',
#   'Icosapent'],
#  'Alanine': ['(2S)-2-aminopropanoic acid',
#   '(S)-2-aminopropanoic acid',
#   '(S)-alanine',
#   'Alanina',
#   'Alanine',
#   'Alaninum',
#   'L-2-Aminopropionic acid',
#   'L-Alanin',
#   'L-alanine',
#   'L-alpha-Alanine',
#   'L-Î±-alanine',
#   'Alanine'],
#  'Valine': ['(2S)-2-Amino-3-methylbutanoic acid',
#   '(S)-Valine',
#   '2-Amino-3-methylbutyric acid',
#   'L-(+)-alpha-Aminoisovaleric acid',
#   'L-alpha-Amino-beta-methylbutyric acid',
#   'L-valin',
#   'L-valine',
#   'Val',
#   'Valine',
#   'Valine'],
#  'Vitamin A': ['(2E,4E,6E,8E)-3,7-dimethyl-9-(2,6,6-trimethylcyclohex-1-en-1-yl)nona-2,4,6,8-tetraen-1-ol',
#   'all-trans-retinol',
#   'all-trans-retinyl alcohol',
#   'all-trans-vitamin A alcohol',
#   'Retinol',
#   'Retinolum',
#   'Vitamin A1',
#   'Vitamin A'],
#  'Vitamin E': ['(+)-Î±-tocopherol',
#   "(2R,4'R,8'R)-Î±-tocopherol",
#   '(2R)-2,5,7,8-TETRAMETHYL-2-[(4R,8R)-4,8,12-TRIMETHYLTRIDECYL]CHROMAN-6-OL',
#   '(R,R,R)-Î±-tocopherol',
#   '5,7,8-trimethyltocol',
#   'alpha-tocopherol',
#   'd-Î±-tocopherol',
#   'Vitamin E'],
#  'Pyridoxine': ['2-methyl-3-hydroxy-4,5-dihydroxymethylpyridine',
#   '3-hydroxy-4,5-bis(hydroxymethyl)-2-methylpyridine',
#   '3-hydroxy-4,5-dimethylol-Î±-picoline',
#   '5-hydroxy-6-methyl-3,4-pyridinedimethanol',
#   'Piridoxina',
#   'Pyridoxine',
#   'Pyridoxinum',
#   'Pyridoxol',
#   'Vitamin B6',
#   'Pyridoxine'],
#  'Lipoic acid': ['(+)-alpha-Lipoic acid',
#   '(R)-(+)-Lipoate',
#   '(R)-(+)-lipoic acid',
#   '(R)-1,2-Dithiolane-3-pentanoic acid',
#   '(R)-1,2-dithiolane-3-valeric acid',
#   '(R)-6,8-thioctic acid',
#   '(R)-lipoic acid',
#   'Alpha lipoic acid',
#   'alpha-Lipoic acid',
#   'alpha-LiponsÃ¤ure',
#   'D-thioctic acid',
#   'Lipoic acid',
#   'R-(+)-thioctic acid',
#   'R-alpha-lipoic acid',
#   'Thioctic acid',
#   'Thioctic acid D-form',
#   'Î±-lipoic acid',
#   'Lipoic acid'],
#  'Isoleucine': ['(2S,3S)-2-Amino-3-methylpentanoic acid',
#   '2-Amino-3-methylvaleric acid',
#   'alpha-amino-beta-methylvaleric acid',
#   'Ile',
#   'Isoleucina',
#   'Isoleucine',
#   'Isoleucinum',
#   'L-Isoleucine',
#   'Î±-amino-Î²-methylvaleric acid',
#   'Isoleucine'],
#  'Aspartame': ['1-Methyl N-L-alpha-aspartyl-L-phenylalanate',
#   '1-methyl N-L-Î±-aspartyl-L-phenylalanate',
#   '3-Amino-N-(alpha-carboxyphenethyl)succinamic acid N-methyl ester',
#   '3-Amino-N-(alpha-methoxycarbonylphenethyl) succinamic acid',
#   '3-Amino-N-(Î±-carboxyphenethyl)succinamic acid N-methyl ester',
#   '3-Amino-N-(Î±-methoxycarbonylphenethyl) succinamic acid',
#   'Asp-phe-ome',
#   'Aspartam',
#   'Aspartame',
#   'Aspartamo',
#   'Aspartamum',
#   'Aspartylphenylalanine methyl ester',
#   'L-Aspartyl-L-phenylalanine methyl ester',
#   'Aspartame'],
#  'Cholecalciferol': ['(+)-vitamin D3',
#   '(3Î²,5Z,7E)-9,10-secocholesta-5,7,10(19)-trien-3-ol',
#   '(5Z,7E)-(3S)-9,10-secocholesta-5,7,10(19)-trien-3-ol',
#   'Activated 7-dehydrocholesterol',
#   'Calciol',
#   'CC',
#   'Cholecalciferol',
#   'Cholecalciferolum',
#   'Colecalciferol',
#   'Colecalciferolum',
#   'Oleovitamin D3',
#   'Vitamin D-3',
#   'Vitamin D3',
#   'Cholecalciferol'],
#  'Menadione': ['2-Methyl-1,4-Naphthalenedione',
#   '2-Methyl-1,4-naphthochinon',
#   '2-Methyl-1,4-naphthoquinone',
#   'Vitamin K 3',
#   'Vitamin K3',
#   'Menadione'],
#  'ATP': ["Adenosine 5'-triphosphate",
#   'Adenosine triphosphate',
#   "Adenosine-5'-triphosphate",
#   'ATP',
#   'ATP'],
#  'Proline': ['(-)-2-Pyrrolidinecarboxylic acid',
#   '(â\x88\x92)-(S)-proline',
#   '(â\x88\x92)-2-pyrrolidinecarboxylic acid',
#   '(â\x88\x92)-proline',
#   '(2S)-pyrrolidine-2-carboxylic acid',
#   '(S)-2-Carboxypyrrolidine',
#   '(S)-2-Pyrrolidinecarboxylic acid',
#   '(S)-pyrrolidine-2-carboxylic acid',
#   '2-Pyrrolidinecarboxylic acid',
#   'L-(â\x88\x92)-proline',
#   'L-alpha-pyrrolidinecarboxylic acid',
#   'L-Prolin',
#   'L-Proline',
#   'L-pyrrolidine-2-carboxylic acid',
#   'L-Î±-pyrrolidinecarboxylic acid',
#   'P',
#   'Prolina',
#   'Proline',
#   'Prolinum',
#   'Proline'],
#  'Adenine': ['6-Aminopurine', 'Adenin', 'Vitamin B4', 'Adenine'],
#  'Asparagine': ['(2S)-2-amino-3-carbamoylpropanoic acid',
#   '(2S)-2,4-diamino-4-oxobutanoic acid',
#   '(S)-2-amino-3-carbamoylpropanoic acid',
#   '(S)-Asparagine',
#   '2-Aminosuccinamic acid',
#   'alpha-aminosuccinamic acid',
#   'Asn',
#   'Asparagine',
#   'Aspartamic acid',
#   'L-2-aminosuccinamic acid',
#   'L-Asparagine',
#   'L-aspartic acid beta-amide',
#   'L-aspartic acid Î²-amide',
#   'Î±-aminosuccinamic acid',
#   'Asparagine'],
#  'Pravastatin': ['(+)-(3R,5R)-3,5-dihydroxy-7-[(1S,2S,6S,8S,8aR)-6-hydroxy-2-methyl-8-{[(S)-2-methylbutyryl]oxy}-1,2,6,7,8,8a-hexahydro-1-naphthyl]heptanoic acid',
#   'Pravastatin',
#   'Pravastatin acid',
#   'Pravastatina',
#   'Pravastatine',
#   'Pravastatinum',
#   'Pravastatin'],
#  'Fluvoxamine': ['Fluvoxamina', 'Fluvoxamine', 'Fluvoxaminum', 'Fluvoxamine'],
#  'Valsartan': ["(S)-N-Valeryl-N-{[2'-(1H-tetrazol-5-yl)biphenyl-4-yl]-methyl}-valine",
#   'N-(P-(O-1H-Tetrazol-5-ylphenyl)benzyl)-N-valeryl-L-valine',
#   "N-pentanoyl-N-{[2'-(1H-tetrazol-5-yl)biphenyl-4-yl]methyl}-L-valine",
#   'Valsartan',
#   'Valsartan'],
#  'Ramipril': ['(2S-(1(R*(R*)),2alpha,3abeta,6abeta))-1-(2-((1-(Ethoxycarbonyl)-3-phenylpropyl)amino)-1-oxopropyl)octahydrocyclopenta(b)pyrrole-2-carboxylic acid',
#   'Ramipril',
#   'Ramiprilum',
#   'Ramipril'],
#  'Masoprocol': ['erythro-nordihydroguaiaretic acid',
#   'masoprocol',
#   'Masoprocolum',
#   'meso-1,4-bis(3,4-dihydroxyphenyl)-2,3-dimethylbutane',
#   'meso-2,3-bis(3,4-dihydroxyphenylmethyl)butane',
#   'meso-4-[4-(3,4-dihydroxyphenyl)-2,3-dimethylbutyl]benzene-1,2-diol',
#   "meso-4,4'-(2,3-dimethyl-1,4-butanediyl)bis(pyrocatechol)",
#   "meso-4,4'-(2,3-dimethyltetramethylene)dipyrocatechol",
#   'meso-NDGA',
#   'meso-nordihydroguaiaretic acid',
#   'meso-Î²,Î³-dimethyl-Î±,Î´-bis(3,4-dihydroxyphenyl)butan',
#   'Nordihydroguaiaretic acid',
#   'Masoprocol'],
#  'Flunisolide': ['Flunisolida',
#   'Flunisolide',
#   'Flunisolide anhydrous',
#   'Flunisolidum',
#   'Flunisolide'],
#  'Baclofen': ['(+-)-Baclofen',
#   '4-Amino-3-(4-chlorophenyl)butyric acid',
#   'Baclofen',
#   'BaclofÃ¨ne',
#   'Baclofeno',
#   'Baclofenum',
#   'beta-(4-Chlorophenyl)gaba',
#   'beta-(Aminomethyl)-4-chlorobenzenepropanoic acid',
#   'beta-(Aminomethyl)-p-chlorohydrocinnamic acid',
#   'beta-(p-Chlorophenyl)-gamma-aminobutyric acid',
#   'DL-4-Amino-3-p-chlorophenylbutanoic acid',
#   'DL-Baclofen',
#   'gamma-Amino-beta-(p-chlorophenyl)butyric acid',
#   'Baclofen'],
#  'Amphetamine': ['(+-)-alpha-Methylphenylethylamine',
#   '1-phenyl-2-aminopropane',
#   'alpha-Methylbenzeneethaneamine',
#   'Amfetamina',
#   'Amfetamine',
#   'Amfetaminum',
#   'Amphetamine',
#   'beta-Aminopropylbenzene',
#   'beta-Phenylisopropylamin',
#   'Desoxynorephedrine',
#   'rac-(2R)-1-phenylpropan-2-amine',
#   'rac-amphetamine',
#   'Î±-methylbenzeneethaneamine',
#   'Î±-methylphenethylamine',
#   'Î²-aminopropylbenzene',
#   'Î²-phenylisopropylamine',
#   'Amphetamine'],
#  'Pentagastrin': ['Pentagastrin', 'Pentagastrin'],
#  'Nicotine': ['(â\x88\x92)-nicotine',
#   '(S)-(â\x88\x92)-nicotine',
#   '(S)-3-(1-methylpyrrolidin-2-yl)pyridine',
#   '(S)-3-(N-methylpyrrolidin-2-yl)pyridine',
#   '(S)-Nicotine',
#   '3-(2-(N-methylpyrrolidinyl))pyridine',
#   '3-(N-methylpyrollidino)pyridine',
#   'L(â\x88\x92)-nicotine',
#   'Nicotina',
#   'Nicotine betadex',
#   'Nicotine polacrilex',
#   'Nikotin',
#   'Nikotyna',
#   'Nicotine'],
#  'Cevimeline': ['2-Methyspiro(1,3-oxathiolane-5,3)quinuclidine',
#   'Cevimelina',
#   'CÃ©vimÃ¨line',
#   'Cevimeline',
#   'Cevimelinum',
#   'Cevimeline'],
#  'Lorazepam': ['Loracepam',
#   'Lorazepam',
#   'o-Chlorooxazepam',
#   'o-Chloroxazepam',
#   'Lorazepam'],
#  'Esmolol': ['(Â±)-esmolol',
#   '(Â±)-methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate',
#   '3-[4-(2-Hydroxy-3-isopropylamino-propoxy)-phenyl]-propionic acid methyl ester',
#   'Esmolol',
#   'Methyl 4-(2-hydroxy-3-((1-methylethyl)amino)propoxy)benzenepropanoate',
#   'methyl p-(2-hydroxy-3-(isopropylamino)propoxy)hydrocinnamate',
#   'Esmolol'],
#  'Bortezomib': ['[(1R)-3-methyl-1-({(2S)-3-phenyl-2-[(pyrazin-2-ylcarbonyl)amino]propanoyl}amino)butyl]boronic acid',
#   'Bortezomib',
#   'N-[(1R)-1-(DIHYDROXYBORYL)-3-methylbutyl]-N-(pyrazin-2-ylcarbonyl)-L-phenylalaninamide',
#   'Bortezomib'],
#  'Ethchlorvynol': ['1-chloro-3-ethyl-1-penten-4-yn-3-ol',
#   '1-Chloro-3-ethyl-pent-1-en-4-yn-3-ol',
#   '3-(beta-chlorovinyl)-1-pentyn-3-ol',
#   '3-(Î²-chlorovinyl)-1-pentyn-3-ol',
#   'etclorvinol',
#   'Ethchlorvynol',
#   'ethyl Î²-chlorovinyl ethynyl carbinol',
#   'Î²-chlorovinyl ethyl ethynyl carbinol',
#   'Ethchlorvynol'],
#  'Carbidopa': ['(-)-L-alpha-Hydrazino-3,4-dihydroxy-alpha-methylhydrocinnamic acid monohydrate',
#   '(S)-(â\x88\x92)-carbidopa',
#   '(S)-carbidopa',
#   '(Î±S)-Î±-hydrazino-3,4-dihydroxy-Î±-methylbenzenepropanoic acid',
#   'Carbidopa',
#   'Carbidopa (anhydrous)',
#   'Carbidopa anhydrous',
#   'Carbidopum',
#   'L-3-(3,4-dihydroxyphenyl)-2-methyl-2-hydrazinopropionic acid',
#   'L-Î±-methyldopahydrazine',
#   'Carbidopa'],
#  'Phentermine': ['alpha,alpha-Dimethylphenethylamine',
#   'Fentermina',
#   'Phentermine',
#   'Phentermine resin',
#   'Phenterminum',
#   'Phentermine'],
#  'Indecainide': ['Indecainida', 'Indecainide', 'Indecainidum', 'Indecainide'],
#  'Tramadol': ['Tramadol', 'Tramadolum', 'Tramadol'],
#  'Vidarabine': ['9-beta-D-arabinofuranosyl-9H-purin-6-amine',
#   '9-beta-D-arabinofuranosyl-adenine',
#   '9-beta-D-Arabinofuranosyladenine',
#   '9-Î²-D-arabinofuranosyl-9H-purin-6-amine',
#   '9-Î²-D-arabinofuranosyladenine',
#   'Spongoadenosine',
#   'Vidarabine',
#   'Vidarabinum',
#   'Vidarabine'],
#  'Betaxolol': ['1-(4-(2-(cyclopropylmethoxy)ethyl)phenoxy)-3-((1-methylethyl)amino)-2-propanol',
#   '1-(isopropylamino)-3-[p-(cyclopropylmethoxyethyl)phenoxy]-2-propanol',
#   'Betaxolol',
#   'BÃ©taxolol',
#   'Betaxololum',
#   'Betaxolol'],
#  'Fluconazole': ['Diflucan',
#   'Difluconazole',
#   'Fluconazol',
#   'Fluconazole',
#   'Fluconazolum',
#   'Triflucan',
#   'Fluconazole'],
#  'Troglitazone': ['Troglitazona', 'Troglitazone', 'Troglitazone'],
#  'Oseltamivir': ['(â\x88\x92)-oseltamivir',
#   '1-Cyclohexene-1-carboxylic acid, 4-(acetylamino)-5-amino-3-(1-ethylpropoxy)-, ethyl ester, (3R-(3alpha,4beta,5alpha))-',
#   'Ethyl (3R,4R,5S)-4-acetamido-5-amino-3-(1-ethylpropoxy)-1-cyclohexene-1-carboxylate',
#   'Oseltamivir',
#   'OsÃ©ltamivir',
#   'Oseltamivirum',
#   'Oseltamivir'],
#  'Erythromycin': ["3''-O-demethylerythromycin",
#   'Abomacetin',
#   'Eritromicina',
#   'Erythromycin',
#   'Erythromycin A',
#   'Erythromycin C',
#   'Ã©rythromycine',
#   'Erythromycinum',
#   'Erythromycin'],
#  'Hydroxocobalamin': ['Hydroxocobalamin',
#   'Hydroxocobalamin anhydrous',
#   'Hydroxocobalamine',
#   'Hydroxocobalaminum anhydrous',
#   'Hydroxycobalamin',
#   'OH-Cbl',
#   'Vitamin B-12b',
#   'Hydroxocobalamin'],
#  'Caffeine': ['1-methyltheobromine',
#   '1,3,7-trimethyl-2,6-dioxopurine',
#   '1,3,7-trimethylpurine-2,6-dione',
#   '1,3,7-trimethylxanthine',
#   '3,7-Dihydro-1,3,7-trimethyl-1H-purin-2,6-dion',
#   '7-methyltheophylline',
#   'Anhydrous caffeine',
#   'CafeÃ\xadna',
#   'CafÃ©ine',
#   'Caffeinum',
#   'Coffein',
#   'Coffeinum',
#   'Guaranine',
#   'Koffein',
#   'MateÃ\xadna',
#   'Methyltheobromine',
#   'TeÃ\xadna',
#   'Thein',
#   'Theine',
#   'Caffeine'],
#  'Succinylcholine': ["2,2'-[(1,4-dioxobutane-1,4-diyl)bis(oxy)]bis(N,N,N-trimethylethanaminium)",
#   'Dicholine succinate',
#   'Succinocholine',
#   'Succinoylcholine',
#   'Succinylbischoline',
#   'Succinyldicholine',
#   'Suxamethonium',
#   'Succinylcholine'],
#  'Sildenafil': ['1-((3-(4,7-Dihydro-1-methyl-7-oxo-3-propyl-1H-pyrazolo(4,3-d)pyrimidin-5-yl)-4-ethoxyphenyl)sulfonyl)-4-methylpiperazine',
#   'Sildenafil',
#   'Sildenafilo',
#   'Sildenafil'],
#  'Dofetilide': ['beta-((p-Methanesulfonamidophenethyl)methylamino)methanesulfono-p-phenetidide',
#   'Dofetilida',
#   'Dofetilide',
#   'Dofetilidum',
#   'Dofetilide'],
#  'Pyrimethamine': ['2,4-Diamino-5-(4-chlorophenyl)-6-ethylpyrimidine',
#   '2,4-Diamino-5-(P-chlorophenyl)-6-ethylpyrimidine',
#   '2,4-Diamino-5-chlorophenyl-6-ethylpyrimidine',
#   '5-(4-Chlorophenyl)-6-ethyl-2,4-diaminopyrimidine',
#   '5-(4-Chlorophenyl)-6-ethyl-2,4-pyrimidinediamine',
#   "5-(4'-Chlorophenyl)-2,4-diamino-6-ethylpyrimidine",
#   'CD',
#   'Chloridine',
#   'Chloridyn',
#   'Diaminopyritamin',
#   'Ethylpyrimidine',
#   'Pirimetamina',
#   'Primethamine',
#   'Pyrimethamine',
#   'PyrimÃ©thamine',
#   'Pyrimethaminum',
#   'Pyrimethamine'],
#  'Reserpine': ['(â\x88\x92)-reserpine',
#   '(3beta,16beta,17alpha,18beta,20alpha)-11,17-Dimethoxy-18-[(3,4,5-trimethoxybenzoyl)oxy]yohimban-16-carboxylic acid methyl ester',
#   '3,4,5-trimethoxybenzoyl methyl reserpate',
#   'Reserpin',
#   'Reserpine',
#   'Reserpine'],
#  'Azithromycin': ['Azithromycin',
#   'Azithromycine',
#   'Azithromycinum',
#   'Azitromicina',
#   'Azithromycin'],
#  'Ticlopidine': ['Ticlopidina', 'Ticlopidine', 'Ticlopidinum', 'Ticlopidine'],
#  'Trospium': ['Trospium'],
#  'Adapalene': ['6-(3-(1-Adamantyl)-4-methoxyphenyl)-2-naphthoic acid',
#   'Adapalene',
#   'AdapalÃ¨ne',
#   'Adapaleno',
#   'Adapalenum',
#   'Adapalene'],
#  'Midodrine': ['(Â±)-2-amino-N-(Î²-hydroxy-2,5-dimethoxyphenethyl)acetamide',
#   "1-(2',5'-Dimethoxyphenyl)-2-glycinamidoethanol",
#   '2-Amino-N-(2,5-dimethoxy-beta-hydroxyphenethyl)acetamide',
#   'DL-N1-(beta-Hydroxy-2,5-dimethoxyphenethyl)glycinamid',
#   'Midodrin',
#   'Midodrina',
#   'Midodrine',
#   'Midodrinum',
#   'Midodrine'],
#  'Remikiren': ['Remikiren', 'Remikiren'],
#  'Pantoprazole': ['Pantoprazol',
#   'Pantoprazole',
#   'Pantoprazolum',
#   'Pantoprazole'],
#  'Torasemide': ['1-Isopropyl-3-((4-m-toluidino-3-pyridyl)sulfonyl)urea',
#   'N-(((1-Methylethyl)amino)carbonyl)-4-((3-methylphenyl)amino)-3-pyridinesulfonamide',
#   'Torasemida',
#   'Torasemide',
#   'TorasÃ©mide',
#   'Torasemidum',
#   'Torsemide',
#   'Torasemide'],
#  'Citalopram': ['Citalopram', 'Citalopramum', 'Nitalapram ', 'Citalopram'],
#  'Eletriptan': ['Eletriptan',
#   'Ã©lÃ©triptan',
#   'EletriptÃ¡n',
#   'Eletriptanum',
#   'Eletriptan'],
#  'Bethanidine': ['Betanidina',
#   'Betanidine',
#   'BÃ©tanidine',
#   'Betanidinum',
#   'Bethanidine',
#   "N,N'-dimethyl-N''-(phenylmethyl)-guanidine",
#   'Bethanidine'],
#  'Moxifloxacin': ['1-Cyclopropyl-6-fluoro-1,4-dihydro-8-methoxy-7-((4as,7as)-octahydro-6H-pyrrolo(3,4-b)pyridin-6-yl)-4-oxo-3-quinolinecarboxylic acid',
#   'Moxifloxacin',
#   'Moxifloxacino',
#   'Moxifloxacin'],
#  'Oxyphenonium': ['Oxyphenonium cation', 'Oxyphenonium ion', 'Oxyphenonium'],
#  'Nelfinavir': ['Nelfinavir', 'Nelfinavir'],
#  'Isoetharine': ['Isoetarina', 'Isoetarinum', 'Isoetharine', 'Isoetharine'],
#  'Glimepiride': ['Glimepirida',
#   'Glimepiride',
#   'GlimÃ©piride',
#   'Glimepiridum',
#   'Glimepiride'],
#  'Diflorasone': ['(6Î±,11Î²,16Î²)-6,9-difluoro-11,17,21-trihydroxy-16-methylpregna-1,4-diene-3,20-dione',
#   'Diflorasona',
#   'Diflorasone',
#   'Diflorasonum',
#   'Diflorasone'],
#  'Indinavir': ['(1(1S,2R),5(S))-2,3,5-Trideoxy-N-(2,3-dihydro-2-hydroxy-1H-inden-1-yl)-5-(2-(((1,1-dimethylethyl)amino)carbonyl)-4-(3-pyridinylmethyl)-1-piperazinyl)-2-(phenylmethyl)-D-erythro-pentonamide',
#   'Indinavir',
#   'Indinavir anhydrous',
#   'Indinavir'],
#  'Gadodiamide': ['Gadodiamida',
#   'Gadodiamide',
#   'Gadodiamide anhydrous',
#   'Gadodiamide'],
#  'Guanadrel': ['Guanadrel', 'Guanadrelum', 'Guanadrel'],
# ...
#   'Hidrocodona',
#   'Hydrocodon',
#   'Hydrocodone',
#   'Hydrocodonum',
#   'Hydrocone',
#   'Hydroconum',
#   'Idrocodone',
#   'Hydrocodone'],
#  'Norgestimate': ['(+)-13-Ethyl-17-hydroxy-18,19-dinor-17Î±-pregn-4-en-20-yn-3-one oxime acetate (ester)',
#   '(17Î±)-17-(Acetyloxy)-13-ethyl-18,19-dinorpregn-4-en-20-yn-3-one 3-oxime',
#   'd-13Î²-Ethyl-17Î±-ethynyl-17Î²-acetoxygon-4-en-3-one oxime',
#   'Dexnorgestrel Acetime',
#   'Norgestimate',
#   'Norgestimato',
#   'Norgestimatum',
#   'Norgestimate'],
#  'Carboplatin': ['Carboplatin',
#   'Carboplatine',
#   'Carboplatino',
#   'CBDCA',
#   'cis-(1,1-cyclobutanedicarboxylato)diammineplatinum(II)',
#   'cis-diammine(1,1-cyclobutanedicarboxylato)platinum',
#   'cis-diammine(1,1-cyclobutanedicarboxylato)platinum(II)',
#   'Carboplatin'],
#  'Methylprednisolone': ['(6Î±,11Î²)-11,17,21-trihydroxy-6-methylpregna-1,4-diene-3,20-dione',
#   '1-dehydro-6Î±-methylhydrocortisone',
#   '6Î±-methyl-11Î²,17Î±,21-triol-1,4-pregnadiene-3,20-dione',
#   'delta(1)-6alpha-Methylhydrocortisone',
#   'Methylprednisolon',
#   'Methylprednisolone',
#   'Methylprednisolonum',
#   'Metilprednisolona',
#   'Methylprednisolone'],
#  'Pindolol': ['1-(1H-indol-4-yloxy)-3-(isopropylamino)propan-2-ol',
#   '1-(1H-indol-4-yloxy)-3-(propan-2-ylamino)-propan-2-ol',
#   '1-(1H-indol-4-yloxy)-3-[(1-methylethyl)amino]propan-2-ol',
#   '4-(2-hydroxy-3-isopropylaminopropoxy)-indole',
#   'Pindolol',
#   'Pindololum',
#   'Pindolol'],
#  'Mepivacaine': ["(+-)-1-Methyl-2',6'-pipecoloxylidide",
#   "1-methyl-2',6'-pipecoloxylidide",
#   'DL-Mepivacaine',
#   'Mepivacaina',
#   'Mepivacaine',
#   'Mepivacainum',
#   'N-(2,6-Dimethylphenyl)-1-methyl-2-piperidinecarboxamide',
#   'N-(2,6-Dimethylphenyl)-1-methylpiperidine-2-carboxamide',
#   'Mepivacaine'],
#  'Zaleplon': ["3'-(3-Cyanopyrazolo(1,5-a)pyrimidin-7-yl)-N-ethylacetanilide",
#   'Zaleplon',
#   'Zaleplon'],
#  'Bromfenac': ['[2-Amino-3-(4-bromo-benzoyl)-phenyl]-acetic acid',
#   '2-amino-3-(4-bromobenzoyl)benzeneacetic acid',
#   'Bromfenac',
#   'Bromfenaco',
#   'Bromfenacum',
#   'Bromfenac'],
#  'Apraclonidine': ['4-Aminoclonidine',
#   'Apraclonidina',
#   'Apraclonidine',
#   'Apraclonidinum',
#   'Apraclonidine'],
#  'Ethiodized oil': ['Ethiodized oil'],
#  'Telmisartan': ["4'-((1,4'-dimethyl-2'-propyl(2,6'-bi-1H-benzimidazol)-1'-yl)methyl)-(1,1'-biphenyl)-2-carboxylic acid",
#   "4'-((4-methyl-6-(1-methyl-2-benzimidazolyl)-2-propyl-1-benzimidazolyl)methyl)-2-biphenylcarboxylic acid",
#   "4'-[(1,4'-dimethyl-2'propyl[2,6'-bi-1H-benzimidazol]-1'-yl)methyl]-[1,1'-biphenyl]-2-carboxylic acid",
#   "4'-[(1,7'-dimethyl-2'-propyl-1H,3'H-2,5'-bibenzimidazol-3'-yl)methyl]biphenyl-2-carboxylic acid",
#   'Telmisartan',
#   'Telmisartan'],
#  'Desloratadine': ['8-Chloro-11-piperidin-4-ylidene-6,11-dihydro-5H-benzo[5,6]cyclohepta[1,2-b]pyridine',
#   '8-chloro-6,11-dihydro-11-(4-piperidinylidene)-5H-benzo(5,6)cyclohepta(1,2-b)pyridine',
#   'Descarboethoxyloratadine',
#   'Desloratadina',
#   'Desloratadine',
#   'Desloratadine'],
#  'Methyldopa': ['(S)-(-)-alpha-Methyldopa',
#   '3-Hydroxy-alpha-methyl-L-tyrosine',
#   'Alpha medopa',
#   'alpha-Methyl dopa',
#   'alpha-methyl-L-dopa',
#   'Alphamethyldopa',
#   'AMD',
#   'Anhydrous methyldopa',
#   'L-alpha-Methyldopa',
#   'L-Methyl Dopa',
#   'Methyl dopa',
#   'Methyldopa',
#   'Methyldopa anhydrous',
#   'metildopa',
#   'Î±-Methyl dopa',
#   'Î±-methyl-L-dopa',
#   'Methyldopa'],
#  'Alosetron': ['2,3,4,5-Tetrahydro-5-methyl-2-((5-methyl-1H-imidazol-4-yl)methyl)-1H-pyrido(4,3-b)indol-1-one',
#   'Alosetron',
#   'Alosetron'],
#  'Dactinomycin': ["2-amino-N,N'-bis(hexadecahydro-2,5,9-trimethyl-6,13-bis(1-methylethyl)-1,4,7,11,14-pentaoxo-1H-pyrrolo(2,1-i)(1,4,7,10,13)oxatetra-azacyclohexadecin-10-yl)-4,6-dimethyl-3-oxo-3H-phenoxazine-1,9-dicarboxamide",
#   'ActD',
#   'Actinomycin C1',
#   'Actinomycin D',
#   'Actinomycin IV',
#   'Dactinomicina',
#   'Dactinomycin',
#   'Dactinomycine',
#   'Dactinomycinum',
#   'Meractinomycin',
#   'Dactinomycin'],
#  'Selenium Sulfide': ['Selenii disulfidum',
#   'Selenium disulfide',
#   'Selenium disulphide',
#   'Selenium sulfide, micronized',
#   'Selenium sulphide',
#   'Selenium sulphide, micronized',
#   'Selenium(IV) disulfide',
#   'Selenium(IV) disulphide',
#   'Selenium(IV) sulfide',
#   'Selenium(IV) sulphide',
#   'Selenium Sulfide'],
#  'Azelastine': ['4-(p-Chlorobenzyl)-2-(hexahydro-1-methyl-1H-azepin-4-yl)-1-(2H)-phthalazinone',
#   'Azelastina',
#   'Azelastine',
#   'AzÃ©lastine',
#   'Azelastinum',
#   'Azelastine'],
#  'Ezetimibe': ['Ezetimiba',
#   'Ã©zÃ©timibe',
#   'Ezetimibe',
#   'Ezetimibum',
#   'Ezetimibe'],
#  'Edetic acid': ['(ethylenedinitrilo)tetraacetic acid, ion(4â\x88\x92)',
#   '{[-(bis-carboxymethyl-amino)-ethyl]-carboxymethyl-amino}-acetic acid',
#   "2,2',2'',2'''-(ethane-1,2-diyldinitrilo)tetraacetate",
#   'Acide edetique',
#   'Acide ethylenediaminetetracetique',
#   'Acido edetico',
#   'Acidum edeticum',
#   'Edetic acid',
#   'EDTA',
#   'EDTA, ion(4-)',
#   'Ethylenediaminetetraacetate',
#   'Ethylenediaminetetraacetic acid',
#   "N,N'-1,2-Ethane diylbis-(N-(carboxymethyl)glycine)",
#   'Edetic acid'],
#  'Dipyridamole': ['Dipiridamol',
#   'Dipyridamine',
#   'Dipyridamole',
#   'Dipyridamolum',
#   'Dipyudamine',
#   'Dypyridamol',
#   'Dipyridamole'],
#  'Telithromycin': ['Telithromycin', 'telitromicina', 'Telithromycin'],
#  'Ethinylestradiol': ['17-ethinyl-3,17-estradiol',
#   '17-ethinyl-3,17-oestradiol',
#   '17-ethinylestradiol',
#   '17alpha-Ethinyl estradiol',
#   '17Î±-ethynylestradiol',
#   'Ethinyl estradiol',
#   'Ethinylestradiol',
#   'Ethinylestradiolum',
#   'Ethinyloestradiol',
#   'Ethynyl estradiol',
#   'Etinilestradiol',
#   'Ethinylestradiol'],
#  'Lomefloxacin': ['(Â±)-1-ethyl-6,8-difluoro-1,4-dihydro-7-(3-methyl-1-piperazinyl)-4-oxo-3-quinolinecarboxylic acid',
#   '1,4-Dihydro-6,8-difluoro-1-ethyl-7-(3-methyl-1-piperazinyl)-4-oxo-3-quinolinecarboxylic acid',
#   'LFLX',
#   'Lomefloxacin',
#   'Lomefloxacine',
#   'Lomefloxacino',
#   'Lomefloxacinum',
#   'Lomefloxacin'],
#  'Cyclopentolate': ['(Â±)-cyclopentolate',
#   '1-hydroxy-Î±-phenylcyclopentaneacetic acid 2-(dimethylamino)ethyl ester',
#   '2-(dimethylamino)ethyl 1-hydroxy-Î±-phenylcyclopentaneacetate',
#   '2-(dimethylamino)ethyl 2-(1-hydroxycyclopentyl)-2-phenylacetate',
#   '2-phenyl-2-(1-hydroxycyclopentyl)ethanoic acid Î²-(dimethylamino)ethyl ester',
#   'Ciclopentolato',
#   'Cyclopentolate',
#   'Cyclopentolatum',
#   'Î±-(1-hydroxycyclopentyl)benzeneacetic acid 2-(dimethylamino)ethyl ester',
#   'Î²-(dimethylamino)ethyl (1-hydroxycyclopentyl)phenylacetate',
#   'Î²-dimethylaminoethyl (1-hydroxycyclopentyl)phenylacetate',
#   'Cyclopentolate'],
#  'Ramelteon': ['Ramelteon', 'Ramelteon'],
#  'Physostigmine': ['Eserine', 'Physostigmine', 'Physostol', 'Physostigmine'],
#  'Isotretinoin': ['(7E,9E,11E,13Z)-retinoic acid',
#   '13-cis-retinoic acid',
#   '13-cis-Vitamin A acid',
#   '13-RA',
#   'cis-RA',
#   'Isotretinoin',
#   'IsotretinoÃ\xadna',
#   'IsotrÃ©tinoine',
#   'Isotretinoino',
#   'Isotretinoinum',
#   'Neovitamin A acid',
#   'Isotretinoin'],
#  'Formoterol': ["2'-hydroxy-5'-(1-hydroxy-2-((p-methoxy-Î±-methylphenethyl)amino)ethyl)formanilide",
#   "2'-hydroxy-5'-{1-hydroxy-2-[(p-methoxy-Î±-methylphenethyl)amino]ethyl}formanilide",
#   'Formoterol',
#   'Formoterolum',
#   'N-[2-hydroxy-5-(1-hydroxy-2-{[2-(4-methoxyphenyl)-1-methylethyl]amino}ethyl)phenyl]formamide',
#   'Formoterol'],
#  'Nandrolone phenpropionate': ['19NTPP',
#   'Nadrolone phenylpropionate',
#   'Nandrolon phenylpropionate',
#   'Nandrolone phenylpionate',
#   'Nandrolone phenylpropionate',
#   'Norandrolone phenyl propionate',
#   'Norandrostenolone phenylpropionate',
#   'Nortestosterone phenylpropionate',
#   'NPP',
#   'NTPP',
#   'Nandrolone phenpropionate'],
#  'Dimenhydrinate': ['(O-benzhydryl(dimethylamino)ethanol) 8-chlorotheophyllinate',
#   '8-chloro-1,3-dimethyl-3,7-dihydro-1H-purine-2,6-dione - 2-(diphenylmethoxy)-N,N-dimethylethanamine (1:1)',
#   'Benzhydryl-Î²-dimethylaminoethylether 8-chlorotheophylline',
#   'Dimenhidrinato',
#   'Dimenhydrinate',
#   'Dimenhydrinatum',
#   'diphenhydramine 8-chlorotheophyllinate',
#   'diphenhydramine 8-chlorotheophylline',
#   'Diphenhydramine theoclate',
#   'N,N-dimethyl-2-diphenylmethoxyethylamine 8-chlorotheophyllinate',
#   'O-benzhydryldimethylaminoethanol 8-chlorotheophyllinate',
#   'Î²-dimethylaminoethyl benzhydryl ether 1,3-dimethyl-8-chloroxanthine',
#   'Dimenhydrinate'],
#  'Glycopyrronium': ['Glicopirronio',
#   'Glycopyrrolate cation',
#   'Glycopyrrolate ion',
#   'Glycopyrronium',
#   'Glycopyrronium cation',
#   'Glycopyrronium ion',
#   'Glycopyrronium'],
#  'Cytarabine': ['1-beta-D-Arabinofuranosylcytosine',
#   '4-Amino-1-beta-D-arabinofuranosyl-2(1H)-pyrimidinone',
#   'Citarabina',
#   'Cytarabine',
#   'Cytarabinum',
#   'Cytosine arabinoside',
#   'Cytosine-1-beta-D-arabinofuranoside',
#   'cytosine-Î²-D-arabinofuranoside',
#   'Cytarabine'],
#  'Dopamine': ['2-(3,4-dihydroxyphenyl)ethylamine',
#   '3-Hydroxytyramine',
#   '3,4-Dihydroxyphenethylamine',
#   '4-(2-aminoethyl)-1,2-benzenediol',
#   '4-(2-Aminoethyl)benzene-1,2-diol',
#   '4-(2-aminoethyl)catechol',
#   '4-(2-aminoethyl)pyrocatechol',
#   'Dopamina',
#   'Dopamine',
#   'Dopaminum',
#   'Oxytyramine',
#   'Dopamine'],
#  'Rivastigmine': ['(S)-3-(1-(Dimethylamino)ethyl)phenyl ethylmethylcarbamate',
#   'm-((S)-1-(Dimethylamino)ethyl)phenyl ethylmethylcarbamate',
#   'Rivastigmina',
#   'Rivastigmine',
#   'Rivastigmine'],
#  'Exemestane': ['6-methyleneandrosta-1,4-diene-3,17-dione',
#   'Exemestane',
#   'Exemestano',
#   'Exemestanum',
#   'Exemestane'],
#  'Oxaprozin': ['Oxaprozin',
#   'Oxaprozina',
#   'Oxaprozine',
#   'Oxaprozinum',
#   'Oxaprozin'],
#  'Methyl aminolevulinate': ['5-aminolevulinic acid methyl ester',
#   'Aminolevulinato de metilo',
#   'Aminolevulinic acid methyl ester',
#   'methyl 5-aminolevulinate',
#   'Methyl aminolevulinate',
#   'Methyl delta-aminolevulinate',
#   'methyl Î´-aminolevulinate',
#   'Methyl aminolevulinate'],
#  'Azathioprine': ['6-((1-Methyl-4-nitro-1H-imidazol-5-yl)thio)-1H-purine',
#   "6-(1'-Methyl-4'-nitro-5'-imidazolyl)-mercaptopurine",
#   'Azamun',
#   'Azathioprine',
#   'Azathioprinum',
#   'Azatioprina',
#   'Azathioprine'],
#  'Neomycin': ['Fradiomycin',
#   'Kaomycine',
#   'Neomicina',
#   'Neomycin',
#   'Vonamycin',
#   'Neomycin'],
#  'Auranofin': ['(1-Thio-beta-D-glucopyranosato)(triethylphosphine)gold 2,3,4,6-tetraacetate',
#   '2,3,4,6-Tetra-O-acetyl-1-thio-beta-D-glucopyranosato-S (triethylphosphine)gold',
#   'Auranofin',
#   'Auranofina',
#   'Auranofine',
#   'Auranofinum',
#   'Triethylphosphine gold',
#   'Auranofin'],
#  'Gabapentin': ['1-(Aminomethyl)cyclohexaneacetic acid',
#   'Gabapentin',
#   'Gabapentina',
#   'Gabapentine',
#   'Gabapentino',
#   'Gabapentinum',
#   'Gabapentin'],
#  'Doxorubicin': ['(1S,3S)-3-glycoloyl-3,5,12-trihydroxy-10-methoxy-6,11-dioxo-1,2,3,4,6,11-hexahydrotetracen-1-yl 3-amino-2,3,6-trideoxy-Î±-L-lyxo-hexopyranoside',
#   '(8S-cis)-10-((3-amino-2,3,6-trideoxy-Î±-L-lyxo-hexopyranosyl)oxy)-7,8,9,10-tetrahydro-6,8,11-trihydroxy-8-(hydroxyacetyl)-1-methoxy-5,12-naphthacenedione',
#   '14-hydroxydaunomycin',
#   '14-hydroxydaunorubicine',
#   'Doxorubicin',
#   'Doxorubicina',
#   'Doxorubicine',
#   'Doxorubicinum',
#   'Hydroxydaunorubicin',
#   'Doxorubicin'],
#  'Frovatriptan': ['Frovatriptan', 'Frovatriptan'],
#  'Hydrochlorothiazide': ['HCTZ',
#   'Hidroclorotiazida',
#   'Hydrochlorothiazide',
#   'Hydrochlorothiazidum',
#   'Hydrochlorothiazide'],
#  'Cyclacillin': ['(1-aminocyclohexyl)penicillin',
#   '(2S,5R,6R)-6-{[(1-aminocyclohexyl)carbonyl]amino}-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylic acid',
#   '6-(1-aminocyclohexanecarboxamido)penicillanic acid',
#   '6-(1-aminocyclohexylcarboxamido)penicillanic acid',
#   'Ciclacilina',
#   'Ciclacillin',
#   'Ciclacilline',
#   'Ciclacillinum',
#   'Cyclacillin',
#   'Cyclacillin'],
#  'Salbutamol': ['Albuterol', 'Salbutamol', 'Salbutamolum', 'Salbutamol'],
#  'Levobupivacaine': ['(-)-bupivacaine',
#   "(S)-1-butyl-2',6'-pipecoloxylidide",
#   '(S)-bupivacaine',
#   "L-(-)-1-Butyl-2',6'-pipecoloxylidide",
#   'L-(â\x88\x92)-bupivacaine',
#   'LevobupivacaÃ\xadna',
#   'Levobupivacaine',
#   'Levobupivacaine'],
#  'Cromoglicic acid': ['5-[3-(2-carboxy-4-oxo-4H-5-chromenyloxy)-2-hydroxypropoxy]-4-oxo-4H-2-chromenecarboxylic acid',
#   'Acide Cromoglicique',
#   'Acido Cromoglicico',
#   'Acidum Cromoglicicum',
#   'Cromoglicate',
#   'Cromoglicic acid',
#   'Cromoglycate',
#   'Cromoglycic acid',
#   'Cromolyn',
#   'Cromoglicic acid'],
#  'Ganciclovir': ['2-(6-Amino-purin-9-ylmethoxy)-propane-1,3-diol',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-1H-purin-6(9H)-one',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-3H-purin-6(9H)-one',
#   '2-amino-9-((1,3-dihydroxypropan-2-yloxy)methyl)-9H-purin-6-ol',
#   '2-Amino-9-(2-hydroxy-1-hydroxymethyl-ethoxymethyl)-1,9-dihydro-purin-6-one',
#   '2-amino-9-(2-hydroxy-1-hydroxymethylethoxymethyl)-6,9-dihydro-1H-6-purinone',
#   '9-((2-Hydroxy-1-(hydroxymethyl)ethoxy)methyl)guanine',
#   '9-[(1,3-dihydroxy-2-propoxy)methyl]guanine',
#   'GA2',
#   'Ganciclovir',
#   'Ganciclovirum',
#   'Gancyclovir',
#   'Ganciclovir'],
#  'Hydroxyurea': ['Carbamohydroxamic acid',
#   'Carbamohydroximic acid',
#   'Carbamoyl oxime',
#   'Carbamyl hydroxamate',
#   'Hidroxicarbamida',
#   'Hydrea',
#   'Hydroxycarbamid',
#   'Hydroxycarbamide',
#   'Hydroxycarbamidum',
#   'Hydroxyharnstoff',
#   'Hydroxyurea',
#   'N-Carbamoylhydroxylamine',
#   'N-Hydroxyurea',
#   'Oxyurea',
#   'Hydroxyurea'],
#  'Letrozole': ['Letrozol', 'Letrozole', 'Letrozole'],
#  'Tioconazole': ['Tioconazol', 'Tioconazole', 'Tioconazolum', 'Tioconazole'],
#  'Busulfan': ['1,4-Bis(methanesulfonoxy)butane',
#   '1,4-Butanediol dimethanesulfonate',
#   '1,4-Dimesyloxybutane',
#   '1,4-Dimethanesulfonoxybutane',
#   'Busulfan',
#   'Busulfano',
#   'Busulfanum',
#   'Busulphan',
#   'Tetramethylene bis(methanesulfonate)',
#   'Busulfan'],
#  'Ketoprofen': ['2-(3-Benzoylphenyl)propionic acid',
#   '3-Benzoyl-alpha-methylbenzeneacetic acid',
#   '3-Benzoyl-Î±-methylbenzeneacetic acid',
#   '3-Benzoylhydratropic acid',
#   'Ketoprofen',
#   'Ketoprofeno',
#   "L'acide (benzoyl-3-phenyl)-2-propionique",
#   'm-Benzoylhydratropic acid',
#   'Ketoprofen'],
#  'Edrophonium': ['(3-hydroxyphenyl)dimethylethylammonium',
#   '3-hydroxy-N,N-dimethyl-N-ethylanilinium',
#   'Edrophonium cation',
#   'Edrophonium ion',
#   'Ethyl-(3-hydroxy-phenyl)-dimethyl-ammonium',
#   'N-ethyl-3-hydroxy-N,N-dimethylanilinium',
#   'N-ethyl-3-hydroxy-N,N-dimethylbenzenaminium',
#   'Edrophonium'],
#  'Metyrapone': ['Metirapona',
#   'MÃ©tyrapone',
#   'Metyrapone',
#   'Metyraponum',
#   'Metyrapone'],
#  'Cinacalcet': ['(R)-Î±-methyl-N-[3-[3-(trifluoromethyl)phenyl]propyl]-1-naphthalenemethane amine',
#   'Cinacalcet',
#   'CNC',
#   'N-((1R)-1-(Naphthalen-1-yl)ethyl)-3-(3-(trifluoromethyl)phenyl)propan-1-amine',
#   'Cinacalcet'],
#  'Clobetasol propionate': ['21-chloro-9-fluoro-11Î²,17-dihydroxy-16Î²-methylpregna-1,4-diene-3,20-dione 17-propionate',
#   'clobetasol 17-propanoate',
#   'clobetasol 17-propionate',
#   'Clobetasol propionate',
#   'Clobetasol propionate E',
#   'Clobetasol propionate'],
#  'Balsalazide': ['(E)-5-((4-(((2-carboxyethyl)amino)carbonyl)phenyl)azo)-2-hydroxybenzoic acid',
#   '(E)-5-({p-[(2-carboxyethyl)carbamoyl]phenyl}azo)-2-salicylic acid',
#   '3-(2-{4-[(2-carboxyethyl)carbamoyl]phenyl}hydrazinylidene)-6-oxocyclohexa-1,4-diene-1-carboxylic acid',
#   '5-[4-(2-carboxy-ethylcarbamoyl)-phenylazo]-2-hydroxy-benzoic acid',
#   'Balsalazida',
#   'Balsalazide',
#   'Balsalazidum',
#   'Balsalazide'],
#  'Sulfamethoxazole': ['3-(p-Aminophenylsulfonamido)-5-methylisoxazole',
#   '3-Sulfanilamido-5-methylisoxazole',
#   '4-Amino-N-(5-methyl-3-isoxazolyl)benzenesulfonamide',
#   'SMX',
#   'Sulfamethoxazole',
#   'Sulfametoxazol',
#   'Sulphamethoxazole',
#   'Sulfamethoxazole'],
#  'Glyburide': ['1-((p-(2-(5-chloro-o-anisamido)ethyl)phenyl)sulfonyl)-3-cyclohexylurea',
#   '1-(p-(2-(5-chloro-2-methoxybenzamido)ethyl)benzenesulfonyl)-3-cyclohexylurea',
#   '5-chloro-N-(2-(4-((((cyclohexylamino)carbonyl)amino)sulfonyl)phenyl)ethyl)-2-methoxybenzamide',
#   'Glibenclamida',
#   'Glibenclamide',
#   'Glibenclamidum',
#   'Glyburide',
#   'Glyburide'],
#  'Minocycline': ['(4S,4aS,5aR,12aS)-4,7-bis(dimethylamino)-3,10,12,12a-tetrahydroxy-1,11-dioxo-1,4,4a,5,5a,6,11,12a-octahydrotetracene-2-carboxamide',
#   '7-Dimethylamino-6-demethyl-6-deoxytetracycline',
#   'Minociclina',
#   'Minociclinum',
#   'Minocyclin',
#   'Minocycline',
#   'Minocyclinum',
#   'Minomycin',
#   'Minocycline'],
#  ...}

# %%
df_genes=pd.read_csv(r"C:\Users\mese4\Documents\The Data incubator\project\genes_dataset\G-SynMiner_miner-geneHUGO.tsv",sep='\t')
#df_genes=df_genes.set_index('symbol')
df_genes.head(10)
# Out:
# C:\Users\mese4\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (32,34,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   # ensembl_gene_id     hgnc_id     symbol  \
# 0   ENSG00000121410      HGNC:5       A1BG
# 1   ENSG00000268895  HGNC:37133   A1BG-AS1
# 2   ENSG00000148584  HGNC:24086       A1CF
# 3   ENSG00000175899      HGNC:7        A2M
# 4   ENSG00000245105  HGNC:27057    A2M-AS1
# 5   ENSG00000166535  HGNC:23336      A2ML1
# 6   ENSG00000256661  HGNC:41022  A2ML1-AS1
# 7   ENSG00000256904  HGNC:41523  A2ML1-AS2
# 8   ENSG00000256069      HGNC:8      A2MP1
# 9   ENSG00000184389  HGNC:30005    A3GALT2
#
#                                  name          locus_group  \
# 0              alpha-1-B glycoprotein  protein-coding gene
# 1                A1BG antisense RNA 1       non-coding RNA
# 2      APOBEC1 complementation factor  protein-coding gene
# 3               alpha-2-macroglobulin  protein-coding gene
# 4  A2M antisense RNA 1 (head to head)       non-coding RNA
# 5        alpha-2-macroglobulin like 1  protein-coding gene
# 6               A2ML1 antisense RNA 1       non-coding RNA
# 7               A2ML1 antisense RNA 2       non-coding RNA
# 8  alpha-2-macroglobulin pseudogene 1           pseudogene
# 9   alpha 1,3-galactosyltransferase 2  protein-coding gene
#
#                   locus_type    status  location location_sortable  \
# 0  gene with protein product  Approved  19q13.43          19q13.43
# 1       RNA, long non-coding  Approved  19q13.43          19q13.43
# 2  gene with protein product  Approved   10q21.1           10q21.1
# 3  gene with protein product  Approved  12p13.31          12p13.31
# 4       RNA, long non-coding  Approved  12p13.31          12p13.31
# 5  gene with protein product  Approved     12p13             12p13
# 6       RNA, long non-coding  Approved  12p13.31          12p13.31
# 7       RNA, long non-coding  Approved  12p13.31          12p13.31
# 8                 pseudogene  Approved  12p13.31          12p13.31
# 9  gene with protein product  Approved    1p35.1           01p35.1
#
#                     alias_symbol  ... horde_id   merops imgt iuphar  \
# 0                            NaN  ...      NaN  I43.950  NaN    NaN
# 1                       FLJ23569  ...      NaN      NaN  NaN    NaN
# 2  ACF|ASP|ACF64|ACF65|APOBEC1CF  ...      NaN      NaN  NaN    NaN
# 3           FWP007|S863-7|CPAMD5  ...      NaN  I39.001  NaN    NaN
# 4                            NaN  ...      NaN      NaN  NaN    NaN
# 5                       FLJ25179  ...      NaN  I39.007  NaN    NaN
# 6                            NaN  ...      NaN      NaN  NaN    NaN
# 7                            NaN  ...      NaN      NaN  NaN    NaN
# 8                            NaN  ...      NaN      NaN  NaN    NaN
# 9                   IGBS3S|IGB3S  ...      NaN      NaN  NaN    NaN
#
#   kznf_gene_catalog mamit-trnadb   cd lncrnadb enzyme_id  \
# 0               NaN          NaN  NaN      NaN       NaN
# 1               NaN          NaN  NaN      NaN       NaN
# 2               NaN          NaN  NaN      NaN       NaN
# 3               NaN          NaN  NaN      NaN       NaN
# 4               NaN          NaN  NaN      NaN       NaN
# 5               NaN          NaN  NaN      NaN       NaN
# 6               NaN          NaN  NaN      NaN       NaN
# 7               NaN          NaN  NaN      NaN       NaN
# 8               NaN          NaN  NaN      NaN       NaN
# 9               NaN          NaN  NaN      NaN       NaN
#
#    intermediate_filament_db
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
#
# [10 rows x 48 columns]

# %%
synonyms_gene = []
gene_tag = df_genes['symbol'].tolist()
gene_name = df_genes['name'].tolist()


for row in df_genes['alias_symbol']:
    row=str(row)
    words = row.split('|')
    synonyms_gene.append(words)

#print(synonyms)
for x, y in zip(synonyms_gene, gene_tag):
    x.append(y)
    
for x, y in zip(synonyms_gene, gene_name):
    x.append(y)
gene_lists= list(zip(gene_tag, synonyms_gene))
gene_dic = dict(gene_lists)
gene_dic = {k:[elem for elem in v if elem != 'nan' ] for k,v in gene_dic.items()}



keys = [key for key, value in gene_dic.items() if 'LORSDH' in value]


gene_dic
# Out:
# {'A1BG': ['nan', 'A1BG', 'alpha-1-B glycoprotein'],
#  'A1BG-AS1': ['FLJ23569', 'A1BG-AS1', 'A1BG antisense RNA 1'],
#  'A1CF': ['ACF',
#   'ASP',
#   'ACF64',
#   'ACF65',
#   'APOBEC1CF',
#   'A1CF',
#   'APOBEC1 complementation factor'],
#  'A2M': ['FWP007', 'S863-7', 'CPAMD5', 'A2M', 'alpha-2-macroglobulin'],
#  'A2M-AS1': ['nan', 'A2M-AS1', 'A2M antisense RNA 1 (head to head)'],
#  'A2ML1': ['FLJ25179', 'A2ML1', 'alpha-2-macroglobulin like 1'],
#  'A2ML1-AS1': ['nan', 'A2ML1-AS1', 'A2ML1 antisense RNA 1'],
#  'A2ML1-AS2': ['nan', 'A2ML1-AS2', 'A2ML1 antisense RNA 2'],
#  'A2MP1': ['nan', 'A2MP1', 'alpha-2-macroglobulin pseudogene 1'],
#  'A3GALT2': ['IGBS3S',
#   'IGB3S',
#   'A3GALT2',
#   'alpha 1,3-galactosyltransferase 2'],
#  'A4GALT': ['A14GALT',
#   'Gb3S',
#   'P(k)',
#   'A4GALT',
#   'alpha 1,4-galactosyltransferase'],
#  'A4GNT': ['alpha4GnT', 'A4GNT', 'alpha-1,4-N-acetylglucosaminyltransferase'],
#  'AAAS': ['nan', 'AAAS', 'aladin WD repeat nucleoporin'],
#  'AACS': ['FLJ12389', 'SUR-5', 'ACSF1', 'AACS', 'acetoacetyl-CoA synthetase'],
#  'AACSP1': ['nan', 'AACSP1', 'acetoacetyl-CoA synthetase pseudogene 1'],
#  'AADAC': ['DAC', 'CES5A1', 'AADAC', 'arylacetamide deacetylase'],
#  'AADACL2': ['MGC72001', 'AADACL2', 'arylacetamide deacetylase-like 2'],
#  'AADACL2-AS1': ['nan', 'AADACL2-AS1', 'AADACL2 antisense RNA 1'],
#  'AADACL3': ['OTTHUMG00000001887',
#   'AADACL3',
#   'arylacetamide deacetylase-like 3'],
#  'AADACL4': ['OTTHUMG00000001889',
#   'AADACL4',
#   'arylacetamide deacetylase-like 4'],
#  'AADACP1': ['nan', 'AADACP1', 'arylacetamide deacetylase pseudogene 1'],
#  'AADAT': ['KATII', 'KAT2', 'AADAT', 'aminoadipate aminotransferase'],
#  'AAED1': ['nan', 'AAED1', 'AhpC/TSA antioxidant enzyme domain containing 1'],
#  'AAGAB': ['FLJ11506',
#   'p34',
#   'AAGAB',
#   'alpha- and gamma-adaptin binding protein'],
#  'AAK1': ['KIAA1048', 'DKFZp686K16132', 'AAK1', 'AP2 associated kinase 1'],
#  'AAMDC': ['PTD015',
#   'FLJ21035',
#   'CK067',
#   'AAMDC',
#   'adipogenesis associated, Mth938 domain containing'],
#  'AAMP': ['nan', 'AAMP', 'angio associated migratory cell protein'],
#  'AANAT': ['SNAT', 'AANAT', 'aralkylamine N-acetyltransferase'],
#  'AAR2': ['bA234K24.2', 'AAR2', 'AAR2 splicing factor homolog'],
#  'AARD': ['LOC441376',
#   'AARD',
#   'alanine and arginine rich domain containing protein'],
#  'AARS': ['CMT2N', 'AARS', 'alanyl-tRNA synthetase'],
#  'AARS2': ['KIAA1270',
#   'bA444E17.1',
#   'AARS2',
#   'alanyl-tRNA synthetase 2, mitochondrial'],
#  'AARSD1': ['MGC2744', 'AARSD1', 'alanyl-tRNA synthetase domain containing 1'],
#  'AARSP1': ['nan', 'AARSP1', 'alanyl-tRNA synthetase pseudogene 1'],
#  'AASDH': ['NRPS998',
#   'LYS2',
#   'ACSF4',
#   'AASDH',
#   'aminoadipate-semialdehyde dehydrogenase'],
#  'AASDHPPT': ['LYS5',
#   'CGI-80',
#   'AASD-PPT',
#   'ACPS',
#   'AASDHPPT',
#   'aminoadipate-semialdehyde dehydrogenase-phosphopantetheinyl transferase'],
#  'AASS': ['LORSDH', 'LKRSDH', 'AASS', 'aminoadipate-semialdehyde synthase'],
#  'AATBC': ['nan',
#   'AATBC',
#   'apoptosis associated transcript in bladder cancer'],
#  'AATF': ['DED',
#   'CHE-1',
#   'CHE1',
#   'BFR2',
#   'AATF',
#   'apoptosis antagonizing transcription factor'],
#  'AATK': ['AATYK',
#   'KIAA0641',
#   'LMTK1',
#   'LMR1',
#   'AATYK1',
#   'PPP1R77',
#   'AATK',
#   'apoptosis-associated tyrosine kinase'],
#  'AATK-AS1': ['nan', 'AATK-AS1', 'AATK antisense RNA 1'],
#  'ABALON': ['INXS',
#   'ABALON',
#   'apoptotic BCL2L1-antisense long non-coding RNA'],
#  'ABAT': ['GABAT', 'ABAT', '4-aminobutyrate aminotransferase'],
#  'ABCA1': ['TGD', 'ABCA1', 'ATP binding cassette subfamily A member 1'],
#  'ABCA2': ['nan', 'ABCA2', 'ATP binding cassette subfamily A member 2'],
#  'ABCA3': ['ABC-C',
#   'EST111653',
#   'LBM180',
#   'ABCA3',
#   'ATP binding cassette subfamily A member 3'],
#  'ABCA4': ['FFM',
#   'ARMD2',
#   'CORD3',
#   'ABCA4',
#   'ATP binding cassette subfamily A member 4'],
#  'ABCA5': ['EST90625', 'ABCA5', 'ATP binding cassette subfamily A member 5'],
#  'ABCA6': ['EST155051', 'ABCA6', 'ATP binding cassette subfamily A member 6'],
#  'ABCA7': ['ABCX', 'ABCA7', 'ATP binding cassette subfamily A member 7'],
#  'ABCA8': ['KIAA0822', 'ABCA8', 'ATP binding cassette subfamily A member 8'],
#  'ABCA9': ['EST640918', 'ABCA9', 'ATP binding cassette subfamily A member 9'],
#  'ABCA9-AS1': ['nan', 'ABCA9-AS1', 'ABCA9 antisense RNA 1'],
#  'ABCA10': ['EST698739',
#   'ABCA10',
#   'ATP binding cassette subfamily A member 10'],
#  'ABCA11P': ['EST1133530',
#   'FLJ14297',
#   'ABCA11P',
#   'ATP binding cassette subfamily A member 11, pseudogene'],
#  'ABCA12': ['DKFZP434G232',
#   'LI2',
#   'ABCA12',
#   'ATP binding cassette subfamily A member 12'],
#  'ABCA13': ['FLJ33876',
#   'FLJ33951',
#   'ABCA13',
#   'ATP binding cassette subfamily A member 13'],
#  'ABCA17P': ['nan',
#   'ABCA17P',
#   'ATP binding cassette subfamily A member 17, pseudogene'],
#  'ABCB1': ['P-gp',
#   'CD243',
#   'GP170',
#   'ABC20',
#   'ABCB1',
#   'ATP binding cassette subfamily B member 1'],
#  'ABCB4': ['MDR2',
#   'PFIC-3',
#   'GBD1',
#   'ABCB4',
#   'ATP binding cassette subfamily B member 4'],
#  'ABCB5': ['EST422562',
#   'ABCB5beta',
#   'ABCB5alpha',
#   'ABCB5',
#   'ATP binding cassette subfamily B member 5'],
#  'ABCB6': ['EST45597',
#   'umat',
#   'MTABC3',
#   'ABCB6',
#   'ATP binding cassette subfamily B member 6 (Langereis blood group)'],
#  'ABCB7': ['EST140535',
#   'Atm1p',
#   'ASAT',
#   'ABCB7',
#   'ATP binding cassette subfamily B member 7'],
#  'ABCB8': ['EST328128',
#   'M-ABC1',
#   'MABC1',
#   'ABCB8',
#   'ATP binding cassette subfamily B member 8'],
#  'ABCB9': ['EST122234', 'ABCB9', 'ATP binding cassette subfamily B member 9'],
#  'ABCB10': ['EST20237',
#   'M-ABC2',
#   'MTABC2',
#   'ABCB10',
#   'ATP binding cassette subfamily B member 10'],
#  'ABCB10P1': ['M-ABC2',
#   'MABC2',
#   'ABCB10P1',
#   'ATP binding cassette subfamily B member 10 pseudogene 1'],
#  'ABCB10P3': ['nan',
#   'ABCB10P3',
#   'ATP binding cassette subfamily B member 10 pseudogene 3'],
#  'ABCB10P4': ['nan',
#   'ABCB10P4',
#   'ATP binding cassette subfamily B member 10 pseudogene 4'],
#  'ABCB11': ['ABC16',
#   'SPGP',
#   'PFIC-2',
#   'PGY4',
#   'ABCB11',
#   'ATP binding cassette subfamily B member 11'],
#  'ABCC1': ['GS-X', 'ABCC1', 'ATP binding cassette subfamily C member 1'],
#  'ABCC2': ['DJS',
#   'MRP2',
#   'cMRP',
#   'ABCC2',
#   'ATP binding cassette subfamily C member 2'],
#  'ABCC3': ['MRP3',
#   'cMOAT2',
#   'EST90757',
#   'MLP2',
#   'MOAT-D',
#   'ABCC3',
#   'ATP binding cassette subfamily C member 3'],
#  'ABCC4': ['MRP4',
#   'EST170205',
#   'MOAT-B',
#   'MOATB',
#   'ABCC4',
#   'ATP binding cassette subfamily C member 4'],
#  'ABCC5': ['MRP5',
#   'SMRP',
#   'EST277145',
#   'MOAT-C',
#   'ABCC5',
#   'ATP binding cassette subfamily C member 5'],
#  'ABCC5-AS1': ['nan', 'ABCC5-AS1', 'ABCC5 antisense RNA 1'],
#  'ABCC6': ['MRP6',
#   'EST349056',
#   'MLP1',
#   'URG7',
#   'ABCC6',
#   'ATP binding cassette subfamily C member 6'],
#  'ABCC6P1': ['nan',
#   'ABCC6P1',
#   'ATP binding cassette subfamily C member 6 pseudogene 1'],
#  'ABCC6P2': ['nan',
#   'ABCC6P2',
#   'ATP binding cassette subfamily C member 6 pseudogene 2'],
#  'ABCC8': ['HI',
#   'PHHI',
#   'SUR1',
#   'MRP8',
#   'ABC36',
#   'HHF1',
#   'TNDM2',
#   'ABCC8',
#   'ATP binding cassette subfamily C member 8'],
#  'ABCC9': ['SUR2',
#   'CMD1O',
#   'ABCC9',
#   'ATP binding cassette subfamily C member 9'],
#  'ABCC10': ['EST182763',
#   'MRP7',
#   'SIMRP7',
#   'ABCC10',
#   'ATP binding cassette subfamily C member 10'],
#  'ABCC11': ['MRP8', 'ABCC11', 'ATP binding cassette subfamily C member 11'],
#  'ABCC12': ['MRP9', 'ABCC12', 'ATP binding cassette subfamily C member 12'],
#  'ABCC13': ['PRED6',
#   'C21orf73',
#   'ABCC13P',
#   'ABCC13',
#   'ATP binding cassette subfamily C member 13 (pseudogene)'],
#  'ABCD1': ['AMN',
#   'ALDP',
#   'adrenoleukodystrophy',
#   'ABCD1',
#   'ATP binding cassette subfamily D member 1'],
#  'ABCD1P2': ['bA453N3.6',
#   'ABCD1P2',
#   'ATP binding cassette subfamily D member 1 pseudogene 2'],
#  'ABCD1P3': ['nan',
#   'ABCD1P3',
#   'ATP binding cassette subfamily D member 1 pseudogene 3'],
#  'ABCD1P4': ['nan',
#   'ABCD1P4',
#   'ATP binding cassette subfamily D member 1 pseudogene 4'],
#  'ABCD1P5': ['nan',
#   'ABCD1P5',
#   'ATP binding cassette subfamily D member 1 pseudogene 5'],
#  'ABCD2': ['ALDR',
#   'ALDRP',
#   'ABCD2',
#   'ATP binding cassette subfamily D member 2'],
#  'ABCD3': ['PMP70',
#   'ZWS2',
#   'ABCD3',
#   'ATP binding cassette subfamily D member 3'],
#  'ABCD4': ['PMP69',
#   'P70R',
#   'EST352188',
#   'ABCD4',
#   'ATP binding cassette subfamily D member 4'],
#  'ABCE1': ['RLI',
#   'OABP',
#   'ABCE1',
#   'ATP binding cassette subfamily E member 1'],
#  'ABCF1': ['EST123147', 'ABCF1', 'ATP binding cassette subfamily F member 1'],
#  'ABCF2': ['EST133090',
#   'ABC28',
#   'M-ABC1',
#   'HUSSY-18',
#   'ABCF2',
#   'ATP binding cassette subfamily F member 2'],
#  'ABCF2P1': ['nan',
#   'ABCF2P1',
#   'ATP binding cassette subfamily F member 2 pseudogene 1'],
#  'ABCF2P2': ['nan',
#   'ABCF2P2',
#   'ATP binding cassette subfamily F member 2 pseudogene 2'],
#  'ABCF3': ['EST201864', 'ABCF3', 'ATP binding cassette subfamily F member 3'],
#  'ABCG1': ['ABC8', 'ABCG1', 'ATP binding cassette subfamily G member 1'],
#  'ABCG2': ['EST157481',
#   'MXR',
#   'BCRP',
#   'ABCP',
#   'CD338',
#   'ABCG2',
#   'ATP binding cassette subfamily G member 2 (Junior blood group)'],
#  'ABCG4': ['WHITE2', 'ABCG4', 'ATP binding cassette subfamily G member 4'],
#  'ABCG5': ['STSL', 'ABCG5', 'ATP binding cassette subfamily G member 5'],
#  'ABCG8': ['GBD4', 'ABCG8', 'ATP binding cassette subfamily G member 8'],
#  'ABHD1': ['LABH1', 'FLJ36128', 'ABHD1', 'abhydrolase domain containing 1'],
#  'ABHD2': ['LABH2', 'ABHD2', 'abhydrolase domain containing 2'],
#  'ABHD3': ['LABH3', 'ABHD3', 'abhydrolase domain containing 3'],
#  'ABHD4': ['FLJ12816', 'ABHD4', 'abhydrolase domain containing 4'],
#  'ABHD5': ['CGI-58', 'NCIE2', 'ABHD5', 'abhydrolase domain containing 5'],
#  'ABHD6': ['nan', 'ABHD6', 'abhydrolase domain containing 6'],
#  'ABHD8': ['FLJ11743',
#   'MGC14280',
#   'MGC2512',
#   'ABHD8',
#   'abhydrolase domain containing 8'],
#  'ABHD10': ['FLJ11342', 'ABHD10', 'abhydrolase domain containing 10'],
#  'ABHD11': ['PP1226', 'ABHD11', 'abhydrolase domain containing 11'],
#  'ABHD11-AS1': ['NCRNA00035',
#   'ABHD11-AS1',
#   'ABHD11 antisense RNA 1 (tail to tail)'],
#  'ABHD12': ['DKFZP434P106',
#   'dJ965G21.2',
#   'BEM46L2',
#   'ABHD12A',
#   'ABHD12',
#   'abhydrolase domain containing 12'],
#  'ABHD12B': ['BEM46L3', 'ABHD12B', 'abhydrolase domain containing 12B'],
#  'ABHD13': ['bA153I24.2',
#   'FLJ14906',
#   'BEM46L1',
#   'ABHD13',
#   'abhydrolase domain containing 13'],
#  'ABHD14A': ['DKFZP564O243',
#   'DORZ1',
#   'ABHD14A',
#   'abhydrolase domain containing 14A'],
#  'ABHD14A-ACY1': ['nan', 'ABHD14A-ACY1', 'ABHD14A-ACY1 readthrough'],
#  'ABHD14B': ['MGC15429',
#   'CIB',
#   'ABHD14B',
#   'abhydrolase domain containing 14B'],
#  'ABHD15': ['nan', 'ABHD15', 'abhydrolase domain containing 15'],
#  'ABHD15-AS1': ['linc-TP53I13',
#   'lnc-TP53I13',
#   'ABHD15-AS1',
#   'ABHD15 antisense RNA 1'],
#  'ABHD16A': ['NG26', 'D6S82E', 'ABHD16A', 'abhydrolase domain containing 16A'],
#  'ABHD16B': ['dJ591C20.1', 'ABHD16B', 'abhydrolase domain containing 16B'],
#  'ABHD17A': ['MGC5244', 'ABHD17A', 'abhydrolase domain containing 17A'],
#  'ABHD17AP1': ['C1orf47',
#   'ABHD17AP1',
#   'abhydrolase domain containing 17A pseudogene 1'],
#  'ABHD17AP3': ['nan',
#   'ABHD17AP3',
#   'abhydrolase domain containing 17A pseudogene 3'],
#  'ABHD17AP4': ['nan',
#   'ABHD17AP4',
#   'abhydrolase domain containing 17A pseudogene P4'],
#  'ABHD17AP5': ['nan',
#   'ABHD17AP5',
#   'abhydrolase domain containing 17A pseudogene 5'],
#  'ABHD17AP6': ['nan',
#   'ABHD17AP6',
#   'abhydrolase domain containing 17A pseudogene 6'],
#  'ABHD17AP7': ['nan',
#   'ABHD17AP7',
#   'abhydrolase domain containing 17A pseudogene 7'],
#  'ABHD17AP8': ['nan',
#   'ABHD17AP8',
#   'abhydrolase domain containing 17A pseudogene 8'],
#  'ABHD17AP9': ['nan',
#   'ABHD17AP9',
#   'abhydrolase domain containing 17A pseudogene 9'],
#  'ABHD17B': ['CGI-67', 'ABHD17B', 'abhydrolase domain containing 17B'],
#  'ABHD17C': ['nan', 'ABHD17C', 'abhydrolase domain containing 17C'],
#  'ABHD18': ['FLJ21106', 'ABHD18', 'abhydrolase domain containing 18'],
#  'ABI1': ['E3B1', 'ABI-1', 'ABI1', 'abl interactor 1'],
#  'ABI2': ['ABI-2',
#   'AIP-1',
#   'ABI2B',
#   'AblBP3',
#   'argBPIA',
#   'SSH3BP2',
#   'ABI2',
#   'abl-interactor 2'],
#  'ABI3': ['NESH', 'SSH3BP3', 'ABI3', 'ABI family member 3'],
#  'ABI3BP': ['NESHBP',
#   'DKFZP586L2024',
#   'TARSH',
#   'ABI3BP',
#   'ABI family member 3 binding protein'],
#  'ABL1': ['JTK7',
#   'c-ABL',
#   'p150',
#   'ABL1',
#   'ABL proto-oncogene 1, non-receptor tyrosine kinase'],
#  'ABL2': ['ARG', 'ABL2', 'ABL proto-oncogene 2, non-receptor tyrosine kinase'],
#  'ABLIM1': ['abLIM', 'limatin', 'ABLIM1', 'actin binding LIM protein 1'],
#  'ABLIM2': ['KIAA1808', 'ABLIM2', 'actin binding LIM protein family member 2'],
#  'ABLIM3': ['KIAA0843', 'ABLIM3', 'actin binding LIM protein family member 3'],
#  'ABO': ['A3GALNT',
#   'A3GALT1',
#   'ABO',
#   'ABO blood group (transferase A, alpha 1-3-N-acetylgalactosaminyltransferase; transferase B, alpha 1-3-galactosyltransferase)'],
#  'ABR': ['MDB', 'ABR', 'active BCR-related'],
#  'ABRA': ['STARS', 'ABRA', 'actin binding Rho activating protein'],
#  'ABRACL': ['PRO2013', 'HSPC280', 'Costars', 'ABRACL', 'ABRA C-terminal like'],
#  'ABT1': ['nan', 'ABT1', 'activator of basal transcription 1'],
#  'ABT1P1': ['nan',
#   'ABT1P1',
#   'activator of basal transcription 1 pseudogene 1'],
#  'ABTB1': ['BPOZ',
#   'EF1ABP',
#   'Btb3',
#   'BTBD21',
#   'ABTB1',
#   'ankyrin repeat and BTB domain containing 1'],
#  'ABTB2': ['DKFZP586C1619',
#   'BTBD22',
#   'ABTB2A',
#   'ABTB2',
#   'ankyrin repeat and BTB domain containing 2'],
#  'ACAA1': ['nan', 'ACAA1', 'acetyl-CoA acyltransferase 1'],
#  'ACAA2': ['DSAEC', 'ACAA2', 'acetyl-CoA acyltransferase 2'],
#  'ACACA': ['ACC1', 'ACACA', 'acetyl-CoA carboxylase alpha'],
#  'ACACB': ['HACC275', 'ACC2', 'ACCB', 'ACACB', 'acetyl-CoA carboxylase beta'],
#  'ACAD8': ['nan', 'ACAD8', 'acyl-CoA dehydrogenase family member 8'],
#  'ACAD9': ['NPD002',
#   'MGC14452',
#   'ACAD9',
#   'acyl-CoA dehydrogenase family member 9'],
#  'ACAD10': ['MGC5601', 'ACAD10', 'acyl-CoA dehydrogenase family member 10'],
#  'ACAD11': ['FLJ12592', 'ACAD11', 'acyl-CoA dehydrogenase family member 11'],
#  'ACADL': ['LCAD', 'ACAD4', 'ACADL', 'acyl-CoA dehydrogenase, long chain'],
#  'ACADM': ['MCAD',
#   'MCADH',
#   'ACAD1',
#   'ACADM',
#   'acyl-CoA dehydrogenase, C-4 to C-12 straight chain'],
#  'ACADS': ['SCAD',
#   'ACAD3',
#   'ACADS',
#   'acyl-CoA dehydrogenase, C-2 to C-3 short chain'],
#  'ACADSB': ['SBCAD',
#   'ACAD7',
#   'ACADSB',
#   'acyl-CoA dehydrogenase, short/branched chain'],
#  'ACADVL': ['VLCAD',
#   'LCACD',
#   'ACAD6',
#   'ACADVL',
#   'acyl-CoA dehydrogenase, very long chain'],
#  'ACAN': ['CSPGCP', 'ACAN', 'aggrecan'],
#  'ACAP1': ['KIAA0050',
#   'ACAP1',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 1'],
#  'ACAP2': ['KIAA0041',
#   'CNT-B2',
#   'ACAP2',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 2'],
#  'ACAP2-IT1': ['nan', 'ACAP2-IT1', 'ACAP2 intronic transcript 1'],
#  'ACAP3': ['KIAA1716',
#   'ACAP3',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 3'],
#  'ACAT1': ['THIL', 'ACAT1', 'acetyl-CoA acetyltransferase 1'],
#  'ACAT2': ['nan', 'ACAT2', 'acetyl-CoA acetyltransferase 2'],
#  'ACBD3': ['GCP60', 'PAP7', 'ACBD3', 'acyl-CoA binding domain containing 3'],
#  'ACBD4': ['FLJ13322', 'ACBD4', 'acyl-CoA binding domain containing 4'],
#  'ACBD5': ['DKFZp434A2417',
#   'KIAA1996',
#   'ACBD5',
#   'acyl-CoA binding domain containing 5'],
#  'ACBD6': ['MGC2404', 'ACBD6', 'acyl-CoA binding domain containing 6'],
#  'ACBD7': ['FLJ38219',
#   'bA455B2.2',
#   'ACBD7',
#   'acyl-CoA binding domain containing 7'],
#  'ACCS': ['PHACS',
#   'ACS',
#   'ACCS',
#   '1-aminocyclopropane-1-carboxylate synthase homolog (inactive)'],
#  'ACCSL': ['nan',
#   'ACCSL',
#   '1-aminocyclopropane-1-carboxylate synthase (inactive)-like'],
#  'ACD': ['Ptop',
#   'Pip1',
#   'Tpp1',
#   'Tint1',
#   'ACD',
#   'adrenocortical dysplasia homolog'],
#  'ACE': ['ACE1', 'CD143', 'ACE', 'angiotensin I converting enzyme'],
#  'ACE2': ['nan', 'ACE2', 'angiotensin I converting enzyme 2'],
#  'ACE3P': ['nan',
#   'ACE3P',
#   'angiotensin I converting enzyme (peptidyl-dipeptidase A) 3, pseudogene'],
#  'ACER1': ['nan', 'ACER1', 'alkaline ceramidase 1'],
#  'ACER2': ['FLJ41587', 'ACER2', 'alkaline ceramidase 2'],
#  'ACER3': ['FLJ11238', 'APHC', 'ACER3', 'alkaline ceramidase 3'],
#  'ACHE': ['nan', 'ACHE', 'acetylcholinesterase (Cartwright blood group)'],
#  'ACIN1': ['KIAA0670',
#   'fSAP152',
#   'ACIN1',
#   'apoptotic chromatin condensation inducer 1'],
#  'ACKR1': ['CCBP1',
#   'GPD',
#   'Dfy',
#   'CD234',
#   'ACKR1',
#   'atypical chemokine receptor 1 (Duffy blood group)'],
#  'ACKR2': ['CCR10', 'D6', 'CCR9', 'ACKR2', 'atypical chemokine receptor 2'],
#  'ACKR3': ['RDC1', 'GPR159', 'ACKR3', 'atypical chemokine receptor 3'],
#  'ACKR4': ['CCR11',
#   'CCBP2',
#   'VSHK1',
#   'CCX-CKR',
#   'PPR1',
#   'ACKR4',
#   'atypical chemokine receptor 4'],
#  'ACLY': ['ATPCL', 'CLATP', 'ACL', 'ACLY', 'ATP citrate lyase'],
#  'ACMSD': ['nan', 'ACMSD', 'aminocarboxymuconate semialdehyde decarboxylase'],
#  'ACO1': ['IRP1', 'IREBP', 'ACO1', 'aconitase 1'],
#  'ACO2': ['ACONM', 'ACO2', 'aconitase 2'],
#  'ACOD1': ['CAD', 'ACOD1', 'aconitate decarboxylase 1'],
#  'ACOT1': ['ACH2', 'CTE-1', 'LACH2', 'ACOT1', 'acyl-CoA thioesterase 1'],
#  'ACOT2': ['Mte1', 'ZAP128', 'ACOT2', 'acyl-CoA thioesterase 2'],
#  'ACOT4': ['FLJ31235', 'PTE-Ib', 'PTE2B', 'ACOT4', 'acyl-CoA thioesterase 4'],
#  'ACOT6': ['nan', 'ACOT6', 'acyl-CoA thioesterase 6'],
#  'ACOT7': ['BACH',
#   'ACH1',
#   'ACT',
#   'CTE-II',
#   'LACH1',
#   'MGC1126',
#   'hBACH',
#   'ACOT7',
#   'acyl-CoA thioesterase 7'],
#  'ACOT8': ['hACTE-III',
#   'hTE',
#   'PTE-2',
#   'NAP1',
#   'ACOT8',
#   'acyl-CoA thioesterase 8'],
#  'ACOT9': ['CGI-16', 'MT-ACT48', 'ACATE2', 'ACOT9', 'acyl-CoA thioesterase 9'],
#  'ACOT11': ['STARD14',
#   'BFIT',
#   'KIAA0707',
#   'BFIT1',
#   'THEM1',
#   'ACOT11',
#   'acyl-CoA thioesterase 11'],
#  'ACOT12': ['Cach', 'THEAL', 'STARD15', 'ACOT12', 'acyl-CoA thioesterase 12'],
#  'ACOT13': ['HT012', 'ACOT13', 'acyl-CoA thioesterase 13'],
#  'ACOX1': ['PALMCOX', 'ACOX1', 'acyl-CoA oxidase 1, palmitoyl'],
#  'ACOX2': ['BRCACOX',
#   'BRCOX',
#   'THCCox',
#   'ACOX2',
#   'acyl-CoA oxidase 2, branched chain'],
#  'ACOX3': ['nan', 'ACOX3', 'acyl-CoA oxidase 3, pristanoyl'],
#  'ACOXL': ['FLJ11042', 'ACOXL', 'acyl-CoA oxidase-like'],
#  'ACP1': ['HAAP', 'LMW-PTP', 'ACP1', 'acid phosphatase 1, soluble'],
#  'ACP2': ['LAP', 'ACP2', 'acid phosphatase 2, lysosomal'],
#  'ACP5': ['TRAP', 'HPAP', 'ACP5', 'acid phosphatase 5, tartrate resistant'],
#  'ACP6': ['LPAP', 'ACPL1', 'ACP6', 'acid phosphatase 6, lysophosphatidic'],
#  'ACP7': ['FLJ16165',
#   'PAPL1',
#   'ACP7',
#   'acid phosphatase 7, tartrate resistant (putative)'],
#  'ACPP': ['ACP3', 'ACP-3', 'PAP', 'ACPP', 'acid phosphatase, prostate'],
#  'ACPT': ['nan', 'ACPT', 'acid phosphatase, testicular'],
#  'ACR': ['nan', 'ACR', 'acrosin'],
#  'ACRBP': ['SP32', 'OY-TES-1', 'CT23', 'ACRBP', 'acrosin binding protein'],
#  'ACRC': ['nan', 'ACRC', 'acidic repeat containing'],
#  'ACRV1': ['SPACA2',
#   'SP-10',
#   'D11S4365',
#   'ACRV1',
#   'acrosomal vesicle protein 1'],
#  'ACSBG1': ['BGM',
#   'FLJ30320',
#   'MGC14352',
#   'BG1',
#   'KIAA0631',
#   'hBG1',
#   'hsBG',
#   'ACSBG1',
#   'acyl-CoA synthetase bubblegum family member 1'],
#  'ACSBG2': ['BGR',
#   'PRTD-NY3',
#   'DKFZp434K1635',
#   'ACSBG2',
#   'acyl-CoA synthetase bubblegum family member 2'],
#  'ACSF2': ['FLJ20920',
#   'ACSMW',
#   'ACSF2',
#   'acyl-CoA synthetase family member 2'],
#  'ACSF3': ['nan', 'ACSF3', 'acyl-CoA synthetase family member 3'],
#  'ACSL1': ['LACS2',
#   'LACS',
#   'ACS1',
#   'LACS1',
#   'FACL1',
#   'ACSL1',
#   'acyl-CoA synthetase long-chain family member 1'],
#  'ACSL3': ['ACS3',
#   'PRO2194',
#   'ACSL3',
#   'acyl-CoA synthetase long-chain family member 3'],
#  'ACSL4': ['ACS4',
#   'LACS4',
#   'ACSL4',
#   'acyl-CoA synthetase long-chain family member 4'],
#  'ACSL5': ['ACS5',
#   'ACS2',
#   'ACSL5',
#   'acyl-CoA synthetase long-chain family member 5'],
#  'ACSL6': ['KIAA0837',
#   'ACS2',
#   'LACS5',
#   'LACS2',
#   'ACSL6',
#   'acyl-CoA synthetase long-chain family member 6'],
#  'ACSM1': ['MACS1',
#   'ACSM1',
#   'acyl-CoA synthetase medium-chain family member 1'],
#  'ACSM2A': ['A-923A4.1',
#   'MGC150530',
#   'ACSM2A',
#   'acyl-CoA synthetase medium-chain family member 2A'],
#  'ACSM2B': ['HXMA',
#   'HYST1046',
#   'ACSM2B',
#   'acyl-CoA synthetase medium-chain family member 2B'],
#  'ACSM3': ['SA', 'ACSM3', 'acyl-CoA synthetase medium-chain family member 3'],
#  'ACSM4': ['nan', 'ACSM4', 'acyl-CoA synthetase medium-chain family member 4'],
#  'ACSM5': ['FLJ20581',
#   'ACSM5',
#   'acyl-CoA synthetase medium-chain family member 5'],
#  'ACSM5P1': ['nan',
#   'ACSM5P1',
#   'acyl-CoA synthetase medium-chain family member 5 pseudogene 1'],
#  'ACSM6': ['bA310E22.3',
#   'ACSM6',
#   'acyl-CoA synthetase medium-chain family member 6'],
#  'ACSS1': ['dJ568C11.3',
#   'AceCS2L',
#   'MGC33843',
#   'ACSS1',
#   'acyl-CoA synthetase short-chain family member 1'],
#  'ACSS2': ['ACS',
#   'ACSA',
#   'AceCS',
#   'dJ1161H23.1',
#   'ACSS2',
#   'acyl-CoA synthetase short-chain family member 2'],
#  'ACSS3': ['FLJ21963',
#   'ACSS3',
#   'acyl-CoA synthetase short-chain family member 3'],
#  'ACTA1': ['NEM3', 'ACTA1', 'actin, alpha 1, skeletal muscle'],
#  'ACTA2': ['ACTSA', 'ACTA2', 'actin, alpha 2, smooth muscle, aorta'],
#  'ACTA2-AS1': ['uc001kfo.1', 'ZXF1', 'ACTA2-AS1', 'ACTA2 antisense RNA 1'],
#  'ACTB': ['nan', 'ACTB', 'actin, beta'],
#  'ACTBL2': ['DKFZp686D0972', 'ACTBL2', 'actin, beta-like 2'],
#  'ACTBP1': ['nan', 'ACTBP1', 'actin, beta pseudogene 1'],
#  'ACTBP2': ['nan', 'ACTBP2', 'actin, beta pseudogene 2'],
#  'ACTBP6': ['nan', 'ACTBP6', 'actin, beta pseudogene 6'],
#  'ACTBP7': ['nan', 'ACTBP7', 'actin, beta pseudogene 7'],
#  'ACTBP8': ['ACTBP2', 'ACTBP8', 'actin, beta pseudogene 8'],
#  'ACTBP9': ['nan', 'ACTBP9', 'actin, beta pseudogene 9'],
#  'ACTBP11': ['nan', 'ACTBP11', 'actin, beta pseudogene 11'],
#  'ACTBP12': ['nan', 'ACTBP12', 'actin, beta pseudogene 12'],
#  'ACTBP13': ['nan', 'ACTBP13', 'actin, beta pseudogene 13'],
#  'ACTBP14': ['nan', 'ACTBP14', 'actin, beta pseudogene 14'],
#  'ACTC1': ['CMD1R', 'ACTC1', 'actin, alpha, cardiac muscle 1'],
#  'ACTG1': ['nan', 'ACTG1', 'actin gamma 1'],
#  'ACTG1P1': ['nan', 'ACTG1P1', 'actin gamma 1 pseudogene 1'],
#  'ACTG1P2': ['nan', 'ACTG1P2', 'actin gamma 1 pseudogene 2'],
#  'ACTG1P3': ['nan', 'ACTG1P3', 'actin gamma 1 pseudogene 3'],
#  'ACTG1P4': ['nan', 'ACTG1P4', 'actin gamma 1 pseudogene 4'],
#  'ACTG1P9': ['nan', 'ACTG1P9', 'actin gamma 1 pseudogene 9'],
#  'ACTG1P10': ['nan', 'ACTG1P10', 'actin gamma 1 pseudogene 10'],
#  'ACTG1P11': ['nan', 'ACTG1P11', 'actin gamma 1 pseudogene 11'],
#  'ACTG1P12': ['nan', 'ACTG1P12', 'actin gamma 1 pseudogene 12'],
#  'ACTG1P13': ['nan', 'ACTG1P13', 'actin gamma 1 pseudogene 13'],
#  'ACTG1P14': ['nan', 'ACTG1P14', 'actin gamma 1 pseudogene 14'],
#  'ACTG1P15': ['nan', 'ACTG1P15', 'actin gamma 1 pseudogene 15'],
#  'ACTG1P16': ['nan', 'ACTG1P16', 'actin gamma 1 pseudogene 16'],
#  'ACTG1P17': ['nan', 'ACTG1P17', 'actin gamma 1 pseudogene 17'],
#  'ACTG1P18': ['nan', 'ACTG1P18', 'actin gamma 1 pseudogene 18'],
#  'ACTG1P19': ['nan', 'ACTG1P19', 'actin gamma 1 pseudogene 19'],
#  'ACTG1P20': ['nan', 'ACTG1P20', 'actin gamma 1 pseudogene 20'],
#  'ACTG1P21': ['nan', 'ACTG1P21', 'actin gamma 1 pseudogene 21'],
#  'ACTG1P22': ['nan', 'ACTG1P22', 'actin gamma 1 pseudogene 22'],
#  'ACTG1P23': ['nan', 'ACTG1P23', 'actin gamma 1 pseudogene 23'],
#  'ACTG1P24': ['nan', 'ACTG1P24', 'actin gamma 1 pseudogene 24'],
#  'ACTG2': ['ACTSG', 'ACTG2', 'actin, gamma 2, smooth muscle, enteric'],
#  'ACTL6A': ['Actl6',
#   'BAF53A',
#   'Arp4',
#   'Baf53a',
#   'INO80K',
#   'ACTL6A',
#   'actin like 6A'],
#  'ACTL6B': ['BAF53B', 'ACTL6B', 'actin like 6B'],
#  'ACTL7A': ['nan', 'ACTL7A', 'actin like 7A'],
#  'ACTL7B': ['Tact1', 'ACTL7B', 'actin like 7B'],
#  'ACTL8': ['CT57', 'ACTL8', 'actin like 8'],
#  'ACTL9': ['MGC33407', 'ACTL9', 'actin like 9'],
#  'ACTL10': ['nan', 'ACTL10', 'actin like 10'],
#  'ACTN1': ['nan', 'ACTN1', 'actinin alpha 1'],
#  'ACTN1-AS1': ['nan', 'ACTN1-AS1', 'ACTN1 antisense RNA 1'],
#  'ACTN2': ['nan', 'ACTN2', 'actinin alpha 2'],
#  'ACTN3': ['nan', 'ACTN3', 'actinin alpha 3 (gene/pseudogene)'],
#  'ACTN4': ['nan', 'ACTN4', 'actinin alpha 4'],
#  'ACTN4P1': ['nan', 'ACTN4P1', 'actinin alpha 4 pseudogene 1'],
#  'ACTN4P2': ['nan', 'ACTN4P2', 'actinin alpha 4 pseudogene 2'],
#  'ACTP1': ['nan', 'ACTP1', 'actin family pseudogene 1'],
#  'ACTR1A': ['ARP1',
#   'Arp1A',
#   'ACTR1A',
#   'ARP1 actin-related protein 1 homolog A, centractin alpha'],
#  'ACTR1B': ['Arp1B',
#   'ACTR1B',
#   'ARP1 actin-related protein 1 homolog B, centractin beta'],
#  'ACTR2': ['ARP2', 'ACTR2', 'ARP2 actin-related protein 2 homolog (yeast)'],
#  'ACTR3': ['ARP3', 'ACTR3', 'ARP3 actin-related protein 3 homolog (yeast)'],
#  'ACTR3B': ['ARP11',
#   'ARP3beta',
#   'ACTR3B',
#   'ARP3 actin-related protein 3 homolog B (yeast)'],
#  'ACTR3BP1': ['nan', 'ACTR3BP1', 'ACTR3B pseudogene 1'],
#  'ACTR3BP2': ['FKSG73', 'ACTR3BP2', 'ACTR3B pseudogene 2'],
#  'ACTR3BP3': ['nan', 'ACTR3BP3', 'ACTR3B pseudogene 3'],
#  'ACTR3BP4': ['nan', 'ACTR3BP4', 'ACTR3B pseudogene 4'],
#  'ACTR3BP5': ['nan', 'ACTR3BP5', 'ACTR3B pseudogene 5'],
#  'ACTR3BP6': ['nan', 'ACTR3BP6', 'ACTR3B pseudogene 6'],
#  'ACTR3C': ['ARP11', 'ACTR3C', 'ARP3 actin-related protein 3 homolog C'],
#  'ACTR3P2': ['nan', 'ACTR3P2', 'ACTR3 pseudogene 2'],
#  'ACTR3P3': ['nan', 'ACTR3P3', 'ACTR3 pseudogene 3'],
#  'ACTR5': ['FLJ12785',
#   'Arp5',
#   'INO80M',
#   'ACTR5',
#   'ARP5 actin-related protein 5 homolog'],
#  'ACTR6': ['ARP6',
#   'FLJ13433',
#   'ACTR6',
#   'ARP6 actin-related protein 6 homolog'],
#  'ACTR6P1': ['nan', 'ACTR6P1', 'ACTR6 pseudogene 1'],
#  'ACTR8': ['INO80N', 'ACTR8', 'ARP8 actin-related protein 8 homolog'],
#  'ACTR10': ['HARP11',
#   'ACTR11',
#   'Arp11',
#   'Arp10',
#   'ACTR10',
#   'actin-related protein 10 homolog'],
#  'ACTRT1': ['AIP1',
#   'KIAA0705',
#   'ARIP1',
#   'Arp-T1',
#   'ACTRT1',
#   'actin related protein T1'],
#  'ACTRT2': ['Arp-T2',
#   'ARPM2',
#   'FLJ25424',
#   'ACTRT2',
#   'actin related protein T2'],
#  'ACTRT3': ['ARPM1', 'ACTRT3', 'actin related protein T3'],
#  'ACVR1': ['SKR1', 'ALK2', 'ACVR1A', 'ACVR1', 'activin A receptor type 1'],
#  'ACVR1B': ['ALK4', 'SKR2', 'ActRIB', 'ACVR1B', 'activin A receptor type 1B'],
#  'ACVR1C': ['ALK7', 'ACVRLK7', 'ACVR1C', 'activin A receptor type 1C'],
#  'ACVR2A': ['ACTRII', 'ACVR2A', 'activin A receptor type 2A'],
#  'ACVR2B': ['ActR-IIB', 'ACVR2B', 'activin A receptor type 2B'],
#  'ACVR2B-AS1': ['nan', 'ACVR2B-AS1', 'ACVR2B antisense RNA 1'],
#  'ACVRL1': ['HHT2', 'ALK1', 'HHT', 'ACVRL1', 'activin A receptor like type 1'],
#  'ACY1': ['nan', 'ACY1', 'aminoacylase 1'],
#  'ACY3': ['HCBP1', 'MGC9740', 'ACY-3', 'ACY3', 'aminoacylase 3'],
#  'ACYP1': ['nan', 'ACYP1', 'acylphosphatase 1'],
#  'ACYP2': ['nan', 'ACYP2', 'acylphosphatase 2'],
#  'ADA': ['nan', 'ADA', 'adenosine deaminase'],
#  'ADAD1': ['Tenr', 'ADAD1', 'adenosine deaminase domain containing 1'],
#  'ADAD1P2': ['nan',
#   'ADAD1P2',
#   'adenosine deaminase domain containing 1 pseudogene 2'],
#  'ADAD2': ['TENRL',
#   'FLJ00337',
#   'ADAD2',
#   'adenosine deaminase domain containing 2'],
#  'ADAL': ['nan', 'ADAL', 'adenosine deaminase-like'],
#  'ADAM1A': ['FTNAP',
#   'PH-30a',
#   'Ftna',
#   'ADAM1P',
#   'ADAM1A',
#   'ADAM metallopeptidase domain 1A (pseudogene)'],
#  'ADAM1B': ['nan', 'ADAM1B', 'ADAM metallopeptidase domain 1B (pseudogene)'],
#  'ADAM2': ['PH-30b',
#   'PH30',
#   'CT15',
#   'ADAM2',
#   'ADAM metallopeptidase domain 2'],
#  'ADAM3A': ['ADAM3',
#   'tMDCI',
#   'ADAM3A',
#   'ADAM metallopeptidase domain 3A (pseudogene)'],
#  'ADAM3B': ['nan', 'ADAM3B', 'ADAM metallopeptidase domain 3B (pseudogene)'],
#  'ADAM5': ['tMDCII', 'ADAM5', 'ADAM metallopeptidase domain 5 (pseudogene)'],
#  'ADAM6': ['tMDCIV', 'ADAM6', 'ADAM metallopeptidase domain 6 (pseudogene)'],
#  'ADAM7': ['GP-83', 'EAPI', 'ADAM7', 'ADAM metallopeptidase domain 7'],
#  'ADAM8': ['CD156',
#   'MS2',
#   'CD156a',
#   'ADAM8',
#   'ADAM metallopeptidase domain 8'],
#  'ADAM9': ['MDC9',
#   'KIAA0021',
#   'MCMP',
#   'Mltng',
#   'ADAM9',
#   'ADAM metallopeptidase domain 9'],
#  'ADAM10': ['kuz',
#   'MADM',
#   'HsT18717',
#   'CD156c',
#   'ADAM10',
#   'ADAM metallopeptidase domain 10'],
#  'ADAM11': ['nan', 'ADAM11', 'ADAM metallopeptidase domain 11'],
#  'ADAM12': ['MCMPMltna', 'MLTN', 'ADAM12', 'ADAM metallopeptidase domain 12'],
#  'ADAM15': ['MDC15', 'ADAM15', 'ADAM metallopeptidase domain 15'],
#  'ADAM17': ['cSVP', 'CD156B', 'ADAM17', 'ADAM metallopeptidase domain 17'],
#  'ADAM18': ['tMDCIII', 'ADAM27', 'ADAM18', 'ADAM metallopeptidase domain 18'],
#  'ADAM19': ['MLTNB', 'ADAM19', 'ADAM metallopeptidase domain 19'],
#  'ADAM20': ['nan', 'ADAM20', 'ADAM metallopeptidase domain 20'],
#  'ADAM20P1': ['nan',
#   'ADAM20P1',
#   'ADAM metallopeptidase domain 20 pseudogene 1'],
#  'ADAM20P2': ['nan',
#   'ADAM20P2',
#   'ADAM metallopeptidase domain 20 pseudogene 2'],
#  'ADAM20P3': ['nan',
#   'ADAM20P3',
#   'ADAM metallopeptidase domain 20 pseudogene 3'],
#  'ADAM21': ['ADAM31', 'ADAM21', 'ADAM metallopeptidase domain 21'],
#  'ADAM21P1': ['nan',
#   'ADAM21P1',
#   'ADAM metallopeptidase domain 21 pseudogene 1'],
#  'ADAM22': ['MDC2', 'ADAM22', 'ADAM metallopeptidase domain 22'],
#  'ADAM23': ['MDC3', 'ADAM23', 'ADAM metallopeptidase domain 23'],
#  'ADAM24P': ['nan', 'ADAM24P', 'ADAM metallopeptidase domain 24, pseudogene'],
#  'ADAM28': ['eMDCII',
#   'MDC-Lm',
#   'MDC-Ls',
#   'ADAM23',
#   'ADAM28',
#   'ADAM metallopeptidase domain 28'],
#  'ADAM29': ['svph1', 'CT73', 'ADAM29', 'ADAM metallopeptidase domain 29'],
#  'ADAM30': ['svph4', 'ADAM30', 'ADAM metallopeptidase domain 30'],
#  'ADAM32': ['nan', 'ADAM32', 'ADAM metallopeptidase domain 32'],
#  'ADAM33': ['DKFZp434K0521',
#   'dJ964F7.1',
#   'ADAM33',
#   'ADAM metallopeptidase domain 33'],
#  'ADAMDEC1': ['M12.219', 'ADAMDEC1', 'ADAM-like, decysin 1'],
#  'ADAMTS1': ['C3-C5',
#   'METH1',
#   'KIAA1346',
#   'ADAMTS1',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 1'],
#  'ADAMTS2': ['ADAMTS-3',
#   'hPCPNI',
#   'PCINP',
#   'ADAM-TS2',
#   'NPI',
#   'ADAMTS2',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 2'],
#  'ADAMTS3': ['KIAA0366',
#   'ADAMTS-4',
#   'ADAMTS3',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 3'],
#  'ADAMTS4': ['KIAA0688',
#   'ADAMTS-2',
#   'ADMP-1',
#   'ADAMTS4',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 4'],
#  'ADAMTS5': ['ADMP-2',
#   'ADAMTS11',
#   'ADAMTS5',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 5'],
#  'ADAMTS6': ['ADAM-TS6',
#   'ADAMTS6',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 6'],
#  'ADAMTS7': ['ADAM-TS7',
#   'DKFZp434H204',
#   'ADAMTS7',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 7'],
#  'ADAMTS7P1': ['nan', 'ADAMTS7P1', 'ADAMTS7 pseudogene 1'],
#  'ADAMTS7P3': ['nan', 'ADAMTS7P3', 'ADAMTS7 pseudogene 3'],
#  'ADAMTS7P4': ['nan', 'ADAMTS7P4', 'ADAMTS7 pseudogene 4'],
#  'ADAMTS8': ['METH2',
#   'FLJ41712',
#   'ADAM-TS8',
#   'ADAMTS8',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 8'],
#  'ADAMTS9': ['KIAA1312',
#   'ADAMTS9',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 9'],
#  'ADAMTS9-AS1': ['nan', 'ADAMTS9-AS1', 'ADAMTS9 antisense RNA 1'],
#  'ADAMTS9-AS2': ['nan', 'ADAMTS9-AS2', 'ADAMTS9 antisense RNA 2'],
#  'ADAMTS10': ['ADAM-TS10',
#   'ADAMTS10',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 10'],
#  'ADAMTS12': ['nan',
#   'ADAMTS12',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 12'],
#  'ADAMTS13': ['VWFCP',
#   'TTP',
#   'vWF-CP',
#   'FLJ42993',
#   'MGC118899',
#   'MGC118900',
#   'DKFZp434C2322',
#   'ADAMTS13',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 13'],
#  'ADAMTS14': ['nan',
#   'ADAMTS14',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 14'],
#  'ADAMTS15': ['nan',
#   'ADAMTS15',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 15'],
#  'ADAMTS16': ['ADAMTS16s',
#   'ADAMTS16',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 16'],
#  'ADAMTS17': ['FLJ32769',
#   'FLJ16363',
#   'ADAMTS17',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 17'],
#  'ADAMTS18': ['nan',
#   'ADAMTS18',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 18'],
#  'ADAMTS19': ['nan',
#   'ADAMTS19',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 19'],
#  'ADAMTS19-AS1': ['RP11-346A9.1', 'ADAMTS19-AS1', 'ADAMTS19 antisense RNA 1'],
#  'ADAMTS20': ['GON-1',
#   'ADAMTS20',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 20'],
#  'ADAMTSL1': ['ADAMTSR1', 'FLJ35283', 'ADAMTSL1', 'ADAMTS like 1'],
#  'ADAMTSL2': ['KIAA0605', 'ADAMTSL2', 'ADAMTS like 2'],
#  'ADAMTSL3': ['KIAA1233', 'punctin-2', 'ADAMTSL3', 'ADAMTS like 3'],
#  'ADAMTSL4': ['DKFZP434K1772', 'ADAMTSL4', 'ADAMTS like 4'],
#  'ADAMTSL4-AS1': ['FLJ45786', 'ADAMTSL4-AS1', 'ADAMTSL4 antisense RNA 1'],
#  'ADAMTSL5': ['nan', 'ADAMTSL5', 'ADAMTS like 5'],
#  'ADAP1': ['GCS1L', 'ADAP1', 'ArfGAP with dual PH domains 1'],
#  'ADAP2': ['nan', 'ADAP2', 'ArfGAP with dual PH domains 2'],
#  'ADAR': ['ADAR1', 'ADAR', 'adenosine deaminase, RNA-specific'],
#  'ADARB1': ['ADAR2',
#   'DRADA2',
#   'ADAR2g',
#   'DRABA2',
#   'RED1',
#   'hRED1',
#   'ADAR2a-L1',
#   'ADAR2a-L2',
#   'ADAR2a-L3',
#   'ADAR2a',
#   'ADAR2b',
#   'ADAR2c',
#   'ADAR2d',
#   'ADARB1',
#   'adenosine deaminase, RNA specific B1'],
#  'ADARB2': ['RED2',
#   'hRED2',
#   'ADAR3',
#   'ADARB2',
#   'adenosine deaminase, RNA specific B2 (inactive)'],
#  'ADARB2-AS1': ['bA466B20.1', 'ADARB2-AS1', 'ADARB2 antisense RNA 1'],
#  'ADAT1': ['nan', 'ADAT1', 'adenosine deaminase, tRNA specific 1'],
#  'ADAT2': ['dJ20N2.1',
#   'TAD2',
#   'ADAT2',
#   'adenosine deaminase, tRNA specific 2'],
#  'ADAT3': ['TAD3', 'ADAT3', 'adenosine deaminase, tRNA specific 3'],
#  'ADCK1': ['FLJ39600', 'ADCK1', 'aarF domain containing kinase 1'],
#  'ADCK2': ['MGC20727', 'ADCK2', 'aarF domain containing kinase 2'],
#  'ADCK3': ['COQ8', 'SCAR9', 'ADCK3', 'aarF domain containing kinase 3'],
#  'ADCK4': ['FLJ12229', 'COQ8', 'ADCK4', 'aarF domain containing kinase 4'],
#  'ADCK5': ['FLJ35454', 'ADCK5', 'aarF domain containing kinase 5'],
#  'ADCY1': ['AC1', 'ADCY1', 'adenylate cyclase 1 (brain)'],
#  'ADCY2': ['HBAC2', 'KIAA1060', 'AC2', 'ADCY2', 'adenylate cyclase 2 (brain)'],
#  'ADCY3': ['AC3', 'ADCY3', 'adenylate cyclase 3'],
#  'ADCY4': ['AC4', 'ADCY4', 'adenylate cyclase 4'],
#  'ADCY5': ['AC5', 'ADCY5', 'adenylate cyclase 5'],
#  'ADCY6': ['AC6', 'ADCY6', 'adenylate cyclase 6'],
#  'ADCY7': ['KIAA0037', 'AC7', 'ADCY7', 'adenylate cyclase 7'],
#  'ADCY8': ['HBAC1', 'AC8', 'ADCY8', 'adenylate cyclase 8 (brain)'],
#  'ADCY9': ['AC9', 'ADCY9', 'adenylate cyclase 9'],
#  'ADCY10': ['SAC',
#   'Sacy',
#   'SACI',
#   'HCA2',
#   'RP1-313L4.2',
#   'ADCY10',
#   'adenylate cyclase 10 (soluble)'],
#  'ADCY10P1': ['nan',
#   'ADCY10P1',
#   'adenylate cyclase 10 (soluble) pseudogene 1'],
#  'ADCYAP1': ['PACAP', 'ADCYAP1', 'adenylate cyclase activating polypeptide 1'],
#  'ADCYAP1R1': ['PAC1',
#   'PACAPR',
#   'PAC1R',
#   'ADCYAP1R1',
#   'ADCYAP receptor type I'],
#  'ADD1': ['nan', 'ADD1', 'adducin 1'],
#  'ADD2': ['ADDB', 'ADD2', 'adducin 2'],
#  'ADD3': ['nan', 'ADD3', 'adducin 3'],
#  'ADD3-AS1': ['nan', 'ADD3-AS1', 'ADD3 antisense RNA 1'],
#  'ADGB': ['FLJ23121', 'dJ408K24.1', 'CAPN16', 'ADGB', 'androglobin'],
#  'ADGRA1': ['KIAA1828', 'ADGRA1', 'adhesion G protein-coupled receptor A1'],
#  'ADGRA1-AS1': ['nan',
#   'ADGRA1-AS1',
#   'adhesion G protein-coupled receptor A1 antisense RNA 1'],
#  'ADGRA2': ['TEM5',
#   'DKFZp434C211',
#   'DKFZp434J0911',
#   'KIAA1531',
#   'FLJ14390',
#   'ADGRA2',
#   'adhesion G protein-coupled receptor A2'],
#  'ADGRA3': ['FLJ38547',
#   'PGR21',
#   'ADGRA3',
#   'adhesion G protein-coupled receptor A3'],
#  'ADGRB1': ['nan', 'ADGRB1', 'adhesion G protein-coupled receptor B1'],
#  'ADGRB2': ['nan', 'ADGRB2', 'adhesion G protein-coupled receptor B2'],
#  'ADGRB3': ['KIAA0550', 'ADGRB3', 'adhesion G protein-coupled receptor B3'],
#  'ADGRD1': ['DKFZp434B1272',
#   'PGR25',
#   'ADGRD1',
#   'adhesion G protein-coupled receptor D1'],
#  'ADGRD2': ['PGR24', 'ADGRD2', 'adhesion G protein-coupled receptor D2'],
#  'ADGRE1': ['nan', 'ADGRE1', 'adhesion G protein-coupled receptor E1'],
#  'ADGRE2': ['CD312', 'ADGRE2', 'adhesion G protein-coupled receptor E2'],
#  'ADGRE3': ['nan', 'ADGRE3', 'adhesion G protein-coupled receptor E3'],
#  'ADGRE4P': ['PGR16',
#   'ADGRE4P',
#   'adhesion G protein-coupled receptor E4, pseudogene'],
#  'ADGRE5': ['TM7LN1', 'ADGRE5', 'adhesion G protein-coupled receptor E5'],
#  'ADGRF1': ['hGPCR36',
#   'PGR19',
#   'ADGRF1',
#   'adhesion G protein-coupled receptor F1'],
#  'ADGRF2': ['hGPCR35',
#   'PGR20',
#   'ADGRF2',
#   'adhesion G protein-coupled receptor F2'],
#  'ADGRF3': ['hGPCR37',
#   'PGR23',
#   'ADGRF3',
#   'adhesion G protein-coupled receptor F3'],
#  'ADGRF4': ['FLJ38076',
#   'PGR18',
#   'ADGRF4',
#   'adhesion G protein-coupled receptor F4'],
#  'ADGRF5': ['DKFZp564O1923',
#   'KIAA0758',
#   'ADGRF5',
#   'adhesion G protein-coupled receptor F5'],
#  'ADGRF5P1': ['nan',
#   'ADGRF5P1',
#   'adhesion G protein-coupled receptor F5 pseudogene 1'],
#  'ADGRF5P2': ['nan',
#   'ADGRF5P2',
#   'adhesion G protein-coupled receptor F5 pseudogene 2'],
#  'ADGRG1': ['TM7LN4',
#   'TM7XN1',
#   'ADGRG1',
#   'adhesion G protein-coupled receptor G1'],
#  'ADGRG2': ['HE6',
#   'TM7LN2',
#   'EDDM6',
#   'ADGRG2',
#   'adhesion G protein-coupled receptor G2'],
#  'ADGRG3': ['Pb99',
#   'PGR26',
#   'ADGRG3',
#   'adhesion G protein-coupled receptor G3'],
#  'ADGRG4': ['RP1-299I16',
#   'PGR17',
#   'ADGRG4',
#   'adhesion G protein-coupled receptor G4'],
#  'ADGRG5': ['PGR27', 'ADGRG5', 'adhesion G protein-coupled receptor G5'],
#  'ADGRG6': ['FLJ14937', 'ADGRG6', 'adhesion G protein-coupled receptor G6'],
#  'ADGRG7': ['FLJ14454', 'ADGRG7', 'adhesion G protein-coupled receptor G7'],
#  'ADGRL1': ['KIAA0821',
#   'CIRL1',
#   'LEC2',
#   'ADGRL1',
#   'adhesion G protein-coupled receptor L1'],
#  'ADGRL2': ['KIAA0786',
#   'LEC1',
#   'ADGRL2',
#   'adhesion G protein-coupled receptor L2'],
#  'ADGRL3': ['KIAA0768',
#   'LEC3',
#   'ADGRL3',
#   'adhesion G protein-coupled receptor L3'],
#  'ADGRL3-AS1': ['nan',
#   'ADGRL3-AS1',
#   'adhesion G protein-coupled receptor L3 antisense RNA 1'],
#  'ADGRL4': ['ETL', 'ADGRL4', 'adhesion G protein-coupled receptor L4'],
#  'ADGRV1': ['DKFZp761P0710',
#   'KIAA0686',
#   'FEB4',
#   'VLGR1',
#   'ADGRV1',
#   'adhesion G protein-coupled receptor V1'],
#  'ADH1A': ['nan',
#   'ADH1A',
#   'alcohol dehydrogenase 1A (class I), alpha polypeptide'],
#  'ADH1B': ['nan',
#   'ADH1B',
#   'alcohol dehydrogenase 1B (class I), beta polypeptide'],
#  'ADH1C': ['nan',
#   'ADH1C',
#   'alcohol dehydrogenase 1C (class I), gamma polypeptide'],
#  'ADH4': ['ADH-2',
#   'ADH4',
#   'alcohol dehydrogenase 4 (class II), pi polypeptide'],
#  'ADH5': ['ADH-3',
#   'ADHX',
#   'ADH5',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide'],
#  'ADH5P2': ['nan',
#   'ADH5P2',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 2'],
#  'ADH5P3': ['nan',
#   'ADH5P3',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 3'],
#  'ADH5P4': ['bA707M13.2',
#   'ADH5P4',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 4'],
#  'ADH6': ['ADH-5', 'ADH6', 'alcohol dehydrogenase 6 (class V)'],
#  'ADH7': ['ADH-4',
#   'ADH7',
#   'alcohol dehydrogenase 7 (class IV), mu or sigma polypeptide'],
#  'ADHFE1': ['ADHFe1',
#   'FLJ32430',
#   'ADHFE1',
#   'alcohol dehydrogenase, iron containing 1'],
#  'ADI1': ['SIPL',
#   'MTCBP-1',
#   'ARD',
#   'APL1',
#   'FLJ10913',
#   'HMFT1638',
#   'mtnD',
#   'ADI1',
#   'acireductone dioxygenase 1'],
#  'ADIG': ['MGC39724', 'SMAF1', 'RP5-1100H13.2', 'ADIG', 'adipogenin'],
#  'ADIPOQ': ['ACRP30',
#   'AdipoQ',
#   'apM1',
#   'GBP28',
#   'adiponectin',
#   'ADIPOQ',
#   'adiponectin, C1Q and collagen domain containing'],
#  'ADIPOQ-AS1': ['nan', 'ADIPOQ-AS1', 'ADIPOQ antisense RNA 1'],
#  'ADIPOR1': ['PAQR1', 'ACDCR1', 'ADIPOR1', 'adiponectin receptor 1'],
#  'ADIPOR1P1': ['nan', 'ADIPOR1P1', 'adiponectin receptor 1 pseudogene 1'],
#  'ADIPOR1P2': ['nan', 'ADIPOR1P2', 'adiponectin receptor 1 pseudogene 2'],
#  'ADIPOR2': ['PAQR2', 'ACDCR2', 'ADIPOR2', 'adiponectin receptor 2'],
#  'ADIRF': ['APM2', 'AFRO', 'ADIRF', 'adipogenesis regulatory factor'],
#  'ADIRF-AS1': ['nan', 'ADIRF-AS1', 'ADIRF antisense RNA 1'],
#  'ADK': ['AK', 'ADK', 'adenosine kinase'],
#  'ADM': ['AM', 'ADM', 'adrenomedullin'],
#  'ADM2': ['AM2', 'FLJ21135', 'ADM2', 'adrenomedullin 2'],
#  'ADM5': ['AM5', 'ADM5', 'adrenomedullin 5 (putative)'],
#  'ADNP': ['KIAA0784',
#   'ADNP1',
#   'ADNP',
#   'activity-dependent neuroprotector homeobox'],
#  'ADNP-AS1': ['nan', 'ADNP-AS1', 'ADNP antisense RNA 1'],
#  'ADNP2': ['KIAA0863', 'ADNP2', 'ADNP homeobox 2'],
#  'ADO': ['FLJ14547', 'ADO', '2-aminoethanethiol (cysteamine) dioxygenase'],
#  'ADORA1': ['RDC7', 'ADORA1', 'adenosine A1 receptor'],
#  'ADORA2A': ['RDC8', 'ADORA2A', 'adenosine A2a receptor'],
#  'ADORA2A-AS1': ['FLJ34651', 'ADORA2A-AS1', 'ADORA2A antisense RNA 1'],
#  'ADORA2B': ['nan', 'ADORA2B', 'adenosine A2b receptor'],
#  'ADORA2BP1': ['nan', 'ADORA2BP1', 'adenosine A2b receptor pseudogene 1'],
#  'ADORA3': ['AD026', 'ADORA3', 'adenosine A3 receptor'],
#  'ADPGK': ['DKFZp434B195', 'ADP-GK', 'ADPGK', 'ADP-dependent glucokinase'],
#  'ADPGK-AS1': ['nan', 'ADPGK-AS1', 'ADPGK antisense RNA 1'],
#  'ADPRH': ['ARH1', 'ADPRH', 'ADP-ribosylarginine hydrolase'],
#  'ADPRHL1': ['ARH2', 'ADPRHL1', 'ADP-ribosylhydrolase like 1'],
#  'ADPRHL2': ['ARH3', 'FLJ20446', 'ADPRHL2', 'ADP-ribosylhydrolase like 2'],
#  'ADPRM': ['MDS006',
#   'ADPRM',
#   'ADP-ribose/CDP-alcohol diphosphatase, manganese dependent'],
#  'ADRA1A': ['ADRA1L1', 'ADRA1A', 'adrenoceptor alpha 1A'],
#  'ADRA1B': ['nan', 'ADRA1B', 'adrenoceptor alpha 1B'],
#  'ADRA1D': ['ADRA1R', 'ADRA1A', 'ADRA1', 'ADRA1D', 'adrenoceptor alpha 1D'],
#  'ADRA2A': ['ADRAR', 'ADRA2A', 'adrenoceptor alpha 2A'],
#  'ADRA2B': ['ADRARL1', 'ADRA2B', 'adrenoceptor alpha 2B'],
#  'ADRA2C': ['ADRARL2', 'ADRA2C', 'adrenoceptor alpha 2C'],
#  'ADRB1': ['nan', 'ADRB1', 'adrenoceptor beta 1'],
#  'ADRB2': ['ADRBR', 'BAR', 'B2AR', 'ADRB2', 'adrenoceptor beta 2'],
#  'ADRB3': ['nan', 'ADRB3', 'adrenoceptor beta 3'],
#  'ADRBK1': ['GRK2', 'BARK1', 'ADRBK1', 'adrenergic, beta, receptor kinase 1'],
#  'ADRBK2': ['GRK3', 'BARK2', 'ADRBK2', 'adrenergic, beta, receptor kinase 2'],
#  'ADRM1': ['GP110',
#   'Rpn13',
#   'ARM1',
#   'ADRM1',
#   'adhesion regulating molecule 1'],
#  'ADSL': ['nan', 'ADSL', 'adenylosuccinate lyase'],
#  'ADSS': ['nan', 'ADSS', 'adenylosuccinate synthase'],
#  'ADSSL1': ['FLJ38602', 'ADSSL1', 'adenylosuccinate synthase like 1'],
#  'ADTRP': ['dJ413H6.1',
#   'AIG1L',
#   'ADTRP',
#   'androgen dependent TFPI regulating protein'],
#  'AEBP1': ['ACLP', 'AEBP1', 'AE binding protein 1'],
#  'AEBP2': ['MGC17922', 'AEBP2', 'AE binding protein 2'],
#  'AEN': ['FLJ12484', 'FLJ12562', 'AEN', 'apoptosis enhancing nuclease'],
#  'AES': ['GRG5', 'TLE5', 'AES', 'amino-terminal enhancer of split'],
#  'AFAP1': ['AFAP-110', 'AFAP', 'AFAP1', 'actin filament associated protein 1'],
#  'AFAP1-AS1': ['MGC10981', 'AFAP1-AS1', 'AFAP1 antisense RNA 1'],
#  'AFAP1L1': ['FLJ36748',
#   'AFAP1L1',
#   'actin filament associated protein 1 like 1'],
#  'AFAP1L2': ['FLJ14564',
#   'Em:AC005383.4',
#   'XB130',
#   'AFAP1L2',
#   'actin filament associated protein 1 like 2'],
#  'AFF1': ['AF-4', 'AF4', 'AFF1', 'AF4/FMR2 family member 1'],
#  'AFF2': ['FRAXE', 'AFF2', 'AF4/FMR2 family member 2'],
#  'AFF2-IT1': ['nan', 'AFF2-IT1', 'AFF2 intronic transcript 1'],
#  'AFF3': ['MLLT2-like', 'AFF3', 'AF4/FMR2 family member 3'],
#  'AFF4': ['AF5Q31', 'MCEF', 'AFF4', 'AF4/FMR2 family member 4'],
#  'AFG3L1P': ['nan',
#   'AFG3L1P',
#   'AFG3 like matrix AAA peptidase subunit 1, pseudogene'],
#  'AFG3L2': ['SPAX5', 'AFG3L2', 'AFG3 like matrix AAA peptidase subunit 2'],
#  'AFG3L2P1': ['nan', 'AFG3L2P1', 'AFG3 like AAA ATPase 2 pseudogene 1'],
#  'AFM': ['ALB2', 'ALBA', 'AFM', 'afamin'],
#  'AFMID': ['DKFZp686F03259', 'KF', 'AFMID', 'arylformamidase'],
#  'AFP': ['FETA', 'AFP', 'alpha fetoprotein'],
#  'AFTPH': ['MGC33965',
#   'FLJ20080',
#   'FLJ23793',
#   'Nbla10388',
#   'AFTPH',
#   'aftiphilin'],
#  'AGA': ['ASRG', 'AGA', 'aspartylglucosaminidase'],
#  'AGAP1': ['KIAA1099',
#   'GGAP1',
#   'AGAP1',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 1'],
#  'AGAP1-IT1': ['nan', 'AGAP1-IT1', 'AGAP1 intronic transcript 1'],
#  'AGAP2': ['nan',
#   'AGAP2',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 2'],
#  'AGAP2-AS1': ['LOC100130776',
#   'PUNISHER',
#   'AGAP2-AS1',
#   'AGAP2 antisense RNA 1'],
#  'AGAP3': ['nan',
#   'AGAP3',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 3'],
#  'AGAP4': ['Em:AC012044.1',
#   'MRIP2',
#   'AGAP4',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 4'],
#  'AGAP5': ['Em:AC073389.1',
#   'AGAP5',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 5'],
#  'AGAP6': ['bA324H6.1',
#   'AGAP6',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 6'],
#  'AGAP7P': ['bA109G10.1',
#   'AGAP7P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 7, pseudogene'],
#  'AGAP9': ['bA301J7.2',
#   'FLJ00312',
#   'AGAP9',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 9'],
#  'AGAP10P': ['bA358L16.1',
#   'bA144G6.2',
#   'AGAP10P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 10 pseudogene'],
#  'AGAP11': ['KIAA1975',
#   'AGAP11',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 11'],
#  'AGAP12P': ['bA164N7.2',
#   'AGAP12P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 12, pseudogene'],
#  'AGAP13P': ['bA548K23.1',
#   'AGAP13P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 13, pseudogene'],
#  'AGAP14P': ['bA145E20.1',
#   'AGAP14P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 14, pseudogene'],
#  'AGBL1': ['FLJ32310', 'CCP4', 'AGBL1', 'ATP/GTP binding protein-like 1'],
#  'AGBL1-AS1': ['nan', 'AGBL1-AS1', 'AGBL1 antisense RNA 1'],
#  'AGBL2': ['FLJ23598', 'CCP2', 'AGBL2', 'ATP/GTP binding protein-like 2'],
#  'AGBL3': ['MGC32955', 'CCP3', 'AGBL3', 'ATP/GTP binding protein-like 3'],
#  'AGBL4': ['FLJ14442', 'CCP6', 'AGBL4', 'ATP/GTP binding protein-like 4'],
#  'AGBL4-IT1': ['nan', 'AGBL4-IT1', 'AGBL4 intronic transcript 1'],
#  'AGBL5': ['FLJ21839', 'CCP5', 'AGBL5', 'ATP/GTP binding protein-like 5'],
#  'AGBL5-AS1': ['nan', 'AGBL5-AS1', 'AGBL5 antisense RNA 1'],
#  'AGBL5-IT1': ['nan', 'AGBL5-IT1', 'AGBL5 intronic transcript 1'],
#  'AGER': ['RAGE',
#   'AGER',
#   'advanced glycosylation end product-specific receptor'],
#  'AGFG1': ['RIP', 'RAB', 'AGFG1', 'ArfGAP with FG repeats 1'],
#  'AGFG2': ['RABR', 'AGFG2', 'ArfGAP with FG repeats 2'],
#  'AGGF1': ['VG5Q',
#   'HSU84971',
#   'FLJ10283',
#   'GPATC7',
#   'GPATCH7',
#   'AGGF1',
#   'angiogenic factor with G-patch and FHA domains 1'],
#  'AGGF1P1': ['nan',
#   'AGGF1P1',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 1'],
#  'AGGF1P2': ['nan',
#   'AGGF1P2',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 2'],
#  'AGGF1P3': ['nan',
#   'AGGF1P3',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 3'],
#  'AGGF1P4': ['nan',
#   'AGGF1P4',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 4'],
#  'AGGF1P5': ['nan',
#   'AGGF1P5',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 5'],
#  'AGGF1P6': ['nan',
#   'AGGF1P6',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 6'],
#  'AGGF1P7': ['nan',
#   'AGGF1P7',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 7'],
#  'AGGF1P8': ['nan',
#   'AGGF1P8',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 8'],
#  'AGGF1P9': ['nan',
#   'AGGF1P9',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 9'],
#  'AGGF1P10': ['nan',
#   'AGGF1P10',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 10'],
#  'AGK': ['FLJ10842', 'AGK', 'acylglycerol kinase'],
#  'AGKP1': ['AGKY1', 'AGKP1', 'acylglycerol kinase pseudogene 1'],
#  'AGL': ['nan',
#   'AGL',
#   'amylo-alpha-1, 6-glucosidase, 4-alpha-glucanotransferase'],
#  'AGMAT': ['FLJ23384', 'AGMAT', 'agmatinase'],
#  'AGMO': ['FLJ16237', 'AGMO', 'alkylglycerol monooxygenase'],
#  'AGO1': ['hAGO1', 'AGO1', 'argonaute 1, RISC catalytic component'],
#  'AGO2': ['hAGO2', 'Q10', 'AGO2', 'argonaute 2, RISC catalytic component'],
#  'AGO3': ['hAGO3',
#   'FLJ12765',
#   'AGO3',
#   'argonaute 3, RISC catalytic component'],
#  'AGO4': ['hAGO4',
#   'KIAA1567',
#   'FLJ20033',
#   'AGO4',
#   'argonaute 4, RISC catalytic component'],
#  'AGPAT1': ['LPAAT-alpha',
#   'AGPAT1',
#   '1-acylglycerol-3-phosphate O-acyltransferase 1'],
#  'AGPAT2': ['LPAAT-beta',
#   'AGPAT2',
#   '1-acylglycerol-3-phosphate O-acyltransferase 2'],
#  'AGPAT3': ['LPAAT-gamma',
#   'AGPAT3',
#   '1-acylglycerol-3-phosphate O-acyltransferase 3'],
#  'AGPAT4': ['LPAAT-delta',
#   'dJ473J16.2',
#   'AGPAT4',
#   '1-acylglycerol-3-phosphate O-acyltransferase 4'],
#  'AGPAT4-IT1': ['FLJ23112', 'AGPAT4-IT1', 'AGPAT4 intronic transcript 1'],
#  'AGPAT5': ['FLJ11210',
#   'LPAAT-e',
#   'LPAAT-epsilon',
#   'AGPAT5',
# ...
#  'ALG13-AS1': ['nan', 'ALG13-AS1', 'ALG13 antisense RNA 1'],
#  'ALG14': ['MGC19780',
#   'ALG14',
#   'ALG14, UDP-N-acetylglucosaminyltransferase subunit'],
#  'ALK': ['CD246', 'ALK', 'anaplastic lymphoma receptor tyrosine kinase'],
#  'ALKBH1': ['hABH',
#   'alkB',
#   'ABH',
#   'ALKBH1',
#   'alkB homolog 1, histone H2A dioxygenase'],
#  'ALKBH2': ['MGC90512',
#   'ABH2',
#   'ALKBH2',
#   'alkB homolog 2, alpha-ketoglutarate-dependent dioxygenase'],
#  'ALKBH3': ['DEPC-1',
#   'ALKBH3',
#   'alkB homolog 3, alpha-ketoglutarate-dependent dioxygenase'],
#  'ALKBH3-AS1': ['nan', 'ALKBH3-AS1', 'ALKBH3 antisense RNA 1'],
#  'ALKBH4': ['FLJ20013', 'ALKBH4', 'alkB homolog 4, lysine demethylase'],
#  'ALKBH5': ['FLJ20308', 'ALKBH5', 'alkB homolog 5, RNA demethylase'],
#  'ALKBH6': ['MGC15677', 'ALKBH6', 'alkB homolog 6'],
#  'ALKBH7': ['MGC10974', 'ALKBH7', 'alkB homolog 7'],
#  'ALKBH8': ['MGC10235',
#   'TRM9',
#   'TRMT9',
#   'ALKBH8',
#   'alkB homolog 8, tRNA methyltransferase'],
#  'ALLC': ['ALC', 'ALLC', 'allantoicase'],
#  'ALMS1': ['KIAA0328',
#   'ALMS1',
#   'ALMS1, centrosome and basal body associated protein'],
#  'ALMS1-IT1': ['nan', 'ALMS1-IT1', 'ALMS1 intronic transcript 1'],
#  'ALMS1P1': ['nan',
#   'ALMS1P1',
#   'ALMS1, centrosome and basal body associated protein pseudogene 1'],
#  'ALOX5': ['5-LOX', 'ALOX5', 'arachidonate 5-lipoxygenase'],
#  'ALOX5AP': ['FLAP',
#   'ALOX5AP',
#   'arachidonate 5-lipoxygenase activating protein'],
#  'ALOX12': ['12S-LOX', 'ALOX12', 'arachidonate 12-lipoxygenase'],
#  'ALOX12-AS1': ['nan', 'ALOX12-AS1', 'ALOX12 antisense RNA 1'],
#  'ALOX12B': ['12R-LOX', 'ALOX12B', 'arachidonate 12-lipoxygenase, 12R type'],
#  'ALOX12P1': ['nan', 'ALOX12P1', 'arachidonate 12-lipoxygenase pseudogene 1'],
#  'ALOX12P2': ['nan', 'ALOX12P2', 'arachidonate 12-lipoxygenase pseudogene 2'],
#  'ALOX15': ['15-LOX-1', 'ALOX15', 'arachidonate 15-lipoxygenase'],
#  'ALOX15B': ['15-LOX-2', 'ALOX15B', 'arachidonate 15-lipoxygenase, type B'],
#  'ALOX15P2': ['nan', 'ALOX15P2', 'arachidonate 15-lipoxygenase pseudogene 2'],
#  'ALOXE3': ['eLOX3', 'E-LOX', 'ALOXE3', 'arachidonate lipoxygenase 3'],
#  'ALPI': ['nan', 'ALPI', 'alkaline phosphatase, intestinal'],
#  'ALPK1': ['Lak', 'FLJ22670', 'KIAA1527', 'ALPK1', 'alpha kinase 1'],
#  'ALPK2': ['HAK', 'ALPK2', 'alpha kinase 2'],
#  'ALPK3': ['MAK', 'KIAA1330', 'Midori', 'ALPK3', 'alpha kinase 3'],
#  'ALPL': ['TNSALP', 'ALPL', 'alkaline phosphatase, liver/bone/kidney'],
#  'ALPP': ['nan', 'ALPP', 'alkaline phosphatase, placental'],
#  'ALPPL2': ['nan', 'ALPPL2', 'alkaline phosphatase, placental like 2'],
#  'ALS2': ['nan', 'ALS2', 'ALS2, alsin Rho guanine nucleotide exchange factor'],
#  'ALS2CL': ['FLJ36525',
#   'RN49018',
#   'DKFZp686I0110',
#   'ALS2CL',
#   'ALS2 C-terminal like'],
#  'ALS2CR11': ['FLJ25351',
#   'ALS2CR11',
#   'amyotrophic lateral sclerosis 2 chromosome region candidate 11'],
#  'ALS2CR12': ['nan',
#   'ALS2CR12',
#   'amyotrophic lateral sclerosis 2 chromosome region candidate 12'],
#  'ALX1': ['nan', 'ALX1', 'ALX homeobox 1'],
#  'ALX3': ['nan', 'ALX3', 'ALX homeobox 3'],
#  'ALX4': ['FPP', 'PFM', 'KIAA1788', 'ALX4', 'ALX homeobox 4'],
#  'ALYREF': ['ALY', 'BEF', 'ALY/REF', 'REF', 'ALYREF', 'Aly/REF export factor'],
#  'AMACR': ['RACE', 'AMACR', 'alpha-methylacyl-CoA racemase'],
#  'AMBN': ['nan', 'AMBN', 'ameloblastin'],
#  'AMBP': ['UTI',
#   'HCP',
#   'EDC1',
#   'HI30',
#   'IATIL',
#   'ITILC',
#   'AMBP',
#   'alpha-1-microglobulin/bikunin precursor'],
#  'AMBRA1': ['FLJ20294',
#   'KIAA1736',
#   'WDR94',
#   'DCAF3',
#   'AMBRA1',
#   'autophagy/beclin-1 regulator 1'],
#  'AMD1': ['SAMDC', 'AMD1', 'adenosylmethionine decarboxylase 1'],
#  'AMD1P1': ['nan',
#   'AMD1P1',
#   'adenosylmethionine decarboxylase 1 pseudogene 1'],
#  'AMD1P2': ['AMDPX',
#   'AMDPY',
#   'AMD1P2',
#   'adenosylmethionine decarboxylase 1 pseudogene 2'],
#  'AMD1P3': ['nan',
#   'AMD1P3',
#   'adenosylmethionine decarboxylase 1 pseudogene 3'],
#  'AMD1P4': ['nan',
#   'AMD1P4',
#   'adenosylmethionine decarboxylase 1 pseudogene 4'],
#  'AMDHD1': ['MGC35366', 'AMDHD1', 'amidohydrolase domain containing 1'],
#  'AMDHD2': ['CGI-14', 'AMDHD2', 'amidohydrolase domain containing 2'],
#  'AMELX': ['nan', 'AMELX', 'amelogenin, X-linked'],
#  'AMELY': ['nan', 'AMELY', 'amelogenin, Y-linked'],
#  'AMER1': ['RP11-403E24.2',
#   'FLJ39827',
#   'WTX',
#   'AMER1',
#   'APC membrane recruitment protein 1'],
#  'AMER2': ['FLJ25477', 'AMER2', 'APC membrane recruitment protein 2'],
#  'AMER3': ['FLJ38377', 'AMER3', 'APC membrane recruitment protein 3'],
#  'AMFR': ['RNF45', 'gp78', 'AMFR', 'autocrine motility factor receptor'],
#  'AMH': ['MIS', 'AMH', 'anti-Mullerian hormone'],
#  'AMHR2': ['MISR2',
#   'MISRII',
#   'AMHR2',
#   'anti-Mullerian hormone receptor type II'],
#  'AMIGO1': ['AMIGO',
#   'KIAA1163',
#   'AMIGO1',
#   'adhesion molecule with Ig-like domain 1'],
#  'AMIGO2': ['ALI1',
#   'DEGA',
#   'AMIGO2',
#   'adhesion molecule with Ig-like domain 2'],
#  'AMIGO3': ['nan', 'AMIGO3', 'adhesion molecule with Ig-like domain 3'],
#  'AMMECR1': ['nan',
#   'AMMECR1',
#   'Alport syndrome, mental retardation, midface hypoplasia and elliptocytosis chromosomal region gene 1'],
#  'AMMECR1-IT1': ['nan', 'AMMECR1-IT1', 'AMMECR1 intronic transcript 1'],
#  'AMMECR1L': ['MGC4268', 'AMMECR1L', 'AMMECR1 like'],
#  'AMMECR1LP1': ['nan', 'AMMECR1LP1', 'AMMECR1 like pseudogene 1'],
#  'AMN': ['amnionless', 'AMN', 'amnion associated transmembrane protein'],
#  'AMN1': ['nan', 'AMN1', 'antagonist of mitotic exit network 1 homolog'],
#  'AMOT': ['KIAA1071', 'AMOT', 'angiomotin'],
#  'AMOTL1': ['JEAP', 'AMOTL1', 'angiomotin like 1'],
#  'AMOTL2': ['LCCP', 'AMOTL2', 'angiomotin like 2'],
#  'AMPD1': ['MAD', 'MADA', 'AMPD1', 'adenosine monophosphate deaminase 1'],
#  'AMPD2': ['SPG63', 'AMPD2', 'adenosine monophosphate deaminase 2'],
#  'AMPD3': ['nan', 'AMPD3', 'adenosine monophosphate deaminase 3'],
#  'AMPH': ['nan', 'AMPH', 'amphiphysin'],
#  'AMT': ['GCST', 'NKH', 'AMT', 'aminomethyltransferase'],
#  'AMTN': ['UNQ689', 'RSTI689', 'AMTN', 'amelotin'],
#  'AMY1A': ['nan', 'AMY1A', 'amylase, alpha 1A (salivary)'],
#  'AMY1B': ['nan', 'AMY1B', 'amylase, alpha 1B (salivary)'],
#  'AMY1C': ['nan', 'AMY1C', 'amylase, alpha 1C (salivary)'],
#  'AMY2A': ['nan', 'AMY2A', 'amylase, alpha 2A (pancreatic)'],
#  'AMY2B': ['nan', 'AMY2B', 'amylase, alpha 2B (pancreatic)'],
#  'AMYP1': ['nan', 'AMYP1', 'amylase, alpha pseudogene 1'],
#  'AMZ1': ['KIAA1950', 'AMZ1', 'archaelysin family metallopeptidase 1'],
#  'AMZ2': ['nan', 'AMZ2', 'archaelysin family metallopeptidase 2'],
#  'AMZ2P1': ['FLJ32065',
#   'AMZ2P1',
#   'archaelysin family metallopeptidase 2 pseudogene 1'],
#  'AMZ2P2': ['nan',
#   'AMZ2P2',
#   'archaelysin family metallopeptidase 2 pseudogene 2'],
#  'ANAPC1': ['MCPR',
#   'TSG24',
#   'APC1',
#   'ANAPC1',
#   'anaphase promoting complex subunit 1'],
#  'ANAPC1P1': ['nan',
#   'ANAPC1P1',
#   'anaphase promoting complex subunit 1 pseudogene 1'],
#  'ANAPC2': ['APC2',
#   'KIAA1406',
#   'ANAPC2',
#   'anaphase promoting complex subunit 2'],
#  'ANAPC4': ['APC4', 'ANAPC4', 'anaphase promoting complex subunit 4'],
#  'ANAPC5': ['APC5', 'ANAPC5', 'anaphase promoting complex subunit 5'],
#  'ANAPC7': ['APC7', 'ANAPC7', 'anaphase promoting complex subunit 7'],
#  'ANAPC10': ['APC10',
#   'DOC1',
#   'DKFZP564L0562',
#   'ANAPC10',
#   'anaphase promoting complex subunit 10'],
#  'ANAPC10P1': ['nan',
#   'ANAPC10P1',
#   'anaphase promoting complex subunit 10 pseudogene 1'],
#  'ANAPC11': ['HSPC214',
#   'APC11',
#   'Apc11p',
#   'MGC882',
#   'ANAPC11',
#   'anaphase promoting complex subunit 11'],
#  'ANAPC13': ['SWM1',
#   'APC13',
#   'DKFZP566D193',
#   'ANAPC13',
#   'anaphase promoting complex subunit 13'],
#  'ANAPC15': ['HSPC020',
#   'DKFZP564M082',
#   'APC15',
#   'ANAPC15',
#   'anaphase promoting complex subunit 15'],
#  'ANAPC16': ['bA570G20.3',
#   'FLJ33728',
#   'APC16',
#   'CENP-27',
#   'ANAPC16',
#   'anaphase promoting complex subunit 16'],
#  'ANG': ['RNASE5',
#   'RAA1',
#   'ANG',
#   'angiogenin, ribonuclease, RNase A family, 5'],
#  'ANGEL1': ['Ccr4e', 'ANGEL1', 'angel homolog 1 (Drosophila)'],
#  'ANGEL2': ['KIAA0759L',
#   'FLJ12793',
#   'Ccr4d',
#   'ANGEL2',
#   'angel homolog 2 (Drosophila)'],
#  'ANGPT1': ['KIAA0003', 'Ang1', 'ANGPT1', 'angiopoietin 1'],
#  'ANGPT2': ['Ang2', 'ANGPT2', 'angiopoietin 2'],
#  'ANGPT4': ['nan', 'ANGPT4', 'angiopoietin 4'],
#  'ANGPTL1': ['ANG3', 'AngY', 'ARP1', 'ANGPTL1', 'angiopoietin like 1'],
#  'ANGPTL2': ['ARP2', 'HARP', 'ANGPTL2', 'angiopoietin like 2'],
#  'ANGPTL3': ['nan', 'ANGPTL3', 'angiopoietin like 3'],
#  'ANGPTL4': ['pp1158',
#   'PGAR',
#   'ARP4',
#   'HFARP',
#   'FIAF',
#   'NL2',
#   'ANGPTL4',
#   'angiopoietin like 4'],
#  'ANGPTL5': ['nan', 'ANGPTL5', 'angiopoietin like 5'],
#  'ANGPTL6': ['ARP5', 'AGF', 'ANGPTL6', 'angiopoietin like 6'],
#  'ANGPTL7': ['CDT6', 'AngX', 'ANGPTL7', 'angiopoietin like 7'],
#  'ANGPTL8': ['TD26', 'RIFL', 'ANGPTL8', 'angiopoietin like 8'],
#  'ANHX': ['nan', 'ANHX', 'anomalous homeobox'],
#  'ANK1': ['SPH1', 'ANK1', 'ankyrin 1'],
#  'ANK2': ['nan', 'ANK2', 'ankyrin 2, neuronal'],
#  'ANK3': ['nan', 'ANK3', 'ankyrin 3, node of Ranvier (ankyrin G)'],
#  'ANKAR': ['FLJ25415', 'ANKAR', 'ankyrin and armadillo repeat containing'],
#  'ANKDD1A': ['FLJ25870',
#   'ANKDD1A',
#   'ankyrin repeat and death domain containing 1A'],
#  'ANKDD1B': ['nan',
#   'ANKDD1B',
#   'ankyrin repeat and death domain containing 1B'],
#  'ANKEF1': ['FLJ21669',
#   'dJ839B4.6',
#   'ANKEF1',
#   'ankyrin repeat and EF-hand domain containing 1'],
#  'ANKFN1': ['FLJ38335',
#   'ANKFN1',
#   'ankyrin repeat and fibronectin type III domain containing 1'],
#  'ANKFY1': ['ANKHZN',
#   'KIAA1255',
#   'ZFYVE14',
#   'BTBD23',
#   'RANK-5',
#   'ANKFY1',
#   'ankyrin repeat and FYVE domain containing 1'],
#  'ANKH': ['HANK',
#   'ANK',
#   'CPPDD',
#   'ANKH',
#   'ANKH inorganic pyrophosphate transport regulator'],
#  'ANKHD1': ['MASK',
#   'FLJ20288',
#   'FLJ11979',
#   'FLJ10042',
#   'FLJ14127',
#   'KIAA1085',
#   'MASK1',
#   'ANKHD1',
#   'ankyrin repeat and KH domain containing 1'],
#  'ANKHD1-EIF4EBP3': ['MASK-BP3',
#   'ANKHD1-EIF4EBP3',
#   'ANKHD1-EIF4EBP3 readthrough'],
#  'ANKIB1': ['DKFZP434A0225',
#   'KIAA1386',
#   'ANKIB1',
#   'ankyrin repeat and IBR domain containing 1'],
#  'ANKK1': ['X-kinase',
#   'ANKK1',
#   'ankyrin repeat and kinase domain containing 1'],
#  'ANKLE1': ['FLJ39369',
#   'LEMD6',
#   'ANKLE1',
#   'ankyrin repeat and LEM domain containing 1'],
#  'ANKLE2': ['LEMD7',
#   'Lem4',
#   'ANKLE2',
#   'ankyrin repeat and LEM domain containing 2'],
#  'ANKMY1': ['FLJ20499',
#   'ZMYND13',
#   'ANKMY1',
#   'ankyrin repeat and MYND domain containing 1'],
#  'ANKMY2': ['DKFZP564O043',
#   'ZMYND20',
#   'ANKMY2',
#   'ankyrin repeat and MYND domain containing 2'],
#  'ANKRA2': ['nan', 'ANKRA2', 'ankyrin repeat family A member 2'],
#  'ANKRD1': ['C-193',
#   'ALRP',
#   'CARP',
#   'CVARP',
#   'MCARP',
#   'ANKRD1',
#   'ankyrin repeat domain 1'],
#  'ANKRD2': ['ARPP', 'ANKRD2', 'ankyrin repeat domain 2'],
#  'ANKRD6': ['KIAA0957', 'ANKRD6', 'ankyrin repeat domain 6'],
#  'ANKRD7': ['TSA806', 'ANKRD7', 'ankyrin repeat domain 7'],
#  'ANKRD9': ['nan', 'ANKRD9', 'ankyrin repeat domain 9'],
#  'ANKRD10': ['FLJ20093', 'ANKRD10', 'ankyrin repeat domain 10'],
#  'ANKRD10-IT1': ['nan', 'ANKRD10-IT1', 'ANKRD10 intronic transcript 1'],
#  'ANKRD11': ['LZ16', 'T13', 'ANKRD11', 'ankyrin repeat domain 11'],
#  'ANKRD12': ['KIAA0874',
#   'FLJ20053',
#   'GAC-1',
#   'ANKRD12',
#   'ankyrin repeat domain 12'],
#  'ANKRD13A': ['NY-REN-25', 'ANKRD13A', 'ankyrin repeat domain 13A'],
#  'ANKRD13B': ['FLJ25555', 'ANKRD13B', 'ankyrin repeat domain 13B'],
#  'ANKRD13C': ['DKFZP566D1346',
#   'dJ677H15.3',
#   'ANKRD13C',
#   'ankyrin repeat domain 13C'],
#  'ANKRD13D': ['nan', 'ANKRD13D', 'ankyrin repeat domain 13 family member D'],
#  'ANKRD16': ['DKFZP434N1511', 'ANKRD16', 'ankyrin repeat domain 16'],
#  'ANKRD17': ['GTAR',
#   'KIAA0697',
#   'FLJ22206',
#   'NY-BR-16',
#   'MASK2',
#   'ANKRD17',
#   'ankyrin repeat domain 17'],
#  'ANKRD18A': ['KIAA2015', 'FLJ35740', 'ANKRD18A', 'ankyrin repeat domain 18A'],
#  'ANKRD18B': ['bA255A11.3', 'ANKRD18B', 'ankyrin repeat domain 18B'],
#  'ANKRD18CP': ['nan', 'ANKRD18CP', 'ankyrin repeat domain 18C, pseudogene'],
#  'ANKRD18DP': ['nan', 'ANKRD18DP', 'ankyrin repeat domain 18D, pseudogene'],
#  'ANKRD18EP': ['nan', 'ANKRD18EP', 'ankyrin repeat domain 18E, pseudogene'],
#  'ANKRD19P': ['FLJ36178', 'ANKRD19P', 'ankyrin repeat domain 19, pseudogene'],
#  'ANKRD20A1': ['DKFZp434A171',
#   'ANKRD20A1',
#   'ankyrin repeat domain 20 family member A1'],
#  'ANKRD20A2': ['nan',
#   'ANKRD20A2',
#   'ankyrin repeat domain 20 family member A2'],
#  'ANKRD20A3': ['nan',
#   'ANKRD20A3',
#   'ankyrin repeat domain 20 family member A3'],
#  'ANKRD20A4': ['OTTHUMG00000066855',
#   'ANKRD20A4',
#   'ankyrin repeat domain 20 family member A4'],
#  'ANKRD20A5P': ['MGC26718',
#   'ANKRD20A5P',
#   'ankyrin repeat domain 20 family member A5, pseudogene'],
#  'ANKRD20A7P': ['nan',
#   'ANKRD20A7P',
#   'ankyrin repeat domain 20 family member A7, pseudogene'],
#  'ANKRD20A8P': ['nan',
#   'ANKRD20A8P',
#   'ankyrin repeat domain 20 family member A8, pseudogene'],
#  'ANKRD20A9P': ['nan',
#   'ANKRD20A9P',
#   'ankyrin repeat domain 20 family member A9, pseudogene'],
#  'ANKRD20A10P': ['nan',
#   'ANKRD20A10P',
#   'ankyrin repeat domain 20 family member A10, pseudogene'],
#  'ANKRD20A11P': ['nan',
#   'ANKRD20A11P',
#   'ankyrin repeat domain 20 family member A11, pseudogene'],
#  'ANKRD20A17P': ['nan',
#   'ANKRD20A17P',
#   'ankyrin repeat domain 20 family member A17, pseudogene'],
#  'ANKRD20A18P': ['nan',
#   'ANKRD20A18P',
#   'ankyrin repeat domain 20 family member A18, pseudogene'],
#  'ANKRD20A19P': ['nan',
#   'ANKRD20A19P',
#   'ankyrin repeat domain 20 family member A19, pseudogene'],
#  'ANKRD22': ['MGC22805', 'ANKRD22', 'ankyrin repeat domain 22'],
#  'ANKRD23': ['DARP',
#   'FLJ32449',
#   'MARP3',
#   'ANKRD23',
#   'ankyrin repeat domain 23'],
#  'ANKRD24': ['KIAA1981', 'ANKRD24', 'ankyrin repeat domain 24'],
#  'ANKRD26': ['KIAA1074', 'ANKRD26', 'ankyrin repeat domain 26'],
#  'ANKRD26P1': ['FLJ43980',
#   'ANKRD26P1',
#   'ankyrin repeat domain 26 pseudogene 1'],
#  'ANKRD26P2': ['nan', 'ANKRD26P2', 'ankyrin repeat domain 26 pseudogene 2'],
#  'ANKRD26P3': ['nan', 'ANKRD26P3', 'ankyrin repeat domain 26 pseudogene 3'],
#  'ANKRD26P4': ['nan', 'ANKRD26P4', 'ankyrin repeat domain 26 pseudogene 4'],
#  'ANKRD27': ['FLJ00040',
#   'DKFZp434L0718',
#   'VARP',
#   'ANKRD27',
#   'ankyrin repeat domain 27'],
#  'ANKRD28': ['KIAA0379',
#   'PITK',
#   'PP6-ARS-A',
#   'PPP1R65',
#   'ANKRD28',
#   'ankyrin repeat domain 28'],
#  'ANKRD29': ['FLJ25053', 'ANKRD29', 'ankyrin repeat domain 29'],
#  'ANKRD30A': ['NY-BR-1', 'ANKRD30A', 'ankyrin repeat domain 30A'],
#  'ANKRD30B': ['NY-BR-1.1', 'ANKRD30B', 'ankyrin repeat domain 30B'],
#  'ANKRD30BL': ['nan', 'ANKRD30BL', 'ankyrin repeat domain 30B-like'],
#  'ANKRD30BP1': ['PRED4',
#   'ANKRD30BP1',
#   'ankyrin repeat domain 30B pseudogene 1'],
#  'ANKRD30BP2': ['CT85',
#   'CTSP-1',
#   'ANKRD30BP2',
#   'ankyrin repeat domain 30B pseudogene 2'],
#  'ANKRD30BP3': ['nan', 'ANKRD30BP3', 'ankyrin repeat domain 30B pseudogene 3'],
#  'ANKRD31': ['FLJ40191', 'ANKRD31', 'ankyrin repeat domain 31'],
#  'ANKRD33': ['DKFZp686O1689', 'PANKY', 'ANKRD33', 'ankyrin repeat domain 33'],
#  'ANKRD33B': ['nan', 'ANKRD33B', 'ankyrin repeat domain 33B'],
#  'ANKRD33B-AS1': ['nan', 'ANKRD33B-AS1', 'ANKRD33B antisense RNA 1'],
#  'ANKRD34A': ['nan', 'ANKRD34A', 'ankyrin repeat domain 34A'],
#  'ANKRD34B': ['DP58', 'ANKRD34B', 'ankyrin repeat domain 34B'],
#  'ANKRD34C': ['nan', 'ANKRD34C', 'ankyrin repeat domain 34C'],
#  'ANKRD34C-AS1': ['nan', 'ANKRD34C-AS1', 'ANKRD34C antisense RNA 1'],
#  'ANKRD35': ['FLJ25124', 'ANKRD35', 'ankyrin repeat domain 35'],
#  'ANKRD36': ['UNQ2430', 'ANKRD36', 'ankyrin repeat domain 36'],
#  'ANKRD36B': ['FLJ21281', 'ANKRD36B', 'ankyrin repeat domain 36B'],
#  'ANKRD36BP1': ['MGC12538',
#   'ANKRD36BP1',
#   'ankyrin repeat domain 36B pseudogene 1'],
#  'ANKRD36BP2': ['nan', 'ANKRD36BP2', 'ankyrin repeat domain 36B pseudogene 2'],
#  'ANKRD36C': ['DKFZp667P0924', 'ANKRD36C', 'ankyrin repeat domain 36C'],
#  'ANKRD36P1': ['nan', 'ANKRD36P1', 'ankyrin repeat domain 36 pseudogene 1'],
#  'ANKRD37': ['Lrp2bp', 'ANKRD37', 'ankyrin repeat domain 37'],
#  'ANKRD39': ['MGC41816', 'ANKRD39', 'ankyrin repeat domain 39'],
#  'ANKRD40': ['MGC15396', 'ANKRD40', 'ankyrin repeat domain 40'],
#  'ANKRD42': ['FLJ37874',
#   'SARP',
#   'PPP1R79',
#   'ANKRD42',
#   'ankyrin repeat domain 42'],
#  ...}

# %%
gene_dic = {k:[elem for elem in v if elem != 'nan' ] for k,v in gene_dic.items()}
gene_dic
# Out:
# {'A1BG': ['A1BG', 'alpha-1-B glycoprotein'],
#  'A1BG-AS1': ['FLJ23569', 'A1BG-AS1', 'A1BG antisense RNA 1'],
#  'A1CF': ['ACF',
#   'ASP',
#   'ACF64',
#   'ACF65',
#   'APOBEC1CF',
#   'A1CF',
#   'APOBEC1 complementation factor'],
#  'A2M': ['FWP007', 'S863-7', 'CPAMD5', 'A2M', 'alpha-2-macroglobulin'],
#  'A2M-AS1': ['A2M-AS1', 'A2M antisense RNA 1 (head to head)'],
#  'A2ML1': ['FLJ25179', 'A2ML1', 'alpha-2-macroglobulin like 1'],
#  'A2ML1-AS1': ['A2ML1-AS1', 'A2ML1 antisense RNA 1'],
#  'A2ML1-AS2': ['A2ML1-AS2', 'A2ML1 antisense RNA 2'],
#  'A2MP1': ['A2MP1', 'alpha-2-macroglobulin pseudogene 1'],
#  'A3GALT2': ['IGBS3S',
#   'IGB3S',
#   'A3GALT2',
#   'alpha 1,3-galactosyltransferase 2'],
#  'A4GALT': ['A14GALT',
#   'Gb3S',
#   'P(k)',
#   'A4GALT',
#   'alpha 1,4-galactosyltransferase'],
#  'A4GNT': ['alpha4GnT', 'A4GNT', 'alpha-1,4-N-acetylglucosaminyltransferase'],
#  'AAAS': ['AAAS', 'aladin WD repeat nucleoporin'],
#  'AACS': ['FLJ12389', 'SUR-5', 'ACSF1', 'AACS', 'acetoacetyl-CoA synthetase'],
#  'AACSP1': ['AACSP1', 'acetoacetyl-CoA synthetase pseudogene 1'],
#  'AADAC': ['DAC', 'CES5A1', 'AADAC', 'arylacetamide deacetylase'],
#  'AADACL2': ['MGC72001', 'AADACL2', 'arylacetamide deacetylase-like 2'],
#  'AADACL2-AS1': ['AADACL2-AS1', 'AADACL2 antisense RNA 1'],
#  'AADACL3': ['OTTHUMG00000001887',
#   'AADACL3',
#   'arylacetamide deacetylase-like 3'],
#  'AADACL4': ['OTTHUMG00000001889',
#   'AADACL4',
#   'arylacetamide deacetylase-like 4'],
#  'AADACP1': ['AADACP1', 'arylacetamide deacetylase pseudogene 1'],
#  'AADAT': ['KATII', 'KAT2', 'AADAT', 'aminoadipate aminotransferase'],
#  'AAED1': ['AAED1', 'AhpC/TSA antioxidant enzyme domain containing 1'],
#  'AAGAB': ['FLJ11506',
#   'p34',
#   'AAGAB',
#   'alpha- and gamma-adaptin binding protein'],
#  'AAK1': ['KIAA1048', 'DKFZp686K16132', 'AAK1', 'AP2 associated kinase 1'],
#  'AAMDC': ['PTD015',
#   'FLJ21035',
#   'CK067',
#   'AAMDC',
#   'adipogenesis associated, Mth938 domain containing'],
#  'AAMP': ['AAMP', 'angio associated migratory cell protein'],
#  'AANAT': ['SNAT', 'AANAT', 'aralkylamine N-acetyltransferase'],
#  'AAR2': ['bA234K24.2', 'AAR2', 'AAR2 splicing factor homolog'],
#  'AARD': ['LOC441376',
#   'AARD',
#   'alanine and arginine rich domain containing protein'],
#  'AARS': ['CMT2N', 'AARS', 'alanyl-tRNA synthetase'],
#  'AARS2': ['KIAA1270',
#   'bA444E17.1',
#   'AARS2',
#   'alanyl-tRNA synthetase 2, mitochondrial'],
#  'AARSD1': ['MGC2744', 'AARSD1', 'alanyl-tRNA synthetase domain containing 1'],
#  'AARSP1': ['AARSP1', 'alanyl-tRNA synthetase pseudogene 1'],
#  'AASDH': ['NRPS998',
#   'LYS2',
#   'ACSF4',
#   'AASDH',
#   'aminoadipate-semialdehyde dehydrogenase'],
#  'AASDHPPT': ['LYS5',
#   'CGI-80',
#   'AASD-PPT',
#   'ACPS',
#   'AASDHPPT',
#   'aminoadipate-semialdehyde dehydrogenase-phosphopantetheinyl transferase'],
#  'AASS': ['LORSDH', 'LKRSDH', 'AASS', 'aminoadipate-semialdehyde synthase'],
#  'AATBC': ['AATBC', 'apoptosis associated transcript in bladder cancer'],
#  'AATF': ['DED',
#   'CHE-1',
#   'CHE1',
#   'BFR2',
#   'AATF',
#   'apoptosis antagonizing transcription factor'],
#  'AATK': ['AATYK',
#   'KIAA0641',
#   'LMTK1',
#   'LMR1',
#   'AATYK1',
#   'PPP1R77',
#   'AATK',
#   'apoptosis-associated tyrosine kinase'],
#  'AATK-AS1': ['AATK-AS1', 'AATK antisense RNA 1'],
#  'ABALON': ['INXS',
#   'ABALON',
#   'apoptotic BCL2L1-antisense long non-coding RNA'],
#  'ABAT': ['GABAT', 'ABAT', '4-aminobutyrate aminotransferase'],
#  'ABCA1': ['TGD', 'ABCA1', 'ATP binding cassette subfamily A member 1'],
#  'ABCA2': ['ABCA2', 'ATP binding cassette subfamily A member 2'],
#  'ABCA3': ['ABC-C',
#   'EST111653',
#   'LBM180',
#   'ABCA3',
#   'ATP binding cassette subfamily A member 3'],
#  'ABCA4': ['FFM',
#   'ARMD2',
#   'CORD3',
#   'ABCA4',
#   'ATP binding cassette subfamily A member 4'],
#  'ABCA5': ['EST90625', 'ABCA5', 'ATP binding cassette subfamily A member 5'],
#  'ABCA6': ['EST155051', 'ABCA6', 'ATP binding cassette subfamily A member 6'],
#  'ABCA7': ['ABCX', 'ABCA7', 'ATP binding cassette subfamily A member 7'],
#  'ABCA8': ['KIAA0822', 'ABCA8', 'ATP binding cassette subfamily A member 8'],
#  'ABCA9': ['EST640918', 'ABCA9', 'ATP binding cassette subfamily A member 9'],
#  'ABCA9-AS1': ['ABCA9-AS1', 'ABCA9 antisense RNA 1'],
#  'ABCA10': ['EST698739',
#   'ABCA10',
#   'ATP binding cassette subfamily A member 10'],
#  'ABCA11P': ['EST1133530',
#   'FLJ14297',
#   'ABCA11P',
#   'ATP binding cassette subfamily A member 11, pseudogene'],
#  'ABCA12': ['DKFZP434G232',
#   'LI2',
#   'ABCA12',
#   'ATP binding cassette subfamily A member 12'],
#  'ABCA13': ['FLJ33876',
#   'FLJ33951',
#   'ABCA13',
#   'ATP binding cassette subfamily A member 13'],
#  'ABCA17P': ['ABCA17P',
#   'ATP binding cassette subfamily A member 17, pseudogene'],
#  'ABCB1': ['P-gp',
#   'CD243',
#   'GP170',
#   'ABC20',
#   'ABCB1',
#   'ATP binding cassette subfamily B member 1'],
#  'ABCB4': ['MDR2',
#   'PFIC-3',
#   'GBD1',
#   'ABCB4',
#   'ATP binding cassette subfamily B member 4'],
#  'ABCB5': ['EST422562',
#   'ABCB5beta',
#   'ABCB5alpha',
#   'ABCB5',
#   'ATP binding cassette subfamily B member 5'],
#  'ABCB6': ['EST45597',
#   'umat',
#   'MTABC3',
#   'ABCB6',
#   'ATP binding cassette subfamily B member 6 (Langereis blood group)'],
#  'ABCB7': ['EST140535',
#   'Atm1p',
#   'ASAT',
#   'ABCB7',
#   'ATP binding cassette subfamily B member 7'],
#  'ABCB8': ['EST328128',
#   'M-ABC1',
#   'MABC1',
#   'ABCB8',
#   'ATP binding cassette subfamily B member 8'],
#  'ABCB9': ['EST122234', 'ABCB9', 'ATP binding cassette subfamily B member 9'],
#  'ABCB10': ['EST20237',
#   'M-ABC2',
#   'MTABC2',
#   'ABCB10',
#   'ATP binding cassette subfamily B member 10'],
#  'ABCB10P1': ['M-ABC2',
#   'MABC2',
#   'ABCB10P1',
#   'ATP binding cassette subfamily B member 10 pseudogene 1'],
#  'ABCB10P3': ['ABCB10P3',
#   'ATP binding cassette subfamily B member 10 pseudogene 3'],
#  'ABCB10P4': ['ABCB10P4',
#   'ATP binding cassette subfamily B member 10 pseudogene 4'],
#  'ABCB11': ['ABC16',
#   'SPGP',
#   'PFIC-2',
#   'PGY4',
#   'ABCB11',
#   'ATP binding cassette subfamily B member 11'],
#  'ABCC1': ['GS-X', 'ABCC1', 'ATP binding cassette subfamily C member 1'],
#  'ABCC2': ['DJS',
#   'MRP2',
#   'cMRP',
#   'ABCC2',
#   'ATP binding cassette subfamily C member 2'],
#  'ABCC3': ['MRP3',
#   'cMOAT2',
#   'EST90757',
#   'MLP2',
#   'MOAT-D',
#   'ABCC3',
#   'ATP binding cassette subfamily C member 3'],
#  'ABCC4': ['MRP4',
#   'EST170205',
#   'MOAT-B',
#   'MOATB',
#   'ABCC4',
#   'ATP binding cassette subfamily C member 4'],
#  'ABCC5': ['MRP5',
#   'SMRP',
#   'EST277145',
#   'MOAT-C',
#   'ABCC5',
#   'ATP binding cassette subfamily C member 5'],
#  'ABCC5-AS1': ['ABCC5-AS1', 'ABCC5 antisense RNA 1'],
#  'ABCC6': ['MRP6',
#   'EST349056',
#   'MLP1',
#   'URG7',
#   'ABCC6',
#   'ATP binding cassette subfamily C member 6'],
#  'ABCC6P1': ['ABCC6P1',
#   'ATP binding cassette subfamily C member 6 pseudogene 1'],
#  'ABCC6P2': ['ABCC6P2',
#   'ATP binding cassette subfamily C member 6 pseudogene 2'],
#  'ABCC8': ['HI',
#   'PHHI',
#   'SUR1',
#   'MRP8',
#   'ABC36',
#   'HHF1',
#   'TNDM2',
#   'ABCC8',
#   'ATP binding cassette subfamily C member 8'],
#  'ABCC9': ['SUR2',
#   'CMD1O',
#   'ABCC9',
#   'ATP binding cassette subfamily C member 9'],
#  'ABCC10': ['EST182763',
#   'MRP7',
#   'SIMRP7',
#   'ABCC10',
#   'ATP binding cassette subfamily C member 10'],
#  'ABCC11': ['MRP8', 'ABCC11', 'ATP binding cassette subfamily C member 11'],
#  'ABCC12': ['MRP9', 'ABCC12', 'ATP binding cassette subfamily C member 12'],
#  'ABCC13': ['PRED6',
#   'C21orf73',
#   'ABCC13P',
#   'ABCC13',
#   'ATP binding cassette subfamily C member 13 (pseudogene)'],
#  'ABCD1': ['AMN',
#   'ALDP',
#   'adrenoleukodystrophy',
#   'ABCD1',
#   'ATP binding cassette subfamily D member 1'],
#  'ABCD1P2': ['bA453N3.6',
#   'ABCD1P2',
#   'ATP binding cassette subfamily D member 1 pseudogene 2'],
#  'ABCD1P3': ['ABCD1P3',
#   'ATP binding cassette subfamily D member 1 pseudogene 3'],
#  'ABCD1P4': ['ABCD1P4',
#   'ATP binding cassette subfamily D member 1 pseudogene 4'],
#  'ABCD1P5': ['ABCD1P5',
#   'ATP binding cassette subfamily D member 1 pseudogene 5'],
#  'ABCD2': ['ALDR',
#   'ALDRP',
#   'ABCD2',
#   'ATP binding cassette subfamily D member 2'],
#  'ABCD3': ['PMP70',
#   'ZWS2',
#   'ABCD3',
#   'ATP binding cassette subfamily D member 3'],
#  'ABCD4': ['PMP69',
#   'P70R',
#   'EST352188',
#   'ABCD4',
#   'ATP binding cassette subfamily D member 4'],
#  'ABCE1': ['RLI',
#   'OABP',
#   'ABCE1',
#   'ATP binding cassette subfamily E member 1'],
#  'ABCF1': ['EST123147', 'ABCF1', 'ATP binding cassette subfamily F member 1'],
#  'ABCF2': ['EST133090',
#   'ABC28',
#   'M-ABC1',
#   'HUSSY-18',
#   'ABCF2',
#   'ATP binding cassette subfamily F member 2'],
#  'ABCF2P1': ['ABCF2P1',
#   'ATP binding cassette subfamily F member 2 pseudogene 1'],
#  'ABCF2P2': ['ABCF2P2',
#   'ATP binding cassette subfamily F member 2 pseudogene 2'],
#  'ABCF3': ['EST201864', 'ABCF3', 'ATP binding cassette subfamily F member 3'],
#  'ABCG1': ['ABC8', 'ABCG1', 'ATP binding cassette subfamily G member 1'],
#  'ABCG2': ['EST157481',
#   'MXR',
#   'BCRP',
#   'ABCP',
#   'CD338',
#   'ABCG2',
#   'ATP binding cassette subfamily G member 2 (Junior blood group)'],
#  'ABCG4': ['WHITE2', 'ABCG4', 'ATP binding cassette subfamily G member 4'],
#  'ABCG5': ['STSL', 'ABCG5', 'ATP binding cassette subfamily G member 5'],
#  'ABCG8': ['GBD4', 'ABCG8', 'ATP binding cassette subfamily G member 8'],
#  'ABHD1': ['LABH1', 'FLJ36128', 'ABHD1', 'abhydrolase domain containing 1'],
#  'ABHD2': ['LABH2', 'ABHD2', 'abhydrolase domain containing 2'],
#  'ABHD3': ['LABH3', 'ABHD3', 'abhydrolase domain containing 3'],
#  'ABHD4': ['FLJ12816', 'ABHD4', 'abhydrolase domain containing 4'],
#  'ABHD5': ['CGI-58', 'NCIE2', 'ABHD5', 'abhydrolase domain containing 5'],
#  'ABHD6': ['ABHD6', 'abhydrolase domain containing 6'],
#  'ABHD8': ['FLJ11743',
#   'MGC14280',
#   'MGC2512',
#   'ABHD8',
#   'abhydrolase domain containing 8'],
#  'ABHD10': ['FLJ11342', 'ABHD10', 'abhydrolase domain containing 10'],
#  'ABHD11': ['PP1226', 'ABHD11', 'abhydrolase domain containing 11'],
#  'ABHD11-AS1': ['NCRNA00035',
#   'ABHD11-AS1',
#   'ABHD11 antisense RNA 1 (tail to tail)'],
#  'ABHD12': ['DKFZP434P106',
#   'dJ965G21.2',
#   'BEM46L2',
#   'ABHD12A',
#   'ABHD12',
#   'abhydrolase domain containing 12'],
#  'ABHD12B': ['BEM46L3', 'ABHD12B', 'abhydrolase domain containing 12B'],
#  'ABHD13': ['bA153I24.2',
#   'FLJ14906',
#   'BEM46L1',
#   'ABHD13',
#   'abhydrolase domain containing 13'],
#  'ABHD14A': ['DKFZP564O243',
#   'DORZ1',
#   'ABHD14A',
#   'abhydrolase domain containing 14A'],
#  'ABHD14A-ACY1': ['ABHD14A-ACY1', 'ABHD14A-ACY1 readthrough'],
#  'ABHD14B': ['MGC15429',
#   'CIB',
#   'ABHD14B',
#   'abhydrolase domain containing 14B'],
#  'ABHD15': ['ABHD15', 'abhydrolase domain containing 15'],
#  'ABHD15-AS1': ['linc-TP53I13',
#   'lnc-TP53I13',
#   'ABHD15-AS1',
#   'ABHD15 antisense RNA 1'],
#  'ABHD16A': ['NG26', 'D6S82E', 'ABHD16A', 'abhydrolase domain containing 16A'],
#  'ABHD16B': ['dJ591C20.1', 'ABHD16B', 'abhydrolase domain containing 16B'],
#  'ABHD17A': ['MGC5244', 'ABHD17A', 'abhydrolase domain containing 17A'],
#  'ABHD17AP1': ['C1orf47',
#   'ABHD17AP1',
#   'abhydrolase domain containing 17A pseudogene 1'],
#  'ABHD17AP3': ['ABHD17AP3', 'abhydrolase domain containing 17A pseudogene 3'],
#  'ABHD17AP4': ['ABHD17AP4', 'abhydrolase domain containing 17A pseudogene P4'],
#  'ABHD17AP5': ['ABHD17AP5', 'abhydrolase domain containing 17A pseudogene 5'],
#  'ABHD17AP6': ['ABHD17AP6', 'abhydrolase domain containing 17A pseudogene 6'],
#  'ABHD17AP7': ['ABHD17AP7', 'abhydrolase domain containing 17A pseudogene 7'],
#  'ABHD17AP8': ['ABHD17AP8', 'abhydrolase domain containing 17A pseudogene 8'],
#  'ABHD17AP9': ['ABHD17AP9', 'abhydrolase domain containing 17A pseudogene 9'],
#  'ABHD17B': ['CGI-67', 'ABHD17B', 'abhydrolase domain containing 17B'],
#  'ABHD17C': ['ABHD17C', 'abhydrolase domain containing 17C'],
#  'ABHD18': ['FLJ21106', 'ABHD18', 'abhydrolase domain containing 18'],
#  'ABI1': ['E3B1', 'ABI-1', 'ABI1', 'abl interactor 1'],
#  'ABI2': ['ABI-2',
#   'AIP-1',
#   'ABI2B',
#   'AblBP3',
#   'argBPIA',
#   'SSH3BP2',
#   'ABI2',
#   'abl-interactor 2'],
#  'ABI3': ['NESH', 'SSH3BP3', 'ABI3', 'ABI family member 3'],
#  'ABI3BP': ['NESHBP',
#   'DKFZP586L2024',
#   'TARSH',
#   'ABI3BP',
#   'ABI family member 3 binding protein'],
#  'ABL1': ['JTK7',
#   'c-ABL',
#   'p150',
#   'ABL1',
#   'ABL proto-oncogene 1, non-receptor tyrosine kinase'],
#  'ABL2': ['ARG', 'ABL2', 'ABL proto-oncogene 2, non-receptor tyrosine kinase'],
#  'ABLIM1': ['abLIM', 'limatin', 'ABLIM1', 'actin binding LIM protein 1'],
#  'ABLIM2': ['KIAA1808', 'ABLIM2', 'actin binding LIM protein family member 2'],
#  'ABLIM3': ['KIAA0843', 'ABLIM3', 'actin binding LIM protein family member 3'],
#  'ABO': ['A3GALNT',
#   'A3GALT1',
#   'ABO',
#   'ABO blood group (transferase A, alpha 1-3-N-acetylgalactosaminyltransferase; transferase B, alpha 1-3-galactosyltransferase)'],
#  'ABR': ['MDB', 'ABR', 'active BCR-related'],
#  'ABRA': ['STARS', 'ABRA', 'actin binding Rho activating protein'],
#  'ABRACL': ['PRO2013', 'HSPC280', 'Costars', 'ABRACL', 'ABRA C-terminal like'],
#  'ABT1': ['ABT1', 'activator of basal transcription 1'],
#  'ABT1P1': ['ABT1P1', 'activator of basal transcription 1 pseudogene 1'],
#  'ABTB1': ['BPOZ',
#   'EF1ABP',
#   'Btb3',
#   'BTBD21',
#   'ABTB1',
#   'ankyrin repeat and BTB domain containing 1'],
#  'ABTB2': ['DKFZP586C1619',
#   'BTBD22',
#   'ABTB2A',
#   'ABTB2',
#   'ankyrin repeat and BTB domain containing 2'],
#  'ACAA1': ['ACAA1', 'acetyl-CoA acyltransferase 1'],
#  'ACAA2': ['DSAEC', 'ACAA2', 'acetyl-CoA acyltransferase 2'],
#  'ACACA': ['ACC1', 'ACACA', 'acetyl-CoA carboxylase alpha'],
#  'ACACB': ['HACC275', 'ACC2', 'ACCB', 'ACACB', 'acetyl-CoA carboxylase beta'],
#  'ACAD8': ['ACAD8', 'acyl-CoA dehydrogenase family member 8'],
#  'ACAD9': ['NPD002',
#   'MGC14452',
#   'ACAD9',
#   'acyl-CoA dehydrogenase family member 9'],
#  'ACAD10': ['MGC5601', 'ACAD10', 'acyl-CoA dehydrogenase family member 10'],
#  'ACAD11': ['FLJ12592', 'ACAD11', 'acyl-CoA dehydrogenase family member 11'],
#  'ACADL': ['LCAD', 'ACAD4', 'ACADL', 'acyl-CoA dehydrogenase, long chain'],
#  'ACADM': ['MCAD',
#   'MCADH',
#   'ACAD1',
#   'ACADM',
#   'acyl-CoA dehydrogenase, C-4 to C-12 straight chain'],
#  'ACADS': ['SCAD',
#   'ACAD3',
#   'ACADS',
#   'acyl-CoA dehydrogenase, C-2 to C-3 short chain'],
#  'ACADSB': ['SBCAD',
#   'ACAD7',
#   'ACADSB',
#   'acyl-CoA dehydrogenase, short/branched chain'],
#  'ACADVL': ['VLCAD',
#   'LCACD',
#   'ACAD6',
#   'ACADVL',
#   'acyl-CoA dehydrogenase, very long chain'],
#  'ACAN': ['CSPGCP', 'ACAN', 'aggrecan'],
#  'ACAP1': ['KIAA0050',
#   'ACAP1',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 1'],
#  'ACAP2': ['KIAA0041',
#   'CNT-B2',
#   'ACAP2',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 2'],
#  'ACAP2-IT1': ['ACAP2-IT1', 'ACAP2 intronic transcript 1'],
#  'ACAP3': ['KIAA1716',
#   'ACAP3',
#   'ArfGAP with coiled-coil, ankyrin repeat and PH domains 3'],
#  'ACAT1': ['THIL', 'ACAT1', 'acetyl-CoA acetyltransferase 1'],
#  'ACAT2': ['ACAT2', 'acetyl-CoA acetyltransferase 2'],
#  'ACBD3': ['GCP60', 'PAP7', 'ACBD3', 'acyl-CoA binding domain containing 3'],
#  'ACBD4': ['FLJ13322', 'ACBD4', 'acyl-CoA binding domain containing 4'],
#  'ACBD5': ['DKFZp434A2417',
#   'KIAA1996',
#   'ACBD5',
#   'acyl-CoA binding domain containing 5'],
#  'ACBD6': ['MGC2404', 'ACBD6', 'acyl-CoA binding domain containing 6'],
#  'ACBD7': ['FLJ38219',
#   'bA455B2.2',
#   'ACBD7',
#   'acyl-CoA binding domain containing 7'],
#  'ACCS': ['PHACS',
#   'ACS',
#   'ACCS',
#   '1-aminocyclopropane-1-carboxylate synthase homolog (inactive)'],
#  'ACCSL': ['ACCSL',
#   '1-aminocyclopropane-1-carboxylate synthase (inactive)-like'],
#  'ACD': ['Ptop',
#   'Pip1',
#   'Tpp1',
#   'Tint1',
#   'ACD',
#   'adrenocortical dysplasia homolog'],
#  'ACE': ['ACE1', 'CD143', 'ACE', 'angiotensin I converting enzyme'],
#  'ACE2': ['ACE2', 'angiotensin I converting enzyme 2'],
#  'ACE3P': ['ACE3P',
#   'angiotensin I converting enzyme (peptidyl-dipeptidase A) 3, pseudogene'],
#  'ACER1': ['ACER1', 'alkaline ceramidase 1'],
#  'ACER2': ['FLJ41587', 'ACER2', 'alkaline ceramidase 2'],
#  'ACER3': ['FLJ11238', 'APHC', 'ACER3', 'alkaline ceramidase 3'],
#  'ACHE': ['ACHE', 'acetylcholinesterase (Cartwright blood group)'],
#  'ACIN1': ['KIAA0670',
#   'fSAP152',
#   'ACIN1',
#   'apoptotic chromatin condensation inducer 1'],
#  'ACKR1': ['CCBP1',
#   'GPD',
#   'Dfy',
#   'CD234',
#   'ACKR1',
#   'atypical chemokine receptor 1 (Duffy blood group)'],
#  'ACKR2': ['CCR10', 'D6', 'CCR9', 'ACKR2', 'atypical chemokine receptor 2'],
#  'ACKR3': ['RDC1', 'GPR159', 'ACKR3', 'atypical chemokine receptor 3'],
#  'ACKR4': ['CCR11',
#   'CCBP2',
#   'VSHK1',
#   'CCX-CKR',
#   'PPR1',
#   'ACKR4',
#   'atypical chemokine receptor 4'],
#  'ACLY': ['ATPCL', 'CLATP', 'ACL', 'ACLY', 'ATP citrate lyase'],
#  'ACMSD': ['ACMSD', 'aminocarboxymuconate semialdehyde decarboxylase'],
#  'ACO1': ['IRP1', 'IREBP', 'ACO1', 'aconitase 1'],
#  'ACO2': ['ACONM', 'ACO2', 'aconitase 2'],
#  'ACOD1': ['CAD', 'ACOD1', 'aconitate decarboxylase 1'],
#  'ACOT1': ['ACH2', 'CTE-1', 'LACH2', 'ACOT1', 'acyl-CoA thioesterase 1'],
#  'ACOT2': ['Mte1', 'ZAP128', 'ACOT2', 'acyl-CoA thioesterase 2'],
#  'ACOT4': ['FLJ31235', 'PTE-Ib', 'PTE2B', 'ACOT4', 'acyl-CoA thioesterase 4'],
#  'ACOT6': ['ACOT6', 'acyl-CoA thioesterase 6'],
#  'ACOT7': ['BACH',
#   'ACH1',
#   'ACT',
#   'CTE-II',
#   'LACH1',
#   'MGC1126',
#   'hBACH',
#   'ACOT7',
#   'acyl-CoA thioesterase 7'],
#  'ACOT8': ['hACTE-III',
#   'hTE',
#   'PTE-2',
#   'NAP1',
#   'ACOT8',
#   'acyl-CoA thioesterase 8'],
#  'ACOT9': ['CGI-16', 'MT-ACT48', 'ACATE2', 'ACOT9', 'acyl-CoA thioesterase 9'],
#  'ACOT11': ['STARD14',
#   'BFIT',
#   'KIAA0707',
#   'BFIT1',
#   'THEM1',
#   'ACOT11',
#   'acyl-CoA thioesterase 11'],
#  'ACOT12': ['Cach', 'THEAL', 'STARD15', 'ACOT12', 'acyl-CoA thioesterase 12'],
#  'ACOT13': ['HT012', 'ACOT13', 'acyl-CoA thioesterase 13'],
#  'ACOX1': ['PALMCOX', 'ACOX1', 'acyl-CoA oxidase 1, palmitoyl'],
#  'ACOX2': ['BRCACOX',
#   'BRCOX',
#   'THCCox',
#   'ACOX2',
#   'acyl-CoA oxidase 2, branched chain'],
#  'ACOX3': ['ACOX3', 'acyl-CoA oxidase 3, pristanoyl'],
#  'ACOXL': ['FLJ11042', 'ACOXL', 'acyl-CoA oxidase-like'],
#  'ACP1': ['HAAP', 'LMW-PTP', 'ACP1', 'acid phosphatase 1, soluble'],
#  'ACP2': ['LAP', 'ACP2', 'acid phosphatase 2, lysosomal'],
#  'ACP5': ['TRAP', 'HPAP', 'ACP5', 'acid phosphatase 5, tartrate resistant'],
#  'ACP6': ['LPAP', 'ACPL1', 'ACP6', 'acid phosphatase 6, lysophosphatidic'],
#  'ACP7': ['FLJ16165',
#   'PAPL1',
#   'ACP7',
#   'acid phosphatase 7, tartrate resistant (putative)'],
#  'ACPP': ['ACP3', 'ACP-3', 'PAP', 'ACPP', 'acid phosphatase, prostate'],
#  'ACPT': ['ACPT', 'acid phosphatase, testicular'],
#  'ACR': ['ACR', 'acrosin'],
#  'ACRBP': ['SP32', 'OY-TES-1', 'CT23', 'ACRBP', 'acrosin binding protein'],
#  'ACRC': ['ACRC', 'acidic repeat containing'],
#  'ACRV1': ['SPACA2',
#   'SP-10',
#   'D11S4365',
#   'ACRV1',
#   'acrosomal vesicle protein 1'],
#  'ACSBG1': ['BGM',
#   'FLJ30320',
#   'MGC14352',
#   'BG1',
#   'KIAA0631',
#   'hBG1',
#   'hsBG',
#   'ACSBG1',
#   'acyl-CoA synthetase bubblegum family member 1'],
#  'ACSBG2': ['BGR',
#   'PRTD-NY3',
#   'DKFZp434K1635',
#   'ACSBG2',
#   'acyl-CoA synthetase bubblegum family member 2'],
#  'ACSF2': ['FLJ20920',
#   'ACSMW',
#   'ACSF2',
#   'acyl-CoA synthetase family member 2'],
#  'ACSF3': ['ACSF3', 'acyl-CoA synthetase family member 3'],
#  'ACSL1': ['LACS2',
#   'LACS',
#   'ACS1',
#   'LACS1',
#   'FACL1',
#   'ACSL1',
#   'acyl-CoA synthetase long-chain family member 1'],
#  'ACSL3': ['ACS3',
#   'PRO2194',
#   'ACSL3',
#   'acyl-CoA synthetase long-chain family member 3'],
#  'ACSL4': ['ACS4',
#   'LACS4',
#   'ACSL4',
#   'acyl-CoA synthetase long-chain family member 4'],
#  'ACSL5': ['ACS5',
#   'ACS2',
#   'ACSL5',
#   'acyl-CoA synthetase long-chain family member 5'],
#  'ACSL6': ['KIAA0837',
#   'ACS2',
#   'LACS5',
#   'LACS2',
#   'ACSL6',
#   'acyl-CoA synthetase long-chain family member 6'],
#  'ACSM1': ['MACS1',
#   'ACSM1',
#   'acyl-CoA synthetase medium-chain family member 1'],
#  'ACSM2A': ['A-923A4.1',
#   'MGC150530',
#   'ACSM2A',
#   'acyl-CoA synthetase medium-chain family member 2A'],
#  'ACSM2B': ['HXMA',
#   'HYST1046',
#   'ACSM2B',
#   'acyl-CoA synthetase medium-chain family member 2B'],
#  'ACSM3': ['SA', 'ACSM3', 'acyl-CoA synthetase medium-chain family member 3'],
#  'ACSM4': ['ACSM4', 'acyl-CoA synthetase medium-chain family member 4'],
#  'ACSM5': ['FLJ20581',
#   'ACSM5',
#   'acyl-CoA synthetase medium-chain family member 5'],
#  'ACSM5P1': ['ACSM5P1',
#   'acyl-CoA synthetase medium-chain family member 5 pseudogene 1'],
#  'ACSM6': ['bA310E22.3',
#   'ACSM6',
#   'acyl-CoA synthetase medium-chain family member 6'],
#  'ACSS1': ['dJ568C11.3',
#   'AceCS2L',
#   'MGC33843',
#   'ACSS1',
#   'acyl-CoA synthetase short-chain family member 1'],
#  'ACSS2': ['ACS',
#   'ACSA',
#   'AceCS',
#   'dJ1161H23.1',
#   'ACSS2',
#   'acyl-CoA synthetase short-chain family member 2'],
#  'ACSS3': ['FLJ21963',
#   'ACSS3',
#   'acyl-CoA synthetase short-chain family member 3'],
#  'ACTA1': ['NEM3', 'ACTA1', 'actin, alpha 1, skeletal muscle'],
#  'ACTA2': ['ACTSA', 'ACTA2', 'actin, alpha 2, smooth muscle, aorta'],
#  'ACTA2-AS1': ['uc001kfo.1', 'ZXF1', 'ACTA2-AS1', 'ACTA2 antisense RNA 1'],
#  'ACTB': ['ACTB', 'actin, beta'],
#  'ACTBL2': ['DKFZp686D0972', 'ACTBL2', 'actin, beta-like 2'],
#  'ACTBP1': ['ACTBP1', 'actin, beta pseudogene 1'],
#  'ACTBP2': ['ACTBP2', 'actin, beta pseudogene 2'],
#  'ACTBP6': ['ACTBP6', 'actin, beta pseudogene 6'],
#  'ACTBP7': ['ACTBP7', 'actin, beta pseudogene 7'],
#  'ACTBP8': ['ACTBP2', 'ACTBP8', 'actin, beta pseudogene 8'],
#  'ACTBP9': ['ACTBP9', 'actin, beta pseudogene 9'],
#  'ACTBP11': ['ACTBP11', 'actin, beta pseudogene 11'],
#  'ACTBP12': ['ACTBP12', 'actin, beta pseudogene 12'],
#  'ACTBP13': ['ACTBP13', 'actin, beta pseudogene 13'],
#  'ACTBP14': ['ACTBP14', 'actin, beta pseudogene 14'],
#  'ACTC1': ['CMD1R', 'ACTC1', 'actin, alpha, cardiac muscle 1'],
#  'ACTG1': ['ACTG1', 'actin gamma 1'],
#  'ACTG1P1': ['ACTG1P1', 'actin gamma 1 pseudogene 1'],
#  'ACTG1P2': ['ACTG1P2', 'actin gamma 1 pseudogene 2'],
#  'ACTG1P3': ['ACTG1P3', 'actin gamma 1 pseudogene 3'],
#  'ACTG1P4': ['ACTG1P4', 'actin gamma 1 pseudogene 4'],
#  'ACTG1P9': ['ACTG1P9', 'actin gamma 1 pseudogene 9'],
#  'ACTG1P10': ['ACTG1P10', 'actin gamma 1 pseudogene 10'],
#  'ACTG1P11': ['ACTG1P11', 'actin gamma 1 pseudogene 11'],
#  'ACTG1P12': ['ACTG1P12', 'actin gamma 1 pseudogene 12'],
#  'ACTG1P13': ['ACTG1P13', 'actin gamma 1 pseudogene 13'],
#  'ACTG1P14': ['ACTG1P14', 'actin gamma 1 pseudogene 14'],
#  'ACTG1P15': ['ACTG1P15', 'actin gamma 1 pseudogene 15'],
#  'ACTG1P16': ['ACTG1P16', 'actin gamma 1 pseudogene 16'],
#  'ACTG1P17': ['ACTG1P17', 'actin gamma 1 pseudogene 17'],
#  'ACTG1P18': ['ACTG1P18', 'actin gamma 1 pseudogene 18'],
#  'ACTG1P19': ['ACTG1P19', 'actin gamma 1 pseudogene 19'],
#  'ACTG1P20': ['ACTG1P20', 'actin gamma 1 pseudogene 20'],
#  'ACTG1P21': ['ACTG1P21', 'actin gamma 1 pseudogene 21'],
#  'ACTG1P22': ['ACTG1P22', 'actin gamma 1 pseudogene 22'],
#  'ACTG1P23': ['ACTG1P23', 'actin gamma 1 pseudogene 23'],
#  'ACTG1P24': ['ACTG1P24', 'actin gamma 1 pseudogene 24'],
#  'ACTG2': ['ACTSG', 'ACTG2', 'actin, gamma 2, smooth muscle, enteric'],
#  'ACTL6A': ['Actl6',
#   'BAF53A',
#   'Arp4',
#   'Baf53a',
#   'INO80K',
#   'ACTL6A',
#   'actin like 6A'],
#  'ACTL6B': ['BAF53B', 'ACTL6B', 'actin like 6B'],
#  'ACTL7A': ['ACTL7A', 'actin like 7A'],
#  'ACTL7B': ['Tact1', 'ACTL7B', 'actin like 7B'],
#  'ACTL8': ['CT57', 'ACTL8', 'actin like 8'],
#  'ACTL9': ['MGC33407', 'ACTL9', 'actin like 9'],
#  'ACTL10': ['ACTL10', 'actin like 10'],
#  'ACTN1': ['ACTN1', 'actinin alpha 1'],
#  'ACTN1-AS1': ['ACTN1-AS1', 'ACTN1 antisense RNA 1'],
#  'ACTN2': ['ACTN2', 'actinin alpha 2'],
#  'ACTN3': ['ACTN3', 'actinin alpha 3 (gene/pseudogene)'],
#  'ACTN4': ['ACTN4', 'actinin alpha 4'],
#  'ACTN4P1': ['ACTN4P1', 'actinin alpha 4 pseudogene 1'],
#  'ACTN4P2': ['ACTN4P2', 'actinin alpha 4 pseudogene 2'],
#  'ACTP1': ['ACTP1', 'actin family pseudogene 1'],
#  'ACTR1A': ['ARP1',
#   'Arp1A',
#   'ACTR1A',
#   'ARP1 actin-related protein 1 homolog A, centractin alpha'],
#  'ACTR1B': ['Arp1B',
#   'ACTR1B',
#   'ARP1 actin-related protein 1 homolog B, centractin beta'],
#  'ACTR2': ['ARP2', 'ACTR2', 'ARP2 actin-related protein 2 homolog (yeast)'],
#  'ACTR3': ['ARP3', 'ACTR3', 'ARP3 actin-related protein 3 homolog (yeast)'],
#  'ACTR3B': ['ARP11',
#   'ARP3beta',
#   'ACTR3B',
#   'ARP3 actin-related protein 3 homolog B (yeast)'],
#  'ACTR3BP1': ['ACTR3BP1', 'ACTR3B pseudogene 1'],
#  'ACTR3BP2': ['FKSG73', 'ACTR3BP2', 'ACTR3B pseudogene 2'],
#  'ACTR3BP3': ['ACTR3BP3', 'ACTR3B pseudogene 3'],
#  'ACTR3BP4': ['ACTR3BP4', 'ACTR3B pseudogene 4'],
#  'ACTR3BP5': ['ACTR3BP5', 'ACTR3B pseudogene 5'],
#  'ACTR3BP6': ['ACTR3BP6', 'ACTR3B pseudogene 6'],
#  'ACTR3C': ['ARP11', 'ACTR3C', 'ARP3 actin-related protein 3 homolog C'],
#  'ACTR3P2': ['ACTR3P2', 'ACTR3 pseudogene 2'],
#  'ACTR3P3': ['ACTR3P3', 'ACTR3 pseudogene 3'],
#  'ACTR5': ['FLJ12785',
#   'Arp5',
#   'INO80M',
#   'ACTR5',
#   'ARP5 actin-related protein 5 homolog'],
#  'ACTR6': ['ARP6',
#   'FLJ13433',
#   'ACTR6',
#   'ARP6 actin-related protein 6 homolog'],
#  'ACTR6P1': ['ACTR6P1', 'ACTR6 pseudogene 1'],
#  'ACTR8': ['INO80N', 'ACTR8', 'ARP8 actin-related protein 8 homolog'],
#  'ACTR10': ['HARP11',
#   'ACTR11',
#   'Arp11',
#   'Arp10',
#   'ACTR10',
#   'actin-related protein 10 homolog'],
#  'ACTRT1': ['AIP1',
#   'KIAA0705',
#   'ARIP1',
#   'Arp-T1',
#   'ACTRT1',
#   'actin related protein T1'],
#  'ACTRT2': ['Arp-T2',
#   'ARPM2',
#   'FLJ25424',
#   'ACTRT2',
#   'actin related protein T2'],
#  'ACTRT3': ['ARPM1', 'ACTRT3', 'actin related protein T3'],
#  'ACVR1': ['SKR1', 'ALK2', 'ACVR1A', 'ACVR1', 'activin A receptor type 1'],
#  'ACVR1B': ['ALK4', 'SKR2', 'ActRIB', 'ACVR1B', 'activin A receptor type 1B'],
#  'ACVR1C': ['ALK7', 'ACVRLK7', 'ACVR1C', 'activin A receptor type 1C'],
#  'ACVR2A': ['ACTRII', 'ACVR2A', 'activin A receptor type 2A'],
#  'ACVR2B': ['ActR-IIB', 'ACVR2B', 'activin A receptor type 2B'],
#  'ACVR2B-AS1': ['ACVR2B-AS1', 'ACVR2B antisense RNA 1'],
#  'ACVRL1': ['HHT2', 'ALK1', 'HHT', 'ACVRL1', 'activin A receptor like type 1'],
#  'ACY1': ['ACY1', 'aminoacylase 1'],
#  'ACY3': ['HCBP1', 'MGC9740', 'ACY-3', 'ACY3', 'aminoacylase 3'],
#  'ACYP1': ['ACYP1', 'acylphosphatase 1'],
#  'ACYP2': ['ACYP2', 'acylphosphatase 2'],
#  'ADA': ['ADA', 'adenosine deaminase'],
#  'ADAD1': ['Tenr', 'ADAD1', 'adenosine deaminase domain containing 1'],
#  'ADAD1P2': ['ADAD1P2',
#   'adenosine deaminase domain containing 1 pseudogene 2'],
#  'ADAD2': ['TENRL',
#   'FLJ00337',
#   'ADAD2',
#   'adenosine deaminase domain containing 2'],
#  'ADAL': ['ADAL', 'adenosine deaminase-like'],
#  'ADAM1A': ['FTNAP',
#   'PH-30a',
#   'Ftna',
#   'ADAM1P',
#   'ADAM1A',
#   'ADAM metallopeptidase domain 1A (pseudogene)'],
#  'ADAM1B': ['ADAM1B', 'ADAM metallopeptidase domain 1B (pseudogene)'],
#  'ADAM2': ['PH-30b',
#   'PH30',
#   'CT15',
#   'ADAM2',
#   'ADAM metallopeptidase domain 2'],
#  'ADAM3A': ['ADAM3',
#   'tMDCI',
#   'ADAM3A',
#   'ADAM metallopeptidase domain 3A (pseudogene)'],
#  'ADAM3B': ['ADAM3B', 'ADAM metallopeptidase domain 3B (pseudogene)'],
#  'ADAM5': ['tMDCII', 'ADAM5', 'ADAM metallopeptidase domain 5 (pseudogene)'],
#  'ADAM6': ['tMDCIV', 'ADAM6', 'ADAM metallopeptidase domain 6 (pseudogene)'],
#  'ADAM7': ['GP-83', 'EAPI', 'ADAM7', 'ADAM metallopeptidase domain 7'],
#  'ADAM8': ['CD156',
#   'MS2',
#   'CD156a',
#   'ADAM8',
#   'ADAM metallopeptidase domain 8'],
#  'ADAM9': ['MDC9',
#   'KIAA0021',
#   'MCMP',
#   'Mltng',
#   'ADAM9',
#   'ADAM metallopeptidase domain 9'],
#  'ADAM10': ['kuz',
#   'MADM',
#   'HsT18717',
#   'CD156c',
#   'ADAM10',
#   'ADAM metallopeptidase domain 10'],
#  'ADAM11': ['ADAM11', 'ADAM metallopeptidase domain 11'],
#  'ADAM12': ['MCMPMltna', 'MLTN', 'ADAM12', 'ADAM metallopeptidase domain 12'],
#  'ADAM15': ['MDC15', 'ADAM15', 'ADAM metallopeptidase domain 15'],
#  'ADAM17': ['cSVP', 'CD156B', 'ADAM17', 'ADAM metallopeptidase domain 17'],
#  'ADAM18': ['tMDCIII', 'ADAM27', 'ADAM18', 'ADAM metallopeptidase domain 18'],
#  'ADAM19': ['MLTNB', 'ADAM19', 'ADAM metallopeptidase domain 19'],
#  'ADAM20': ['ADAM20', 'ADAM metallopeptidase domain 20'],
#  'ADAM20P1': ['ADAM20P1', 'ADAM metallopeptidase domain 20 pseudogene 1'],
#  'ADAM20P2': ['ADAM20P2', 'ADAM metallopeptidase domain 20 pseudogene 2'],
#  'ADAM20P3': ['ADAM20P3', 'ADAM metallopeptidase domain 20 pseudogene 3'],
#  'ADAM21': ['ADAM31', 'ADAM21', 'ADAM metallopeptidase domain 21'],
#  'ADAM21P1': ['ADAM21P1', 'ADAM metallopeptidase domain 21 pseudogene 1'],
#  'ADAM22': ['MDC2', 'ADAM22', 'ADAM metallopeptidase domain 22'],
#  'ADAM23': ['MDC3', 'ADAM23', 'ADAM metallopeptidase domain 23'],
#  'ADAM24P': ['ADAM24P', 'ADAM metallopeptidase domain 24, pseudogene'],
#  'ADAM28': ['eMDCII',
#   'MDC-Lm',
#   'MDC-Ls',
#   'ADAM23',
#   'ADAM28',
#   'ADAM metallopeptidase domain 28'],
#  'ADAM29': ['svph1', 'CT73', 'ADAM29', 'ADAM metallopeptidase domain 29'],
#  'ADAM30': ['svph4', 'ADAM30', 'ADAM metallopeptidase domain 30'],
#  'ADAM32': ['ADAM32', 'ADAM metallopeptidase domain 32'],
#  'ADAM33': ['DKFZp434K0521',
#   'dJ964F7.1',
#   'ADAM33',
#   'ADAM metallopeptidase domain 33'],
#  'ADAMDEC1': ['M12.219', 'ADAMDEC1', 'ADAM-like, decysin 1'],
#  'ADAMTS1': ['C3-C5',
#   'METH1',
#   'KIAA1346',
#   'ADAMTS1',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 1'],
#  'ADAMTS2': ['ADAMTS-3',
#   'hPCPNI',
#   'PCINP',
#   'ADAM-TS2',
#   'NPI',
#   'ADAMTS2',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 2'],
#  'ADAMTS3': ['KIAA0366',
#   'ADAMTS-4',
#   'ADAMTS3',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 3'],
#  'ADAMTS4': ['KIAA0688',
#   'ADAMTS-2',
#   'ADMP-1',
#   'ADAMTS4',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 4'],
#  'ADAMTS5': ['ADMP-2',
#   'ADAMTS11',
#   'ADAMTS5',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 5'],
#  'ADAMTS6': ['ADAM-TS6',
#   'ADAMTS6',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 6'],
#  'ADAMTS7': ['ADAM-TS7',
#   'DKFZp434H204',
#   'ADAMTS7',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 7'],
#  'ADAMTS7P1': ['ADAMTS7P1', 'ADAMTS7 pseudogene 1'],
#  'ADAMTS7P3': ['ADAMTS7P3', 'ADAMTS7 pseudogene 3'],
#  'ADAMTS7P4': ['ADAMTS7P4', 'ADAMTS7 pseudogene 4'],
#  'ADAMTS8': ['METH2',
#   'FLJ41712',
#   'ADAM-TS8',
#   'ADAMTS8',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 8'],
#  'ADAMTS9': ['KIAA1312',
#   'ADAMTS9',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 9'],
#  'ADAMTS9-AS1': ['ADAMTS9-AS1', 'ADAMTS9 antisense RNA 1'],
#  'ADAMTS9-AS2': ['ADAMTS9-AS2', 'ADAMTS9 antisense RNA 2'],
#  'ADAMTS10': ['ADAM-TS10',
#   'ADAMTS10',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 10'],
#  'ADAMTS12': ['ADAMTS12',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 12'],
#  'ADAMTS13': ['VWFCP',
#   'TTP',
#   'vWF-CP',
#   'FLJ42993',
#   'MGC118899',
#   'MGC118900',
#   'DKFZp434C2322',
#   'ADAMTS13',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 13'],
#  'ADAMTS14': ['ADAMTS14',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 14'],
#  'ADAMTS15': ['ADAMTS15',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 15'],
#  'ADAMTS16': ['ADAMTS16s',
#   'ADAMTS16',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 16'],
#  'ADAMTS17': ['FLJ32769',
#   'FLJ16363',
#   'ADAMTS17',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 17'],
#  'ADAMTS18': ['ADAMTS18',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 18'],
#  'ADAMTS19': ['ADAMTS19',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 19'],
#  'ADAMTS19-AS1': ['RP11-346A9.1', 'ADAMTS19-AS1', 'ADAMTS19 antisense RNA 1'],
#  'ADAMTS20': ['GON-1',
#   'ADAMTS20',
#   'ADAM metallopeptidase with thrombospondin type 1 motif 20'],
#  'ADAMTSL1': ['ADAMTSR1', 'FLJ35283', 'ADAMTSL1', 'ADAMTS like 1'],
#  'ADAMTSL2': ['KIAA0605', 'ADAMTSL2', 'ADAMTS like 2'],
#  'ADAMTSL3': ['KIAA1233', 'punctin-2', 'ADAMTSL3', 'ADAMTS like 3'],
#  'ADAMTSL4': ['DKFZP434K1772', 'ADAMTSL4', 'ADAMTS like 4'],
#  'ADAMTSL4-AS1': ['FLJ45786', 'ADAMTSL4-AS1', 'ADAMTSL4 antisense RNA 1'],
#  'ADAMTSL5': ['ADAMTSL5', 'ADAMTS like 5'],
#  'ADAP1': ['GCS1L', 'ADAP1', 'ArfGAP with dual PH domains 1'],
#  'ADAP2': ['ADAP2', 'ArfGAP with dual PH domains 2'],
#  'ADAR': ['ADAR1', 'ADAR', 'adenosine deaminase, RNA-specific'],
#  'ADARB1': ['ADAR2',
#   'DRADA2',
#   'ADAR2g',
#   'DRABA2',
#   'RED1',
#   'hRED1',
#   'ADAR2a-L1',
#   'ADAR2a-L2',
#   'ADAR2a-L3',
#   'ADAR2a',
#   'ADAR2b',
#   'ADAR2c',
#   'ADAR2d',
#   'ADARB1',
#   'adenosine deaminase, RNA specific B1'],
#  'ADARB2': ['RED2',
#   'hRED2',
#   'ADAR3',
#   'ADARB2',
#   'adenosine deaminase, RNA specific B2 (inactive)'],
#  'ADARB2-AS1': ['bA466B20.1', 'ADARB2-AS1', 'ADARB2 antisense RNA 1'],
#  'ADAT1': ['ADAT1', 'adenosine deaminase, tRNA specific 1'],
#  'ADAT2': ['dJ20N2.1',
#   'TAD2',
#   'ADAT2',
#   'adenosine deaminase, tRNA specific 2'],
#  'ADAT3': ['TAD3', 'ADAT3', 'adenosine deaminase, tRNA specific 3'],
#  'ADCK1': ['FLJ39600', 'ADCK1', 'aarF domain containing kinase 1'],
#  'ADCK2': ['MGC20727', 'ADCK2', 'aarF domain containing kinase 2'],
#  'ADCK3': ['COQ8', 'SCAR9', 'ADCK3', 'aarF domain containing kinase 3'],
#  'ADCK4': ['FLJ12229', 'COQ8', 'ADCK4', 'aarF domain containing kinase 4'],
#  'ADCK5': ['FLJ35454', 'ADCK5', 'aarF domain containing kinase 5'],
#  'ADCY1': ['AC1', 'ADCY1', 'adenylate cyclase 1 (brain)'],
#  'ADCY2': ['HBAC2', 'KIAA1060', 'AC2', 'ADCY2', 'adenylate cyclase 2 (brain)'],
#  'ADCY3': ['AC3', 'ADCY3', 'adenylate cyclase 3'],
#  'ADCY4': ['AC4', 'ADCY4', 'adenylate cyclase 4'],
#  'ADCY5': ['AC5', 'ADCY5', 'adenylate cyclase 5'],
#  'ADCY6': ['AC6', 'ADCY6', 'adenylate cyclase 6'],
#  'ADCY7': ['KIAA0037', 'AC7', 'ADCY7', 'adenylate cyclase 7'],
#  'ADCY8': ['HBAC1', 'AC8', 'ADCY8', 'adenylate cyclase 8 (brain)'],
#  'ADCY9': ['AC9', 'ADCY9', 'adenylate cyclase 9'],
#  'ADCY10': ['SAC',
#   'Sacy',
#   'SACI',
#   'HCA2',
#   'RP1-313L4.2',
#   'ADCY10',
#   'adenylate cyclase 10 (soluble)'],
#  'ADCY10P1': ['ADCY10P1', 'adenylate cyclase 10 (soluble) pseudogene 1'],
#  'ADCYAP1': ['PACAP', 'ADCYAP1', 'adenylate cyclase activating polypeptide 1'],
#  'ADCYAP1R1': ['PAC1',
#   'PACAPR',
#   'PAC1R',
#   'ADCYAP1R1',
#   'ADCYAP receptor type I'],
#  'ADD1': ['ADD1', 'adducin 1'],
#  'ADD2': ['ADDB', 'ADD2', 'adducin 2'],
#  'ADD3': ['ADD3', 'adducin 3'],
#  'ADD3-AS1': ['ADD3-AS1', 'ADD3 antisense RNA 1'],
#  'ADGB': ['FLJ23121', 'dJ408K24.1', 'CAPN16', 'ADGB', 'androglobin'],
#  'ADGRA1': ['KIAA1828', 'ADGRA1', 'adhesion G protein-coupled receptor A1'],
#  'ADGRA1-AS1': ['ADGRA1-AS1',
#   'adhesion G protein-coupled receptor A1 antisense RNA 1'],
#  'ADGRA2': ['TEM5',
#   'DKFZp434C211',
#   'DKFZp434J0911',
#   'KIAA1531',
#   'FLJ14390',
#   'ADGRA2',
#   'adhesion G protein-coupled receptor A2'],
#  'ADGRA3': ['FLJ38547',
#   'PGR21',
#   'ADGRA3',
#   'adhesion G protein-coupled receptor A3'],
#  'ADGRB1': ['ADGRB1', 'adhesion G protein-coupled receptor B1'],
#  'ADGRB2': ['ADGRB2', 'adhesion G protein-coupled receptor B2'],
#  'ADGRB3': ['KIAA0550', 'ADGRB3', 'adhesion G protein-coupled receptor B3'],
#  'ADGRD1': ['DKFZp434B1272',
#   'PGR25',
#   'ADGRD1',
#   'adhesion G protein-coupled receptor D1'],
#  'ADGRD2': ['PGR24', 'ADGRD2', 'adhesion G protein-coupled receptor D2'],
#  'ADGRE1': ['ADGRE1', 'adhesion G protein-coupled receptor E1'],
#  'ADGRE2': ['CD312', 'ADGRE2', 'adhesion G protein-coupled receptor E2'],
#  'ADGRE3': ['ADGRE3', 'adhesion G protein-coupled receptor E3'],
#  'ADGRE4P': ['PGR16',
#   'ADGRE4P',
#   'adhesion G protein-coupled receptor E4, pseudogene'],
#  'ADGRE5': ['TM7LN1', 'ADGRE5', 'adhesion G protein-coupled receptor E5'],
#  'ADGRF1': ['hGPCR36',
#   'PGR19',
#   'ADGRF1',
#   'adhesion G protein-coupled receptor F1'],
#  'ADGRF2': ['hGPCR35',
#   'PGR20',
#   'ADGRF2',
#   'adhesion G protein-coupled receptor F2'],
#  'ADGRF3': ['hGPCR37',
#   'PGR23',
#   'ADGRF3',
#   'adhesion G protein-coupled receptor F3'],
#  'ADGRF4': ['FLJ38076',
#   'PGR18',
#   'ADGRF4',
#   'adhesion G protein-coupled receptor F4'],
#  'ADGRF5': ['DKFZp564O1923',
#   'KIAA0758',
#   'ADGRF5',
#   'adhesion G protein-coupled receptor F5'],
#  'ADGRF5P1': ['ADGRF5P1',
#   'adhesion G protein-coupled receptor F5 pseudogene 1'],
#  'ADGRF5P2': ['ADGRF5P2',
#   'adhesion G protein-coupled receptor F5 pseudogene 2'],
#  'ADGRG1': ['TM7LN4',
#   'TM7XN1',
#   'ADGRG1',
#   'adhesion G protein-coupled receptor G1'],
#  'ADGRG2': ['HE6',
#   'TM7LN2',
#   'EDDM6',
#   'ADGRG2',
#   'adhesion G protein-coupled receptor G2'],
#  'ADGRG3': ['Pb99',
#   'PGR26',
#   'ADGRG3',
#   'adhesion G protein-coupled receptor G3'],
#  'ADGRG4': ['RP1-299I16',
#   'PGR17',
#   'ADGRG4',
#   'adhesion G protein-coupled receptor G4'],
#  'ADGRG5': ['PGR27', 'ADGRG5', 'adhesion G protein-coupled receptor G5'],
#  'ADGRG6': ['FLJ14937', 'ADGRG6', 'adhesion G protein-coupled receptor G6'],
#  'ADGRG7': ['FLJ14454', 'ADGRG7', 'adhesion G protein-coupled receptor G7'],
#  'ADGRL1': ['KIAA0821',
#   'CIRL1',
#   'LEC2',
#   'ADGRL1',
#   'adhesion G protein-coupled receptor L1'],
#  'ADGRL2': ['KIAA0786',
#   'LEC1',
#   'ADGRL2',
#   'adhesion G protein-coupled receptor L2'],
#  'ADGRL3': ['KIAA0768',
#   'LEC3',
#   'ADGRL3',
#   'adhesion G protein-coupled receptor L3'],
#  'ADGRL3-AS1': ['ADGRL3-AS1',
#   'adhesion G protein-coupled receptor L3 antisense RNA 1'],
#  'ADGRL4': ['ETL', 'ADGRL4', 'adhesion G protein-coupled receptor L4'],
#  'ADGRV1': ['DKFZp761P0710',
#   'KIAA0686',
#   'FEB4',
#   'VLGR1',
#   'ADGRV1',
#   'adhesion G protein-coupled receptor V1'],
#  'ADH1A': ['ADH1A', 'alcohol dehydrogenase 1A (class I), alpha polypeptide'],
#  'ADH1B': ['ADH1B', 'alcohol dehydrogenase 1B (class I), beta polypeptide'],
#  'ADH1C': ['ADH1C', 'alcohol dehydrogenase 1C (class I), gamma polypeptide'],
#  'ADH4': ['ADH-2',
#   'ADH4',
#   'alcohol dehydrogenase 4 (class II), pi polypeptide'],
#  'ADH5': ['ADH-3',
#   'ADHX',
#   'ADH5',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide'],
#  'ADH5P2': ['ADH5P2',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 2'],
#  'ADH5P3': ['ADH5P3',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 3'],
#  'ADH5P4': ['bA707M13.2',
#   'ADH5P4',
#   'alcohol dehydrogenase 5 (class III), chi polypeptide, pseudogene 4'],
#  'ADH6': ['ADH-5', 'ADH6', 'alcohol dehydrogenase 6 (class V)'],
#  'ADH7': ['ADH-4',
#   'ADH7',
#   'alcohol dehydrogenase 7 (class IV), mu or sigma polypeptide'],
#  'ADHFE1': ['ADHFe1',
#   'FLJ32430',
#   'ADHFE1',
#   'alcohol dehydrogenase, iron containing 1'],
#  'ADI1': ['SIPL',
#   'MTCBP-1',
#   'ARD',
#   'APL1',
#   'FLJ10913',
#   'HMFT1638',
#   'mtnD',
#   'ADI1',
#   'acireductone dioxygenase 1'],
#  'ADIG': ['MGC39724', 'SMAF1', 'RP5-1100H13.2', 'ADIG', 'adipogenin'],
#  'ADIPOQ': ['ACRP30',
#   'AdipoQ',
#   'apM1',
#   'GBP28',
#   'adiponectin',
#   'ADIPOQ',
#   'adiponectin, C1Q and collagen domain containing'],
#  'ADIPOQ-AS1': ['ADIPOQ-AS1', 'ADIPOQ antisense RNA 1'],
#  'ADIPOR1': ['PAQR1', 'ACDCR1', 'ADIPOR1', 'adiponectin receptor 1'],
#  'ADIPOR1P1': ['ADIPOR1P1', 'adiponectin receptor 1 pseudogene 1'],
#  'ADIPOR1P2': ['ADIPOR1P2', 'adiponectin receptor 1 pseudogene 2'],
#  'ADIPOR2': ['PAQR2', 'ACDCR2', 'ADIPOR2', 'adiponectin receptor 2'],
#  'ADIRF': ['APM2', 'AFRO', 'ADIRF', 'adipogenesis regulatory factor'],
#  'ADIRF-AS1': ['ADIRF-AS1', 'ADIRF antisense RNA 1'],
#  'ADK': ['AK', 'ADK', 'adenosine kinase'],
#  'ADM': ['AM', 'ADM', 'adrenomedullin'],
#  'ADM2': ['AM2', 'FLJ21135', 'ADM2', 'adrenomedullin 2'],
#  'ADM5': ['AM5', 'ADM5', 'adrenomedullin 5 (putative)'],
#  'ADNP': ['KIAA0784',
#   'ADNP1',
#   'ADNP',
#   'activity-dependent neuroprotector homeobox'],
#  'ADNP-AS1': ['ADNP-AS1', 'ADNP antisense RNA 1'],
#  'ADNP2': ['KIAA0863', 'ADNP2', 'ADNP homeobox 2'],
#  'ADO': ['FLJ14547', 'ADO', '2-aminoethanethiol (cysteamine) dioxygenase'],
#  'ADORA1': ['RDC7', 'ADORA1', 'adenosine A1 receptor'],
#  'ADORA2A': ['RDC8', 'ADORA2A', 'adenosine A2a receptor'],
#  'ADORA2A-AS1': ['FLJ34651', 'ADORA2A-AS1', 'ADORA2A antisense RNA 1'],
#  'ADORA2B': ['ADORA2B', 'adenosine A2b receptor'],
#  'ADORA2BP1': ['ADORA2BP1', 'adenosine A2b receptor pseudogene 1'],
#  'ADORA3': ['AD026', 'ADORA3', 'adenosine A3 receptor'],
#  'ADPGK': ['DKFZp434B195', 'ADP-GK', 'ADPGK', 'ADP-dependent glucokinase'],
#  'ADPGK-AS1': ['ADPGK-AS1', 'ADPGK antisense RNA 1'],
#  'ADPRH': ['ARH1', 'ADPRH', 'ADP-ribosylarginine hydrolase'],
#  'ADPRHL1': ['ARH2', 'ADPRHL1', 'ADP-ribosylhydrolase like 1'],
#  'ADPRHL2': ['ARH3', 'FLJ20446', 'ADPRHL2', 'ADP-ribosylhydrolase like 2'],
#  'ADPRM': ['MDS006',
#   'ADPRM',
#   'ADP-ribose/CDP-alcohol diphosphatase, manganese dependent'],
#  'ADRA1A': ['ADRA1L1', 'ADRA1A', 'adrenoceptor alpha 1A'],
#  'ADRA1B': ['ADRA1B', 'adrenoceptor alpha 1B'],
#  'ADRA1D': ['ADRA1R', 'ADRA1A', 'ADRA1', 'ADRA1D', 'adrenoceptor alpha 1D'],
#  'ADRA2A': ['ADRAR', 'ADRA2A', 'adrenoceptor alpha 2A'],
#  'ADRA2B': ['ADRARL1', 'ADRA2B', 'adrenoceptor alpha 2B'],
#  'ADRA2C': ['ADRARL2', 'ADRA2C', 'adrenoceptor alpha 2C'],
#  'ADRB1': ['ADRB1', 'adrenoceptor beta 1'],
#  'ADRB2': ['ADRBR', 'BAR', 'B2AR', 'ADRB2', 'adrenoceptor beta 2'],
#  'ADRB3': ['ADRB3', 'adrenoceptor beta 3'],
#  'ADRBK1': ['GRK2', 'BARK1', 'ADRBK1', 'adrenergic, beta, receptor kinase 1'],
#  'ADRBK2': ['GRK3', 'BARK2', 'ADRBK2', 'adrenergic, beta, receptor kinase 2'],
#  'ADRM1': ['GP110',
#   'Rpn13',
#   'ARM1',
#   'ADRM1',
#   'adhesion regulating molecule 1'],
#  'ADSL': ['ADSL', 'adenylosuccinate lyase'],
#  'ADSS': ['ADSS', 'adenylosuccinate synthase'],
#  'ADSSL1': ['FLJ38602', 'ADSSL1', 'adenylosuccinate synthase like 1'],
#  'ADTRP': ['dJ413H6.1',
#   'AIG1L',
#   'ADTRP',
#   'androgen dependent TFPI regulating protein'],
#  'AEBP1': ['ACLP', 'AEBP1', 'AE binding protein 1'],
#  'AEBP2': ['MGC17922', 'AEBP2', 'AE binding protein 2'],
#  'AEN': ['FLJ12484', 'FLJ12562', 'AEN', 'apoptosis enhancing nuclease'],
#  'AES': ['GRG5', 'TLE5', 'AES', 'amino-terminal enhancer of split'],
#  'AFAP1': ['AFAP-110', 'AFAP', 'AFAP1', 'actin filament associated protein 1'],
#  'AFAP1-AS1': ['MGC10981', 'AFAP1-AS1', 'AFAP1 antisense RNA 1'],
#  'AFAP1L1': ['FLJ36748',
#   'AFAP1L1',
#   'actin filament associated protein 1 like 1'],
#  'AFAP1L2': ['FLJ14564',
#   'Em:AC005383.4',
#   'XB130',
#   'AFAP1L2',
#   'actin filament associated protein 1 like 2'],
#  'AFF1': ['AF-4', 'AF4', 'AFF1', 'AF4/FMR2 family member 1'],
#  'AFF2': ['FRAXE', 'AFF2', 'AF4/FMR2 family member 2'],
#  'AFF2-IT1': ['AFF2-IT1', 'AFF2 intronic transcript 1'],
#  'AFF3': ['MLLT2-like', 'AFF3', 'AF4/FMR2 family member 3'],
#  'AFF4': ['AF5Q31', 'MCEF', 'AFF4', 'AF4/FMR2 family member 4'],
#  'AFG3L1P': ['AFG3L1P',
#   'AFG3 like matrix AAA peptidase subunit 1, pseudogene'],
#  'AFG3L2': ['SPAX5', 'AFG3L2', 'AFG3 like matrix AAA peptidase subunit 2'],
#  'AFG3L2P1': ['AFG3L2P1', 'AFG3 like AAA ATPase 2 pseudogene 1'],
#  'AFM': ['ALB2', 'ALBA', 'AFM', 'afamin'],
#  'AFMID': ['DKFZp686F03259', 'KF', 'AFMID', 'arylformamidase'],
#  'AFP': ['FETA', 'AFP', 'alpha fetoprotein'],
#  'AFTPH': ['MGC33965',
#   'FLJ20080',
#   'FLJ23793',
#   'Nbla10388',
#   'AFTPH',
#   'aftiphilin'],
#  'AGA': ['ASRG', 'AGA', 'aspartylglucosaminidase'],
#  'AGAP1': ['KIAA1099',
#   'GGAP1',
#   'AGAP1',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 1'],
#  'AGAP1-IT1': ['AGAP1-IT1', 'AGAP1 intronic transcript 1'],
#  'AGAP2': ['AGAP2',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 2'],
#  'AGAP2-AS1': ['LOC100130776',
#   'PUNISHER',
#   'AGAP2-AS1',
#   'AGAP2 antisense RNA 1'],
#  'AGAP3': ['AGAP3',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 3'],
#  'AGAP4': ['Em:AC012044.1',
#   'MRIP2',
#   'AGAP4',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 4'],
#  'AGAP5': ['Em:AC073389.1',
#   'AGAP5',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 5'],
#  'AGAP6': ['bA324H6.1',
#   'AGAP6',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 6'],
#  'AGAP7P': ['bA109G10.1',
#   'AGAP7P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 7, pseudogene'],
#  'AGAP9': ['bA301J7.2',
#   'FLJ00312',
#   'AGAP9',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 9'],
#  'AGAP10P': ['bA358L16.1',
#   'bA144G6.2',
#   'AGAP10P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 10 pseudogene'],
#  'AGAP11': ['KIAA1975',
#   'AGAP11',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 11'],
#  'AGAP12P': ['bA164N7.2',
#   'AGAP12P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 12, pseudogene'],
#  'AGAP13P': ['bA548K23.1',
#   'AGAP13P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 13, pseudogene'],
#  'AGAP14P': ['bA145E20.1',
#   'AGAP14P',
#   'ArfGAP with GTPase domain, ankyrin repeat and PH domain 14, pseudogene'],
#  'AGBL1': ['FLJ32310', 'CCP4', 'AGBL1', 'ATP/GTP binding protein-like 1'],
#  'AGBL1-AS1': ['AGBL1-AS1', 'AGBL1 antisense RNA 1'],
#  'AGBL2': ['FLJ23598', 'CCP2', 'AGBL2', 'ATP/GTP binding protein-like 2'],
#  'AGBL3': ['MGC32955', 'CCP3', 'AGBL3', 'ATP/GTP binding protein-like 3'],
#  'AGBL4': ['FLJ14442', 'CCP6', 'AGBL4', 'ATP/GTP binding protein-like 4'],
#  'AGBL4-IT1': ['AGBL4-IT1', 'AGBL4 intronic transcript 1'],
#  'AGBL5': ['FLJ21839', 'CCP5', 'AGBL5', 'ATP/GTP binding protein-like 5'],
#  'AGBL5-AS1': ['AGBL5-AS1', 'AGBL5 antisense RNA 1'],
#  'AGBL5-IT1': ['AGBL5-IT1', 'AGBL5 intronic transcript 1'],
#  'AGER': ['RAGE',
#   'AGER',
#   'advanced glycosylation end product-specific receptor'],
#  'AGFG1': ['RIP', 'RAB', 'AGFG1', 'ArfGAP with FG repeats 1'],
#  'AGFG2': ['RABR', 'AGFG2', 'ArfGAP with FG repeats 2'],
#  'AGGF1': ['VG5Q',
#   'HSU84971',
#   'FLJ10283',
#   'GPATC7',
#   'GPATCH7',
#   'AGGF1',
#   'angiogenic factor with G-patch and FHA domains 1'],
#  'AGGF1P1': ['AGGF1P1',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 1'],
#  'AGGF1P2': ['AGGF1P2',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 2'],
#  'AGGF1P3': ['AGGF1P3',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 3'],
#  'AGGF1P4': ['AGGF1P4',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 4'],
#  'AGGF1P5': ['AGGF1P5',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 5'],
#  'AGGF1P6': ['AGGF1P6',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 6'],
#  'AGGF1P7': ['AGGF1P7',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 7'],
#  'AGGF1P8': ['AGGF1P8',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 8'],
#  'AGGF1P9': ['AGGF1P9',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 9'],
#  'AGGF1P10': ['AGGF1P10',
#   'angiogenic factor with G-patch and FHA domains 1 pseudogene 10'],
#  'AGK': ['FLJ10842', 'AGK', 'acylglycerol kinase'],
#  'AGKP1': ['AGKY1', 'AGKP1', 'acylglycerol kinase pseudogene 1'],
#  'AGL': ['AGL', 'amylo-alpha-1, 6-glucosidase, 4-alpha-glucanotransferase'],
#  'AGMAT': ['FLJ23384', 'AGMAT', 'agmatinase'],
#  'AGMO': ['FLJ16237', 'AGMO', 'alkylglycerol monooxygenase'],
#  'AGO1': ['hAGO1', 'AGO1', 'argonaute 1, RISC catalytic component'],
#  'AGO2': ['hAGO2', 'Q10', 'AGO2', 'argonaute 2, RISC catalytic component'],
#  'AGO3': ['hAGO3',
#   'FLJ12765',
#   'AGO3',
#   'argonaute 3, RISC catalytic component'],
#  'AGO4': ['hAGO4',
#   'KIAA1567',
#   'FLJ20033',
#   'AGO4',
#   'argonaute 4, RISC catalytic component'],
#  'AGPAT1': ['LPAAT-alpha',
#   'AGPAT1',
#   '1-acylglycerol-3-phosphate O-acyltransferase 1'],
#  'AGPAT2': ['LPAAT-beta',
#   'AGPAT2',
#   '1-acylglycerol-3-phosphate O-acyltransferase 2'],
#  'AGPAT3': ['LPAAT-gamma',
#   'AGPAT3',
#   '1-acylglycerol-3-phosphate O-acyltransferase 3'],
#  'AGPAT4': ['LPAAT-delta',
#   'dJ473J16.2',
#   'AGPAT4',
#   '1-acylglycerol-3-phosphate O-acyltransferase 4'],
#  'AGPAT4-IT1': ['FLJ23112', 'AGPAT4-IT1', 'AGPAT4 intronic transcript 1'],
#  'AGPAT5': ['FLJ11210',
#   'LPAAT-e',
#   'LPAAT-epsilon',
#   'AGPAT5',
#   '1-acylglycerol-3-phosphate O-acyltransferase 5'],
#  'AGPAT5P1': ['AGPAT5P1',
#   '1-acylglycerol-3-phosphate O-acyltransferase 5 pseudogene 1'],
#  'AGPS': ['ADHAPS',
#   'ADAS',
#   'ALDHPSY',
#   'ADPS',
#   'ADAP-S',
#   'AGPS',
#   'alkylglycerone phosphate synthase'],
#  'AGR2': ['XAG-2',
#   'HAG-2',
#   'AG2',
#   'PDIA17',
#   'AGR2',
#   'anterior gradient 2, protein disulphide isomerase family member'],
#  'AGR3': ['HAG3',
#   'hAG-3',
#   'BCMP11',
#   'PDIA18',
#   'AGR3',
#   'anterior gradient 3, protein disulphide isomerase family member'],
#  'AGRN': ['AGRIN', 'AGRN', 'agrin'],
#  'AGRP': ['Agrt', 'ART', 'ASIP2', 'AGRP', 'agouti related neuropeptide'],
#  'AGT': ['AGT', 'angiotensinogen'],
#  'AGTPBP1': ['KIAA1035',
#   'Nna1',
#   'CCP1',
#   'AGTPBP1',
#   'ATP/GTP binding protein 1'],
#  'AGTR1': ['AT1',
#   'AT2R1',
#   'AGTR1A',
#   'AT2R1A',
#   'HAT1R',
#   'AG2S',
#   'AT2R1B',
#   'AT1B',
#   'AGTR1',
#   'angiotensin II receptor type 1'],
#  'AGTR2': ['AT2', 'MRX88', 'AGTR2', 'angiotensin II receptor type 2'],
#  'AGTRAP': ['ATRAP', 'AGTRAP', 'angiotensin II receptor associated protein'],
#  'AGXT': ['AGXT1',
#   'PH1',
#   'AGT',
#   'SPT',
#   'AGT1',
#   'AGXT',
#   'alanine-glyoxylate aminotransferase'],
#  'AGXT2': ['AGT2', 'AGXT2', 'alanine--glyoxylate aminotransferase 2'],
#  'AHCTF1': ['ELYS', 'AHCTF1', 'AT-hook containing transcription factor 1'],
#  'AHCY': ['SAHH', 'AHCY', 'adenosylhomocysteinase'],
#  'AHCYL1': ['XPVKONA',
#   'IRBIT',
#   'PPP1R78',
#   'AHCYL1',
#   'adenosylhomocysteinase like 1'],
# ...
#  'ALG9': ['ALG9', 'ALG9, alpha-1,2-mannosyltransferase'],
#  'ALG9-IT1': ['ALG9-IT1', 'ALG9 intronic transcript 1'],
#  'ALG10': ['FLJ14751',
#   'DIE2',
#   'ALG10A',
#   'ALG10',
#   'ALG10, alpha-1,2-glucosyltransferase'],
#  'ALG10B': ['KCR1', 'ALG10B', 'ALG10B, alpha-1,2-glucosyltransferase'],
#  'ALG11': ['KIAA0266', 'ALG11', 'ALG11, alpha-1,2-mannosyltransferase'],
#  'ALG12': ['ECM39', 'ALG12', 'ALG12, alpha-1,6-mannosyltransferase'],
#  'ALG13': ['MDS031',
#   'YGL047W',
#   'FLJ23018',
#   'TDRD13',
#   'ALG13',
#   'ALG13, UDP-N-acetylglucosaminyltransferase subunit'],
#  'ALG13-AS1': ['ALG13-AS1', 'ALG13 antisense RNA 1'],
#  'ALG14': ['MGC19780',
#   'ALG14',
#   'ALG14, UDP-N-acetylglucosaminyltransferase subunit'],
#  'ALK': ['CD246', 'ALK', 'anaplastic lymphoma receptor tyrosine kinase'],
#  'ALKBH1': ['hABH',
#   'alkB',
#   'ABH',
#   'ALKBH1',
#   'alkB homolog 1, histone H2A dioxygenase'],
#  'ALKBH2': ['MGC90512',
#   'ABH2',
#   'ALKBH2',
#   'alkB homolog 2, alpha-ketoglutarate-dependent dioxygenase'],
#  'ALKBH3': ['DEPC-1',
#   'ALKBH3',
#   'alkB homolog 3, alpha-ketoglutarate-dependent dioxygenase'],
#  'ALKBH3-AS1': ['ALKBH3-AS1', 'ALKBH3 antisense RNA 1'],
#  'ALKBH4': ['FLJ20013', 'ALKBH4', 'alkB homolog 4, lysine demethylase'],
#  'ALKBH5': ['FLJ20308', 'ALKBH5', 'alkB homolog 5, RNA demethylase'],
#  'ALKBH6': ['MGC15677', 'ALKBH6', 'alkB homolog 6'],
#  'ALKBH7': ['MGC10974', 'ALKBH7', 'alkB homolog 7'],
#  'ALKBH8': ['MGC10235',
#   'TRM9',
#   'TRMT9',
#   'ALKBH8',
#   'alkB homolog 8, tRNA methyltransferase'],
#  'ALLC': ['ALC', 'ALLC', 'allantoicase'],
#  'ALMS1': ['KIAA0328',
#   'ALMS1',
#   'ALMS1, centrosome and basal body associated protein'],
#  'ALMS1-IT1': ['ALMS1-IT1', 'ALMS1 intronic transcript 1'],
#  'ALMS1P1': ['ALMS1P1',
#   'ALMS1, centrosome and basal body associated protein pseudogene 1'],
#  'ALOX5': ['5-LOX', 'ALOX5', 'arachidonate 5-lipoxygenase'],
#  'ALOX5AP': ['FLAP',
#   'ALOX5AP',
#   'arachidonate 5-lipoxygenase activating protein'],
#  'ALOX12': ['12S-LOX', 'ALOX12', 'arachidonate 12-lipoxygenase'],
#  'ALOX12-AS1': ['ALOX12-AS1', 'ALOX12 antisense RNA 1'],
#  'ALOX12B': ['12R-LOX', 'ALOX12B', 'arachidonate 12-lipoxygenase, 12R type'],
#  'ALOX12P1': ['ALOX12P1', 'arachidonate 12-lipoxygenase pseudogene 1'],
#  'ALOX12P2': ['ALOX12P2', 'arachidonate 12-lipoxygenase pseudogene 2'],
#  'ALOX15': ['15-LOX-1', 'ALOX15', 'arachidonate 15-lipoxygenase'],
#  'ALOX15B': ['15-LOX-2', 'ALOX15B', 'arachidonate 15-lipoxygenase, type B'],
#  'ALOX15P2': ['ALOX15P2', 'arachidonate 15-lipoxygenase pseudogene 2'],
#  'ALOXE3': ['eLOX3', 'E-LOX', 'ALOXE3', 'arachidonate lipoxygenase 3'],
#  'ALPI': ['ALPI', 'alkaline phosphatase, intestinal'],
#  'ALPK1': ['Lak', 'FLJ22670', 'KIAA1527', 'ALPK1', 'alpha kinase 1'],
#  'ALPK2': ['HAK', 'ALPK2', 'alpha kinase 2'],
#  'ALPK3': ['MAK', 'KIAA1330', 'Midori', 'ALPK3', 'alpha kinase 3'],
#  'ALPL': ['TNSALP', 'ALPL', 'alkaline phosphatase, liver/bone/kidney'],
#  'ALPP': ['ALPP', 'alkaline phosphatase, placental'],
#  'ALPPL2': ['ALPPL2', 'alkaline phosphatase, placental like 2'],
#  'ALS2': ['ALS2', 'ALS2, alsin Rho guanine nucleotide exchange factor'],
#  'ALS2CL': ['FLJ36525',
#   'RN49018',
#   'DKFZp686I0110',
#   'ALS2CL',
#   'ALS2 C-terminal like'],
#  'ALS2CR11': ['FLJ25351',
#   'ALS2CR11',
#   'amyotrophic lateral sclerosis 2 chromosome region candidate 11'],
#  'ALS2CR12': ['ALS2CR12',
#   'amyotrophic lateral sclerosis 2 chromosome region candidate 12'],
#  'ALX1': ['ALX1', 'ALX homeobox 1'],
#  'ALX3': ['ALX3', 'ALX homeobox 3'],
#  'ALX4': ['FPP', 'PFM', 'KIAA1788', 'ALX4', 'ALX homeobox 4'],
#  'ALYREF': ['ALY', 'BEF', 'ALY/REF', 'REF', 'ALYREF', 'Aly/REF export factor'],
#  'AMACR': ['RACE', 'AMACR', 'alpha-methylacyl-CoA racemase'],
#  'AMBN': ['AMBN', 'ameloblastin'],
#  'AMBP': ['UTI',
#   'HCP',
#   'EDC1',
#   'HI30',
#   'IATIL',
#   'ITILC',
#   'AMBP',
#   'alpha-1-microglobulin/bikunin precursor'],
#  'AMBRA1': ['FLJ20294',
#   'KIAA1736',
#   'WDR94',
#   'DCAF3',
#   'AMBRA1',
#   'autophagy/beclin-1 regulator 1'],
#  'AMD1': ['SAMDC', 'AMD1', 'adenosylmethionine decarboxylase 1'],
#  'AMD1P1': ['AMD1P1', 'adenosylmethionine decarboxylase 1 pseudogene 1'],
#  'AMD1P2': ['AMDPX',
#   'AMDPY',
#   'AMD1P2',
#   'adenosylmethionine decarboxylase 1 pseudogene 2'],
#  'AMD1P3': ['AMD1P3', 'adenosylmethionine decarboxylase 1 pseudogene 3'],
#  'AMD1P4': ['AMD1P4', 'adenosylmethionine decarboxylase 1 pseudogene 4'],
#  'AMDHD1': ['MGC35366', 'AMDHD1', 'amidohydrolase domain containing 1'],
#  'AMDHD2': ['CGI-14', 'AMDHD2', 'amidohydrolase domain containing 2'],
#  'AMELX': ['AMELX', 'amelogenin, X-linked'],
#  'AMELY': ['AMELY', 'amelogenin, Y-linked'],
#  'AMER1': ['RP11-403E24.2',
#   'FLJ39827',
#   'WTX',
#   'AMER1',
#   'APC membrane recruitment protein 1'],
#  'AMER2': ['FLJ25477', 'AMER2', 'APC membrane recruitment protein 2'],
#  'AMER3': ['FLJ38377', 'AMER3', 'APC membrane recruitment protein 3'],
#  'AMFR': ['RNF45', 'gp78', 'AMFR', 'autocrine motility factor receptor'],
#  'AMH': ['MIS', 'AMH', 'anti-Mullerian hormone'],
#  'AMHR2': ['MISR2',
#   'MISRII',
#   'AMHR2',
#   'anti-Mullerian hormone receptor type II'],
#  'AMIGO1': ['AMIGO',
#   'KIAA1163',
#   'AMIGO1',
#   'adhesion molecule with Ig-like domain 1'],
#  'AMIGO2': ['ALI1',
#   'DEGA',
#   'AMIGO2',
#   'adhesion molecule with Ig-like domain 2'],
#  'AMIGO3': ['AMIGO3', 'adhesion molecule with Ig-like domain 3'],
#  'AMMECR1': ['AMMECR1',
#   'Alport syndrome, mental retardation, midface hypoplasia and elliptocytosis chromosomal region gene 1'],
#  'AMMECR1-IT1': ['AMMECR1-IT1', 'AMMECR1 intronic transcript 1'],
#  'AMMECR1L': ['MGC4268', 'AMMECR1L', 'AMMECR1 like'],
#  'AMMECR1LP1': ['AMMECR1LP1', 'AMMECR1 like pseudogene 1'],
#  'AMN': ['amnionless', 'AMN', 'amnion associated transmembrane protein'],
#  'AMN1': ['AMN1', 'antagonist of mitotic exit network 1 homolog'],
#  'AMOT': ['KIAA1071', 'AMOT', 'angiomotin'],
#  'AMOTL1': ['JEAP', 'AMOTL1', 'angiomotin like 1'],
#  'AMOTL2': ['LCCP', 'AMOTL2', 'angiomotin like 2'],
#  'AMPD1': ['MAD', 'MADA', 'AMPD1', 'adenosine monophosphate deaminase 1'],
#  'AMPD2': ['SPG63', 'AMPD2', 'adenosine monophosphate deaminase 2'],
#  'AMPD3': ['AMPD3', 'adenosine monophosphate deaminase 3'],
#  'AMPH': ['AMPH', 'amphiphysin'],
#  'AMT': ['GCST', 'NKH', 'AMT', 'aminomethyltransferase'],
#  'AMTN': ['UNQ689', 'RSTI689', 'AMTN', 'amelotin'],
#  'AMY1A': ['AMY1A', 'amylase, alpha 1A (salivary)'],
#  'AMY1B': ['AMY1B', 'amylase, alpha 1B (salivary)'],
#  'AMY1C': ['AMY1C', 'amylase, alpha 1C (salivary)'],
#  'AMY2A': ['AMY2A', 'amylase, alpha 2A (pancreatic)'],
#  'AMY2B': ['AMY2B', 'amylase, alpha 2B (pancreatic)'],
#  'AMYP1': ['AMYP1', 'amylase, alpha pseudogene 1'],
#  'AMZ1': ['KIAA1950', 'AMZ1', 'archaelysin family metallopeptidase 1'],
#  'AMZ2': ['AMZ2', 'archaelysin family metallopeptidase 2'],
#  'AMZ2P1': ['FLJ32065',
#   'AMZ2P1',
#   'archaelysin family metallopeptidase 2 pseudogene 1'],
#  'AMZ2P2': ['AMZ2P2', 'archaelysin family metallopeptidase 2 pseudogene 2'],
#  'ANAPC1': ['MCPR',
#   'TSG24',
#   'APC1',
#   'ANAPC1',
#   'anaphase promoting complex subunit 1'],
#  'ANAPC1P1': ['ANAPC1P1', 'anaphase promoting complex subunit 1 pseudogene 1'],
#  'ANAPC2': ['APC2',
#   'KIAA1406',
#   'ANAPC2',
#   'anaphase promoting complex subunit 2'],
#  'ANAPC4': ['APC4', 'ANAPC4', 'anaphase promoting complex subunit 4'],
#  'ANAPC5': ['APC5', 'ANAPC5', 'anaphase promoting complex subunit 5'],
#  'ANAPC7': ['APC7', 'ANAPC7', 'anaphase promoting complex subunit 7'],
#  'ANAPC10': ['APC10',
#   'DOC1',
#   'DKFZP564L0562',
#   'ANAPC10',
#   'anaphase promoting complex subunit 10'],
#  'ANAPC10P1': ['ANAPC10P1',
#   'anaphase promoting complex subunit 10 pseudogene 1'],
#  'ANAPC11': ['HSPC214',
#   'APC11',
#   'Apc11p',
#   'MGC882',
#   'ANAPC11',
#   'anaphase promoting complex subunit 11'],
#  'ANAPC13': ['SWM1',
#   'APC13',
#   'DKFZP566D193',
#   'ANAPC13',
#   'anaphase promoting complex subunit 13'],
#  'ANAPC15': ['HSPC020',
#   'DKFZP564M082',
#   'APC15',
#   'ANAPC15',
#   'anaphase promoting complex subunit 15'],
#  'ANAPC16': ['bA570G20.3',
#   'FLJ33728',
#   'APC16',
#   'CENP-27',
#   'ANAPC16',
#   'anaphase promoting complex subunit 16'],
#  'ANG': ['RNASE5',
#   'RAA1',
#   'ANG',
#   'angiogenin, ribonuclease, RNase A family, 5'],
#  'ANGEL1': ['Ccr4e', 'ANGEL1', 'angel homolog 1 (Drosophila)'],
#  'ANGEL2': ['KIAA0759L',
#   'FLJ12793',
#   'Ccr4d',
#   'ANGEL2',
#   'angel homolog 2 (Drosophila)'],
#  'ANGPT1': ['KIAA0003', 'Ang1', 'ANGPT1', 'angiopoietin 1'],
#  'ANGPT2': ['Ang2', 'ANGPT2', 'angiopoietin 2'],
#  'ANGPT4': ['ANGPT4', 'angiopoietin 4'],
#  'ANGPTL1': ['ANG3', 'AngY', 'ARP1', 'ANGPTL1', 'angiopoietin like 1'],
#  'ANGPTL2': ['ARP2', 'HARP', 'ANGPTL2', 'angiopoietin like 2'],
#  'ANGPTL3': ['ANGPTL3', 'angiopoietin like 3'],
#  'ANGPTL4': ['pp1158',
#   'PGAR',
#   'ARP4',
#   'HFARP',
#   'FIAF',
#   'NL2',
#   'ANGPTL4',
#   'angiopoietin like 4'],
#  'ANGPTL5': ['ANGPTL5', 'angiopoietin like 5'],
#  'ANGPTL6': ['ARP5', 'AGF', 'ANGPTL6', 'angiopoietin like 6'],
#  'ANGPTL7': ['CDT6', 'AngX', 'ANGPTL7', 'angiopoietin like 7'],
#  'ANGPTL8': ['TD26', 'RIFL', 'ANGPTL8', 'angiopoietin like 8'],
#  'ANHX': ['ANHX', 'anomalous homeobox'],
#  'ANK1': ['SPH1', 'ANK1', 'ankyrin 1'],
#  'ANK2': ['ANK2', 'ankyrin 2, neuronal'],
#  'ANK3': ['ANK3', 'ankyrin 3, node of Ranvier (ankyrin G)'],
#  'ANKAR': ['FLJ25415', 'ANKAR', 'ankyrin and armadillo repeat containing'],
#  'ANKDD1A': ['FLJ25870',
#   'ANKDD1A',
#   'ankyrin repeat and death domain containing 1A'],
#  'ANKDD1B': ['ANKDD1B', 'ankyrin repeat and death domain containing 1B'],
#  'ANKEF1': ['FLJ21669',
#   'dJ839B4.6',
#   'ANKEF1',
#   'ankyrin repeat and EF-hand domain containing 1'],
#  'ANKFN1': ['FLJ38335',
#   'ANKFN1',
#   'ankyrin repeat and fibronectin type III domain containing 1'],
#  'ANKFY1': ['ANKHZN',
#   'KIAA1255',
#   'ZFYVE14',
#   'BTBD23',
#   'RANK-5',
#   'ANKFY1',
#   'ankyrin repeat and FYVE domain containing 1'],
#  'ANKH': ['HANK',
#   'ANK',
#   'CPPDD',
#   'ANKH',
#   'ANKH inorganic pyrophosphate transport regulator'],
#  'ANKHD1': ['MASK',
#   'FLJ20288',
#   'FLJ11979',
#   'FLJ10042',
#   'FLJ14127',
#   'KIAA1085',
#   'MASK1',
#   'ANKHD1',
#   'ankyrin repeat and KH domain containing 1'],
#  'ANKHD1-EIF4EBP3': ['MASK-BP3',
#   'ANKHD1-EIF4EBP3',
#   'ANKHD1-EIF4EBP3 readthrough'],
#  'ANKIB1': ['DKFZP434A0225',
#   'KIAA1386',
#   'ANKIB1',
#   'ankyrin repeat and IBR domain containing 1'],
#  'ANKK1': ['X-kinase',
#   'ANKK1',
#   'ankyrin repeat and kinase domain containing 1'],
#  'ANKLE1': ['FLJ39369',
#   'LEMD6',
#   'ANKLE1',
#   'ankyrin repeat and LEM domain containing 1'],
#  'ANKLE2': ['LEMD7',
#   'Lem4',
#   'ANKLE2',
#   'ankyrin repeat and LEM domain containing 2'],
#  'ANKMY1': ['FLJ20499',
#   'ZMYND13',
#   'ANKMY1',
#   'ankyrin repeat and MYND domain containing 1'],
#  'ANKMY2': ['DKFZP564O043',
#   'ZMYND20',
#   'ANKMY2',
#   'ankyrin repeat and MYND domain containing 2'],
#  'ANKRA2': ['ANKRA2', 'ankyrin repeat family A member 2'],
#  'ANKRD1': ['C-193',
#   'ALRP',
#   'CARP',
#   'CVARP',
#   'MCARP',
#   'ANKRD1',
#   'ankyrin repeat domain 1'],
#  'ANKRD2': ['ARPP', 'ANKRD2', 'ankyrin repeat domain 2'],
#  'ANKRD6': ['KIAA0957', 'ANKRD6', 'ankyrin repeat domain 6'],
#  'ANKRD7': ['TSA806', 'ANKRD7', 'ankyrin repeat domain 7'],
#  'ANKRD9': ['ANKRD9', 'ankyrin repeat domain 9'],
#  'ANKRD10': ['FLJ20093', 'ANKRD10', 'ankyrin repeat domain 10'],
#  'ANKRD10-IT1': ['ANKRD10-IT1', 'ANKRD10 intronic transcript 1'],
#  'ANKRD11': ['LZ16', 'T13', 'ANKRD11', 'ankyrin repeat domain 11'],
#  'ANKRD12': ['KIAA0874',
#   'FLJ20053',
#   'GAC-1',
#   'ANKRD12',
#   'ankyrin repeat domain 12'],
#  'ANKRD13A': ['NY-REN-25', 'ANKRD13A', 'ankyrin repeat domain 13A'],
#  'ANKRD13B': ['FLJ25555', 'ANKRD13B', 'ankyrin repeat domain 13B'],
#  'ANKRD13C': ['DKFZP566D1346',
#   'dJ677H15.3',
#   'ANKRD13C',
#   'ankyrin repeat domain 13C'],
#  'ANKRD13D': ['ANKRD13D', 'ankyrin repeat domain 13 family member D'],
#  'ANKRD16': ['DKFZP434N1511', 'ANKRD16', 'ankyrin repeat domain 16'],
#  'ANKRD17': ['GTAR',
#   'KIAA0697',
#   'FLJ22206',
#   'NY-BR-16',
#   'MASK2',
#   'ANKRD17',
#   'ankyrin repeat domain 17'],
#  'ANKRD18A': ['KIAA2015', 'FLJ35740', 'ANKRD18A', 'ankyrin repeat domain 18A'],
#  'ANKRD18B': ['bA255A11.3', 'ANKRD18B', 'ankyrin repeat domain 18B'],
#  'ANKRD18CP': ['ANKRD18CP', 'ankyrin repeat domain 18C, pseudogene'],
#  'ANKRD18DP': ['ANKRD18DP', 'ankyrin repeat domain 18D, pseudogene'],
#  'ANKRD18EP': ['ANKRD18EP', 'ankyrin repeat domain 18E, pseudogene'],
#  'ANKRD19P': ['FLJ36178', 'ANKRD19P', 'ankyrin repeat domain 19, pseudogene'],
#  'ANKRD20A1': ['DKFZp434A171',
#   'ANKRD20A1',
#   'ankyrin repeat domain 20 family member A1'],
#  'ANKRD20A2': ['ANKRD20A2', 'ankyrin repeat domain 20 family member A2'],
#  'ANKRD20A3': ['ANKRD20A3', 'ankyrin repeat domain 20 family member A3'],
#  'ANKRD20A4': ['OTTHUMG00000066855',
#   'ANKRD20A4',
#   'ankyrin repeat domain 20 family member A4'],
#  'ANKRD20A5P': ['MGC26718',
#   'ANKRD20A5P',
#   'ankyrin repeat domain 20 family member A5, pseudogene'],
#  'ANKRD20A7P': ['ANKRD20A7P',
#   'ankyrin repeat domain 20 family member A7, pseudogene'],
#  'ANKRD20A8P': ['ANKRD20A8P',
#   'ankyrin repeat domain 20 family member A8, pseudogene'],
#  'ANKRD20A9P': ['ANKRD20A9P',
#   'ankyrin repeat domain 20 family member A9, pseudogene'],
#  'ANKRD20A10P': ['ANKRD20A10P',
#   'ankyrin repeat domain 20 family member A10, pseudogene'],
#  'ANKRD20A11P': ['ANKRD20A11P',
#   'ankyrin repeat domain 20 family member A11, pseudogene'],
#  'ANKRD20A17P': ['ANKRD20A17P',
#   'ankyrin repeat domain 20 family member A17, pseudogene'],
#  'ANKRD20A18P': ['ANKRD20A18P',
#   'ankyrin repeat domain 20 family member A18, pseudogene'],
#  'ANKRD20A19P': ['ANKRD20A19P',
#   'ankyrin repeat domain 20 family member A19, pseudogene'],
#  'ANKRD22': ['MGC22805', 'ANKRD22', 'ankyrin repeat domain 22'],
#  'ANKRD23': ['DARP',
#   'FLJ32449',
#   'MARP3',
#   'ANKRD23',
#   'ankyrin repeat domain 23'],
#  'ANKRD24': ['KIAA1981', 'ANKRD24', 'ankyrin repeat domain 24'],
#  'ANKRD26': ['KIAA1074', 'ANKRD26', 'ankyrin repeat domain 26'],
#  'ANKRD26P1': ['FLJ43980',
#   'ANKRD26P1',
#   'ankyrin repeat domain 26 pseudogene 1'],
#  'ANKRD26P2': ['ANKRD26P2', 'ankyrin repeat domain 26 pseudogene 2'],
#  'ANKRD26P3': ['ANKRD26P3', 'ankyrin repeat domain 26 pseudogene 3'],
#  'ANKRD26P4': ['ANKRD26P4', 'ankyrin repeat domain 26 pseudogene 4'],
#  'ANKRD27': ['FLJ00040',
#   'DKFZp434L0718',
#   'VARP',
#   'ANKRD27',
#   'ankyrin repeat domain 27'],
#  'ANKRD28': ['KIAA0379',
#   'PITK',
#   'PP6-ARS-A',
#   'PPP1R65',
#   'ANKRD28',
#   'ankyrin repeat domain 28'],
#  'ANKRD29': ['FLJ25053', 'ANKRD29', 'ankyrin repeat domain 29'],
#  'ANKRD30A': ['NY-BR-1', 'ANKRD30A', 'ankyrin repeat domain 30A'],
#  'ANKRD30B': ['NY-BR-1.1', 'ANKRD30B', 'ankyrin repeat domain 30B'],
#  'ANKRD30BL': ['ANKRD30BL', 'ankyrin repeat domain 30B-like'],
#  'ANKRD30BP1': ['PRED4',
#   'ANKRD30BP1',
#   'ankyrin repeat domain 30B pseudogene 1'],
#  'ANKRD30BP2': ['CT85',
#   'CTSP-1',
#   'ANKRD30BP2',
#   'ankyrin repeat domain 30B pseudogene 2'],
#  'ANKRD30BP3': ['ANKRD30BP3', 'ankyrin repeat domain 30B pseudogene 3'],
#  'ANKRD31': ['FLJ40191', 'ANKRD31', 'ankyrin repeat domain 31'],
#  'ANKRD33': ['DKFZp686O1689', 'PANKY', 'ANKRD33', 'ankyrin repeat domain 33'],
#  'ANKRD33B': ['ANKRD33B', 'ankyrin repeat domain 33B'],
#  'ANKRD33B-AS1': ['ANKRD33B-AS1', 'ANKRD33B antisense RNA 1'],
#  'ANKRD34A': ['ANKRD34A', 'ankyrin repeat domain 34A'],
#  'ANKRD34B': ['DP58', 'ANKRD34B', 'ankyrin repeat domain 34B'],
#  'ANKRD34C': ['ANKRD34C', 'ankyrin repeat domain 34C'],
#  'ANKRD34C-AS1': ['ANKRD34C-AS1', 'ANKRD34C antisense RNA 1'],
#  'ANKRD35': ['FLJ25124', 'ANKRD35', 'ankyrin repeat domain 35'],
#  'ANKRD36': ['UNQ2430', 'ANKRD36', 'ankyrin repeat domain 36'],
#  'ANKRD36B': ['FLJ21281', 'ANKRD36B', 'ankyrin repeat domain 36B'],
#  'ANKRD36BP1': ['MGC12538',
#   'ANKRD36BP1',
#   'ankyrin repeat domain 36B pseudogene 1'],
#  'ANKRD36BP2': ['ANKRD36BP2', 'ankyrin repeat domain 36B pseudogene 2'],
#  'ANKRD36C': ['DKFZp667P0924', 'ANKRD36C', 'ankyrin repeat domain 36C'],
#  'ANKRD36P1': ['ANKRD36P1', 'ankyrin repeat domain 36 pseudogene 1'],
#  'ANKRD37': ['Lrp2bp', 'ANKRD37', 'ankyrin repeat domain 37'],
#  'ANKRD39': ['MGC41816', 'ANKRD39', 'ankyrin repeat domain 39'],
#  'ANKRD40': ['MGC15396', 'ANKRD40', 'ankyrin repeat domain 40'],
#  'ANKRD42': ['FLJ37874',
#   'SARP',
#   'PPP1R79',
#   'ANKRD42',
#   'ankyrin repeat domain 42'],
#  ...}

# %%
dump(gene_dic, 'gene_dic.joblib') 
gene_dic = load('gene_dic.joblib')

# %%
alias=df_genes[df_genes['alias_symbol'].notnull()]

alias=alias['alias_symbol']

alias=alias.tolist()


def aliases_lst(df_alias_lst):
    
    alias_lst=[]
    for x in alias:
        gn=x.split('|')
        alias_lst.append(gn)
    
    flat_list = []
    for sublist in alias_lst:
        for item in sublist:
            item=item.lower()
            flat_list.append(item)
    return flat_list

lst_alias_gns=aliases_lst(alias) 

symbol=df_genes['symbol']
symbol=symbol.tolist()
gene_check=symbol+lst_alias_gns
gene_check
gene_check_lower=aliases_lst(gene_check)

# %%
#gene_check_lower

# %%
rule = rrulewrapper(YEARLY, byeaster=1, interval=1)
loc = RRuleLocator(rule)
formatter = DateFormatter('%m/%d/%y')

# %%
df1=df['source_x']
def preprint(a):

    if 'BioRxiv' in a :
        return 'Preprint'
    elif 'MedRxiv' in a:
        return 'Preprint'
    elif 'ArXiv' in a:
        return 'Preprint'
    else:
        return 'Peer-Review'
    
a=[preprint(n) for n in df1]

df_abs = pd.DataFrame(a,columns =['preprint'])  
df_abs
df['preprint']=df_abs
df_19=df[(df['publish_time'] > '2019-12-01')]

df['publish_time'] = pd.to_datetime(df['publish_time'], errors='coerce')
df_19['year'] = df['publish_time'].dt.year
df_19['month'] = df['publish_time'].dt.month

df_19 ['year_month']= df_19['year'].map(str) + '-' + df_19['month'].map(str)
df_19 = df_19.dropna(subset=['abstract'])
df_19
# Out:
# C:\Users\mese4\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\mese4\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\mese4\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         cord_uid                                                sha  \
# 4231    4tt0vnr4           aa3858e3cf21baa00c6f60272e4b59d3490129e0
# 4234    9c0zrp7p           23d0641f1f78528bbf3fa7b0b749abc1299a9cb4
# 4236    iaktm72a           9be8c80283a7fed59057d7788eb2850708f45450
# 4237    gcmpatlb           d5d29d1d48e1a4fe8f39d38639766c86dc976e5e
# 4246    k2monfg0           772046ceb62525b9f5c685e2d2b8dd33573107ba
# ...          ...                                                ...
# 169809  vbw0wbn1           07c638d72edcbd6f41a84d30023b0cfd864c3d68
# 169811  7dqr5adm                                                NaN
# 169813  ajqbljai  76ca0fe38a7e8bc1b730be50658fa9cb2eb7e4f2; e33a...
# 169814  gsktliyd           24741265a77032e848afe0cd1745adda124818be
# 169817  9svgq9f1  75a2fe5ad9b6eb8caf30399b9440f7dd610a32d3; 4461...
#
#                       source_x  \
# 4231                       PMC
# 4234                       PMC
# 4236                       PMC
# 4237                       PMC
# 4246                       PMC
# ...                        ...
# 169809                PMC; WHO
# 169811            Medline; WHO
# 169813            Medline; PMC
# 169814  Elsevier; Medline; PMC
# 169817            Medline; PMC
#
#                                                     title  \
# 4231    CXCR6 regulates localization of tissue-residen...
# 4234      Local risk perception enhances epidemic control
# 4236    Curcumin to Promote the Synthesis of Silver NP...
# 4237    Factors that enable effective One Health colla...
# 4246    Risk factors for the development of acute resp...
# ...                                                   ...
# 169809  Statistical analysis and visualization of the ...
# 169811  A cohort of patients with COVID-19 in a major ...
# 169813  Epidemiology of Covid-19 in a Long-Term Care F...
# 169814  A SARS-CoV-2 familial cluster infection reveal...
# 169817  Virusâvirus interactions impact the populati...
#
#                                  doi       pmcid    pubmed_id      license  \
# 4231            10.1084/jem.20181308  PMC6888981  3.15586e+07  cc-by-nc-sa
# 4234    10.1371/journal.pone.0225576  PMC6890219  3.17946e+07        cc-by
# 4236      10.1038/s41598-019-54752-4  PMC6890765  3.17969e+07        cc-by
# 4237    10.1371/journal.pone.0224660  PMC6892547  3.18006e+07        cc-by
# 4246       10.1186/s13054-019-2646-8  PMC6898929  3.18105e+07        cc-by
# ...                              ...         ...          ...          ...
# 169809    10.1007/s13337-020-00610-1  PMC7283982          NaN        no-cc
# 169811            10.3390/jcm9061733         NaN  3.25127e+07          unk
# 169813         10.1056/nejmoa2005412  PMC7121761  3.22202e+07        no-cc
# 169814    10.1016/j.jiph.2020.05.018  PMC7250748  3.25055e+07        no-cc
# 169817       10.1073/pnas.1911083116  PMC6936719  3.18439e+07        cc-by
#
#                                                  abstract publish_time  ...  \
# 4231    Resident memory T cells (T(RM) cells) are an i...   2019-12-02  ...
# 4234    As infectious disease outbreaks emerge, public...   2019-12-03  ...
# 4236    This work presents a simple one-pot protocol t...   2019-12-03  ...
# 4237    Advocates for a One Health approach recognize ...   2019-12-04  ...
# 4246    BACKGROUND: Clinical and epidemiological diffe...   2019-12-06  ...
# ...                                                   ...          ...  ...
# 169809  A local outbreak of initially unknown cause pn...   2020-06-10  ...
# 169811  Background: Since the confirmation of the firs...   2020-01-01  ...
# 169813  BACKGROUND: Long-term care facilities are high...   2020-03-27  ...
# 169814  Information on SARS-CoV-2 asymptomatic infecti...   2020-05-27  ...
# 169817  The human respiratory tract hosts a diverse co...   2019-12-26  ...
#
#        who_covidence_id arxiv_id  \
# 4231                NaN      NaN
# 4234                NaN      NaN
# 4236                NaN      NaN
# 4237                NaN      NaN
# 4246                NaN      NaN
# ...                 ...      ...
# 169809          #592057      NaN
# 169811        #32512688      NaN
# 169813              NaN      NaN
# 169814              NaN      NaN
# 169817              NaN      NaN
#
#                                            pdf_json_files  \
# 4231    document_parses/pdf_json/aa3858e3cf21baa00c6f6...
# 4234    document_parses/pdf_json/23d0641f1f78528bbf3fa...
# 4236    document_parses/pdf_json/9be8c80283a7fed59057d...
# 4237    document_parses/pdf_json/d5d29d1d48e1a4fe8f39d...
# 4246    document_parses/pdf_json/772046ceb62525b9f5c68...
# ...                                                   ...
# 169809  document_parses/pdf_json/07c638d72edcbd6f41a84...
# 169811                                                NaN
# 169813  document_parses/pdf_json/76ca0fe38a7e8bc1b730b...
# 169814  document_parses/pdf_json/24741265a77032e848afe...
# 169817  document_parses/pdf_json/75a2fe5ad9b6eb8caf303...
#
#                                       pmc_json_files  \
# 4231    document_parses/pmc_json/PMC6888981.xml.json
# 4234    document_parses/pmc_json/PMC6890219.xml.json
# 4236    document_parses/pmc_json/PMC6890765.xml.json
# 4237    document_parses/pmc_json/PMC6892547.xml.json
# 4246    document_parses/pmc_json/PMC6898929.xml.json
# ...                                              ...
# 169809  document_parses/pmc_json/PMC7283982.xml.json
# 169811                                           NaN
# 169813  document_parses/pmc_json/PMC7121761.xml.json
# 169814  document_parses/pmc_json/PMC7250748.xml.json
# 169817  document_parses/pmc_json/PMC6936719.xml.json
#
#                                                       url        s2_id  \
# 4231    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 4234    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 4236    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 4237    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# 4246    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...          NaN
# ...                                                   ...          ...
# 169809         https://doi.org/10.1007/s13337-020-00610-1  219554233.0
# 169811  https://doi.org/10.3390/jcm9061733; https://ww...  219553115.0
# 169813  https://www.ncbi.nlm.nih.gov/pubmed/32220208/;...  214683161.0
# 169814  https://www.sciencedirect.com/science/article/...  218891131.0
# 169817  https://doi.org/10.1073/pnas.1911083116; https...  209388856.0
#
#            preprint    year  month   year_month
# 4231    Peer-Review  2019.0   12.0  2019.0-12.0
# 4234    Peer-Review  2019.0   12.0  2019.0-12.0
# 4236    Peer-Review  2019.0   12.0  2019.0-12.0
# 4237    Peer-Review  2019.0   12.0  2019.0-12.0
# 4246    Peer-Review  2019.0   12.0  2019.0-12.0
# ...             ...     ...    ...          ...
# 169809  Peer-Review  2020.0    6.0   2020.0-6.0
# 169811  Peer-Review  2020.0    1.0   2020.0-1.0
# 169813  Peer-Review  2020.0    3.0   2020.0-3.0
# 169814  Peer-Review  2020.0    5.0   2020.0-5.0
# 169817  Peer-Review  2019.0   12.0  2019.0-12.0
#
# [49511 rows x 23 columns]

# %%
df_19

# %%
sns.set_context("talk")
sns.set_style('darkgrid')

g = sns.catplot(x="year_month", hue="preprint", 

                data=df_19, kind="count",

                height=5, aspect=5)

g.savefig("publications_years.png")

# %%
##Creating a list of stop words and adding custom stopwords
stop_words = set(stopwords.words("english"))

# %%
#nltk.download('wordnet')

stop_words = set(stopwords.words("english"))
new_words = ["using", "show", 'covid','patient','disease','patients','treatment','viral','data','including','coronavirus','health','study',"result",'unknown','2555','method','infection','day','case','however','moreover','conclusion','virus','patient', "large", "also", "iv", "one",'nan', "new", "previously", "shown",'recently','promising']
stop_words = stop_words.union(new_words)

# %%
len(df_19['abstract'])
dataset=df_19

# %%
#text = dataset['abstract'].translate(string.maketrans(“”,””), string.punctuation)
import string
#dataset['abstract_']=dataset['abstract'].str.replace('[{}]'.format(string.punctuation), '')
dataset['abstract_'] = dataset['abstract'].astype(str)
corpus = []
for i in range(0, len(dataset['abstract_'])):
    #Remove punctuations
    text = dataset['abstract_'].iloc[i]
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    #text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
   # text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split() 
    
    ##Stemming
    ps=PorterStemmer()    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)

#len(corpus)

# %%
#dataset['corpus']

corpus[2010]
# Out:
# 'sequential recommendation leverage temporal information usersâ\x80\x99 transaction transition dependency better inferring user preference, become increasingly popular academic research practical applications. short-term transition dependency contain information partial item orders, long-term transition dependency infer long-range user preference, two dependency mutually restrictive complementary. although work investigates unifying long-term short-term dependency better performance, still neglect fact short-term interaction multi-folds, either individual-level interaction union-level interactions. existing sequential recommendation mainly focus userâ\x80\x99s individual (i.e., individual-level) interaction ignore important collective influence union-level. since union-level interaction reflect human decision made based multiple item he/she already interacted, ignoring interaction disability capturing collective influence items. alleviate issue, proposed joint relational dependency learning (jrd-l) sequential recommendation exploit long-term short-term preference individual-level union-level. specifically, jrd-l combine long-term user preference short-term interest measuring short-term pair relation individual-level union-level. moreover, jrd-l alleviate sparsity problem union-level interaction adding descriptive detail item, carried individual-level relations. extensive numerical experiment demonstrate jrd-l outperforms state-of-the-art baseline sequential recommendation.'

# %%
corpus[1050]
dataset['corpus']=corpus

dataset.tail()
# Out:
#         cord_uid                                                sha  \
# 169809  vbw0wbn1           07c638d72edcbd6f41a84d30023b0cfd864c3d68
# 169811  7dqr5adm                                                NaN
# 169813  ajqbljai  76ca0fe38a7e8bc1b730be50658fa9cb2eb7e4f2; e33a...
# 169814  gsktliyd           24741265a77032e848afe0cd1745adda124818be
# 169817  9svgq9f1  75a2fe5ad9b6eb8caf30399b9440f7dd610a32d3; 4461...
#
#                       source_x  \
# 169809                PMC; WHO
# 169811            Medline; WHO
# 169813            Medline; PMC
# 169814  Elsevier; Medline; PMC
# 169817            Medline; PMC
#
#                                                     title  \
# 169809  Statistical analysis and visualization of the ...
# 169811  A cohort of patients with COVID-19 in a major ...
# 169813  Epidemiology of Covid-19 in a Long-Term Care F...
# 169814  A SARS-CoV-2 familial cluster infection reveal...
# 169817  Virusâvirus interactions impact the populati...
#
#                                doi       pmcid    pubmed_id license  \
# 169809  10.1007/s13337-020-00610-1  PMC7283982          NaN   no-cc
# 169811          10.3390/jcm9061733         NaN  3.25127e+07     unk
# 169813       10.1056/nejmoa2005412  PMC7121761  3.22202e+07   no-cc
# 169814  10.1016/j.jiph.2020.05.018  PMC7250748  3.25055e+07   no-cc
# 169817     10.1073/pnas.1911083116  PMC6936719  3.18439e+07   cc-by
#
#                                                  abstract publish_time  ...  \
# 169809  A local outbreak of initially unknown cause pn...   2020-06-10  ...
# 169811  Background: Since the confirmation of the firs...   2020-01-01  ...
# 169813  BACKGROUND: Long-term care facilities are high...   2020-03-27  ...
# 169814  Information on SARS-CoV-2 asymptomatic infecti...   2020-05-27  ...
# 169817  The human respiratory tract hosts a diverse co...   2019-12-26  ...
#
#                                            pdf_json_files  \
# 169809  document_parses/pdf_json/07c638d72edcbd6f41a84...
# 169811                                                NaN
# 169813  document_parses/pdf_json/76ca0fe38a7e8bc1b730b...
# 169814  document_parses/pdf_json/24741265a77032e848afe...
# 169817  document_parses/pdf_json/75a2fe5ad9b6eb8caf303...
#
#                                       pmc_json_files  \
# 169809  document_parses/pmc_json/PMC7283982.xml.json
# 169811                                           NaN
# 169813  document_parses/pmc_json/PMC7121761.xml.json
# 169814  document_parses/pmc_json/PMC7250748.xml.json
# 169817  document_parses/pmc_json/PMC6936719.xml.json
#
#                                                       url        s2_id  \
# 169809         https://doi.org/10.1007/s13337-020-00610-1  219554233.0
# 169811  https://doi.org/10.3390/jcm9061733; https://ww...  219553115.0
# 169813  https://www.ncbi.nlm.nih.gov/pubmed/32220208/;...  214683161.0
# 169814  https://www.sciencedirect.com/science/article/...  218891131.0
# 169817  https://doi.org/10.1073/pnas.1911083116; https...  209388856.0
#
#            preprint    year month   year_month  \
# 169809  Peer-Review  2020.0   6.0   2020.0-6.0
# 169811  Peer-Review  2020.0   1.0   2020.0-1.0
# 169813  Peer-Review  2020.0   3.0   2020.0-3.0
# 169814  Peer-Review  2020.0   5.0   2020.0-5.0
# 169817  Peer-Review  2019.0  12.0  2019.0-12.0
#
#                                                 abstract_  \
# 169809  A local outbreak of initially unknown cause pn...
# 169811  Background: Since the confirmation of the firs...
# 169813  BACKGROUND: Long-term care facilities are high...
# 169814  Information on SARS-CoV-2 asymptomatic infecti...
# 169817  The human respiratory tract hosts a diverse co...
#
#                                                    corpus
# 169809  local outbreak initially cause pneumonia detec...
# 169811  background: since confirmation first infected ...
# 169813  background: long-term care facility high-risk ...
# 169814  information sars-cov-2 asymptomatic infectivit...
# 169817  human respiratory tract host diverse community...
#
# [5 rows x 25 columns]

# %%
dataset['abstract'].describe()
# Out:
# count                                                 49511
# unique                                                42783
# top       An amendment to this paper has been published ...
# freq                                                     40
# Name: abstract, dtype: object

# %%
df_sub=dataset.sample(n = 100) 
df_sub
# Out:
#         cord_uid                                       sha  \
# 72754   hrmx9eav  23ec3684bc9bab1e88497d714cf3a67b8f99f50f
# 135808  3jmy9dy3  1a9f79f247a64d013a2644ea05151d9b39524bc8
# 66911   6jfvs677                                       NaN
# 89495   djxw2n23                                       NaN
# 68899   eqo1lrjv                                       NaN
# ...          ...                                       ...
# 142017  f3w2gu8c  86c58960f3733a069909fe40cb2c20301e5f794b
# 57337   v88f9e7m                                       NaN
# 109771  ib87gmr8                                       NaN
# 100485  uzgp7u1n  73eeae7a6d4b86c87623113ccadf6c018a6231de
# 38321   r4qnxp1z                                       NaN
#
#                       source_x  \
# 72754                  BioRxiv
# 135808  Elsevier; Medline; PMC
# 66911                      WHO
# 89495                      WHO
# 68899                      WHO
# ...                        ...
# 142017  Elsevier; Medline; PMC
# 57337                  Medline
# 109771                     WHO
# 100485                   ArXiv
# 38321                  Medline
#
#                                                     title  \
# 72754   Modeling the structure of the frameshift stimu...
# 135808  Running a Radiation Oncology Department at the...
# 66911   Recommendation for the diagnosis and treatment...
# 89495   The Perception of COVID-19 among Italian Denti...
# 68899   Randomization amid a pandemic - a critical app...
# ...                                                   ...
# 142017        Anaesthesia and COVID-19: infection control
# 57337   Prudent public health intervention strategies ...
# 109771  The application of privacy protection and arti...
# 100485  Endpoints for randomized controlled clinical t...
# 38321   Effects of Slaughter Knife Sharpness on Blood ...
#
#                                          doi       pmcid    pubmed_id  \
# 72754              10.1101/2020.06.08.141150         NaN          NaN
# 135808            10.1016/j.adro.2020.03.003  PMC7102610     32292837
# 66911   10.7499/j.issn.1008-8830.2020.02.003         NaN          NaN
# 89495                                    NaN         NaN          NaN
# 68899                     10.1111/voxs.12564         NaN          NaN
# ...                                      ...         ...          ...
# 142017             10.1016/j.bja.2020.03.025  PMC7142687     32307115
# 57337               10.4103/ijmr.ijmr_504_20         NaN  3.22023e+07
# 109771                                   NaN         NaN          NaN
# 100485                                   NaN         NaN          NaN
# 38321                    10.3390/ani10040579         NaN  3.22355e+07
#
#           license                                           abstract  \
# 72754     biorxiv  The coronavirus causing the COVID-19 pandemic,...
# 135808  els-covid  Abstract Starting from Wuhan, China, SARS-CoV-...
# 66911         unk  Since December 2019, a cluster of patients hav...
# 89495         unk  COVID-19 has severely impacted dentists, who a...
# 68899         unk  Abstract The novel coronavirus disease (COVID-...
# ...           ...                                                ...
# 142017  els-covid  Summary The world is currently facing an unpre...
# 57337         unk  Background & objectives :Coronavirus disease 2...
# 109771        unk  Objective The outbreak of novel coronavirus ra...
# 100485      arxiv  Introduction: Endpoint choice for randomized c...
# 38321         unk  The sharpness of the knife used for slaughter ...
#
#        publish_time  ...                                     pdf_json_files  \
# 72754    2020-06-11  ...  document_parses/pdf_json/23ec3684bc9bab1e88497...
# 135808   2020-03-20  ...  document_parses/pdf_json/1a9f79f247a64d013a264...
# 66911    2020-01-01  ...                                                NaN
# 89495    2020-01-01  ...                                                NaN
# 68899    2020-01-01  ...                                                NaN
# ...             ...  ...                                                ...
# 142017   2020-04-08  ...  document_parses/pdf_json/86c58960f3733a069909f...
# 57337    2020-03-23  ...                                                NaN
# 109771   2020-01-01  ...                                                NaN
# 100485   2020-06-09  ...  document_parses/pdf_json/73eeae7a6d4b86c876231...
# 38321    2020-03-30  ...                                                NaN
#
#                                       pmc_json_files  \
# 72754                                            NaN
# 135808  document_parses/pmc_json/PMC7102610.xml.json
# 66911                                            NaN
# 89495                                            NaN
# 68899                                            NaN
# ...                                              ...
# 142017  document_parses/pmc_json/PMC7142687.xml.json
# 57337                                            NaN
# 109771                                           NaN
# 100485                                           NaN
# 38321                                            NaN
#
#                                                       url        s2_id  \
# 72754           https://doi.org/10.1101/2020.06.08.141150  219636821.0
# 135808  https://www.sciencedirect.com/science/article/...  214729950.0
# 66911   https://doi.org/10.7499/j.issn.1008-8830.2020....  216406312.0
# 89495                                                 NaN  219991389.0
# 68899                  https://doi.org/10.1111/voxs.12564  219429421.0
# ...                                                   ...          ...
# 142017  https://api.elsevier.com/content/article/pii/S...  215516074.0
# 57337   https://doi.org/10.4103/ijmr.ijmr_504_20; http...  214616960.0
# 109771                                                NaN  215909872.0
# 100485             https://arxiv.org/pdf/2006.10533v1.pdf  219793031.0
# 38321   https://doi.org/10.3390/ani10040579; https://w...  214769524.0
#
#            preprint    year month  year_month  \
# 72754      Preprint  2020.0   6.0  2020.0-6.0
# 135808  Peer-Review  2020.0   3.0  2020.0-3.0
# 66911   Peer-Review  2020.0   1.0  2020.0-1.0
# 89495   Peer-Review  2020.0   1.0  2020.0-1.0
# 68899   Peer-Review  2020.0   1.0  2020.0-1.0
# ...             ...     ...   ...         ...
# 142017  Peer-Review  2020.0   4.0  2020.0-4.0
# 57337   Peer-Review  2020.0   3.0  2020.0-3.0
# 109771  Peer-Review  2020.0   1.0  2020.0-1.0
# 100485     Preprint  2020.0   6.0  2020.0-6.0
# 38321   Peer-Review  2020.0   3.0  2020.0-3.0
#
#                                                 abstract_  \
# 72754   The coronavirus causing the COVID-19 pandemic,...
# 135808  Abstract Starting from Wuhan, China, SARS-CoV-...
# 66911   Since December 2019, a cluster of patients hav...
# 89495   COVID-19 has severely impacted dentists, who a...
# 68899   Abstract The novel coronavirus disease (COVID-...
# ...                                                   ...
# 142017  Summary The world is currently facing an unpre...
# 57337   Background & objectives :Coronavirus disease 2...
# 109771  Objective The outbreak of novel coronavirus ra...
# 100485  Introduction: Endpoint choice for randomized c...
# 38321   The sharpness of the knife used for slaughter ...
#
#                                                    corpus
# 72754   causing covid-19 pandemic, sars-cov-2, us â1...
# 135808  abstract starting wuhan, china, sars-cov-2 cat...
# 66911   since december 2019, cluster diagnosed infecte...
# 89495   covid-19 severely impacted dentists, great ris...
# 68899   abstract novel (covid-19) spreading rapidly, p...
# ...                                                   ...
# 142017  summary world currently facing unprecedented h...
# 57337   background & objective :coronavirus 2019 (covi...
# 109771  objective outbreak novel raised many problem a...
# 100485  introduction: endpoint choice randomized contr...
# 38321   sharpness knife used slaughter utmost importan...
#
# [100 rows x 25 columns]

# %%
type(df_sub)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sub.to_csv('df_sub.csv',encoding='utf-8')

# %%
from sklearn.feature_extraction.text import CountVectorizer

import re

cv=CountVectorizer(max_df=0.9,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(genes_found)

#list(cv.vocabulary_.keys())[:10]

# %%
#Most frequently occuring words
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]#Convert most freq words to dataframe for plotting bar plot
top_words = get_top_n_words(genes_found, n=20)
top_df = pd.DataFrame(top_words)
top_df.columns=["Gene", "Freq"]#Barplot of most freq words
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Gene", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)

g.figure.savefig('most_frqu_gene.png')

# %%
from sklearn.feature_extraction.text import TfidfTransformer
 
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(X)# get feature names
feature_names=cv.get_feature_names()
 
# fetch document for which keywords needs to be extracted
doc=corpus[1]
 
#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

# %%
#Function for sorting tf_idf in descending order
from scipy.sparse import coo_matrix
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results
#sort the tf-idf vectors by descending order of scores
sorted_items=sort_coo(tf_idf_vector.tocoo())#extract only the top n; n here is 10
keywords=extract_topn_from_vector(feature_names,sorted_items,5)
 
# now print the results
print("\nAbstract:")
print(doc)
print("\nKeywords:")
for k in keywords:
    print(k,keywords[k])

# %%
df = pd.DataFrame(gene_names)
df

# %%
import pyensembl
ensembl = pyensembl.EnsemblRelease(99)
ensembl
#import sys
#!{sys.executable} -m pip install pyensembl

#!pyensembl install --release 75 99 --species human


gene_names = ensembl.gene_names(contig=None, strand=None)#(contig=6, position=29945884)


gene_names
genes_low=[]

for gene in gene_names:
    l=gene.lower()
    genes_low.append(l)
    
genes_low

# %%
gene_names
genes_low=[]

for gene in gene_names:
    l=gene.lower()
    print(l)
    genes_low.append(l)

# %%
#Nanemd entity recognion for gene identification
import PySysrev, spacy, random
#TRAIN_DATA = PySysrev.processAnnotations(project_id=3144,label='GENE')

#TRAIN_DATA[1]

# %%
nlp = spacy.blank('en')          # create a spacy model
nlp.meta['name'] = 'gene'        # name the model 'gene'

ner = nlp.create_pipe('ner')     # create an NER stage
ner.add_label('GENE')            # add the label 'GENE' to the stage

nlp.add_pipe(ner)                # put the pipe together
optimizer = nlp.begin_training() # get an optimizer for training the model

# %%
for itn in range(10):
    random.shuffle(TRAIN_DATA)                     #shuffle examples 
    text = [item[0] for item in TRAIN_DATA]        #get training text items
    annotations = [item[1] for item in TRAIN_DATA] #get training annotations
    nlp.update(text, annotations, sgd=optimizer, drop=0.6)

# %%
print('done')

# %%
#print('done')
#nlp.to_disk(r"C:\Users\mese4\Documents\The Data incubator\project\Spacy model\gene_id_model")

# %%
nlp=nlp.from_disk(r"C:\Users\mese4\Documents\The Data incubator\project\Spacy model\gene_id_model")

# %%
doc = nlp("""Epigenetic Silencing of the mutL homolog 1 (MLH1) Promoter in
Relation to the Development of Gastric Cancer (GC) and its use as a
Biomarker for Patients with Microsatellite, CD8 and HIF-1α, HIF1 for the Covid19 gene N, 
TRPM7 mmp8 MMP1 MMP2  and GAID2a, HNF4α, hnf4 ACE2  ORF1b  a nrf2 , Nucleoprotein1 , 
Nrf2 and brca2 Instability.""")


from spacy import displacy
displacy.render(doc,style="ent",jupyter=True,options={'distance':140})

# %%
text
# Out:
# 4231      resident memory cell (t(rm) cells) important f...
# 4234      infectious outbreak emerge, public agency ofte...
# 4236      work present simple one-pot protocol achieve c...
# 4237      advocate approach recognize global challenge r...
# 4246      background: clinical epidemiological differenc...
#                                 ...
# 169811    background: since confirmation first infected ...
# 169813    background: long-term care facility high-risk ...
# 169814    information sars-cov-2 asymptomatic infectivit...
# 169817    human respiratory tract host diverse community...
# 169818
# Name: corpus, Length: 82306, dtype: object

# %%
text = dataset['corpus']
#gene_listsof_ls=get_all_genes(text)

#gene_listsof_ls[:20]

# %%
import pickle
DOC_genes = pickle.dumps(text)

# %%
text1=text.tolist()
text1
# Out:
# ['resident memory cell (t(rm) cells) important first-line defense respiratory pathogens, unique contribution lung t(rm) cell population protective immunity factor govern localization different compartment lung well understood. here, airway interstitial t(rm) cell distinct effector function cxcr6 control partitioning t(rm) cell within lung recruiting cd8 t(rm) cell airways. absence cxcr6 significantly decrease airway cd8 t(rm) cell due altered trafficking cxcr6(â\x88\x92/â\x88\x92) cell within lung, decreased survival airways. cxcl16, ligand cxcr6, localized primarily respiratory epithelium, mouse lacking cxcl16 decreased cd8 t(rm) cell airways. finally, blocking cxcl16 inhibited steady-state maintenance airway t(rm) cells. thus, cxcr6/cxcl16 signaling axis control localization t(rm) cell different compartment lung maintains airway t(rm) cells.',
#  'infectious outbreak emerge, public agency often enact vaccination social distancing measure slow transmission. success depends strategy resources, public adherence. individual willingness take precaution may influenced global factors, news media, local factors, infected family member friends. here, compare three mode epidemiological decision-making midst growing outbreak network-based mathematical model capture plausible heterogeneity human contact patterns. individual decide whether adopt recommended intervention based overall prevalence, proportion social contact infected, number social contact infected. strategy substantially mitigate transmission, vaccinating (or self isolating) based number infected acquaintance expected prevent infection requiring fewest intervention resources. unlike strategies, substantial herd effect, providing indirect protection fraction population.',
#  'work present simple one-pot protocol achieve core-doped shell nanohybrids comprising silver nanoparticles, curcumin thermoresponsive polymeric shell taking advantage reducing property phenolic curcumin substance ability decorate metallic surfaces. silver nanoparticles synthesized, via sodium citrate silver nitrate addition boiling aqueous solution curcumin, monomer surfactant. curcumin sodium citrate promoted silver nucleation, acting reducing stabilizing agents. curcumin-capped agnps enabled, adding radical polymerization initiator, assembling growing polymer chain around hydrophobic agnp surface. resultant core-doped shell nanohybrids exhibit plasmonic, luminescent volume thermoresponsive properties, improved possibility used successful therapeutic platforms. fact, possibility nanoconfine synergistic antioxidant, antiviral, antibacterial feature silver curcumin bioavailable hybrid pave way application biomedical field.',
#  'advocate approach recognize global challenge require multidisciplinary collaborative efforts. past publication looked interdisciplinary competency training collaboration, identified factor condition enable operational health. scoping review literature, multidisciplinary team researcher analyzed peer-reviewed publication describing multisectoral collaboration around infectious disease-related events. review identified 12 factor support successful collaboration coordinated response event across three levels: two individual factor (education & training prior experience & existing relationships), four organizational factor (organizational structures, culture, human resource and, communication), six network factor (network structures, relationships, leadership, management, available & accessible resources, political environment). researcher identified stage collaboration factor critical, organizing starting condition process-based factors. research found publication multisectoral collaboration event uniformly report success challenge collaboration rarely identify output outcome collaborative process. paper proposes common language framework enable uniform reporting, implementation, evaluation future collaborations.',
#  'background: clinical epidemiological difference acute respiratory distress syndrome (ards) present initiation mechanical ventilation [mv] (ards mv onset) develops course mv (ards mv onset) well understood. conducted observational five peruvian icu characterize difference ards mv onset mv onset identify risk factor development ards mv onset. methods: consecutively enrolled critically ill acute respiratory failure requiring least 24 h mechanical ventilation followed prospectively first 28 day compared baseline characteristic clinical outcome ards status. results: enrolled 1657 participant mv (mean age 60.0 years, 55% males) 334 (20.2%) ards mv onset 180 (10.9%) developed ards mv onset. average tidal volume initiation mv 8.7 ml/kg predicted body weight (pbw) participant ards mv onset, 8.6 ml/kg pbw developed ards mv onset, 8.5 ml/kg pbw never developed ards (p = 0.23). overall, 90-day mortality 56% 55% ards mv onset ards mv onset, respectively, compared 46% among never developed ards (p < 0.01). adult ards higher body mass index (bmi) without ards (27.3 v 26.5 kg/m(2), p < 0.01). higher peak pressure (adjusted interquartile = 1.51, 95% ci 1.21â\x80\x931.88), higher mean airway pressure (adjusted interquartile = 1.41, 95% ci 1.13â\x80\x931.76), higher positive end-expiratory pressure (adjusted interquartile = 1.29, 95% ci 1.10â\x80\x931.50) mv onset associated higher odds developing ards mv onset. conclusions: mechanically ventilated patients, 31% participant ards point icu stay. optimal lung-protective ventilation used majority patients. ards mv onset similar 90-day mortality ards mv onset. higher airway pressure mv onset, higher peep, higher bmi associated development ards mv onset.',
#  'background: increasing number aging individual chronic co-morbidities travel region falciparum malaria endemic. non-communicable disease leading risk factor death countries. thus, influence chronic disease outcome falciparum malaria issue major importance. aim present ass whether non-communicable disease increase risk severe imported falciparum malaria. methods: retrospective observational adult case imported falciparum malaria hospitalized 2001 2015 tertiary care charitã© university hospital, berlin, performed. results: total 536 adult (median age 37 years; 31.3% female) enrolled. these, 329 (61.4%) originated endemic countries, 207 (38.6%) non-endemic regions. criterion severe malaria fulfilled 68 (12.7%) cases. older age, lack previous malaria episodes, tourist, delayed presentation, well-characterized risk factor associated severe malaria univariate analysis. adjustment potential confounders hypertension (adjusted odds ratio aor, 3.06 95% confidence interval, ci 1.34â\x80\x937.02), cardiovascular disease (aor, 8.20 95% ci 2.30â\x80\x9329.22), dyslipidaemia (aor, 6.08 95% ci 1.13â\x80\x9332.88) individual disease associated severe multivariable logistic regression. hypertension proved independent risk factor among individual endemic (aor, 4.83, 95% ci 1.44â\x80\x9316.22) well non-endemic origin (aor, 3.60 95% ci 1.05â\x80\x9312.35). conclusions: imported falciparum malaria hypertension related disease risk factor severe disease.',
#  'background: marked paucity concerning aki sub-saharan africa, substantial burden trauma hiv. methods: prospective collected admitted multi-disciplinary icu south africa 2017. development aki (before icu admission) recorded renal recovery 90 day icu discharge determined. results: 849 admissions, mean age 42.5 year mean sap 3 score 48.1. comorbidities included hypertension (30.5%), hiv (32.6%), diabetes (13.3%), ckd (7.8%) active tuberculosis (6.2%). common reason admission trauma (26%). aki developed 497 (58.5%). male gender, illness severity, length stay, vasopressor drug sepsis independently associated aki. aki associated higher in-hospital mortality rate 31.8% v 7.23% without aki. age, active tuberculosis, higher sap 3 score, mechanical ventilation, vasopressor support sepsis associated increased adjusted odds ratio death. hiv independently associated aki hospital mortality. ckd developed 14 110 (12.7%) stage 3 aki; none dialysis-dependent. conclusions: prospective multidisciplinary icu cohort younger patients, aki common, often associated trauma addition traditional risk factor associated good functional renal recovery 90 day survivors. although hiv prevalence high associated higher mortality, related severity illness hiv status per se.',
#  'background: use extracorporeal membrane oxygenation (ecmo) awake, spontaneously breathing non-intubated (awake ecmo) may novel therapeutic strategy severe acute respiratory distress syndrome (ards) patients. purpose ass feasibility safety awake ecmo severe ards receiving prolonged ecmo (> 14 days). methods: describe experience 12 consecutive severe ards (age, 39.1 â± 16.4 years) supported awake ecmo wait native lung recovery prolonged ecmo july 2013 january 2018. outcome reported hospital mortality, ecmo-related complication physiological weaning invasive ventilation. results: received median 26.0 (15.5, 64.8) day total ecmo duration cohort. longest ecmo support duration 121 days. awake ecmo extubation implemented median 10.2(5.0, 42.9) day ecmo. awake ecmo associated increased morbidity. total invasive ventilation duration, length stay icu hospital cohort 14.0(12.0, 37.3) days, 33.0(22.3, 56.5) day 46.5(27.3, 84.8) days, respectively. hospital mortality rate 33.3% (4/12) cohort. survivor stable respiratory rate heart rate extubation compared non-survivors. conclusions: carefully selected patients, awake ecmo feasible safe strategy severe pulmonary ards receiving prolonged ecmo support wait native lung recovery.',
#  'objectives: feline immunodeficiency (fiv) feline leukaemia (felv) retrovirus affecting cat worldwide. objective estimate prevalence retrovirus domestic cat hungary characterise phylogenetic relationship fiv strains. methods: total 335 anticoagulated whole-blood sample obtained healthy ill cat population examined presence fiv felv two methods: elisa pcr. statistical analysis carried analyse obtained. sequencing phylogenetic analysis partial polymerase (pol) gene sequence performed describe circulating fiv subtypes. results: statistical analysis showed 11.8% 9.9% true prevalence felv fiv, respectively, elisa. apparent prevalence calculated pcr result 17.3% felv 13.1% fiv. phylogenetic analysis partial pol gene sequence obtained 22 fiv strain showed observed hungarian strain belonged fiv subtype b. strain grouped several monophyletic subgroup reflecting geographic location origin samples. overall mean genetic similarity analysed strain 98.2%. conclusion relevance: report first thorough overview prevalence felv fiv hungary, relatively high, give insight genetic diversity hungarian strain fiv.',
#  'background: ebolavirus (ebov) outbreaks, sporadic, cause tremendous morbidity mortality. therapeutic vaccine currently licensed; however, vaccine promise clinical trials. critical step towards development effective therapeutic better understanding factor govern host susceptibility pathogen. macrophage important cell population targeted replication, explore effect cytokine polarization macrophage infection. methods/main findings: utilized bsl2 ebov model virus, infectious, recombinant vesicular stomatitis encoding ebov glycoprotein (gp) (rvsv/ebov gp) place native glycoprotein. macrophage polarized towards m2-like anti-inflammatory state combined il-4 il-13 susceptible rvsv/ebov gp, wild-type vsv (rvsv/g), suggesting ebov gp-dependent entry event enhanced cytokines. examination rna expression known surface receptor bind internalize filovirus demonstrated il-4/il-13 stimulated expression c-type lectin receptor dc-sign human macrophage addition competitive inhibitor mannan abrogated il-4/il-13 enhanced infection. two murine dc-sign-like family members, signr3 signr5, upregulated il-4/il-13 murine macrophages, signr3 enhanced mannan-inhibited manner, suggesting murine signr3 play similar role human dc-sign. vivo il-4/il-13 administration significantly increased virus-mediated mortality mouse model transfer ex vivo il-4/il-13-treated murine peritoneal macrophage peritoneal cavity mouse enhanced pathogenesis. significance: study highlight ability macrophage polarization influence ebov gp-dependent replication vivo ex vivo, m2a polarization upregulating cell surface receptor expression thereby enhancing replication. finding provide increased understanding host factor macrophage governing susceptibility filovirus identify novel murine receptor mediating ebov entry.',
#  'child vulnerable risk air pollution, susceptibility acquiring chronic disease developing lungs. despite these, specific mask designed tested child available protect young common particulate air pollutant today. evaluated safety, fit comfort specially designed paediatric n95 mask optional micro ventilator (micro fan, mf) healthy child aged 7â\x80\x9314 years, randomized, two-period crossover design. subjectsâ\x80\x99 cardiorespiratory physiological measurement assessed different state physical activity different intervention (mask without mf). total 106 subject recruited july-august 2016. use mask without mf increased end-tidal co(2) (etco(2)) fractional concentration inspired co(2) (fico(2)) rest mild exertion, expected. use mask mf brought fico(2) level comparably closer baseline level without mask activities. mask, without mf, found well fitting, comfortable safe use child rest mild exertion. n95 mask tested offer start study paediatric population.',
#  'background: pristine carbon dot (cds) derived citric acid pyrolysis used variety biomedical research imaging drug delivery. however, potential cytotoxic effect pyrolysis temperature cell underexplored. address need, studied toxicity cd breast cancer cell mtt ldh assays. addition, investigated photo-induced cytotoxicity synthesized cd wide concentration range white light. results: result suggest little cytotoxicity cd 24 h exposure cells. high quantum yield cd caused significant toxicity cell highest concentration 2.0 1.5 mg/ml compared cd similar concentrations. synthesized cd entered cell without significant cytotoxicity. cd caused concentration- irradiation time-dependent photo-induced cytotoxicity. conclusion: optimization synthesis condition may help develop safe efficient cd imaging drug delivery.',
#  'background: thrombotic thrombocytopenic purpura autoimmune carry high mortality. report literature described relationship graf thrombotic thrombocytopenic purpura. present graf found biochemically clinically hyperthyroid concurrent thrombotic thrombocytopenic purpura. presentation: 30-year-old african american woman history hypertension family history graf diagnosed hyperthyroidism placed methimazole. presented hospital complaint progressive shortness breath dizziness. vital sign stable. evaluation, diagnosed thrombotic thrombocytopenic purpura, depending clinical laboratory results, found highly elevated free t4 suppressed thyroid-stimulating hormone. received multiple session plasmapheresis ultimately total thyroidectomy. patientâ\x80\x99s hospital course complicated pneumonia acute respiratory distress syndrome. platelet stabilized approximately 50,000/î¼l, adamts13 activity normalized despite multiple complications. ultimately cardiac arrest pulseless electrical activity died despite multiple attempt cardiopulmonary resuscitation. conclusion: graf uncommon trigger development thrombotic thrombocytopenic purpura, case reported thus far. therefore, clinician aware association appropriate clinical context comprehensively monitor hyperthyroid treatment.',
#  'recent years, outbreak infectious caused zika (zikv) posed major threat global public health, calling development therapeutic treat zikv disease. here, described different stage zikv life cycle summarized latest progress development small-molecule inhibitor zikv infection. discussed general strategy discovery small-molecule zikv inhibitors.',
#  'npl4 likely upstream factor recognizing lys48-linked polyubiquitylated substrate proteasomal degradation pathway yeast. along ufd1, npl4 form heterodimer (un), function cofactor cdc48 atpase. here, report crystal structure yeast npl4 complex lys48-linked diubiquitin npl4-binding motif ufd1. distal proximal ubiquitin moiety lys48-linked diubiquitin primarily interact c-terminal helix n-terminal loop npl4 c-terminal domain (ctd), respectively. mutational analysis suggests ctd contributes linkage selectivity initial binding ubiquitin chains. ufd1 occupies hydrophobic groove mpr1/pad1 n-terminal (mpn) domain npl4, corresponds catalytic groove mpn domain jab1/mpn/mov34 metalloenzyme (jamm)-family deubiquitylating enzyme. provides important structural insight polyubiquitin chain recognition cdc48â\x80\x93un complex assembly.',
#  'rotavirus (rv) replicates round-shaped cytoplasmic factories, although assemble remains unknown. rv infection, nsp5 undergoes hyperphosphorylation, primed phosphorylation single serine residue. role posttranslational modification formation viroplasms impact replication remain obscure. here, investigated role nsp5 rv taking advantage modified fully tractable reverse-genetics system. trans-complementing cell line stably producing nsp5 used generate characterize several recombinant rotavirus (rrvs) mutation nsp5. demonstrate rrv lacking nsp5 completely unable assemble viroplasms replicate, confirming pivotal role rotavirus replication. number mutant impaired nsp5 phosphorylation generated interrogate function posttranslational modification assembly replication-competent viroplasms. showed rrv mutant strain exhibited impaired replication ability assemble round-shaped viroplasms ma104 cells. furthermore, investigated mechanism nsp5 hyperphosphorylation rv nsp5 phosphorylation-negative rrv strains, well ma104-derived stable transfectant cell line expressing either wild-type nsp5 selected nsp5 deletion mutants. result indicate nsp5 hyperphosphorylation crucial step assembly round-shaped viroplasms, highlighting key role c-terminal tail nsp5 formation replication-competent factories. complex nsp5 phosphorylation cascade may serve paradigm assembly functional factory rna viruses. importance rotavirus (rv) double-stranded rna genome replicated packaged progeny cytoplasmic structure termed viroplasms. nonstructural protein nsp5, undergoes complex hyperphosphorylation process rv infection, required formation virus-induced organelles. however, role viroplasm formation rv replication never directly assessed due lack fully tractable reverse-genetics (rg) system rotaviruses. here, novel application developed rg system establishing stable trans-complementing nsp5-producing cell line required rescue rotavirus mutation nsp5. approach allowed u provide first direct evidence pivotal role protein rv replication. furthermore, recombinant rv mutants, shed light molecular mechanism nsp5 hyperphosphorylation involvement assembly maturation replication-competent viroplasms.',
#  'acute respiratory distress syndrome (ards) devastating hypoxemic respiratory failure, characterized disruption alveolar-capillary membrane barrier. current management ards remains supportive, lung-protective ventilation conservative fluid strategy. mesenchymal stem cell (mscs) emerged potentially attractive candidate management ards facilitating lung tissue regeneration repair releasing paracrine soluble factors. last decade, variety strategy emerged optimize msc-based therapy. among these, strategy genetically modified msc received increased attention due distinct advantage, conferring incremental migratory capacity and, enhancing anti-inflammatory, immunomodulatory, angiogenic, antifibrotic effect cell numerous preclinical ards models, may turn provide additional benefit management ards. here, provide overview recent study testing efficacy genetically modified msc preclinical model ards.',
#  'mortality rate hemorrhagic african swine fever (asf), target domestic pig wild boar caused african swine fever (asfv), reach 100%. since first confirmed asf outbreak china 3 august 2018, 156 asf outbreak detected 32 provinces. 1,170,000 pig culled order halt spread. effective vaccine present molecular diagnosis technology trade-off sensitivity, specificity, cost speed, none cater perfectly asf control. thus, technology overcomes need laboratory facilities, relatively low cost, rapidly sensitively detects asfv would highly valuable. here, describe raa-cas12a-based system combine recombinase aided amplification (raa) crispr/cas12a asfv detection. fluorescence intensity readout system detected asfv p72 gene level low 10 am. on-site asfv detection, lateral-flow strip readout introduced first time raa-cas12a based system (named cords, cas12a-based on-site rapid detection system). used cord detect target dna highly specifically lateral-flow strip readout assay displayed cross-reactivity 13 swine virus classical swine fever (csf). cord could identify asfv dna target femtomolar sensitivity hour 37â°c, requires incubator. ease use, reagent cord lyophilized three tube remained sensitivity stored 4â°c least 7 days. thus, cord provide rapid, sensitive easily operable asfv on-site detection. lyophilized cord withstand long-term transportation storage, ready field-based applications.',
#  'anaplasma phagocytophilum agent tick-borne fever, equine, canine human granulocytic anaplasmosis. common route a. phagocytophilum transmission tick bite, main vector europe ixodes ricinus. despite apparently ubiquitous presence pathogen a. phagocytophilum tick various wild domestic animal europe, date published clinical case human granulocytic anaplasmosis (hga) remain rare compared worldwide status. unclear reflects epidemiological dynamic human europe underdiagnosed underreported. epidemiologic study europe suggested increased occupational risk forestry workers, hunters, veterinarians, farmer tick-bite history living endemic areas. although overall genetic diversity a. phagocytophilum europe higher usa, strain responsible human infection related continents. however, genetic variability assessment difference pathogenicity infectivity strain various host insufficiently explored date. european hga case presented mild infection, common clinical sign pyrexia, headache, myalgia arthralgia. diagnosis hga usa recommended based clinical sign patientâ\x80\x99s history later confirmed specialized laboratory tests. however, europe since majority case presenting mild infection, laboratory test may performed order avoid antibiotic overuse. drug choice hga doxycycline potential serious complication instituted clinical suspicion alone.',
#  'tick-borne nairoviruses (order bunyavirales) encode ovarian tumor domain protease (otu) suppresses innate immune response reversing post-translational modification protein ubiquitin (ub) interferon-stimulated gene product 15 (isg15). ub highly conserved across eukaryotes, whereas isg15 present vertebrate show substantial sequence diversity. prior attempt address effect isg15 diversity protein-isg15 interaction focused single speciesâ\x80\x99 isg15 limited selection nairovirus otus. gain complete perspective otu-isg15 interactions, biochemically assessed relative activity 14 diverse nairovirus otus 12 speciesâ\x80\x99 isg15 found isg15 activity predominantly restricted particular nairovirus lineage reflecting, general, known virus-host associations. uncover underlying molecular factor driving otus affinity isg15, x-ray crystal structure kupe ganjam otus bound sheep isg15 solved compared complex crimean-congo hemorrhagic fever erve otus bound human mouse isg15, respectively. mutational structural analysis seven residue isg15 identified predominantly influence isg15 specie specificity among nairovirus otus. additionally, otu residue identified influence isg15 preference, suggesting potential otus adapt different host isg15s. finding provide foundation develop research method trace nairovirus-host relationship delineate full impact isg15 diversity nairovirus infection.',
#  'background: herpesviridae reactivation among non-immunocompromised critically ill associated impaired prognosis, especially acute respiratory distress syndrome (ards). however, little known herpes simplex (hsv) cytomegalovirus (cmv) reactivation occurring severe ards veno-venous extracorporeal membrane oxygenation (ecmo). tried determine frequency herpesviridae reactivation impact patientsâ\x80\x99 prognosis ecmo severe ards. results: 5-year period, 123 non-immunocompromised severe ards requiring veno-venous ecmo included. sixty-seven (54%) experienced hsv and/or cmv reactivation ecmo course (20 co-infection, 40 hsv alone, 7 cmv alone). hsv reactivation occurred earlier cmv beginning mv [(6â\x80\x9315) vs. 19 (13â\x80\x9329) days; p < 0.01] ecmo implementation [(2â\x80\x938) vs. 14 (10â\x80\x9320) days; p < 0.01]. univariate analysis, hsv/cmv reactivation associated longer duration mechanical ventilation [(22â\x80\x9352.5) vs. 17.5 (9â\x80\x9328) days; p < 0.01], longer duration ecmo [15 (10â\x80\x9322.5) vs. 9 (5â\x80\x9314) days; p < 0.01], prolonged icu [29 (19.5â\x80\x9347.5) vs. 16 (9â\x80\x9330) days; p < 0.01] hospital stay [44 (29â\x80\x9363.5) vs. 24 (11â\x80\x9343) days; p < 0.01] compared non-reactivated patients. however, multivariate analysis, reactivation remained associated prolonged mv only. considered separately, hsv cmv reactivation associated longer duration mv compared non-reactivation [29 (19.5â\x80\x9341) 28 (20.5â\x80\x9337), respectively, vs. 17.5 (9â\x80\x9328) days; p < 0.05]. co-reactivation longer duration mv [58.5 (38â\x80\x9372.3); p < 0.05] icu stay [51.5 (32.5â\x80\x9369) vs. 27.5 (17.75â\x80\x9335.5) 29 (20â\x80\x9330.5), respectively] compared hsv cmv reactivation alone. multivariate analysis, hsv reactivation remained independently associated longer duration mv hospital length stay. conclusions: herpesviridae reactivation frequent among severe ards veno-venous ecmo associated longer duration mechanical ventilation. direct causative link hsv cmv reactivation respiratory function worsening ecmo remains confirmed.',
#  'influenza major cause morbidity mortality worldwide, well china. knowledge spatial temporal characteristic influenza important evaluating developing control programs. aim describe accurate spatiotemporal pattern influenza prefecture level explore risk factor associated influenza incidence risk mainland china 2005 2018. incidence influenza obtained chinese notifiable infectious reporting system (cnidrs). besag york molliã© (bym) model extended include temporal space-time interaction terms. parameter extended bayesian spatiotemporal model estimated integrated nested laplace approximation (inla) package r-inla r. total 702,226 influenza case reported mainland china cnidrs 2005â\x80\x932018. yearly reported incidence rate influenza increased 15.6 time period, 3.51 2005 55.09 2008 per 100,000 populations. temporal term spatiotemporal model showed much increase occurred last 3 year period. risk factor analysis showed decreased number influenza vaccine sale, update influenza surveillance protocol, increase rate influenza (h1n1)pdm09 among processed specimen influenza-like illness (ili) patients, increase latitude longitude geographic location associated increase influenza incidence risk. adjusting fixed covariate effect time random effects, map spatial structured term show high-risk area clustered central part china lowest-risk area east west. space-time variation influenza found since 2009. conclusion, increasing trend influenza observed 2005 2018. insufficient flu vaccine supplements, newly emerging influenza (h1n1)pdm09 expansion influenza surveillance effort might major cause dramatic change outbreak spatio-temporal epidemic patterns. cluster prefecture high relative risk influenza identified central part china. future research risk factor national local level necessary explain changing spatiotemporal pattern influenza china.',
#  'porcine epidemic diarrhea (pedv) induce intestinal dysfunction, resulting severe diarrhea even death, mode action underlying effect remains unclear. determined effect pedv intestinal absorption expression gene nutrient transporter via biochemical test microarray analysis. sixteen 7-day-old healthy piglet fed milk replacer randomly allocated two groups. 5-day adaption, piglet (n = 8/group) orally administrated either sterile saline pedv (the strain yunnan province) 10(4.5) tcid(50) (50% tissue culture infectious dose) per pig. pig orally infused d-xylose (0.1 g/kg bw) 5 post pedv saline administration. hour later, jugular vein blood sample well intestinal sample collected analysis. comparison control group, pedv increased diarrhea incidence, blood diamine oxidase activity, ifabp level, reducing growth plasma d-xylose concentration piglets. moreover, pedv altered plasma jejunal amino acid profiles, decreased expression aquaporins amino acid transporter (l-type amino acid transporter 1, sodium-independent amino acid transporter, b(â°(,+))-type amino acid transport protein, sodium-dependent neutral amino acid transporter 1, sodium-dependent glutamate/aspartate transporter 3, peptide transporter (1), lipid transport metabolism-related gene (lipoprotein lipase, apolipoprotein a1, apolipoprotein a4, apolipoprotein c2, solute carrier family 27 member 2, solute carrier family 27 member 4, fatty acid synthase, long-chain acyl-coa synthetase (3), glucose transport gene (glucose transporter-2 insulin receptor) jejunum. however, pedv administration increased mrna level phosphoenolpyruvate carboxykinase 1, argininosuccinate synthase 1, sodium/glucose co-transporter-1, cystic fibrosis transmembrane conductance regulator jejunum. collectively, comprehensive result indicate pedv induces intestinal injury inhibits expression gene encoding nutrient transporters.',
#  'chronic kidney epidemiologically identified risk factor development severe dengue dengue-affected patients. however, available immune pathogenesis end stage renal (esrd) affected dengue insufficient. performed vitro evaluate sequential immunological reaction load dengue type 2-infected mononuclear cell esrd (n = 34) healthy control (n = 30). concentration interleukin (il)-1 receptor antagonist (ra), il-2, il-6, il-8, il-10, il-12p40, granulocyte-macrophage colony-stimulating factor (gm-csf), monocyte chemotactic protein-1 (mcp-1), macrophage inflammatory protein-1b (mip-1b), vascular endothelial growth factor (vegf), tumor necrosis factor (tnf)-î± load cycle threshold (ct) measured dengue type 2-infected mononuclear cell 6 h, 24 h, 48 h, 72 h post-infection. found esrd group significantly higher gm-csf il-2 level 6 h post-infection. however, il-8, il-10, il-12p40, tnf-î±, mcp-1, mip-1b level found significantly lower control group. 24 h, 48 h, 72 h post-infection, significantly lower level il-1ra, il-6, il-8, il-10, il-12p40, tnf-î±, mcp-1, mip-1b detected esrd group. concentration vegf 24 h 48 h, gm-csf 48 h 72 h found lower esrd group control group. compared controls, load ct value significantly lower esrd group 6 h 24 h post-infection significant difference load ct value two group found 48 h 72 h post-infection. discloses expression immune mediator dengue-infected mononuclear cell impaired esrd patients.',
#  'background: rna pseudoknot structure play important role biological processes. however, existing rna secondary structure prediction algorithm cannot predict pseudoknot structure efficiently. although random matching improve number base pairs, non-consecutive base pair cannot make contribution reduce free energy. result: order improve efficiency searching procedure, algorithm take consecutive base pair basic components. firstly, algorithm calculates archive consecutive base pair triplet structure, number consecutive base pair greater given minimum stem length. secondly, annealing schedule adapted select optimal solution minimum free energy. finally, proposed algorithm evaluated real instance pseudobase. conclusion: experimental result demonstrated provide competitive oftentimes better performance compared chosen state-of-the-art rna structure prediction algorithms.',
#  'background: telocytes (tcs) newly identified interstitial cell participate tissue protection repair. present investigated mechanism underlying protective effect tc mouse model respiratory distress. methods: mouse model acute respiratory distress syndrome (ards) established intratracheal instillation lipopolysaccharide (lps). instillation tc culture medium, lung injury assessed, angiogenesis markers, cd31 endothelial nitric oxide synthase (enos), detected immunofluorescence. bioinformatics analysis used screen significantly differentially expressed micrornas (mirnas) cultured tc stimulated lps, regulation downstream angiogenesis gene mirnas analysed verified. pi3k subunit pathway evaluated pi3k p110î± inhibitor involved mechanisms. results: ards mice, instillation tc culture medium ameliorated lps-induced inflammation lung injury increased protein level cd31 enos injured lungs. total 7 mirnas 1899 mrna differentially regulated tc stimulated lps. functional prediction analysis showed differentially expressed mrna enriched angiogenesis-related processes, highly correlated mir-21a-3p. culture medium tc mir-21a-3p inhibition failed promote angiogenesis mouse model lps-induced ards. cultured tcs, lp stimulation upregulated expression mir-21a-3p, targeted transcription factor e2f8 decreased notch2 protein expression. tc culture medium enhanced hemangioendothelioma endothelial cell (eoma cells) proliferation, blocked mir-21a-3p inhibitor. pi3k p110î± inhibitor decreased vascular endothelial growth factor level lps-stimulated tc reversed enhancing effect tc culture medium eoma cell proliferation. conclusions: tc exerted protective effect inflammatory condition promoting angiogenesis via mir-21a-3p. pi3k p110î± subunit transcriptional factor e2f8 could involved process.',
#  'monitored survival human pathogenic bacteria [escherichia coli (atcc), extended-spectrum î²-lactamase-producing e. coli (clinical isolate), delhi metallo-î²-lactamase-producing e. coli (clinical isolate), staphylococcus aureus (atcc)] dry material (vinyl chloride, aluminum, plastic, stainless steel) distinct temperature (room temperature 15â°câ\x80\x9337â°c). bacteria favored lower temperature prolonged survival dry fomites, regardless material type. interestingly, mixed s. aureus, e. coli survived longer time lower temperature. cardiolipin, promote survival s. aureus harsh environments, effect maintaining survival e. coli. although trend remained unchanged, adjusting humidity 40% 60% affected survival bacteria dry surfaces. scanning electron microscopic analysis revealed morphological difference bacteria immediately dry conditions. addition, atp assessment, used visualize high-touch surface hospitals, effective monitoring bacterial dynamics. specialized handrail device fitted heater, maintained normal human body core temperature, successfully prohibited prolonged survival bacteria [enterococcus faecalis (atcc), e. coli (atcc), pseudomonas aeruginosa (atcc), s. aureus (atcc), acinetobacter baumannii (clinical isolate), serratia marcescens (clinical isolate)], exception spore-forming bacillus subtilis (from laboratory collection) yeast-like fungus candida albicans (from laboratory collection)] dry surfaces. taken together, concluded tested bacteria favor lower temperature survival dry environments. therefore, thermal control dry fomite potential control bacterial survival high-touch surface hospitals.',
#  'ebola (evd) epidemic western africa (2013â\x80\x922016), antimalarial administered evd due high coexisting malaria burden accordance world organization guidelines. ebola center liberia, evd receiving combination antimalarial artesunate-amodiaquine lower risk death compared treated artemether-lumefantrine. artemether artesunate derivative artemisinin, beneficial anti-ebola (ebov) effect observed could possibly attributed change lumefantrine amodiaquine. amodiaquine widely used antimalarial country experience outbreak evd and, therefore, hold promise approved drug could repurposed treating ebov infections. investigated potential anti-ebov effect amodiaquine well-characterized nonhuman primate model evd. similar 3-day antimalarial dosing strategy human patients, plasma concentration amodiaquine healthy animal similar found humans. however, regimen survival benefit decrease sign ebov-infected animals. amodiaquine failed demonstrate efficacy, cannot exclude potential therapeutic value amodiaquine used combination artesunate another antiviral.',
#  'zika (zikv) currently major concern human public due association neurological disorders. intensive effort implemented zikv, currently approved vaccine antiviral available combat zikv infection. sense, identification virulence factor associated change zikv virulence could help develop safe effective countermeasure treat zikv prevent future outbreaks. here, compared virulence two related zikv strain recent outbreak brazil (2015), rio grande norte natal (rgn) paraiba. spite virus identified period time region, significant difference virulence replication observed validated mouse model zikv infection. zikv-rgn 50% mouse lethal dose (mld(50)) ~10(5) focus forming unit (ffus), zikv-paraiba resulted 100% lethality le 10 ffus. combining deep-sequencing analysis described infectious zikv-rgn cdna clone, identified natural polymorphism non-structural protein 2 (ns2a) increase virulence zikv. moreover, result demonstrate single amino acid alanine valine substitution position 117 (a117v) ns2a sufficient convert attenuated rzikv-rgn virulent paraiba-like (mld(50) < 10 ffu). mechanism action evaluated indicate substitution a117v zikv ns2a protein reduces host innate immune response viral-induced apoptosis vitro. therefore, amino acid substitution a117v zikv ns2a could used genetic risk-assessment marker future zikv outbreaks.',
#  'influenza major global public threat highly pathogenic variants, zoonotic reservoir, pandemic potential. metagenomic sequencing offer potential diagnostic test influenza provides insight transmission, evolution, drug resistance simultaneously detects viruses. therefore set apply oxford nanopore technology sequencing metagenomic sequencing respiratory samples. generated influenza read limit detection 10(2) 10(3) genome copies/ml pooled samples, observing strong relationship titer proportion influenza read (p = 4.7 ã\x97 10(â\x88\x925)). applying method clinical throat swabs, generated influenza read 27/27 sample mid-to-high titer (cycle threshold [c(t)] values, <30) 6/13 sample low titer (c(t) values, 30 40). false-positive read generated 10 influenza virus-negative samples. thus, nanopore sequencing operated 83% sensitivity (95% confidence interval [ci], 67 93%) 100% specificity (95% ci, 69 100%) compared current diagnostic standard. coverage full-length dependent sample composition, negatively influenced increased host bacterial reads. however, high influenza titers, able reconstruct >99% complete sequence eight gene segments. detected human coinfection clinical sample. optimization required improve sensitivity, approach show promise nanopore platform used diagnosis genetic analysis influenza respiratory viruses.',
#  'background: telocytes (tcs) capacity cellâ\x80\x93cell communication adjacent cell within tissue, contributing tissue repair recovery injury. present aim investigating molecular mechanism tgfî²1-itgb1-pi3k signal pathway regulate tc cycle proliferation. methods: gene expression integrin (itg) family measured mouse primary tc compare cells. tc proliferation, movement, cell cycle, pi3k isoform protein gene assayed itgb1-negative positive mouse lung tc treated inhibition pi3kp110î±, pi3kî±/î´, pkcî², gsk3, followed tgfî²1 treatment. results: found character interaction itg pkc family member network primary mouse lung tcs, different cell lung tissue. deletion itgb1 changed tc sensitivity multifunctional cytokine signal pathway inhibitors. compensatory mechanism occur among tgfî²1-induced pi3kp110î±, pi3kî±/î´, pkcî², gsk3 itgb1 gene deleted, leading alteration tc cell cycle proliferation. pi3k isoform protein genes, mrna expression pik3cg altered itgb1-negative tc cycle proliferation. conclusion: tc strong capacity proliferation compensatory signaling mechanism contribute development drug resistance due alteration tc sensitivity.',
#  'pre-emptive vaccination regarded protective measure control influenza outbreak. mainly two type influenza virusesâ\x80\x94influenza b several subtypesâ\x80\x94that commonly found circulate among humans. traditional trivalent (tiv) flu vaccine target two strain influenza strain influenza b. quadrivalent (qiv) vaccine target extra b strain ensures better protection influenza; however, use qiv vaccine costly, hence impose extra financial burden society. scenario might create dilemma choosing vaccine type individual level. article endeavour explain dilemma framework vaccination game, individual opt three options: choose either qiv tiv vaccine none. approach presumes mean-field framework vaccination game infinite well-mixed population, entangling spreading process influenza coevolution two type vaccination decision-making process taking place epidemic season. conduct series numerical simulation attempt illustrate different scenarios. framework validated so-called multi-agent simulation (mas) approach.',
#  'dynamic spreadable largely governed four factors: proactive vaccination, retroactive treatment, individual decisions, prescribing behaviour physicians. imposed vaccination policy antiviral society, complex factor (costs expected effect vaccine treatments, fear infected) trigger emulous situation individual avoid pre-emptive ex post provision. aside established voluntary vaccination game, propose game model associated resistance evolution antiviral/antibiotic overuse. moreover, imperfectness vaccination inevitably led anti-vaccine behaviour, necessitating proactive policy. however, excessively heavy implementation treatment antiviral medicine, resistant strain emerge. model explicitly exhibit dual social dilemma situation, behaviour change local time scale, vaccination uptake later evolves global time scale. impact resistance evolution coexistence dual dilemma investigated control reproduction number social efficiency deficit, respectively. investigation might elucidate substantial impact vaccination framework epidemic dynamics, hence suggest appropriate use antiviral treatment.',
#  'background: influenza infection often remain undiagnosed admitted hospital due lack routine testing. tested for, diagnosis influenza often delayed due slow turnaround time centralised laboratory pcr testing. newer molecular systems, comparable accuracy laboratory pcr testing, generate 1 hour, making potentially deployable point-of-care test (pocts). high-quality evidence impact routine poct influenza clinical outcome is, however, currently lacking. pragmatic multicentre randomised controlled trial aim address evidence gap. method analysis: flupoc trial pragmatic, multicentre, randomised controlled trial evaluating adult admitted teaching hospital district general hospital acute respiratory illness, influenza season defined public england. 840 recruited three influenza seasons, randomised (1:1) receive either poct filmarray respiratory panel, routine clinical care. clinical control team informed result real time influenza detected clinical team encouraged offer neuraminidase inhibitor (nai) accordance national guidelines. allocated standard clinical care swab taken later analysis allow assessment missed diagnoses. outcome assessment retrospective note analysis. outcome measure include proportion influenza-positive detected appropriately treated nais, isolation facility use, antibiotic use, length hospital stay, complication mortality. ethic dissemination: prior commencing study, approval obtained south central hampshire ethic committee (reference 17/sc/0368, granted 7 september 2017). result generated protocol published peer-reviewed scientific journal presented national international conferences. trial registration number: isrctn17197293',
#  'background: dexmedetomidine reported improve organ dysfunction critically ill patients. recent randomized controlled trial (dexmedetomidine sepsis intensive care unit (icu) randomized evolution [desire]), demonstrated dexmedetomidine associated reduced mortality risk among severe sepsis. performed exploratory sub-analysis examine mechanism underlying improved survival sedated dexmedetomidine. methods: desire trial compared sedation strategy without dexmedetomidine among 201 mechanically ventilated adult sepsis across eight icu japan. present study, included 104 acute physiology chronic evaluation ii (apache ii) score â\x89¥ 23 (54 dexmedetomidine [dex] group 50 non-dexmedetomidine [non-dex] group). initially, compared change sequential organ failure assessment (sofa) score baseline within 6 day randomization groups. subsequently, evaluated variable comprising organ component sofa score showed relevant improvement initial comparison. results: mean age 71.0 â± 14.1 years. difference median apache ii score two group (29 [interquartile range (iqr), 25â\x80\x9331] vs. 30 [iqr, 25â\x80\x9333]; p = 0.35). median sofa score baseline lower dex group (9 [iqr, 7â\x80\x9311] vs. 11 [iqr, 9â\x80\x9313]; p = 0.01). renal sofa subscore baseline similar groups, significantly decreased dex group 4 (p = 0.02). first 6 days, urinary output significantly different (p = 0.09), serum creatinine level significantly lower (p = 0.04) dex group. 28-day in-hospital mortality rate significantly lower dex group (22% vs. 42%; p = 0.03, 28% vs. 52%; p = 0.01, respectively). conclusion: sedation strategy dexmedetomidine associated improved renal function decrease mortality rate among severe sepsis. trial registration: trial registered clinicaltrials.gov (nct01760967) january 1, 2013.',
#  'background: global end-diastolic volume (gedv) measured transpulmonary thermodilution regarded indicator cardiac preload. bolus cold saline injected central vein travel heart lung, aorta detection femoral artery. well accepted injection inferior vena cava result higher values, impact aortic volume gedv unknown. study, hypothesized larger aortic volume directly translates numerically higher gedv measurement. methods: retrospectively analyzed 88 critically ill thermodilution monitoring require contrast-enhanced thoraco-abdominal computed tomography scan. aortic volume derived imaging compared gedv measurement temporal proximity. results: median aortic volume 194 ml (interquartile range 147 249 ml). per milliliter increase aortic volume, found gedv increase 3.0 ml (95% ci 2.0 4.1 ml, p < 0.001). femoral central venous line used saline bolus injection, gedv raised additionally 2.1 ml (95% ci 0.5 3.7 ml, p = 0.01) per ml volume vena cava inferior. aortic volume explained 59.3% variance thermodilution-derived gedv. aortic volume included multivariate regression, gedv variance unaffected sex, age, body height, weight. conclusions: result suggest aortic volume substantial confounding variable gedv measurement performed transpulmonary thermodilution. aorta anatomically located heart, gedv considered reflect cardiac preload. guiding volume management raw indexed reference range gedv may misleading.',
# ...
#  'introduction: risk light siren use emergency medical service well documented. critical care transport team performs 1,800 interfacility nonemergency medical service transport annually dense urban environment. historically, utilized light siren navigate traffic patterns. use exceeded industry standards. quality improvement project undertaken decrease use light sirens. methods/results: baseline use light siren 2011 76% en route 73% return facility. revised internal policy guiding appropriate usage light sirens. 2012, without improvement usage, use justification process implemented. 2013, use light siren still high en route, decreased 53% return trip. 2014, added accountability measure requiring justification, subsequent drop 2015 14% en route 13% return. following 3 years, transport team sustained light siren use 20% below. conclusions: quality improvement initiative impacted team behavior decreased use light siren 5 years, sustained improvement 20%. improvement accomplished ongoing evaluation, education, gathering, open communication. negative impact outcome time. light siren continue used indicated.',
#  'introduction: direct hospital admission child without evaluation emergency department (ed) common, guideline exist maximize safety assessing stability. report describes novel approach support safety. methods: interdisciplinary childrenâ\x80\x99s hospital team developed brief ed-based evaluation process called ed rapid assessment intended inpatient disposition (ed rapid). entail brief evaluation vital sign clinical stability ed attending physician nurse. child deemed stable admitted inpatient wards, whereas requiring immediate intervention undergo full ed evaluation disposition. assessed outcome child evaluated process march 2013 february 2015. results: period, identified 715 undergoing ed rapid evaluation. these, directly admitted 691 (96.4%) hospital ward ed rapid evaluation; median ed time 4.0 minutes. transitioned 24 (3.4%) full ed evaluation, 14 (2.0%) ward bed unavailable, 10 (1.4%) clinical reason identified evaluation. admitted four 10 stopped (40% stops, 0.6% total) intensive care unit, 6 (60% stops, 0.8% total) hospital ward ed care. eight child (1.1%) admitted hospital ward ed rapid evaluation required transfer intensive care unit within 12 hours. conclusion: ed rapid evaluation process child directly admitted hospital feasible effective setting.',
#  'introduction: pediatric early warning score (pews) identify hospitalized child risk deterioration. manual calculation prone human error. electronic record (ehrs) enable automated calculation, removing human error. studyâ\x80\x99s objective compare accuracy automated ehr-based pew calculation (autopews) manual calculation evaluate non-inferiority autopews predicting deterioration. methods: performed retrospective cohort inclusive non-intensive care unit inpatient freestanding childrenâ\x80\x99s hospital 4.5 month fall 2018. autopews mapped historical manual pew scoring rubric frequently used ehr documentation. determined accuracy comparing expected respiratory subset score based current respiratory rate actual respiratory score autopews manual pews. agreement determined kappa statistics. used predicted probability generalized linear mixed model calculate area curve combination score (autopews, manual) deterioration outcome (rapid response team activation, unplanned intensive care unit transfer, critical deterioration event). compared adjusted difference area curve scores. non-inferiority defined difference <0.05. results: 23,514 total pew representative 5,384 patients. autopews respiratory score 99.97% accurate, manual pew respiratory score 86% accurate. autopews higher overall manual pew (mean 0.65 versus 0.34). showed fair-to-good agreement (weighted kappa 0.42). non-inferiority autopews compared manual pew demonstrated deterioration outcomes. conclusions: automation pew calculation improved accuracy without sacrificing predictive ability.',
#  'objective: herpes simplex (hsv) encephalitis overall mortality rate 11%â\x80\x9329% treatment. although rare, hsv encephalitis frequently tested empirically treated, especially neonatal population. hsv diagnosed polymerase chain reaction (pcr) testing, although frequently requires sending sample reference laboratories. inherent delay result may lead prolonging empiric hospital stay, resulting increased costs. investigates whether onsite hsv pcr testing decrease hospitalization duration, acyclovir duration, financial cost institution. project design: single-center project utilized ihi model improvement evaluate third-party hsv pcr processing versus implemented onsite pcr-based meningitisâ\x80\x93encephalitis panel hsv central nervous system evaluation. primary outcome hospital cost differential secondary outcomes, duration acyclovir administration time result. results: identified 96 child age 0â\x80\x9318 2010 2016, 74 utilizing offsite third-party testing, 22 utilizing onsite. observed per-patient cost saving $428 ($618.43â\x80\x93$190.43, p = 0.029) upon implementation onsite testing. mean duration acyclovir therapy decreased 3.7 0.26 day per (p < 0.001). time decreased 4.6 0.13 day (p < 0.001). conclusions: acquisition real-time local hsv pcr capability significantly decreased time empiric medication use significantly reducing hospital cost military facility.',
#  'introduction: bubble continuous positive airway pressure (bcpap) associated decreased risk chronic lung (cld) preterm neonates. report examined effectiveness adopting bcpap reduce respiratory complication medication usage community hospital nicu. methods: efficacy bcpap assessed retrospective examination comparison 45 neonate received bcpap 87 neonate received conventional ventilation only. medication usage collected analyzed. results: introduction bcpap protocol, median number day oxygen decreased bcpap group compared conventional ventilation group (median = 33 days, iqr = 7.5â\x80\x9366 v median = 0, iqr = 0â\x80\x930; p < 0.001). exposure conventional ventilation decreased bcpap group compared conventional ventilation group (median = 18 days, iqr = 5â\x80\x9342.5 v median = 0, iqr = 0â\x80\x937; p < 0.001). postimplementation bcpap revealed decrease cld 26 (30%) conventional ventilation group 2 (4%) bcpap group (p = 0.002); significant decrease use sedative medication bcpap group compared conventional ventilation group (mean = 5.20 doses, sd = 31.97 v mean = 1.43, sd = 9.98; p < 0.001). conclusion: use bcpap result significant decrease use conventional ventilation, risk cld, need sedative medication.',
#  'introduction: pediatric hospital readmission represent gap care quality discharge follow-up, social factor typically addressed hospitals. aimed reduce 30-day pediatric readmission rate 2 general pediatric service intervention enhance care spanning hospital stay, discharge, follow-up process. methods: multidisciplinary team developed intervention bundle based need assessment evidence-based model transitional care. intervention included pre-discharge planning transition coordinator, screening intervention adverse social determinant (sdh), medication reconciliation discharge, communication primary care provider, access hospital-based transition clinic, access 24-hour direct telephone line staffed hospital attending pediatricians. implemented sequentially october 2013 february 2017. primary outcome readmission rate within 30 day index discharge. length stay balancing measure. results: intervention, included service discharged 4,853 children. pre-implementation readmission rate 10.3% declined 7.4% remained stable 4-month post-intervention observation period. among 1,394 family screened adverse sdh, 48% reported received assistance â\x89¥ 1 concern. length stay increased 4.10 day 2013 4.30 day 2017. conclusions: intervention bundle, sdh, associated sustained reduction readmission rate 2 general pediatric services. transitional care address multiple domain family need childâ\x80\x99s crisis help reduce pediatric readmissions.',
#  'introduction: dissemination quality improvement (qi) intervention broader range healthcare setting requires proactive assessment local work system processes. objective examine feasibility survey-based work system assessment (wsa) tool facilitate dissemination program optimizing blood culture (bc) use. methods: informed finding onsite, interview-based wsa 2 hospitals, 50-item wsa survey devised administrated 15 hospital participating qi collaborative. wsa survey summarized, shared, discussed individual hospital inform adaptation implementation bc program. physician champion leading local qi team assessed use wsa survey completing 8-item survey. results: total 347 clinician completed wsa survey, physician champion 12 hospital evaluated use wsa survey. wsa survey evaluation wsa survey showed survey-based wsa tool could help participating hospital understand current bc ordering practice identify potential barrier implementing program perspective different clinicians. conclusions: demonstrated survey-based tool could used facilitate wsa dissemination program improving bc use multisite collaborative. survey-based wsa tool used facilitate future large-scale intervention dissemination efforts.',
#  'introduction: healthcare cost rising, clinical pathway (cpw) mean promote high-value care standardizing care improving outcome without compromising cost quality. however, provider always follow cpw, understanding perception limited. objective examine pediatric hospital medicine (phm) pediatric emergency medicine (pem) physician perspective cpw. methods: conducted semistructured, in-depth, one-on-one qualitative interview phm pem physician february 2017 august 2017. interview audio-recorded, professionally transcribed, accuracy verified. inductive analytic strategy, systematically coded identify themes. results: interviewed 15 phm 15 pem physicians. provider identified many benefit limitation cpw, positively negatively impact resource utilization, communication, education personnel, patients, families, well practice behavior attitudes. perceived benefit included (1) reduction unnecessary utilization, (2) standardization care, (3) improved communication, (4) education oneself others, (5) confidence validation action align cpw. limitation cpw (1) resource utilization revisions, updates, dissemination; (2) â\x80\x9ctunnel visionâ\x80\x9d cognitive biases; (3) loss autonomy; (4) prescriptive medicine; (5) information overload; (6) pressure adhere; (7) guilt action align cpw. conclusions: cpw tool advantage disadvantage used viewed differently providers. insight physician perceive cpw may help optimize hospital improvement work enhance high-value care.',
#  'introduction: handoff transition care common weak point healthcare provider communication move sites. consistent pattern communication st. jude childrenâ\x80\x99s research hospital (st. jude) affiliated clinics, affiliate program office st. jude developed implemented standardized communication tool facilitate transition different healthcare sites. methods: team provider created flow diagram define current state communication transitioning remote sites. fishbone diagram identified common barrier effective communication lack consistent communication ownership. developed communication tool address barriers, disseminated secure email. measured percent usage completed hand-off tool transitioned, staff experience, number errors. results: time send receive communication bundle <10 minutes. within 3 month implementing smart bundle 3 pilot sites, bundle used completely 6 8 transition associated somewhat improved staff satisfaction. identified adverse event related communication bundle. conclusions: small pilot study, accomplished closed-loop communication geographically remote healthcare site electronically transmitted standardized communication bundle.',
#  'introduction: pediatric in-hospital cardiac arrest emergent transfer pediatric intensive care unit (icu) represent serious safety concern associated increased morbidity mortality. institution turned electronic record predictive analytics search earlier accurate detection risk decompensation. methods: objective electronic record 2011 2017 utilized develop automated early warning system score aimed identifying hospitalized child risk clinical deterioration. five vital sign measurement supplemental oxygen requirement used build vitals risk index (vri) model, multivariate logistic regression. compared vri hospitalâ\x80\x99s existing early warning system, adaptation monaghanâ\x80\x99s pediatric early warning score system (pews). population included hospitalized child 18 year age younger cared outside icu. dataset included 158 hospitalization (102 emergent transfer icu 56 â\x80\x9ccode blueâ\x80\x9d events) 135,597 control hospitalizations. results: identifying deteriorating 2 hour event, significant difference pediatric early warning score vriâ\x80\x99s area receiver operating characteristic curve false-positive rate â\x89¤ 10% (pauc(10) 0.065 0.064, respectively; p = 0.74), threshold chosen compare 2 approach clinically tolerable false-positive rates. conclusions: vri represents objective, simple, automated predictive analytics tool identifying hospitalized pediatric risk deteriorating outside icu setting.',
#  'introduction: accurate timely documentation pediatric early warning score (pews) bedside nurse electronic record (ehr) important promote early identification stage deterioration. implementation pew calculator embedded ehr, hope improve accuracy recorded score reduce time vital sign collection final documentation ehr. methods: identification highest pew value 24 hour unplanned transfer rapid response activation without transfer occurred period november 1, 2013, december 31, 2016. accuracy calculated cardiac respiratory subscore based heart rate respiratory rate time pew calculation determined. tracked calculation time chart via difference nursing documentation pew compared vital sign collection. september 3, 2015, pew calculated mentally bedside nurse; afterward, nurse entered unique pew feature ehr, ehr automatically calculated pews. results: evaluated 2,409 pew scores, 1,411 998 initiation pew calculator. accuracy ehr calculator 71%, median time document 55 minutes. following implementation calculator, score incorrectly calculated low, median time document 20 minutes. conclusions: transition ehr-based pew calculator eliminated inaccurately low pew value reduced time document.',
#  ...]

# %%
#working
def get_genes_entries(en):#funtion to create a of names from caption
    
    
    spans = []
    
    
    doc=nlp(en)
    for token in doc:
        #print(token.ent_type_)
        if token.ent_type_ =='GENE': 
            i=token.i
            span = doc[i-8:i+8]
            spans.append(span)
         
    return spans
    


def get_all_genesesntries(lst_lst):
    list_genes=[]
    for lst in lst_lst:
        a=get_genes_entries(lst)
        list_genes.append(a)  
    return list_genes

# %%
text1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-aecf5455a8ad> in <module>
# ----> 1 text1
#
# NameError: name 'text1' is not defined

# %%
gene_listsof_ls=get_all_genes(text1)
gene_listsof_ls

# %%
def get_genes(en):#funtion to create a of names from caption
    
    
    genes = []
    
    
    doc=nlp(en)
    for token in doc:
        #print(token.ent_type_)
        if token.ent_type_ =='GENE': 
            
            genes.append(token) 
         
    return genes
    


def get_all_genes(lst_lst):
    list_genes=[]
    for lst in lst_lst:
        a=get_genes(lst)
        list_genes.append(a)  
    return list_genes

# %%
entrie=("Epigenetic Silencing of the mutL homolog 1 (MLH1) Promoter in Relation to the Development of Gastric Cancer (GC) and its use as a Biomarker for Patients with Microsatellite, CD8 and HIF-1α, HIF1 for the Covid19 gene N, TRPM7 mmp8 MMP1 MMP2  and GAID2a, HNF4α, hnf4 ACE2  ORF1b  a nrf2 , Nucleoprotein1 , Nrf2 and brca2 Instability.")
a=get_genes(entrie)
a

# %%
def gene_checker(lst_lst):
    gene_found=[]
    for lst in lst_lst:
        lstgene_found=[]
        for g in lst:
            a=(''+g.text+'')
            a=a.lower()
            #print(a)
            if a in gene_check_lower:
                lstgene_found.append(a)
        gene_found.append(lstgene_found)
    return gene_found

genes_found=gene_checker(gene_listsof_ls)
genes_found[:100]

# %%
len(genes_found)
dataset['genes_found']=genes_found


#dataset.head()

# %%
dataset.head(20)

# %%
genes_found=gene_checker(gene_listsof_ls)

# %%
len(genes_found)

# %%
def gene_unique(lst_lst):
    
    list_clean = list(filter(None, lst_lst))
    for lst in list_clean:
        list_unique= list(dict.fromkeys(lst))
        print(lst)
        #for gene in list_unique:
            #list_cmb.append(gene)

    return list_cmb

a=gene_unique(genes_found)
a

# %%
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker
import scispacy
#import en_core_sci_sm   #The model we are going to use
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.umls_linking import UmlsEntityLinker
import en_ner_bionlp13cg_md

# %%
#scispacy
from scispacy.umls_linking import UmlsEntityLinker

nlp = spacy.load('en_core_web_sm')
#linker = UmlsEntityLinker(resolve_abbreviations=True)

#nlp.add_pipe(linker)
#abbreviation_pipe = AbbreviationDetector(nlp)
#nlp.add_pipe(abbreviation_pipe)

# %%
def get_scispacy(en):#funtion to create a of names from caption
    
    
    genes = []
    
    
    doc=nlp(en)
    print(list(doc.ents))
    #for abrv in doc._.abbreviations:
     #   print(f"{abrv} \t ({abrv.start}, {abrv.end}) {abrv._.long_form}")
    #display_entities(en_ner_bionlp13cg_md,doc)
    #displacy.render(next(doc.sents), style='dep', jupyter=True)
    #for token in doc:
     #   #print(token.ent_type_)
      #  if token.ent_type_ =='GENE': 
            
       #     genes.append(token) 
         
    return genes
    


def get_all_scispacy(lst_lst):
    list_genes=[]
    for lst in lst_lst:
        a=get_genes(lst)
        list_genes.append(a)  
    return list_genes

# %%
get_scispacy(text1[9])

# %%
#linker = UmlsEntityLinker(resolve_abbreviations=True)
nlp = spacy.blank('en')          # create a spacy model
nlp.meta['name'] = 'gene'        # name the model 'gene'

ner = nlp.create_pipe('ner')     # create an NER stage
ner.add_label('GENE')            # add the label 'GENE' to the stage

nlp.add_pipe(ner)                # put the pipe together
optimizer = nlp.begin_training() # get an optimizer for training the model
genenlp=nlp.from_disk(r"C:\Users\mese4\Documents\The Data incubator\project\Spacy model\gene_id_model")

#nlp.add_pipe(genenlp)

# %%
nlp.add_pipe(genenlp)
