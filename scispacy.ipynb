# %%
# !conda activate scispacy #activates scispacy

# %%
import scispacy
import spacy
from spacy import displacy
from collections import Counter
import en_core_sci_md
import en_ner_bionlp13cg_md
from joblib import dump, load

# %%
import os
import numpy as np
import pandas as pd

os.chdir(r"C:\Users\mese4\Documents\The Data incubator\project\cord-19_2020-07-01\2020-07-01")
df=pd.read_csv('df_sub.csv', encoding='ISO-8859-1')

# %%
drug_dic = load('drug_dic.joblib') 
gene_dic = load('gene_dic.joblib')

# %%
test_doc ='nrf2, cd18, anaplasma phagocytophilum agent tick-borne fever, equine, mmp1, hif1, canine human nrf2 granulocytic anaplasmosis. common route a. phagocytophilum transmission tick bite, high and up-regulation of Nrf2 main vector europe nrf2, cd18, hif1a, ixodes ricinus. despite apparently ubiquitous presence pathogen a. phagocytophilum tick various wild domestic animal europe, date published clinical case human granulocytic anaplasmosis (hga) remain rare compared MMP2 worldwide status. unclear reflects epidemiological dynamic human europe underdiagnosed underreported. epidemiologic study europe suggested increased occupational risk forestry workers, hunters, veterinarians, farmer tick-bite history living Hn4a endemic areas. although overall genetic diversity a. phagocytophilum europe higher usa, strain responsible human infection related continents. however, genetic variability assessment difference pathogenicity infectivity strain various host insufficiently explored date. european hga case presented mild infection, common clinical sign pyrexia, headache, myalgia arthralgia. diagnosis hga usa recommended based clinical sign patientÃ¢Â\x80Â\x99s history later confirmed specialized laboratory tests. however, europe since majority case presenting mild infection, laboratory test may performed order avoid antibiotic overuse. drug choice hga doxycycline potential serious complication instituted Hif1-a clinical suspicion alone.'

# %%
nlp = spacy.load("en_core_sci_md")

# %%
def get_entities(document): 
    
#This function gets scientific entites from a str document and the nlp model en_core_sci_md

   
    doc = nlp(document)
    ent_lst=[]
    for ent in doc.ents:
        #print(ent.text)
        ent_lst.append(ent)         
    return  ent_lst

# %%
get_entities(b1[0])
# Out:
# [medical worker,
#  hubei medical team,
#  hospital hubei province,
#  treating,
#  patients,
#  time,
#  characteristic,
#  military hospitals,
#  diagnosis,
#  pneumonia,
#  national commission people's,
#  republic china,
#  guideline diagnosis,
#  military,
#  diagnosis criteria,
#  antiviral treatment,
#  glucocorticoid,
#  interpretation,
#  guideline,
#  diagnosis diseases]

# %%
bionlp = spacy.load("en_ner_bionlp13cg_md")

# %%
def get_genes(document): 
    
#This function gets genes, drugs and organism from a str document and an nlp en_ner_bionlp13cg_md

   
    doc = bionlp(document)
    gene_lst = {}
    drug_lst = {}
    org_lst = {}
    
    for ent in doc.ents:
        if ent.label_ =='GENE_OR_GENE_PRODUCT':
            gene_lst[ent]=ent.text
        elif ent.label_ =='SIMPLE_CHEMICAL':
            drug_lst[ent]=ent.text
        elif ent.label_ =='CELL' or ent.label_ =='ORGANISM' or ent.label_ =='ORGANISM_SUBSTANCE':
            org_lst[ent]=ent.text
    return  gene_lst,drug_lst,org_lst 

#returns list of dicts: 
#[0] dictionary with gene_lst
#[1] dictionary with drug_lst
#[2] dictionary with organism/cell entities for searching propuses

# %%
#v.2 checker

def get_genes(document): 
    
#This function gets genes, drugs and organism from a str document and an nlp en_ner_bionlp13cg_md

   
    doc = bionlp(document)
    gene_lst = {}
    drug_lst = {}
    org_lst = {}
    
    for ent in doc.ents:
        if ent.label_ =='GENE_OR_GENE_PRODUCT':
            for k,v in gene_dic.items():
                if ent.text in v:
                    gene_lst[ent]= k 
         

        elif ent.label_ =='SIMPLE_CHEMICAL':
            for k,v in drug_dic.items():
                if ent.text in v:
                    drug_lst[ent]=k

        elif ent.label_ =='CELL' or ent.label_ =='ORGANISM' or ent.label_ =='ORGANISM_SUBSTANCE':
            org_lst[ent]=ent.text
    return  gene_lst,drug_lst,org_lst 

#returns list of dicts: 
#[0] dictionary with gene_lst
#[1] dictionary with drug_lst
#[2] dictionary with organism/cell entities for searching propuses

# %%
def get_entiteis_cmb (srt):
#Funciton to combine get_entities() and get_genes from a document into a list
    all_lst = []
    ent = get_entities(srt)
    bio = get_genes(srt)
    all_lst.append(ent)
    for i in range(len(bio)):
        all_lst.append(bio[i])
    return all_lst

# %%
def get_all_scispacy(lst_txt): 
#Do get_entiteis_cmb() to all the documents
    list_scispacy=[]
    for lst in lst_txt:
        a=get_entiteis_cmb(lst)
        list_scispacy.append(a)  
    return list_scispacy

# %%
get_entiteis_cmb(test_doc)
# Out:
# [[nrf2,
#   cd18,
#   anaplasma phagocytophilum agent,
#   tick-borne fever,
#   equine,
#   mmp1,
#   hif1,
#   canine,
#   human,
#   granulocytic anaplasmosis,
#   high,
#   up-regulation,
#   Nrf2,
#   nrf2,
#   cd18,
#   hif1a,
#   ixodes ricinus,
#   presence,
#   pathogen,
#   phagocytophilum tick,
#   wild domestic,
#   animal europe,
#   clinical case,
#   human,
#   granulocytic anaplasmosis,
#   hga,
#   MMP2,
#   status,
#   epidemiological dynamic,
#   epidemiologic study,
#   increased,
#   occupational risk,
#   workers,
#   hunters,
#   veterinarians,
#   farmer,
#   tick-bite history,
#   endemic,
#   genetic diversity,
#   phagocytophilum europe,
#   strain,
#   human,
#   infection,
#   continents,
#   genetic variability,
#   pathogenicity,
#   infectivity,
#   host,
#   european,
#   mild infection,
#   clinical sign pyrexia,
#   headache,
#   myalgia arthralgia,
#   diagnosis,
#   recommended,
#   clinical,
#   history,
#   laboratory tests,
#   europe,
#   mild infection,
#   laboratory test,
#   antibiotic overuse,
#   drug choice,
#   doxycycline,
#   potential,
#   complication,
#   Hif1-a,
#   clinical suspicion],
#  {nrf2: 'nfe2l2', cd18: 'itgb2', nrf2: 'nfe2l2', cd18: 'itgb2'},
#  {doxycycline: 'doxycycline'},
#  {tick-borne: 'tick-borne',
#   equine: 'equine',
#   canine human granulocytic: 'canine human granulocytic',
#   tick: 'tick',
#   ricinus: 'ricinus',
#   phagocytophilum tick: 'phagocytophilum tick',
#   human granulocytic: 'human granulocytic',
#   human: 'human',
#   human: 'human',
#   Hif1-a: 'Hif1-a'}]

# %%
test_doc1=test_doc

list_test=[test_doc,'Dimethyl fumarate induces and increase in nrf2 up-regulation. Dimethyl fumarate induces an increase in nrf2, Hnf4a up-regulation. ']
list_test
# Out:
# ['nrf2, cd18, anaplasma phagocytophilum agent tick-borne fever, equine, mmp1, hif1, canine human granulocytic anaplasmosis. common route a. phagocytophilum transmission tick bite, high and up-regulation of Nrf2 main vector europe nrf2, cd18, hif1a, ixodes ricinus. despite apparently ubiquitous presence pathogen a. phagocytophilum tick various wild domestic animal europe, date published clinical case human granulocytic anaplasmosis (hga) remain rare compared MMP2 worldwide status. unclear reflects epidemiological dynamic human europe underdiagnosed underreported. epidemiologic study europe suggested increased occupational risk forestry workers, hunters, veterinarians, farmer tick-bite history living Hn4a endemic areas. although overall genetic diversity a. phagocytophilum europe higher usa, strain responsible human infection related continents. however, genetic variability assessment difference pathogenicity infectivity strain various host insufficiently explored date. european hga case presented mild infection, common clinical sign pyrexia, headache, myalgia arthralgia. diagnosis hga usa recommended based clinical sign patientÃ¢Â\x80Â\x99s history later confirmed specialized laboratory tests. however, europe since majority case presenting mild infection, laboratory test may performed order avoid antibiotic overuse. drug choice hga doxycycline potential serious complication instituted Hif1-a clinical suspicion alone.',
#  'Dimethyl fumarate induces and increase in nrf2 up-regulation. Dimethyl fumarate induces an increase in nrf2, Hnf4a up-regulation. ']

# %%
#v.1.0 to get up and down genes


gene_up = ['up', 'increase', 'increased', 'up-regulation', 
           'upregulation', 'overexpression','activation','overexpressed','overexpressing',
           'induction', 'high', 'activated',
           'activated', 'activating', 'amplified','enriched', 'insensitive',
           'enhanced' ,'enhancing'   
]


gene_down = ['inhibited', 'inhibiting','repressing', 'suppressing', 'capping',
             'degrading', 'derepressing', 'down', 'decrease', 'decreasing','down-regulation',
             'downregulation', 'repression', 'repressed','repress','decrease', 'decreassing',              
            ]

def get_regulation(lst_lsts):
    
    #function that creates spans +/- 3  of entity type == genes and checks for terms used to describe
    #gene up/down-regulation. If found, new class (up/down) assigned.
    
    ent_lst = lst_lsts[0]
    gn_lst = list(lst_lsts[1].values())
    
    span_gn = []
    
    for i in range(len(ent_lst)):
        
        if ent_lst[i].text in gn_lst:
            
            span_gn.append(ent_lst[i-3:i+3])
            
    span_gn = list(map(str, span_gn))
    #print(span_gn)
    g_span = dict(list(zip(gn_lst,span_gn)))
    #print(g_span)
    #print(g_span)
    gn_up = []
    gn_dw = []
    gn_n = []
    
    
    for k,v in g_span.items():
        
        if any(elem in v for elem in gene_up):
            gn_up.append(k)
            #print(k)
        elif any(elem in v for elem in gene_down):
            gn_dw.append(k)
        else:
            gn_n.append(k)

    
    #returns list of lists with genes_up at [0], genes_down at [1] and genes_non_mentioned at [2]  
    return gn_up,gn_dw,gn_n

def get_all_regulation(lst_lts): #get_spans for all texts
    list_spans=[]
    for lst in lst_lts:
        a=get_regulation(lst)
        list_spans.append(a)  
    return list_spans

# %%
a=get_all_scispacy(list_test)
b=get_all_regulation(a)
b
# Out:
# [([], [], []), ([], [], [])]

# %%
# Out:
# {nrf2: 'nrf2',
#  cd18: 'cd18',
#  phagocytophilum: 'phagocytophilum',
#  patientÃ¢ÂÂs: 'patientÃ¢Â\x80Â\x99s'}

# %%
def df_data(df,strg_clm,id_clm):
    text = df[strg_clm].astype(str).values.tolist()
    id_colum = df[id_clm]
    scispacy = get_all_scispacy(text)
    spans = get_all_regulation(scispacy)
    gn_lst = []
    dg_lst = []
    ent_lst = []
    
    for lst_lsts in scispacy:
        #print(lst_lsts[0])
        gn_lst.append(list(lst_lsts[1].values()))
        dg_lst.append(list(lst_lsts[2].values()))
        ent_text = []
        for ent in lst_lsts[0]:      
            ent_text.append(ent.text)
        ent_lst.append(ent_text)

    gene_up = []
    gene_down = []
    gene_non_reg = []
    
    for lst_lsts in spans:
        #print(lst_lsts[0])
        gene_up.append(lst_lsts[0])
        gene_down.append(lst_lsts[1])
        gene_non_reg.append(lst_lsts[2])
    
        
        
    df_sci = pd.DataFrame(list(zip(id_colum,text,gn_lst,dg_lst,ent_lst,gene_up,gene_down,gene_non_reg)), 
               columns =['cordID', 'Corpus','Genes','Drugs/Chemicals','Biomedical_Entities','Genes_upregulated','Genes_downregulated','Genes_non_regulated']) 
    return df_sci

# %%
a=df_data(df,'corpus','cord_uid')
a
# Out:
#       cordID                                             Corpus Genes  \
# 0   hrmx9eav  causing covid-19 pandemic, sars-cov-2, us Ã¢Â...    []
# 1   3jmy9dy3  abstract starting wuhan, china, sars-cov-2 cat...    []
# 2   6jfvs677  since december 2019, cluster diagnosed infecte...    []
# 3   djxw2n23  covid-19 severely impacted dentists, great ris...    []
# 4   eqo1lrjv  abstract novel (covid-19) spreading rapidly, p...    []
# ..       ...                                                ...   ...
# 95  f3w2gu8c  summary world currently facing unprecedented h...    []
# 96  v88f9e7m  background & objective :coronavirus 2019 (covi...    []
# 97  ib87gmr8  objective outbreak novel raised many problem a...    []
# 98  uzgp7u1n  introduction: endpoint choice randomized contr...    []
# 99  r4qnxp1z  sharpness knife used slaughter utmost importan...    []
#
#                               Drugs/Chemicals  \
# 0                                          []
# 1                                          []
# 2                                          []
# 3                                          []
# 4           [hydroxychloroquine, favipiravir]
# ..                                        ...
# 95                                         []
# 96                                         []
# 97                                         []
# 98                                         []
# 99  [epinephrine, dextrose, unspecified form]
#
#                                   Biomedical_Entities Genes_upregulated  \
# 0   [covid-19, pandemic, sars-cov-2, programmed ri...                []
# 1   [abstract, china, catastrophic epidemic, count...                []
# 2   [cluster diagnosed, infected, novel, china epi...                []
# 3   [covid-19, severely, impacted, dentists, risk ...                []
# 4   [abstract, novel, covid-19, pandemic, affected...                []
# ..                                                ...               ...
# 95  [summary world, healthcare crisis, pandemic, b...                []
# 96  [objective, coronavirus 2019, covid-19, contai...                []
# 97  [objective, outbreak, problem, auxiliary infor...                []
# 98  [introduction, endpoint, randomized controlled...                []
# 99  [sharpness knife, slaughter, animal, welfare, ...                []
#
#    Genes_downregulated Genes_non_regulated
# 0                   []                  []
# 1                   []                  []
# 2                   []                  []
# 3                   []                  []
# 4                   []                  []
# ..                 ...                 ...
# 95                  []                  []
# 96                  []                  []
# 97                  []                  []
# 98                  []                  []
# 99                  []                  []
#
# [100 rows x 8 columns]

# %%
type(a['Biomedical_Entities'][0][1])
# Out:
# spacy.tokens.span.Span

# %%
a['Biomedical_Entities']

selection = ['summary']

#a[pd.DataFrame(a.Biomedical_Entities.tolist()).isin(selection).any(1)]

a[a.Biomedical_Entities.str.contains('summary',case=False)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-305-7be1a0bf22df> in <module>
#       5 #a[pd.DataFrame(a.Biomedical_Entities.tolist()).isin(selection).any(1)]
#       6
# ----> 7 a[a.Biomedical_Entities.str.contains('summary',case=False)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,\n              nan, nan, nan, nan, nan, nan, nan, nan, nan],\n             dtype='float64')] are in the [columns]"

# %%
#use this to filter resutls
a=df
selection = ['covid-19']
df[pd.DataFrame(df.Biomedical_Entities.tolist()).isin(selection).any(1)]
# Out:
#       cordID                                             Corpus  \
# 0   hrmx9eav  causing covid-19 pandemic, sars-cov-2, us Ã¢Â...
# 3   djxw2n23  covid-19 severely impacted dentists, great ris...
# 4   eqo1lrjv  abstract novel (covid-19) spreading rapidly, p...
# 6   140icux7  background: insufficient evidence support clin...
# 8   6xgiep8q  abstract background: existing recommendation w...
# 9   5atqn157  mainstay personal protective equipment (ppe) c...
# 11  f46me8l1  background: ongoing pandemic novel 2019 (covid...
# 12  68ykes60  background: recommendation lifestyle quarantin...
# 14  nav88l73  background type novel (covid-19) occurred wuha...
# 15  u4bmrwcx  background covid-19 pneumonia associated signi...
# 16  1zyeusat  since december 2019, corona 2019 (covid-19) , ...
# 17  2j3u7gb0  personnel community worker front line covid-19...
# 18  nxldhuf1  nowadays, epidemic covid-19 china control. how...
# 24  7gek6oc7  currently, 2019 (covid-19) clustering onset ch...
# 26  q2qivnf8  covid-19 pandemic driven rapid, widespread ado...
# 29  f17f50ob  hypothesized rheumatic disease (rd) would incr...
# 33  6l4hzcf3  abstract overall time important factor local r...
# 40  msethhsr  sars-coronavirus-2 (sars-cov-2) cause 2019 (co...
# 41  o7qibwzj  common symptom pandemic (covid-19) include fev...
# 42  q8wxxyjh  aim sleep mental chronic insomnia china 2019 (...
# 45  lejn9z0y  different agent-based model developed estimate...
# 48  3sencqst  objective work predict spread covid-19 startin...
# 49  qy95c0j0  objective: many country implemented quarantine...
# 50  lmmrnitr  march 29, 2020 flattening strategy covid-19 u....
# 51  r8lymmec  early month covid-19 epidemic, wondered force ...
# 54  rwj3h4gm  background: stay home order colorado stay safe...
# 55  d4wzmrz4  background approximately 5% 2019 (covid-19) de...
# 56  kd2nqnh9  coronaviruses, sars-cov-2 etiological agent co...
# 58  piaevrdm  abstract covid-19 pandemic confirmed started s...
# 61  op74lfkg  31 december 2019, severe acute respiratory syn...
# 62  x0yiv35v  background: nonpharmaceutical intervention str...
# 64  y4003zzd  2019 (covid-19) has, span weeks, immobilized e...
# 66  l8393uca  global covid-19 pandemic potential severely af...
# 68  vv0zc0gd  covid-19 pandemic, caused sars-cov-2, surpasse...
# 69  ye4rdv0z  recent pandemic caused severe acute respirator...
# 70  mvged6u9  disease-2019 (covid-19) infectious caused seve...
# 72  z73jeoia  background rapid spread covid-19 china country...
# 75  shfuj6ma  pandemic severe acute respiratory syndrome 2 (...
# 77  14ji8cq1  sars-cov-2 pandemic cause covid-19 respiratory...
# 78  hk8nbpix  significant amount clinical research interest ...
# 82  5hcprnzv  Ã£Â¢Ã¢ÂÃ¢Â¢quarantine lead stress condition c...
# 83  0end8c9f  resumen el desenlace de la infecciÃ£Â³n por sa...
# 84  di41fift  article, present young female diagnosed lupus ...
# 85  p1iktm9v  (covid-19) infectious discovered 2019 currentl...
# 86  jtulg3sm  global crisis created covid-19 providing valua...
# 88  45d9tj2l  2019 (covid-19) pandemic continues, increasing...
# 93  6d8nuf3y  background purpose: information stroke survivo...
# 96  v88f9e7m  background & objective :coronavirus 2019 (covi...
# 98  uzgp7u1n  introduction: endpoint choice randomized contr...
#
#                                                 Genes  \
# 0                     [Â¼s-long, stem 3, rarely-seen]
# 3                                             [phq-4]
# 4                                                  []
# 6                     [logistic/cox, 19(18, ferritin]
# 8   [preprint article march 2020, sars-cov-2 nucle...
# 9           [n95, n95, germicidal ultraviolet-c, n95]
# 11                                              [cfr]
# 12                                                 []
# 14                          [shenzhen, il-6, 66(22.1]
# 15                         [beta1, sars-cov mers-cov]
# 16                                      [corona 2019]
# 17                                              [rds]
# 18                                                 []
# 24                                              [cts]
# 26                                              [c's]
# 29                                           [rd, rd]
# 33                                                 []
# 40                                [sars-cov mers-cov]
# 41                                                 []
# 42                                    [gad-7, phq-15]
# 45                                                 []
# 48                                                 []
# 49                                                 []
# 50                                                 []
# 51                                                 []
# 54                                          [insulin]
# 55                                       [il-6, il-6]
# 56                                    [sars-like cov]
# 58                                                 []
# 61                                                 []
# 62                                                 []
# 64                                                 []
# 66                                                 []
# 68                                             [low-]
# 69         [md, n7-mtase sars-cov, md, pca, n7-mtase]
# 70  [cardiovascular risk factor, renin-angiotensin...
# 72                                              [gam]
# 75                                                 []
# 77                                                 []
# 78                                                 []
# 82                                                 []
# 83               [nlrp3, nlrp3, il-1 beta, il 1 beta]
# 84                                                 []
# 85  [angiotensin-converting enzyme 2, ace2, cgp-60...
# 86                                                 []
# 88                                     [stay-at-home]
# 93  [cardiac troponin i, pro-brain natriuretic pep...
# 96                              [port-of-entry-based]
# 98                                                 []
#
#                                       Drugs/Chemicals  \
# 0                                                  []
# 3                                                  []
# 4   [hydroxychloroquine, lopinavir/ritonavir, remd...
# 6                                                  []
# 8                                                  []
# 9              [point-of-use, germicidal, germicidal]
# 11                                                 []
# 12                                                 []
# 14                                                 []
# 15          [ifn beta1b, p=0.229, hydroxychloroquine]
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 24                                                 []
# 26                                                 []
# 29                        [staff, hydroxychloroquine]
# 33                                                 []
# 40                                   [discus, discus]
# 41                                           [oxygen]
# 42                                                 []
# 45                                                 []
# 48                                                 []
# 49                                                 []
# 50                                                 []
# 51                                                 []
# 54             [glucose, glucose, fluid carbohydrate]
# 55  [anti-cytokine, tocilizumab, soc, glucocortico...
# 56                                                 []
# 58                                     [worldÃ¢ÂÂs]
# 61                                                 []
# 62                                                 []
# 64                                                 []
# 66                                                 []
# 68                                                 []
# 69                                                 []
# 70                                      [angiotensin]
# 72                                                 []
# 75                                                 []
# 77                                                 []
# 78                                           [discus]
# 82                           [Ã£Â¢Ã¢ÂÃ¢Â¢quarantine]
# 83                                                 []
# 84  [intravenous steroids, methylprednisolone, oxy...
# 85                                     [tetracycline]
# 86                                                 []
# 88                                                 []
# 93                                                 []
# 96                                                 []
# 98                                                 []
#
#                                   Biomedical_Entities  \
# 0   [covid-19, pandemic, sars-cov-2, programmed ri...
# 3   [covid-19, severely, impacted, dentists, risk ...
# 4   [abstract, novel, covid-19, pandemic, affected...
# 6   [background, insufficient, evidence, clinical,...
# 8   [abstract, background, recommendation, mother,...
# 9   [mainstay, personal protective equipment, covi...
# 11  [background, pandemic, covid-19, global public...
# 12  [background, recommendation, researcher, insti...
# 14  [background type novel, covid-19, hubei provin...
# 15  [background, covid-19 pneumonia, associated si...
# 16  [corona 2019, covid-19, spread mainland, china...
# 17  [personnel, community, covid-19, emergency res...
# 18  [epidemic, covid-19 china control, epidemic, w...
# 24  [covid-19, china, chinese healthcare system, e...
# 26  [covid-19, pandemic, telemedicine, distributio...
# 29  [hypothesized, rheumatic disease, rd, increase...
# 33  [abstract, factor local, distant evolution, pr...
# 40  [sars-coronavirus-2, sars-cov-2, covid-19, inf...
# 41  [symptom pandemic, covid-19, fever cough, man,...
# 42  [aim, sleep mental, chronic insomnia china 201...
# 45  [agent-based model, estimate, spread progressi...
# 48  [objective, spread, covid-19, data, forecast, ...
# 49  [objective, country, quarantine, outbreak, cov...
# 50  [flattening strategy, covid-19, removal, socia...
# 51  [early month, covid-19 epidemic, force, global...
# 54  [background, stay home, colorado stay, califor...
# 55  [covid-19, life-threatening, pneumonia, increa...
# 56  [coronaviruses, etiological agent, covid-19 di...
# 58  [abstract, covid-19, pandemic, bangladesh, inf...
# 61  [severe, acute respiratory syndrome 2, sars-co...
# 62  [background, nonpharmaceutical intervention, m...
# 64  [covid-19, weeks, immobilized, country, instit...
# 66  [global, covid-19, pandemic, potential, rheuma...
# 68  [covid-19, pandemic, sars-cov-2, model, middle...
# 69  [pandemic, severe, acute respiratory syndrome ...
# 70  [disease-2019, covid-19, infectious, severe, a...
# 72  [spread, covid-19 china country, outbreak, epi...
# 75  [pandemic, severe, acute respiratory syndrome ...
# 77  [pandemic, covid-19 respiratory syndrome, glob...
# 78  [amount, clinical research, thrombosis, vessel...
# 82  [Ã£Â¢Ã¢ÂÃ¢Â¢quarantine, dietary habits, dieta...
# 83  [desenlace, infecciÃ£Â³n por sars-cov-2, covid...
# 84  [article, young, female, diagnosed, lupus pneu...
# 85  [covid-19, infectious discovered, outbreak, wo...
# 86  [global crisis, covid-19, strength research sy...
# 88  [covid-19, pandemic, number country territory,...
# 93  [purpose, information, stroke, infected, covid...
# 96  [objective, coronavirus 2019, covid-19, contai...
# 98  [introduction, endpoint, randomized controlled...
#
#                Genes_upregulated Genes_downregulated  \
# 0                             []                  []
# 3                             []                  []
# 4                             []                  []
# 6                             []                  []
# 8                             []                  []
# 9                          [n95]                  []
# 11                            []                  []
# 12                            []                  []
# 14                            []                  []
# 15                            []                  []
# 16                            []                  []
# 17                            []                  []
# 18                            []                  []
# 24                            []                  []
# 26                            []                  []
# 29                          [rd]                  []
# 33                            []                  []
# 40                            []                  []
# 41                            []                  []
# 42                            []                  []
# 45                            []                  []
# 48                            []                  []
# 49                            []                  []
# 50                            []                  []
# 51                            []                  []
# 54                            []                  []
# 55                            []                  []
# 56                            []                  []
# 58                            []                  []
# 61                            []                  []
# 62                            []                  []
# 64                            []                  []
# 66                            []                  []
# 68                            []                  []
# 69                            []                  []
# 70  [cardiovascular risk factor]                  []
# 72                            []                  []
# 75                            []                  []
# 77                            []                  []
# 78                            []                  []
# 82                            []                  []
# 83                            []                  []
# 84                            []                  []
# 85                            []                  []
# 86                            []                  []
# 88                            []                  []
# 93                            []                  []
# 96                            []                  []
# 98                            []                  []
#
#                                   Genes_non_regulated
# 0                                          [Â¼s-long]
# 3                                             [phq-4]
# 4                                                  []
# 6                                                  []
# 8                                                  []
# 9                                                  []
# 11                                              [cfr]
# 12                                                 []
# 14                                                 []
# 15                                                 []
# 16                                      [corona 2019]
# 17                                              [rds]
# 18                                                 []
# 24                                                 []
# 26                                                 []
# 29                                                 []
# 33                                                 []
# 40                                                 []
# 41                                                 []
# 42                                    [gad-7, phq-15]
# 45                                                 []
# 48                                                 []
# 49                                                 []
# 50                                                 []
# 51                                                 []
# 54                                                 []
# 55                                                 []
# 56                                                 []
# 58                                                 []
# 61                                                 []
# 62                                                 []
# 64                                                 []
# 66                                                 []
# 68                                                 []
# 69                                               [md]
# 70                                                 []
# 72                                                 []
# 75                                                 []
# 77                                                 []
# 78                                                 []
# 82                                                 []
# 83                                            [nlrp3]
# 84                                                 []
# 85  [angiotensin-converting enzyme 2, ace2, cgp-60...
# 86                                                 []
# 88                                     [stay-at-home]
# 93  [cardiac troponin i, pro-brain natriuretic pep...
# 96                                                 []
# 98                                                 []
